# %% [markdown]
# # Imports and Configs

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import matthews_corrcoef, make_scorer
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
from sklearn.base import clone
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import optuna
import glob
import scipy
import gc

warnings.filterwarnings('ignore')

# %%
SEED = 6
N_FOLDS = 5
TARGET = 'class'
THRESHOLD = 0.5

# %% [markdown]
# # Loading Data

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e8/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e8/test.csv', index_col='id')

X = train.drop(columns=[TARGET])
y = train[TARGET].map({'e': 0, 'p': 1})

# %%
def get_data(folder_name):
    base_dir = '/kaggle/input/mushroom-classification-oof-files'
    oof_pred_probs_files = glob.glob(f'{base_dir}/{folder_name}/*_oof_pred_probs_*.pkl')
    test_pred_probs_files = glob.glob(f'{base_dir}/{folder_name}/*_test_pred_probs_*.pkl')

    oof_pred_probs = pickle.load(open(oof_pred_probs_files[0], 'rb'))
    test_pred_probs = pickle.load(open(test_pred_probs_files[0], 'rb'))
    
    scores = []
    skf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)
    for _, val_idx in skf.split(X, y):
        y_val = y[val_idx]
        y_pred_probs = oof_pred_probs[val_idx]          
        score = matthews_corrcoef(y_val, np.argmax(y_pred_probs, axis=1))
        scores.append(score)
        
    if isinstance(test_pred_probs, pd.DataFrame):
        return oof_pred_probs[:, 1], test_pred_probs.values[:, 1], scores
    return oof_pred_probs[:, 1], test_pred_probs[:, 1], scores

# %% [markdown]
# # Loading OOF Predictions

# %%
test_pred_probs = {}
oof_pred_probs = {}
scores = {}

model_folder_mappings = {
    'AutoGluon':        'autogluon',
    'XGBoost(dart)':    'xgboost-dart',
    'XGBoost(rf)':      'xgboost-rf',
    'XGBoost':          'xgboost',
    'LightGBM(dart)':   'lightgbm-dart',
    'LightGBM':         'lightgbm',
    'HistGB':           'histgb',
    'CatBoost':         'catboost',
    'KerasANN':         'keras-ann',
    
    'AutoGluon(1)':     'experiments/autogluon1',
    'AutoGluon(2)':     'experiments/autogluon2',
    'AutoGluon(3)':     'experiments/autogluon3',
    # 'HistGB(1)':        'experiments/histgb1',
    # 'HistGB(2)':        'experiments/histgb2',
    'HistGB(3)':        'experiments/histgb3',
    'HistGB(4)':        'experiments/histgb4',
    'HistGB(5)':        'experiments/histgb5',
    'Keras(1)':         'experiments/keras1',
    'Keras(2)':         'experiments/keras2',
    'Keras(3)':         'experiments/keras3',
    'Keras(4)':         'experiments/keras4',
    'Keras(5)':         'experiments/keras5',
    'Keras(6)':         'experiments/keras6',
    'LightGBM(1)':      'experiments/lightgbm1',
    # 'LightGBM(2)':     'experiments/lightgbm2',
    'LightGBM(3)':      'experiments/lightgbm3',
    'LightGBM(4)':      'experiments/lightgbm4',
    'LightGBM(5)':      'experiments/lightgbm5',
    'XGBoost(1)':       'experiments/xgboost1',
    # 'XGBoost(2)':      'experiments/xgboost2',
    'XGBoost(3)':       'experiments/xgboost3',
    'XGBoost(4)':       'experiments/xgboost4',
}

# %%
for model_name, folder_name in model_folder_mappings.items():
    oof_pred_probs[model_name], test_pred_probs[model_name], scores[model_name] = get_data(folder_name)

# %% [markdown]
# # Stacking With Logistic Regression

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS, threshold=THRESHOLD):
        self.model = model
        self.n_folds = n_folds
        self.threshold = threshold

    def fit_predict(self, X, y, X_test):
        print('Training Ensemble\n')
        
        scores = []
        coeffs = np.zeros((1, X.shape[1]))
        test_pred_probs = np.zeros((X_test.shape[0], len(np.unique(y))))
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        
        skf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)
        for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y)):
            X_train, X_val = X[train_idx], X[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]
            
            model = clone(self.model)
            model.fit(X_train, y_train)
            
            y_pred_probs = model.predict_proba(X_val)  
            oof_pred_probs[val_idx] = y_pred_probs
            y_preds = y_pred_probs[:, 1] >= self.threshold
            
            temp_test_pred_probs = model.predict_proba(X_test)
            test_pred_probs += temp_test_pred_probs / self.n_folds
            
            coeffs += model[-1].coef_ / self.n_folds
            
            score = matthews_corrcoef(y_val, y_preds)
            scores.append(score)
            
            print(f'--- Fold {fold_idx + 1} - MCC: {score:.6f} ({model[-1].n_iter_[0]} iterations)')
            
            del model, X_train, y_train, X_val, y_val, y_pred_probs
            gc.collect()
            
        print(f'\n------ Average MCC: {np.mean(scores):.6f} ± {np.std(scores):.6f}')
        
        self._save_submission(test_pred_probs, np.mean(scores))
        
        return scores, oof_pred_probs, coeffs
    
    def _save_submission(self, test_pred_probs, score):
        name = 'ensemble'
        sub = pd.read_csv('/kaggle/input/playground-series-s4e8/sample_submission.csv')
        sub[TARGET] = test_pred_probs[:, 1] >= self.threshold
        sub[TARGET] = sub[TARGET].map({False: 'e', True: 'p'})
        sub.to_csv(f'sub_{name}_{score:.6f}.csv', index=False)

# %%
X = np.column_stack(list(oof_pred_probs.values())).astype(np.float64).clip(1e-15, 1-1e-15)
X_test = np.column_stack(list(test_pred_probs.values())).astype(np.float64).clip(1e-15, 1-1e-15)

# %%
lr_params = {
    'max_iter': 500,
    'penalty': 'none',
    'class_weight': 'balanced'
}

model = make_pipeline(
    FunctionTransformer(scipy.special.logit), 
    LogisticRegression(**lr_params)
)

trainer = Trainer(model)
ensemble_scores, ensemble_oof_pred_probs, coeffs = trainer.fit_predict(X, y, X_test)
scores['Ensemble'] = ensemble_scores
# Out:
# Training Ensemble
#
# --- Fold 1 - MCC: 0.984910 (176 iterations)
# --- Fold 2 - MCC: 0.985306 (152 iterations)
# --- Fold 3 - MCC: 0.984801 (184 iterations)
# --- Fold 4 - MCC: 0.985039 (235 iterations)
# --- Fold 5 - MCC: 0.985043 (163 iterations)
#
# ------ Average MCC: 0.985020 ± 0.000169

# %%
sorted_indices = np.argsort(coeffs[0])[::-1]
sorted_coeffs = np.array(coeffs[0])[sorted_indices]
sorted_model_names = np.array(list(oof_pred_probs.keys()))[sorted_indices]

plt.figure(figsize=(10, 8))
ax = sns.barplot(x=sorted_coeffs, y=sorted_model_names, palette="RdYlGn_r")

for i, (value, name) in enumerate(zip(sorted_coeffs, sorted_model_names)):
    if value > 0:
        ax.text(value, i, f'{value:.3f}', va='center', ha='left', color='black')
    else:
        ax.text(value, i, f'{value:.3f}', va='center', ha='right', color='black')

xlim = ax.get_xlim()
ax.set_xlim(xlim[0] - 0.1 * abs(xlim[0]), xlim[1] + 0.1 * abs(xlim[1]))
        
plt.title('Model Coefficients')
plt.xlabel('')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Optimizing Threshold

# %%
def objective(trial):
    threshold = trial.suggest_float('threshold', 0.4, 0.6)
    y_preds = ensemble_oof_pred_probs[:, 1] >= threshold
    return matthews_corrcoef(y, y_preds)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500, n_jobs=-1)
# Out:
# [I 2024-09-01 10:12:46,806] A new study created in memory with name: no-name-e1205019-1254-4990-b274-31104bfb0fa5
# [I 2024-09-01 10:12:49,534] Trial 3 finished with value: 0.98497102336617 and parameters: {'threshold': 0.5250972884202515}. Best is trial 3 with value: 0.98497102336617.
# [I 2024-09-01 10:12:49,629] Trial 2 finished with value: 0.9850477505448517 and parameters: {'threshold': 0.4567440094993511}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:49,656] Trial 1 finished with value: 0.9850409178165892 and parameters: {'threshold': 0.44811976202831544}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:49,822] Trial 0 finished with value: 0.9848010946623443 and parameters: {'threshold': 0.5915704423208522}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:52,301] Trial 5 finished with value: 0.9850420173082375 and parameters: {'threshold': 0.4240131157480259}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:52,388] Trial 6 finished with value: 0.9849283659516118 and parameters: {'threshold': 0.553249953966646}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:52,462] Trial 7 finished with value: 0.9848834293160899 and parameters: {'threshold': 0.5721296968876115}. Best is trial 2 with value: 0.9850477505448517.
# [I 2024-09-01 10:12:52,720] Trial 4 finished with value: 0.9850495779615422 and parameters: {'threshold': 0.43769838383320375}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:54,896] Trial 9 finished with value: 0.9848477224681483 and parameters: {'threshold': 0.5814487663207022}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:54,987] Trial 8 finished with value: 0.9850241044189673 and parameters: {'threshold': 0.4962582534978549}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:55,298] Trial 10 finished with value: 0.9848954256728736 and parameters: {'threshold': 0.5676564447865464}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:55,302] Trial 11 finished with value: 0.9848889967549925 and parameters: {'threshold': 0.5680947546052969}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:57,323] Trial 12 finished with value: 0.9850440534462114 and parameters: {'threshold': 0.4275821575438121}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:57,835] Trial 14 finished with value: 0.9850403392658811 and parameters: {'threshold': 0.46545865824214105}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:57,914] Trial 15 finished with value: 0.9850456893699618 and parameters: {'threshold': 0.46992604280116845}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:12:58,002] Trial 13 finished with value: 0.9850289453399733 and parameters: {'threshold': 0.48789111410179775}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:00,403] Trial 16 finished with value: 0.9850404776289894 and parameters: {'threshold': 0.4690510246292291}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:00,499] Trial 17 finished with value: 0.9849939797362977 and parameters: {'threshold': 0.40100561120388806}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:00,607] Trial 18 finished with value: 0.9850052240769548 and parameters: {'threshold': 0.40821540063803385}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:00,643] Trial 19 finished with value: 0.9850052240769548 and parameters: {'threshold': 0.40834224225440874}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:05,508] Trial 23 finished with value: 0.9849824358566298 and parameters: {'threshold': 0.5196690000869773}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:05,543] Trial 21 finished with value: 0.9849696788880459 and parameters: {'threshold': 0.5239142503993647}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:05,588] Trial 22 finished with value: 0.9849811029804102 and parameters: {'threshold': 0.518993184213068}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:05,629] Trial 20 finished with value: 0.9849992239713532 and parameters: {'threshold': 0.4029438236477634}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:08,282] Trial 26 finished with value: 0.9850418031695364 and parameters: {'threshold': 0.4532903393055627}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:08,557] Trial 25 finished with value: 0.985040998930389 and parameters: {'threshold': 0.44964846818378934}. Best is trial 4 with value: 0.9850495779615422.
# [I 2024-09-01 10:13:08,829] Trial 24 finished with value: 0.9850497270734913 and parameters: {'threshold': 0.45757033154780286}. Best is trial 24 with value: 0.9850497270734913.
# [I 2024-09-01 10:13:09,271] Trial 27 finished with value: 0.9850412270499274 and parameters: {'threshold': 0.4552892726162894}. Best is trial 24 with value: 0.9850497270734913.
# [I 2024-09-01 10:13:11,060] Trial 29 finished with value: 0.9850452527264424 and parameters: {'threshold': 0.4757817614753882}. Best is trial 24 with value: 0.9850497270734913.
# [I 2024-09-01 10:13:11,066] Trial 28 finished with value: 0.9850460298280597 and parameters: {'threshold': 0.4795378831206239}. Best is trial 24 with value: 0.9850497270734913.
# [I 2024-09-01 10:13:11,335] Trial 30 finished with value: 0.9850449453859155 and parameters: {'threshold': 0.43515737141474664}. Best is trial 24 with value: 0.9850497270734913.
# [I 2024-09-01 10:13:11,713] Trial 31 finished with value: 0.9850519564354461 and parameters: {'threshold': 0.4314324919823898}. Best is trial 31 with value: 0.9850519564354461.
# [I 2024-09-01 10:13:13,679] Trial 32 finished with value: 0.9850446608464688 and parameters: {'threshold': 0.4263736449707107}. Best is trial 31 with value: 0.9850519564354461.
# [I 2024-09-01 10:13:13,728] Trial 33 finished with value: 0.985052639990034 and parameters: {'threshold': 0.43360374696020004}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:14,034] Trial 34 finished with value: 0.9850384808680113 and parameters: {'threshold': 0.4842048589711258}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:14,170] Trial 35 finished with value: 0.985052639990034 and parameters: {'threshold': 0.433490203443058}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:16,696] Trial 37 finished with value: 0.9850482703701887 and parameters: {'threshold': 0.4373789308015413}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:16,713] Trial 36 finished with value: 0.9850413315722732 and parameters: {'threshold': 0.4422479655537849}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:16,939] Trial 38 finished with value: 0.9850482703701887 and parameters: {'threshold': 0.4372780523561834}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:17,114] Trial 39 finished with value: 0.9850406732794827 and parameters: {'threshold': 0.4419975626909867}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:19,126] Trial 41 finished with value: 0.9850353419302706 and parameters: {'threshold': 0.41764596306635443}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:19,201] Trial 40 finished with value: 0.9850366570032211 and parameters: {'threshold': 0.41824391358261875}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:19,315] Trial 42 finished with value: 0.9850366447150762 and parameters: {'threshold': 0.4178789046365234}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:19,499] Trial 43 finished with value: 0.9850413429378122 and parameters: {'threshold': 0.4232502721025461}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:21,585] Trial 44 finished with value: 0.9850433202455372 and parameters: {'threshold': 0.42446583972567387}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:21,669] Trial 45 finished with value: 0.9850446045974093 and parameters: {'threshold': 0.4591057995796378}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:21,732] Trial 46 finished with value: 0.9850503720321339 and parameters: {'threshold': 0.45751114167065704}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:21,945] Trial 47 finished with value: 0.9850497317074366 and parameters: {'threshold': 0.4577156687455606}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:23,961] Trial 48 finished with value: 0.9850069915652949 and parameters: {'threshold': 0.5047214872784325}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:24,115] Trial 49 finished with value: 0.9850229394953373 and parameters: {'threshold': 0.4993282226434078}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:24,118] Trial 50 finished with value: 0.9850178449874171 and parameters: {'threshold': 0.5012181734275777}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:24,378] Trial 51 finished with value: 0.9850376612117069 and parameters: {'threshold': 0.4470896045033679}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:26,320] Trial 52 finished with value: 0.9850253473804812 and parameters: {'threshold': 0.49470580519408575}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:26,508] Trial 54 finished with value: 0.9850466797081061 and parameters: {'threshold': 0.46284566256328863}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:26,574] Trial 53 finished with value: 0.9850407489068287 and parameters: {'threshold': 0.4599825640876305}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:26,785] Trial 55 finished with value: 0.985043366012237 and parameters: {'threshold': 0.4611107296581111}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:28,721] Trial 56 finished with value: 0.9850466844092216 and parameters: {'threshold': 0.46300686684749115}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:28,883] Trial 57 finished with value: 0.9850467143840063 and parameters: {'threshold': 0.42976474672102605}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:28,980] Trial 58 finished with value: 0.9849446700578232 and parameters: {'threshold': 0.5430798322051142}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:29,177] Trial 59 finished with value: 0.9850506661107036 and parameters: {'threshold': 0.4318195512173446}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:31,154] Trial 60 finished with value: 0.9850506490798795 and parameters: {'threshold': 0.43078243677652794}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:31,289] Trial 61 finished with value: 0.9849435330430885 and parameters: {'threshold': 0.5463729407875886}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:31,481] Trial 62 finished with value: 0.9850421541319763 and parameters: {'threshold': 0.44622468472041915}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:31,585] Trial 63 finished with value: 0.9850202614998514 and parameters: {'threshold': 0.41215179890076886}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:33,581] Trial 64 finished with value: 0.9850396142733459 and parameters: {'threshold': 0.4475148807961014}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:33,685] Trial 65 finished with value: 0.9850427456708302 and parameters: {'threshold': 0.44488699798714304}. Best is trial 33 with value: 0.985052639990034.
# [I 2024-09-01 10:13:33,885] Trial 66 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43283424923489794}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:33,957] Trial 67 finished with value: 0.9850494356288708 and parameters: {'threshold': 0.4343209016199627}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:35,962] Trial 68 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4330894523666962}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:36,063] Trial 69 finished with value: 0.9850494356288708 and parameters: {'threshold': 0.4343646476699947}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:36,302] Trial 70 finished with value: 0.9850506703725329 and parameters: {'threshold': 0.43189295153123214}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:36,367] Trial 71 finished with value: 0.9850519351600596 and parameters: {'threshold': 0.4307661623033355}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:38,369] Trial 72 finished with value: 0.9847903390718489 and parameters: {'threshold': 0.595763430556627}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:38,478] Trial 73 finished with value: 0.9850506490798795 and parameters: {'threshold': 0.4307862577173077}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:38,767] Trial 74 finished with value: 0.9850467398241756 and parameters: {'threshold': 0.4302431775449519}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:38,797] Trial 75 finished with value: 0.9850169789241782 and parameters: {'threshold': 0.41093547501086725}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:40,769] Trial 76 finished with value: 0.9850170029255898 and parameters: {'threshold': 0.41158176222627535}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:40,863] Trial 77 finished with value: 0.9850300617656156 and parameters: {'threshold': 0.4150540585694789}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:41,191] Trial 79 finished with value: 0.9850373515444925 and parameters: {'threshold': 0.4202996591249874}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:41,286] Trial 78 finished with value: 0.9850241815122375 and parameters: {'threshold': 0.41324743521214724}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:43,177] Trial 80 finished with value: 0.9850373639041526 and parameters: {'threshold': 0.42088074160558825}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:43,313] Trial 81 finished with value: 0.9850393408987261 and parameters: {'threshold': 0.4215664886630499}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:43,657] Trial 82 finished with value: 0.9849952820703304 and parameters: {'threshold': 0.40145013133481633}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:43,726] Trial 83 finished with value: 0.9850038782007917 and parameters: {'threshold': 0.40651785712913946}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:45,595] Trial 84 finished with value: 0.9850012223488519 and parameters: {'threshold': 0.4043840739858382}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:45,723] Trial 85 finished with value: 0.9850444780563212 and parameters: {'threshold': 0.4397912667208158}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:46,073] Trial 86 finished with value: 0.985043619737761 and parameters: {'threshold': 0.4503833538598636}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:46,135] Trial 87 finished with value: 0.9850445174587683 and parameters: {'threshold': 0.4407599604191314}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:48,723] Trial 88 finished with value: 0.9850451669382534 and parameters: {'threshold': 0.44078748508663873}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:48,981] Trial 91 finished with value: 0.9850519734854424 and parameters: {'threshold': 0.4322518447967809}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:49,024] Trial 89 finished with value: 0.9850462542599352 and parameters: {'threshold': 0.4514715167189325}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:49,103] Trial 90 finished with value: 0.9850453354219194 and parameters: {'threshold': 0.4271911721003707}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:51,221] Trial 92 finished with value: 0.9850434504201984 and parameters: {'threshold': 0.42893496840812056}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:51,483] Trial 93 finished with value: 0.9850446608464688 and parameters: {'threshold': 0.4262775721947876}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:51,544] Trial 94 finished with value: 0.9850407603173366 and parameters: {'threshold': 0.4257638306109318}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:51,583] Trial 95 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4332720752306211}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:53,661] Trial 96 finished with value: 0.9850519991099154 and parameters: {'threshold': 0.4336983205857188}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:53,974] Trial 98 finished with value: 0.9850489111577658 and parameters: {'threshold': 0.43710808614338026}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:53,989] Trial 97 finished with value: 0.9850481496218303 and parameters: {'threshold': 0.4345250636988255}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:54,024] Trial 99 finished with value: 0.9850487947684675 and parameters: {'threshold': 0.4344930869980852}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:56,053] Trial 100 finished with value: 0.9850495779615422 and parameters: {'threshold': 0.43767780136165274}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:56,423] Trial 103 finished with value: 0.9850411177058255 and parameters: {'threshold': 0.4688614842076083}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:56,466] Trial 101 finished with value: 0.9850420872691948 and parameters: {'threshold': 0.4446424672676764}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:56,507] Trial 102 finished with value: 0.9850400678761365 and parameters: {'threshold': 0.4430969456988033}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:58,446] Trial 104 finished with value: 0.9850407483310056 and parameters: {'threshold': 0.4438021767053409}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:58,824] Trial 105 finished with value: 0.985039436059183 and parameters: {'threshold': 0.4434761525590907}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:58,902] Trial 106 finished with value: 0.9850519692204692 and parameters: {'threshold': 0.43203934176670095}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:13:58,948] Trial 107 finished with value: 0.9850405544781651 and parameters: {'threshold': 0.45424182422995246}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:00,833] Trial 108 finished with value: 0.9850411810962091 and parameters: {'threshold': 0.4538253718516795}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:01,240] Trial 109 finished with value: 0.9850359708408604 and parameters: {'threshold': 0.41725314959468296}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:01,374] Trial 110 finished with value: 0.9850439654554992 and parameters: {'threshold': 0.42437349946480174}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:01,440] Trial 111 finished with value: 0.9850406977207883 and parameters: {'threshold': 0.42342483966236105}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:03,322] Trial 112 finished with value: 0.9850353747064948 and parameters: {'threshold': 0.41874042518649846}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:03,682] Trial 113 finished with value: 0.9850400275641302 and parameters: {'threshold': 0.42273338828845214}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:03,795] Trial 114 finished with value: 0.9850519564354461 and parameters: {'threshold': 0.4314398943075781}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:03,907] Trial 115 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4332989047662116}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:05,728] Trial 116 finished with value: 0.9850519564354461 and parameters: {'threshold': 0.43149889311272255}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:06,073] Trial 117 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43308156908209083}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:06,172] Trial 118 finished with value: 0.9850494313437971 and parameters: {'threshold': 0.4341323108850286}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:06,383] Trial 119 finished with value: 0.985047023584703 and parameters: {'threshold': 0.43855168227965424}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:08,166] Trial 120 finished with value: 0.9848317058937242 and parameters: {'threshold': 0.5841093793745347}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:08,453] Trial 121 finished with value: 0.9850450926108504 and parameters: {'threshold': 0.43875910332029405}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:08,555] Trial 122 finished with value: 0.9850451100567719 and parameters: {'threshold': 0.43928653286974767}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:08,834] Trial 123 finished with value: 0.9850403268082586 and parameters: {'threshold': 0.44926534832822185}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:10,541] Trial 124 finished with value: 0.9850453564537809 and parameters: {'threshold': 0.4278357366384837}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:10,858] Trial 125 finished with value: 0.9850459848183822 and parameters: {'threshold': 0.4272130483233344}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:10,929] Trial 126 finished with value: 0.9850447619200121 and parameters: {'threshold': 0.4294604854358845}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:11,280] Trial 127 finished with value: 0.9850453690926895 and parameters: {'threshold': 0.4281779066911316}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:13,006] Trial 128 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4327930261202095}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:13,319] Trial 129 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4330285843922518}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:13,406] Trial 130 finished with value: 0.985031364473068 and parameters: {'threshold': 0.4152810582135368}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:13,736] Trial 131 finished with value: 0.9850359423007552 and parameters: {'threshold': 0.4163224579974595}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:15,390] Trial 132 finished with value: 0.9850294002986753 and parameters: {'threshold': 0.4146147241476012}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:15,709] Trial 133 finished with value: 0.9850409178165892 and parameters: {'threshold': 0.44808060341200795}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:15,799] Trial 134 finished with value: 0.9850462701209715 and parameters: {'threshold': 0.4356274172325108}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:16,149] Trial 135 finished with value: 0.9850468722109145 and parameters: {'threshold': 0.43494536481678275}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:17,785] Trial 136 finished with value: 0.9850513325939588 and parameters: {'threshold': 0.43264678273317064}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:18,080] Trial 137 finished with value: 0.9850520033864334 and parameters: {'threshold': 0.43384742297974604}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:18,172] Trial 138 finished with value: 0.9850506661107036 and parameters: {'threshold': 0.4318079334262189}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:18,583] Trial 139 finished with value: 0.9850387163746044 and parameters: {'threshold': 0.4221514551369341}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:20,611] Trial 140 finished with value: 0.9850387163746044 and parameters: {'threshold': 0.4221737163098225}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:21,070] Trial 142 finished with value: 0.9850380587184411 and parameters: {'threshold': 0.42186985741242894}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:21,106] Trial 141 finished with value: 0.9850495823026906 and parameters: {'threshold': 0.43778865829127556}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:21,475] Trial 143 finished with value: 0.985041344794164 and parameters: {'threshold': 0.4426902166961181}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:23,371] Trial 144 finished with value: 0.985044482427774 and parameters: {'threshold': 0.4399716709048193}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:23,674] Trial 145 finished with value: 0.9850425953513838 and parameters: {'threshold': 0.44130400289028526}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:23,737] Trial 146 finished with value: 0.9850400722934829 and parameters: {'threshold': 0.44328979835352733}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:24,005] Trial 147 finished with value: 0.9850445043097765 and parameters: {'threshold': 0.4404865629443656}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:25,752] Trial 148 finished with value: 0.9850420507248108 and parameters: {'threshold': 0.4253564324247874}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:26,089] Trial 149 finished with value: 0.9850434040477646 and parameters: {'threshold': 0.42753673636800515}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:26,177] Trial 150 finished with value: 0.9850407603173366 and parameters: {'threshold': 0.42565896213897664}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:26,456] Trial 151 finished with value: 0.9850420507248108 and parameters: {'threshold': 0.42536885549807973}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:28,154] Trial 152 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4334179294530314}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:28,452] Trial 153 finished with value: 0.9850481496218303 and parameters: {'threshold': 0.43459427648128307}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:28,549] Trial 154 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43313181081788654}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:28,852] Trial 155 finished with value: 0.9850519734854424 and parameters: {'threshold': 0.43238239838172304}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:30,570] Trial 156 finished with value: 0.9850494313437971 and parameters: {'threshold': 0.4341691764891009}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:30,841] Trial 157 finished with value: 0.9850513197963335 and parameters: {'threshold': 0.43194756203421947}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:30,967] Trial 158 finished with value: 0.9850488938390416 and parameters: {'threshold': 0.4365668047879493}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:31,313] Trial 159 finished with value: 0.9849873250034537 and parameters: {'threshold': 0.5130112677385654}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:33,030] Trial 160 finished with value: 0.9850421228831692 and parameters: {'threshold': 0.44550096733808675}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:33,265] Trial 161 finished with value: 0.985040926802848 and parameters: {'threshold': 0.44828729777514464}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:33,388] Trial 162 finished with value: 0.985042794711757 and parameters: {'threshold': 0.4460282465520531}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:33,731] Trial 163 finished with value: 0.9850402637994722 and parameters: {'threshold': 0.4477763234762292}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:35,392] Trial 164 finished with value: 0.9850421600576738 and parameters: {'threshold': 0.4290771380898264}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:35,645] Trial 165 finished with value: 0.9850480386561372 and parameters: {'threshold': 0.43027759251543}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:35,789] Trial 166 finished with value: 0.9850467398241756 and parameters: {'threshold': 0.4302490119036679}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:36,174] Trial 167 finished with value: 0.9850447619200121 and parameters: {'threshold': 0.4295113638751185}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:37,809] Trial 168 finished with value: 0.9850487947684675 and parameters: {'threshold': 0.4344412911092067}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:38,069] Trial 169 finished with value: 0.9850489111577658 and parameters: {'threshold': 0.4371143934633818}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:38,184] Trial 170 finished with value: 0.9850482487131502 and parameters: {'threshold': 0.43666781721803505}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:38,577] Trial 171 finished with value: 0.9850489198270235 and parameters: {'threshold': 0.4375701456247536}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:40,191] Trial 172 finished with value: 0.9850476556447322 and parameters: {'threshold': 0.4380920504435259}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:40,479] Trial 173 finished with value: 0.9849444275658739 and parameters: {'threshold': 0.5375475886679655}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:40,573] Trial 174 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43274423981710053}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:40,973] Trial 175 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43302859706332064}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:42,650] Trial 176 finished with value: 0.9850373515444925 and parameters: {'threshold': 0.4202782633632979}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:42,986] Trial 177 finished with value: 0.9850373515444925 and parameters: {'threshold': 0.4201655491538845}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:43,026] Trial 178 finished with value: 0.9850373639041526 and parameters: {'threshold': 0.4208393065713402}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:43,409] Trial 179 finished with value: 0.9850360528293515 and parameters: {'threshold': 0.41991680809095655}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:45,059] Trial 180 finished with value: 0.9850420507248108 and parameters: {'threshold': 0.425416913443152}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:45,415] Trial 181 finished with value: 0.9850446818251144 and parameters: {'threshold': 0.42700287782042823}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:45,436] Trial 182 finished with value: 0.9850446566556877 and parameters: {'threshold': 0.42606461258765077}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:45,841] Trial 183 finished with value: 0.9850520033864334 and parameters: {'threshold': 0.4338529435315848}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:47,459] Trial 184 finished with value: 0.9850526314470486 and parameters: {'threshold': 0.43267403883082933}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:47,895] Trial 185 finished with value: 0.9849125733698606 and parameters: {'threshold': 0.5611415309658547}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:47,903] Trial 186 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4327716978500872}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:48,281] Trial 187 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43298477517001505}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:49,867] Trial 188 finished with value: 0.985052639990034 and parameters: {'threshold': 0.43360713770990345}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:50,307] Trial 189 finished with value: 0.9850425953513838 and parameters: {'threshold': 0.44137445988409624}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:50,342] Trial 190 finished with value: 0.9850445043097765 and parameters: {'threshold': 0.44052576123393905}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:50,715] Trial 191 finished with value: 0.9850425953513838 and parameters: {'threshold': 0.4413338488470981}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:52,477] Trial 192 finished with value: 0.985042604140931 and parameters: {'threshold': 0.4415638469065301}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:52,881] Trial 194 finished with value: 0.985045590525594 and parameters: {'threshold': 0.4351530857923408}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:53,444] Trial 193 finished with value: 0.9850432141176513 and parameters: {'threshold': 0.4405833650869201}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:53,644] Trial 195 finished with value: 0.9850462701209715 and parameters: {'threshold': 0.4356385693867549}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:55,154] Trial 196 finished with value: 0.985052639990034 and parameters: {'threshold': 0.43343025047673867}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:55,681] Trial 197 finished with value: 0.9850519991099154 and parameters: {'threshold': 0.4337200502068442}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:56,113] Trial 198 finished with value: 0.9850520033864334 and parameters: {'threshold': 0.4338544574097609}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:56,234] Trial 199 finished with value: 0.9850441082811517 and parameters: {'threshold': 0.429274132543186}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:57,523] Trial 200 finished with value: 0.9850473637953362 and parameters: {'threshold': 0.42981053250385404}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:58,092] Trial 201 finished with value: 0.9850460649730114 and parameters: {'threshold': 0.42972395629331644}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:58,476] Trial 202 finished with value: 0.9850428052386911 and parameters: {'threshold': 0.42902030059626195}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:58,666] Trial 203 finished with value: 0.9850447323420947 and parameters: {'threshold': 0.4285462850200199}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:14:59,914] Trial 204 finished with value: 0.9850462701209715 and parameters: {'threshold': 0.435700070646196}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:00,535] Trial 205 finished with value: 0.9850482487131502 and parameters: {'threshold': 0.4366952490740663}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:00,888] Trial 206 finished with value: 0.9850488938390416 and parameters: {'threshold': 0.4365778380846638}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:01,160] Trial 207 finished with value: 0.9850243867826735 and parameters: {'threshold': 0.48757010211509155}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:02,407] Trial 208 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4332357843919588}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:02,966] Trial 209 finished with value: 0.9850427223279986 and parameters: {'threshold': 0.4776111844772668}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:03,345] Trial 210 finished with value: 0.9850513197963335 and parameters: {'threshold': 0.43201470697521305}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:03,635] Trial 211 finished with value: 0.9850506661107036 and parameters: {'threshold': 0.43170777835443114}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:04,859] Trial 212 finished with value: 0.9850420507248108 and parameters: {'threshold': 0.425536121355529}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:05,373] Trial 213 finished with value: 0.9850407185450709 and parameters: {'threshold': 0.42386543800307275}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:05,726] Trial 214 finished with value: 0.985052639990034 and parameters: {'threshold': 0.43337767774688946}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:06,086] Trial 215 finished with value: 0.9850433369532041 and parameters: {'threshold': 0.4249697067613391}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:07,292] Trial 216 finished with value: 0.9850494313437971 and parameters: {'threshold': 0.4341264858531654}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:07,771] Trial 217 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4336031247609527}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:08,121] Trial 218 finished with value: 0.9850502317624371 and parameters: {'threshold': 0.43786189218072225}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:08,531] Trial 219 finished with value: 0.9850470192317007 and parameters: {'threshold': 0.4383611316171192}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:09,687] Trial 220 finished with value: 0.9850457595268772 and parameters: {'threshold': 0.4393299399373593}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:10,196] Trial 221 finished with value: 0.985041402260537 and parameters: {'threshold': 0.4439396662920999}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:10,503] Trial 222 finished with value: 0.985041402260537 and parameters: {'threshold': 0.4440524068934582}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:10,925] Trial 223 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.4313946263230126}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:12,132] Trial 224 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4332538375412991}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:12,642] Trial 225 finished with value: 0.9850519734854424 and parameters: {'threshold': 0.4324343895241302}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:12,918] Trial 226 finished with value: 0.9850519692204692 and parameters: {'threshold': 0.4320497740491082}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:13,406] Trial 227 finished with value: 0.9850513112728299 and parameters: {'threshold': 0.4315801728252846}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:14,501] Trial 228 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.4312232232633449}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:15,048] Trial 229 finished with value: 0.9850453354219194 and parameters: {'threshold': 0.42710167514277764}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:15,303] Trial 230 finished with value: 0.9850420507248108 and parameters: {'threshold': 0.425542217356205}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:15,841] Trial 231 finished with value: 0.9850453396249931 and parameters: {'threshold': 0.4274280721709482}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:16,906] Trial 232 finished with value: 0.9850446608464688 and parameters: {'threshold': 0.4263612204741137}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:17,437] Trial 233 finished with value: 0.9850447112644899 and parameters: {'threshold': 0.4278934903930087}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:17,707] Trial 234 finished with value: 0.9850428094651646 and parameters: {'threshold': 0.4291088256866175}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:18,267] Trial 235 finished with value: 0.9850476035877487 and parameters: {'threshold': 0.43680220824228416}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:19,307] Trial 236 finished with value: 0.985048928502878 and parameters: {'threshold': 0.43765516653966163}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:19,865] Trial 237 finished with value: 0.9850489111577658 and parameters: {'threshold': 0.4370831891456286}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:20,108] Trial 238 finished with value: 0.9850468722109145 and parameters: {'threshold': 0.4349762167657399}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:20,667] Trial 239 finished with value: 0.9850476035877487 and parameters: {'threshold': 0.43677534931992845}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:21,751] Trial 240 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4335478691122804}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:22,344] Trial 241 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4328936778085189}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:22,576] Trial 242 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.43128559686594037}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:23,144] Trial 243 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.4313133657904963}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:24,126] Trial 244 finished with value: 0.985051315533757 and parameters: {'threshold': 0.43183618876758095}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:24,764] Trial 245 finished with value: 0.9850526186449398 and parameters: {'threshold': 0.4321371231666591}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:25,241] Trial 246 finished with value: 0.985053285145511 and parameters: {'threshold': 0.43285920882347734}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:25,987] Trial 247 finished with value: 0.9850445043097765 and parameters: {'threshold': 0.4405143582963339}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:27,097] Trial 248 finished with value: 0.9850464352246431 and parameters: {'threshold': 0.44030200109432793}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:27,669] Trial 249 finished with value: 0.9850425865684337 and parameters: {'threshold': 0.4409998693540284}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:28,043] Trial 250 finished with value: 0.9850464352246431 and parameters: {'threshold': 0.4401746667350391}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:28,681] Trial 251 finished with value: 0.9850464352246431 and parameters: {'threshold': 0.4402922988793828}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:29,485] Trial 252 finished with value: 0.9850487947684675 and parameters: {'threshold': 0.4344989140374153}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:30,085] Trial 253 finished with value: 0.9850449669170718 and parameters: {'threshold': 0.43544103939341683}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:30,437] Trial 254 finished with value: 0.9850462701209715 and parameters: {'threshold': 0.43572050317278654}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:31,099] Trial 255 finished with value: 0.9850475173538663 and parameters: {'threshold': 0.4349094461617746}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:31,927] Trial 256 finished with value: 0.9850406894026205 and parameters: {'threshold': 0.4231040573925965}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:32,541] Trial 257 finished with value: 0.9850446231888144 and parameters: {'threshold': 0.4248126062187363}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:32,874] Trial 258 finished with value: 0.9850406852460107 and parameters: {'threshold': 0.42292455623757613}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:33,520] Trial 259 finished with value: 0.9850400358709073 and parameters: {'threshold': 0.4228429814696405}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:34,305] Trial 260 finished with value: 0.9850466678979054 and parameters: {'threshold': 0.42823930538819327}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:34,954] Trial 261 finished with value: 0.9850447196905838 and parameters: {'threshold': 0.428112905443635}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:35,232] Trial 262 finished with value: 0.9850434504201984 and parameters: {'threshold': 0.4289062738517264}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:35,916] Trial 263 finished with value: 0.9850440576543879 and parameters: {'threshold': 0.4276044658384861}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:36,701] Trial 264 finished with value: 0.9850466678979054 and parameters: {'threshold': 0.42824735715528306}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:37,380] Trial 265 finished with value: 0.985052639990034 and parameters: {'threshold': 0.4333680635648617}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:37,635] Trial 266 finished with value: 0.9850401209931389 and parameters: {'threshold': 0.44426706674023936}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:38,348] Trial 267 finished with value: 0.9850500722106951 and parameters: {'threshold': 0.43401850952611765}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:39,105] Trial 268 finished with value: 0.9850427723956896 and parameters: {'threshold': 0.4455796937863529}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:15:39,768] Trial 269 finished with value: 0.985048928502878 and parameters: {'threshold': 0.43762107727823213}. Best is trial 66 with value: 0.985053285145511.
# ...
# [I 2024-09-01 10:17:06,801] Trial 410 finished with value: 0.9850438943176463 and parameters: {'threshold': 0.4414129180758728}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:07,580] Trial 411 finished with value: 0.9850396142733459 and parameters: {'threshold': 0.44740063874991526}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:08,035] Trial 412 finished with value: 0.9850393657453019 and parameters: {'threshold': 0.4222197767970638}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:08,865] Trial 413 finished with value: 0.9850159268014615 and parameters: {'threshold': 0.5017981158355318}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:09,232] Trial 414 finished with value: 0.9850367145441732 and parameters: {'threshold': 0.4207081145689363}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:09,954] Trial 415 finished with value: 0.9850393574565126 and parameters: {'threshold': 0.4220376963635716}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:10,477] Trial 416 finished with value: 0.9850467398241756 and parameters: {'threshold': 0.4302105202751049}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:11,298] Trial 417 finished with value: 0.9850467398241756 and parameters: {'threshold': 0.43019953337396305}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:11,656] Trial 418 finished with value: 0.9850506363240792 and parameters: {'threshold': 0.43059033095005395}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:12,358] Trial 419 finished with value: 0.9850486753383887 and parameters: {'threshold': 0.43007500529209164}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:12,988] Trial 420 finished with value: 0.9850460649730114 and parameters: {'threshold': 0.42966706291943213}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:13,715] Trial 421 finished with value: 0.9850459638240178 and parameters: {'threshold': 0.426589352879744}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:14,038] Trial 422 finished with value: 0.9850420590954474 and parameters: {'threshold': 0.4258105907969829}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:14,749] Trial 423 finished with value: 0.9850420590954474 and parameters: {'threshold': 0.4258254166297608}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:15,408] Trial 424 finished with value: 0.985045306046585 and parameters: {'threshold': 0.42618100863591885}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:16,121] Trial 425 finished with value: 0.9850463697676507 and parameters: {'threshold': 0.4381773356028017}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:16,439] Trial 426 finished with value: 0.9850482703701887 and parameters: {'threshold': 0.4372576058690157}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:17,128] Trial 427 finished with value: 0.9849913789343763 and parameters: {'threshold': 0.40076490219087096}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:17,822] Trial 428 finished with value: 0.9850470192317007 and parameters: {'threshold': 0.43839271879131947}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:18,526] Trial 429 finished with value: 0.9850487861948662 and parameters: {'threshold': 0.4342887203850725}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:18,839] Trial 430 finished with value: 0.985052639990034 and parameters: {'threshold': 0.43361775929171253}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:19,514] Trial 431 finished with value: 0.9850526357177166 and parameters: {'threshold': 0.4327111825847085}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:20,232] Trial 432 finished with value: 0.985053285145511 and parameters: {'threshold': 0.4327498953484404}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:20,940] Trial 433 finished with value: 0.9850396142733459 and parameters: {'threshold': 0.44736880274427904}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:21,246] Trial 434 finished with value: 0.9850414644590901 and parameters: {'threshold': 0.44513351216468894}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:21,951] Trial 435 finished with value: 0.9850421541319763 and parameters: {'threshold': 0.4462940743702947}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:22,716] Trial 436 finished with value: 0.9850409178165892 and parameters: {'threshold': 0.44806535539135933}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:23,403] Trial 437 finished with value: 0.9850401209931389 and parameters: {'threshold': 0.44421181171517543}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:23,665] Trial 438 finished with value: 0.9850353419302706 and parameters: {'threshold': 0.4176106251701255}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:24,351] Trial 439 finished with value: 0.9850488938390416 and parameters: {'threshold': 0.4364782503723572}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:25,148] Trial 440 finished with value: 0.9850475690150319 and parameters: {'threshold': 0.43590446526305276}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:25,807] Trial 441 finished with value: 0.9850489458743776 and parameters: {'threshold': 0.4380380487031992}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:26,087] Trial 442 finished with value: 0.9850488938390416 and parameters: {'threshold': 0.4365354969081286}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:26,783] Trial 443 finished with value: 0.9850519734854424 and parameters: {'threshold': 0.43244617118965084}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:27,576] Trial 444 finished with value: 0.985051315533757 and parameters: {'threshold': 0.43184256355214373}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:28,238] Trial 445 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.43128578041795357}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:28,480] Trial 446 finished with value: 0.9850506363240792 and parameters: {'threshold': 0.43057640143644943}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:29,199] Trial 447 finished with value: 0.9850427967906916 and parameters: {'threshold': 0.42883078525486995}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:30,029] Trial 448 finished with value: 0.9850466678979054 and parameters: {'threshold': 0.4284299890018059}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:30,632] Trial 449 finished with value: 0.9850453354219194 and parameters: {'threshold': 0.4270855733637375}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:30,901] Trial 450 finished with value: 0.9850433202455372 and parameters: {'threshold': 0.4244620521428548}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:31,640] Trial 451 finished with value: 0.9850407185450709 and parameters: {'threshold': 0.42388181623057386}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:32,464] Trial 452 finished with value: 0.9850413512607732 and parameters: {'threshold': 0.42357156718349426}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:33,089] Trial 453 finished with value: 0.985043859213469 and parameters: {'threshold': 0.4405526501507438}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:33,322] Trial 454 finished with value: 0.9850450926108504 and parameters: {'threshold': 0.43879231798073676}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:34,012] Trial 455 finished with value: 0.9850425953513838 and parameters: {'threshold': 0.44137537251544473}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:34,892] Trial 456 finished with value: 0.9850425865684337 and parameters: {'threshold': 0.44099726275032536}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:35,593] Trial 457 finished with value: 0.9850451669382534 and parameters: {'threshold': 0.4408374770581589}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:35,918] Trial 458 finished with value: 0.9850520033864334 and parameters: {'threshold': 0.43379700447390246}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:36,811] Trial 459 finished with value: 0.9850513582337397 and parameters: {'threshold': 0.43388158465392634}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:38,061] Trial 460 finished with value: 0.9850519564354461 and parameters: {'threshold': 0.4315354099486358}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:38,470] Trial 461 finished with value: 0.9850519991099154 and parameters: {'threshold': 0.4337183764228562}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:38,747] Trial 462 finished with value: 0.9850513539563198 and parameters: {'threshold': 0.4337837928302669}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:39,427] Trial 463 finished with value: 0.9850475087667614 and parameters: {'threshold': 0.43478569542705475}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:40,489] Trial 464 finished with value: 0.9850481496218303 and parameters: {'threshold': 0.4346147949178591}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:40,860] Trial 465 finished with value: 0.9850453564537809 and parameters: {'threshold': 0.42783699974592404}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:41,235] Trial 466 finished with value: 0.9848859434041284 and parameters: {'threshold': 0.5708799606603613}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:41,848] Trial 467 finished with value: 0.9850434208873774 and parameters: {'threshold': 0.42793457567897936}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:42,996] Trial 468 finished with value: 0.9850354034722831 and parameters: {'threshold': 0.41978301897329795}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:43,370] Trial 469 finished with value: 0.9850434419740028 and parameters: {'threshold': 0.4287836199508947}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:43,642] Trial 470 finished with value: 0.9850453270207201 and parameters: {'threshold': 0.426837080027944}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:44,269] Trial 471 finished with value: 0.9850360528293515 and parameters: {'threshold': 0.41994553806642365}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:45,424] Trial 472 finished with value: 0.9850482703701887 and parameters: {'threshold': 0.4372448876029545}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:45,820] Trial 473 finished with value: 0.9849842981031841 and parameters: {'threshold': 0.5182477463515146}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:46,087] Trial 474 finished with value: 0.9848017189570087 and parameters: {'threshold': 0.5911692660147349}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:46,669] Trial 475 finished with value: 0.9850457551621759 and parameters: {'threshold': 0.43924814751915}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:47,848] Trial 476 finished with value: 0.9850450882534931 and parameters: {'threshold': 0.43869477556440556}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:48,218] Trial 477 finished with value: 0.9850293962553794 and parameters: {'threshold': 0.41433921081573827}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:48,542] Trial 478 finished with value: 0.985045737719862 and parameters: {'threshold': 0.4387454372643703}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:49,070] Trial 479 finished with value: 0.9850526015985517 and parameters: {'threshold': 0.43129200351710273}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:50,305] Trial 480 finished with value: 0.9850506363240792 and parameters: {'threshold': 0.4305871213547856}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:50,655] Trial 481 finished with value: 0.9850519564354461 and parameters: {'threshold': 0.4314679283263311}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:50,968] Trial 482 finished with value: 0.9850427070604192 and parameters: {'threshold': 0.4604177252476191}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:51,485] Trial 483 finished with value: 0.9850400608308233 and parameters: {'threshold': 0.4236614728394273}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:52,767] Trial 484 finished with value: 0.9850426666903231 and parameters: {'threshold': 0.42406105105394915}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:53,155] Trial 485 finished with value: 0.9850407185450709 and parameters: {'threshold': 0.42383842004702166}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:53,458] Trial 486 finished with value: 0.9850387909857322 and parameters: {'threshold': 0.44352919770071897}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:53,862] Trial 487 finished with value: 0.9850400678761365 and parameters: {'threshold': 0.4430453066481518}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:55,187] Trial 488 finished with value: 0.9850387909857322 and parameters: {'threshold': 0.44352981386223284}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:55,590] Trial 489 finished with value: 0.9850449669170718 and parameters: {'threshold': 0.43545668036510204}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:55,824] Trial 490 finished with value: 0.9850475733308491 and parameters: {'threshold': 0.43597711216711565}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:56,303] Trial 491 finished with value: 0.9850449669170718 and parameters: {'threshold': 0.43551502762065214}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:57,673] Trial 492 finished with value: 0.9850482270973429 and parameters: {'threshold': 0.43604412030895073}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:57,964] Trial 493 finished with value: 0.9850482487131502 and parameters: {'threshold': 0.43666213467741516}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:58,198] Trial 494 finished with value: 0.9850441125107692 and parameters: {'threshold': 0.42943166475337735}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:17:58,690] Trial 495 finished with value: 0.9850447661520262 and parameters: {'threshold': 0.4296360999088822}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:18:00,081] Trial 496 finished with value: 0.9850441082811517 and parameters: {'threshold': 0.4292899063543614}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:18:00,328] Trial 497 finished with value: 0.9850428094651646 and parameters: {'threshold': 0.4291428794281662}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:18:00,402] Trial 498 finished with value: 0.9850513112728299 and parameters: {'threshold': 0.431611551069883}. Best is trial 66 with value: 0.985053285145511.
# [I 2024-09-01 10:18:00,810] Trial 499 finished with value: 0.9850519734854424 and parameters: {'threshold': 0.4322693658538372}. Best is trial 66 with value: 0.985053285145511.

# %%
study.best_params
# Out:
# {'threshold': 0.43283424923489794}

# %%
model = make_pipeline(
    FunctionTransformer(scipy.special.logit), 
    LogisticRegression(**lr_params)
)

trainer = Trainer(model, threshold=study.best_params['threshold'])
ensemble_scores, ensemble_oof_pred_probs, _ = trainer.fit_predict(X, y, X_test)
scores['Ensemble (tuned T)'] = ensemble_scores
# Out:
# Training Ensemble
#
# --- Fold 1 - MCC: 0.984904 (176 iterations)
# --- Fold 2 - MCC: 0.985281 (152 iterations)
# --- Fold 3 - MCC: 0.984940 (184 iterations)
# --- Fold 4 - MCC: 0.985046 (235 iterations)
# --- Fold 5 - MCC: 0.985095 (163 iterations)
#
# ------ Average MCC: 0.985053 ± 0.000133

# %% [markdown]
# # Results

# %%
scores = pd.DataFrame(scores)
mean_scores = scores.mean().sort_values(ascending=False)
order = scores.mean().sort_values(ascending=False).index.tolist()

min_score = mean_scores.min()
max_score = mean_scores.max()
padding = (max_score - min_score) * 0.5
lower_limit = min_score - padding
upper_limit = max_score + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 10))

sns.boxplot(data=scores, order=order, ax=axs[0], orient='h', palette="RdYlGn_r")
axs[0].set_title('Fold MCC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_scores.values, y=mean_scores.index, ax=axs[1], palette="RdYlGn_r")
axs[1].set_title('Average MCC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_scores.values):
    barplot.text(score, i, round(score, 6), va='center')

plt.tight_layout()
plt.show()
