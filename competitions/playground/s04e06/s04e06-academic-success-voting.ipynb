# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
train["is_train"] = True
test["is_train"] = False
combined = pd.concat([train, test], sort=False)

for col in combined.columns:
    counts = combined[col].value_counts()
    to_replace = counts[counts < 10].index
    if len(to_replace) > 0:
        max_val = combined[col].max()
        combined[col] = combined[col].replace(to_replace, max_val + 1)
        
train = combined[combined["is_train"]].drop(columns="is_train")
test = combined[~combined["is_train"]].drop(columns=["is_train", TARGET])

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.834096, AUC: 0.929961
# --- Fold 2 - Accuracy: 0.835141, AUC: 0.931980
# --- Fold 3 - Accuracy: 0.833769, AUC: 0.929411
# --- Fold 4 - Accuracy: 0.833170, AUC: 0.929665
# --- Fold 5 - Accuracy: 0.825851, AUC: 0.924036
#
# ------ Accuracy: 0.832405 ± 0.003339
# ------ AUC:      0.929011 ± 0.002648

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836383, AUC: 0.929961
# --- Fold 2 - Accuracy: 0.835468, AUC: 0.932082
# --- Fold 3 - Accuracy: 0.835272, AUC: 0.929505
# --- Fold 4 - Accuracy: 0.833170, AUC: 0.929313
# --- Fold 5 - Accuracy: 0.825982, AUC: 0.924274
#
# ------ Accuracy: 0.833255 ± 0.003786
# ------ AUC:      0.929027 ± 0.002573

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837101, AUC: 0.930630
# --- Fold 2 - Accuracy: 0.836056, AUC: 0.932537
# --- Fold 3 - Accuracy: 0.835533, AUC: 0.930054
# --- Fold 4 - Accuracy: 0.833889, AUC: 0.929663
# --- Fold 5 - Accuracy: 0.825067, AUC: 0.924481
#
# ------ Accuracy: 0.833529 ± 0.004357
# ------ AUC:      0.929473 ± 0.002684

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.833638, AUC: 0.929106
# --- Fold 2 - Accuracy: 0.836121, AUC: 0.930430
# --- Fold 3 - Accuracy: 0.832331, AUC: 0.927791
# --- Fold 4 - Accuracy: 0.829707, AUC: 0.928454
# --- Fold 5 - Accuracy: 0.824152, AUC: 0.923588
#
# ------ Accuracy: 0.831190 ± 0.004083
# ------ AUC:      0.927874 ± 0.002314

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834096, AUC: 0.929137
# --- Fold 2 - Accuracy: 0.832919, AUC: 0.930752
# --- Fold 3 - Accuracy: 0.832985, AUC: 0.928941
# --- Fold 4 - Accuracy: 0.831406, AUC: 0.929429
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924149
#
# ------ Accuracy: 0.831399 ± 0.003028
# ------ AUC:      0.928481 ± 0.002257

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.830110, AUC: 0.923149
# --- Fold 2 - Accuracy: 0.831547, AUC: 0.925091
# --- Fold 3 - Accuracy: 0.829130, AUC: 0.921426
# --- Fold 4 - Accuracy: 0.827027, AUC: 0.923402
# --- Fold 5 - Accuracy: 0.821800, AUC: 0.917529
#
# ------ Accuracy: 0.827923 ± 0.003396
# ------ AUC:      0.922120 ± 0.002572

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=5000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-11 04:59:51,191] A new study created in memory with name: no-name-d8208a9f-26b6-46c6-8363-77c93cb3fd07
# [I 2024-06-11 04:59:51,213] Trial 0 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.43985356878735826, 'cb_weight': 0.7957904563588319, 'lgbm_weight': 0.25959240143669027, 'hgb_weight': 0.06829135067332459, 'gb_weight': 0.2807276830168083, 'rf_weight': 0.10396010698454083}. Best is trial 0 with value: 0.8337907420476228.
# [I 2024-06-11 04:59:51,230] Trial 1 finished with value: 0.8333986774353747 and parameters: {'xgb_weight': 0.20463076864004015, 'cb_weight': 0.521543016757378, 'lgbm_weight': 0.40401295484409705, 'hgb_weight': 0.9112016813538184, 'gb_weight': 0.5962661710745152, 'rf_weight': 0.7824953598329196}. Best is trial 0 with value: 0.8337907420476228.
# [I 2024-06-11 04:59:51,247] Trial 2 finished with value: 0.833464021537416 and parameters: {'xgb_weight': 0.7278658220011488, 'cb_weight': 0.43813615052710797, 'lgbm_weight': 0.7086480972866932, 'hgb_weight': 0.01342442802056798, 'gb_weight': 0.7013120941589882, 'rf_weight': 0.057861205577308006}. Best is trial 0 with value: 0.8337907420476228.
# [I 2024-06-11 04:59:51,262] Trial 3 finished with value: 0.83366005384354 and parameters: {'xgb_weight': 0.03578521912047783, 'cb_weight': 0.6132670279833461, 'lgbm_weight': 0.17159076709272725, 'hgb_weight': 0.17949951055850788, 'gb_weight': 0.33511882564335327, 'rf_weight': 0.6960062276534873}. Best is trial 0 with value: 0.8337907420476228.
# [I 2024-06-11 04:59:51,280] Trial 4 finished with value: 0.8336861914843566 and parameters: {'xgb_weight': 0.3346518021406846, 'cb_weight': 0.9261858815246499, 'lgbm_weight': 0.22974483397492784, 'hgb_weight': 0.31957086227104825, 'gb_weight': 0.07295630456757374, 'rf_weight': 0.901207821593088}. Best is trial 0 with value: 0.8337907420476228.
# [I 2024-06-11 04:59:51,296] Trial 5 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.3049747677071136, 'cb_weight': 0.8931621365018354, 'lgbm_weight': 0.7474597043254408, 'hgb_weight': 0.8805583556511112, 'gb_weight': 0.9743869963771163, 'rf_weight': 0.8155491079446362}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,317] Trial 6 finished with value: 0.8336861914843566 and parameters: {'xgb_weight': 0.8248056229860612, 'cb_weight': 0.19053930895397497, 'lgbm_weight': 0.7632717404695857, 'hgb_weight': 0.4686982367087603, 'gb_weight': 0.21883787717718606, 'rf_weight': 0.0630709139099167}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,333] Trial 7 finished with value: 0.8333594709741499 and parameters: {'xgb_weight': 0.8285726751769968, 'cb_weight': 0.4929084602270888, 'lgbm_weight': 0.06327912449760298, 'hgb_weight': 0.40514334626035586, 'gb_weight': 0.39430032416879846, 'rf_weight': 0.04472233815689186}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,349] Trial 8 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.32547502788908744, 'cb_weight': 0.4580537467638328, 'lgbm_weight': 0.7119007439977811, 'hgb_weight': 0.18631377306956354, 'gb_weight': 0.3592134830944279, 'rf_weight': 0.17442460396765547}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,365] Trial 9 finished with value: 0.8335685721006821 and parameters: {'xgb_weight': 0.8292763521422472, 'cb_weight': 0.46828421902900885, 'lgbm_weight': 0.5313386822307394, 'hgb_weight': 0.15502007189206213, 'gb_weight': 0.8146255375883881, 'rf_weight': 0.645457761956481}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,425] Trial 10 finished with value: 0.8336339162027235 and parameters: {'xgb_weight': 0.6095766020797799, 'cb_weight': 0.9992552055143539, 'lgbm_weight': 0.9447969789509825, 'hgb_weight': 0.833389478453494, 'gb_weight': 0.9854305959546334, 'rf_weight': 0.38290461505239404}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,490] Trial 11 finished with value: 0.8335162968190492 and parameters: {'xgb_weight': 0.24456599928586492, 'cb_weight': 0.21473657129308166, 'lgbm_weight': 0.701797180362064, 'hgb_weight': 0.71158046970673, 'gb_weight': 0.5090533860613291, 'rf_weight': 0.3750781767211888}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,550] Trial 12 finished with value: 0.8337253979455814 and parameters: {'xgb_weight': 0.5006270126491921, 'cb_weight': 0.7010723345173923, 'lgbm_weight': 0.9231172079250596, 'hgb_weight': 0.6538774912642469, 'gb_weight': 0.96237034029522, 'rf_weight': 0.2834441988735178}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,609] Trial 13 finished with value: 0.8330327504639431 and parameters: {'xgb_weight': 0.05004315407925708, 'cb_weight': 0.02838800959590171, 'lgbm_weight': 0.5650710953269806, 'hgb_weight': 0.9863384340919354, 'gb_weight': 0.024998537312128644, 'rf_weight': 0.5490904684084637}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,669] Trial 14 finished with value: 0.8333986774353747 and parameters: {'xgb_weight': 0.37403369204999837, 'cb_weight': 0.30132195770630754, 'lgbm_weight': 0.8293596933796759, 'hgb_weight': 0.6482677496055513, 'gb_weight': 0.7433069112959824, 'rf_weight': 0.9818791481652503}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,732] Trial 15 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.1853240677290861, 'cb_weight': 0.8274825500711543, 'lgbm_weight': 0.6256378628780135, 'hgb_weight': 0.27101462086914824, 'gb_weight': 0.510489232559652, 'rf_weight': 0.244710824528548}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,797] Trial 16 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.5474389882989359, 'cb_weight': 0.6677022744145161, 'lgbm_weight': 0.3541982571451059, 'hgb_weight': 0.5670505753214603, 'gb_weight': 0.17844173233617688, 'rf_weight': 0.4833655516915536}. Best is trial 5 with value: 0.8339083614312972.
# [I 2024-06-11 04:59:51,857] Trial 17 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.5826130839360626, 'cb_weight': 0.7169944947321337, 'lgbm_weight': 0.379877714548417, 'hgb_weight': 0.7779355355986967, 'gb_weight': 0.16398589487924276, 'rf_weight': 0.5213279973583286}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:51,916] Trial 18 finished with value: 0.8336992603047649 and parameters: {'xgb_weight': 0.9900774866187416, 'cb_weight': 0.8298344518939711, 'lgbm_weight': 0.39834843108292667, 'hgb_weight': 0.7632810084385809, 'gb_weight': 0.8701626318359873, 'rf_weight': 0.8449030681566114}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:51,976] Trial 19 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.6377175773316901, 'cb_weight': 0.7337250137196357, 'lgbm_weight': 0.48094920380786216, 'hgb_weight': 0.8738101758117103, 'gb_weight': 0.6593695462537517, 'rf_weight': 0.6396843890583596}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,036] Trial 20 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.6630649370767506, 'cb_weight': 0.743748021248257, 'lgbm_weight': 0.4494114027498443, 'hgb_weight': 0.994001777590908, 'gb_weight': 0.6156694741108781, 'rf_weight': 0.5911471375915633}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,105] Trial 21 finished with value: 0.8338168796884393 and parameters: {'xgb_weight': 0.646393418065879, 'cb_weight': 0.6125404009859885, 'lgbm_weight': 0.4609861263305217, 'hgb_weight': 0.9864365390644643, 'gb_weight': 0.6251790065930661, 'rf_weight': 0.5644785939328665}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,166] Trial 22 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.7246638771109153, 'cb_weight': 0.7293316649214638, 'lgbm_weight': 0.3132106080795108, 'hgb_weight': 0.8062819335491641, 'gb_weight': 0.6157859642195369, 'rf_weight': 0.6687963313474137}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,225] Trial 23 finished with value: 0.8338168796884393 and parameters: {'xgb_weight': 0.6195818633900393, 'cb_weight': 0.7565676052189857, 'lgbm_weight': 0.44284581599389705, 'hgb_weight': 0.9069490394943307, 'gb_weight': 0.4096299944274914, 'rf_weight': 0.44406946095230926}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,281] Trial 24 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.7438939628211396, 'cb_weight': 0.6144454557158272, 'lgbm_weight': 0.6007440524218137, 'hgb_weight': 0.7633813154058472, 'gb_weight': 0.46304094089669867, 'rf_weight': 0.5925128701932769}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,343] Trial 25 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.9372522151945325, 'cb_weight': 0.8982548526996328, 'lgbm_weight': 0.4886725626484962, 'hgb_weight': 0.9830139236968379, 'gb_weight': 0.6830711406011372, 'rf_weight': 0.7423067397835054}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,402] Trial 26 finished with value: 0.8336469850231318 and parameters: {'xgb_weight': 0.5525275359662163, 'cb_weight': 0.5557381019925214, 'lgbm_weight': 0.15273568738621413, 'hgb_weight': 0.5736662699394366, 'gb_weight': 0.5679260603883239, 'rf_weight': 0.4064598954255376}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,465] Trial 27 finished with value: 0.8333725397945582 and parameters: {'xgb_weight': 0.44789538117508704, 'cb_weight': 0.3472069588446511, 'lgbm_weight': 0.2819196815533853, 'hgb_weight': 0.8773465655127822, 'gb_weight': 0.7749087177071698, 'rf_weight': 0.5190905415116962}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,525] Trial 28 finished with value: 0.833607778561907 and parameters: {'xgb_weight': 0.6795464187053716, 'cb_weight': 0.671673840487004, 'lgbm_weight': 0.3532111546715057, 'hgb_weight': 0.6856953443146336, 'gb_weight': 0.884479901195943, 'rf_weight': 0.6069553708125154}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,583] Trial 29 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.4378512129552218, 'cb_weight': 0.7892729650757961, 'lgbm_weight': 0.6315562812965896, 'hgb_weight': 0.824019305831993, 'gb_weight': 0.24099354200746959, 'rf_weight': 0.7193097932595374}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,644] Trial 30 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.4529940787344567, 'cb_weight': 0.807403190397219, 'lgbm_weight': 0.6332707926071343, 'hgb_weight': 0.5716155884551974, 'gb_weight': 0.13185374143381623, 'rf_weight': 0.7310926592336012}. Best is trial 17 with value: 0.8339606367129303.
# [I 2024-06-11 04:59:52,702] Trial 31 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.5484949708811788, 'cb_weight': 0.7686072895893927, 'lgbm_weight': 0.4792847559275038, 'hgb_weight': 0.8176211470235046, 'gb_weight': 0.25507136363981364, 'rf_weight': 0.6383145688728888}. Best is trial 31 with value: 0.8340129119945634.
# [I 2024-06-11 04:59:52,761] Trial 32 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.5340874148570299, 'cb_weight': 0.9618779956525133, 'lgbm_weight': 0.5331261455881299, 'hgb_weight': 0.7996247928024359, 'gb_weight': 0.26217949509076915, 'rf_weight': 0.6574681492104514}. Best is trial 31 with value: 0.8340129119945634.
# [I 2024-06-11 04:59:52,818] Trial 33 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.5544884253892887, 'cb_weight': 0.9303840309276988, 'lgbm_weight': 0.5428894862080438, 'hgb_weight': 0.7537641323734253, 'gb_weight': 0.273737647120421, 'rf_weight': 0.7665526987738635}. Best is trial 31 with value: 0.8340129119945634.
# [I 2024-06-11 04:59:52,877] Trial 34 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.40123796947119783, 'cb_weight': 0.9740234770620566, 'lgbm_weight': 0.6464673322842371, 'hgb_weight': 0.8116116322229383, 'gb_weight': 0.2846389970886048, 'rf_weight': 0.7003153972845317}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:52,940] Trial 35 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.4006190247943661, 'cb_weight': 0.8532196043798824, 'lgbm_weight': 0.8406879988454253, 'hgb_weight': 0.9239347552487992, 'gb_weight': 0.19738826656573483, 'rf_weight': 0.851687664812546}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,001] Trial 36 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.24837602906381984, 'cb_weight': 0.8733578780842459, 'lgbm_weight': 0.6501572356897999, 'hgb_weight': 0.63510196734314, 'gb_weight': 0.12717721527260026, 'rf_weight': 0.8987688152867733}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,060] Trial 37 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.4024322221570835, 'cb_weight': 0.5517484026045314, 'lgbm_weight': 0.18941245314667074, 'hgb_weight': 0.8232403892168891, 'gb_weight': 0.2956668067542521, 'rf_weight': 0.48959603702536353}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,119] Trial 38 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.48569118288318264, 'cb_weight': 0.7813377211047009, 'lgbm_weight': 0.392717178136143, 'hgb_weight': 0.7328563875298655, 'gb_weight': 0.07601558953350222, 'rf_weight': 0.7006296788778806}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,179] Trial 39 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.131611256478239, 'cb_weight': 0.960276085854213, 'lgbm_weight': 0.7868165319942676, 'hgb_weight': 0.49428259710809935, 'gb_weight': 0.32129592708116084, 'rf_weight': 0.8218835870767928}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,239] Trial 40 finished with value: 0.8338168796884393 and parameters: {'xgb_weight': 0.30293927937797605, 'cb_weight': 0.6273795154437735, 'lgbm_weight': 0.675910052935808, 'hgb_weight': 0.9379936950332066, 'gb_weight': 0.23320408130842823, 'rf_weight': 0.7846775030468475}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,303] Trial 41 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.5024297621277154, 'cb_weight': 0.9865403225567009, 'lgbm_weight': 0.5894695577535087, 'hgb_weight': 0.8169115449678912, 'gb_weight': 0.25457442909951455, 'rf_weight': 0.7159341905179842}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,367] Trial 42 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.49614088891022956, 'cb_weight': 0.9826026564336837, 'lgbm_weight': 0.5994078642488994, 'hgb_weight': 0.8500670974977755, 'gb_weight': 0.1427640982560711, 'rf_weight': 0.7062382547114102}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,431] Trial 43 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.5932151539454799, 'cb_weight': 0.9805903709306479, 'lgbm_weight': 0.5697849066554096, 'hgb_weight': 0.8668676175061772, 'gb_weight': 0.15777139206613694, 'rf_weight': 0.6219449681486054}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,493] Trial 44 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.5050428059275667, 'cb_weight': 0.9782067014485444, 'lgbm_weight': 0.5901589580857156, 'hgb_weight': 0.8600858804261162, 'gb_weight': 0.0028189866116988815, 'rf_weight': 0.6861147969911175}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,556] Trial 45 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.3546159045613149, 'cb_weight': 0.9153829097505175, 'lgbm_weight': 0.7011207018981738, 'hgb_weight': 0.7013665015660961, 'gb_weight': 0.09702086108251796, 'rf_weight': 0.7820906751426688}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,622] Trial 46 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.48047035742167205, 'cb_weight': 0.9941046115804734, 'lgbm_weight': 0.5726975270451846, 'hgb_weight': 0.9263531122003636, 'gb_weight': 0.3726602026989708, 'rf_weight': 0.6193322438176386}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,684] Trial 47 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.7209027001131343, 'cb_weight': 0.9295866711366627, 'lgbm_weight': 0.5169779886489766, 'hgb_weight': 0.9367756383981949, 'gb_weight': 0.36736724439912766, 'rf_weight': 0.6306552837842014}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,746] Trial 48 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.5910653303665325, 'cb_weight': 0.8829746987560102, 'lgbm_weight': 0.5586718069901057, 'hgb_weight': 0.9091416056910553, 'gb_weight': 0.39869133959004344, 'rf_weight': 0.5508643379025114}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,807] Trial 49 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.7891636265627391, 'cb_weight': 0.9953110936471948, 'lgbm_weight': 0.7736693414390008, 'hgb_weight': 0.06218521460142756, 'gb_weight': 0.32739234312680493, 'rf_weight': 0.8954099790881176}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,868] Trial 50 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.2853281035783234, 'cb_weight': 0.8480528392505748, 'lgbm_weight': 0.7400877755104973, 'hgb_weight': 0.3416696010013379, 'gb_weight': 0.4544707122987921, 'rf_weight': 0.4503382203900824}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,929] Trial 51 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.47863343016343984, 'cb_weight': 0.9503375995981165, 'lgbm_weight': 0.6037215014399271, 'hgb_weight': 0.8474272144235044, 'gb_weight': 0.20856262410444293, 'rf_weight': 0.691258711070246}. Best is trial 34 with value: 0.8340782560966047.
# [I 2024-06-11 04:59:53,989] Trial 52 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.5104875566641555, 'cb_weight': 0.9911827485383927, 'lgbm_weight': 0.5733941094623719, 'hgb_weight': 0.9481962958257811, 'gb_weight': 0.16365827856613224, 'rf_weight': 0.6235963917129952}. Best is trial 52 with value: 0.8341043937374213.
# [I 2024-06-11 04:59:54,050] Trial 53 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.4017400049097621, 'cb_weight': 0.895555821664781, 'lgbm_weight': 0.681517384546248, 'hgb_weight': 0.9507688705513777, 'gb_weight': 0.28679235683808135, 'rf_weight': 0.6219873381822657}. Best is trial 52 with value: 0.8341043937374213.
# [I 2024-06-11 04:59:54,114] Trial 54 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.40248894725770407, 'cb_weight': 0.8936593501170463, 'lgbm_weight': 0.6678180409811675, 'hgb_weight': 0.950047662871792, 'gb_weight': 0.3078282195928834, 'rf_weight': 0.6236845755397458}. Best is trial 52 with value: 0.8341043937374213.
# [I 2024-06-11 04:59:54,181] Trial 55 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.396381729478946, 'cb_weight': 0.9029748551704669, 'lgbm_weight': 0.6667191880473242, 'hgb_weight': 0.9515359644015218, 'gb_weight': 0.3162713356103795, 'rf_weight': 0.5961525670314071}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,244] Trial 56 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.3674761798689844, 'cb_weight': 0.9014657252396175, 'lgbm_weight': 0.6677548906192383, 'hgb_weight': 0.9967336491922537, 'gb_weight': 0.3018504419529271, 'rf_weight': 0.5887126894505134}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,303] Trial 57 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.3751100859980023, 'cb_weight': 0.9277507332395848, 'lgbm_weight': 0.822593163925373, 'hgb_weight': 0.9692971192263944, 'gb_weight': 0.051112787397068066, 'rf_weight': 0.57317226671256}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,366] Trial 58 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.33495212803977537, 'cb_weight': 0.8629001636593265, 'lgbm_weight': 0.8439037735676859, 'hgb_weight': 0.9982054661424028, 'gb_weight': 0.039764635934610215, 'rf_weight': 0.5769368762712734}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,426] Trial 59 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.3564112211624354, 'cb_weight': 0.8200744762208911, 'lgbm_weight': 0.9998146299941275, 'hgb_weight': 0.9611382918229134, 'gb_weight': 0.10185781918378822, 'rf_weight': 0.3326878667403384}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,493] Trial 60 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.254032059699249, 'cb_weight': 0.928364375666053, 'lgbm_weight': 0.9062931213860076, 'hgb_weight': 0.8938963256499094, 'gb_weight': 0.4458330133582322, 'rf_weight': 0.49704044306438866}. Best is trial 55 with value: 0.8341174625578295.
# [I 2024-06-11 04:59:54,558] Trial 61 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.25792294566302465, 'cb_weight': 0.9290884034535067, 'lgbm_weight': 0.8916434774304492, 'hgb_weight': 0.8974708137002008, 'gb_weight': 0.34178060449580583, 'rf_weight': 0.5390794291121636}. Best is trial 61 with value: 0.8341436001986461.
# [I 2024-06-11 04:59:54,621] Trial 62 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.15342607793239194, 'cb_weight': 0.8991495433357617, 'lgbm_weight': 0.9283423620260246, 'hgb_weight': 0.8969854455675395, 'gb_weight': 0.4361283630387297, 'rf_weight': 0.5251052665718347}. Best is trial 62 with value: 0.8341566690190544.
# [I 2024-06-11 04:59:54,683] Trial 63 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.09430444554009054, 'cb_weight': 0.9286754968589829, 'lgbm_weight': 0.9030791450657616, 'hgb_weight': 0.9071769182930354, 'gb_weight': 0.4377684653616464, 'rf_weight': 0.4561600523966563}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:54,749] Trial 64 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.12938099085372917, 'cb_weight': 0.8297523181754204, 'lgbm_weight': 0.8986176492975512, 'hgb_weight': 0.9058536912238978, 'gb_weight': 0.4485278628080208, 'rf_weight': 0.4636042282632702}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:54,812] Trial 65 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.08798379282484137, 'cb_weight': 0.8463821509395175, 'lgbm_weight': 0.8966187072057274, 'hgb_weight': 0.8821543892140847, 'gb_weight': 0.5408980128919503, 'rf_weight': 0.44732538245278786}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:54,875] Trial 66 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.0010643828099183572, 'cb_weight': 0.8363183834817182, 'lgbm_weight': 0.898044752148833, 'hgb_weight': 0.9019537879527749, 'gb_weight': 0.5313668509664419, 'rf_weight': 0.449071738877967}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:54,938] Trial 67 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.009638536402705166, 'cb_weight': 0.6859447407181998, 'lgbm_weight': 0.8896336780258564, 'hgb_weight': 0.8932852738864826, 'gb_weight': 0.4449929815372534, 'rf_weight': 0.3958217223560146}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,002] Trial 68 finished with value: 0.8336339162027235 and parameters: {'xgb_weight': 0.1786592747171869, 'cb_weight': 0.15820076704221941, 'lgbm_weight': 0.9936567245153515, 'hgb_weight': 0.9029900778647567, 'gb_weight': 0.42974675812532476, 'rf_weight': 0.520410578136096}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,064] Trial 69 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.08275093417214717, 'cb_weight': 0.40989828801371375, 'lgbm_weight': 0.9508857464210161, 'hgb_weight': 0.7876315904048966, 'gb_weight': 0.475480488099333, 'rf_weight': 0.3570212995496612}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,136] Trial 70 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.16153653326547018, 'cb_weight': 0.9406313194476219, 'lgbm_weight': 0.887027189600236, 'hgb_weight': 0.8913916797004515, 'gb_weight': 0.5047380017578971, 'rf_weight': 0.2972178617087427}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,202] Trial 71 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.10193362341392752, 'cb_weight': 0.8392012181470737, 'lgbm_weight': 0.9113191371165663, 'hgb_weight': 0.8782504065826604, 'gb_weight': 0.5749114994415863, 'rf_weight': 0.42378761451217145}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,264] Trial 72 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.06235743800338703, 'cb_weight': 0.8044253462905138, 'lgbm_weight': 0.8688476098309951, 'hgb_weight': 0.8396641452181737, 'gb_weight': 0.5252477620322379, 'rf_weight': 0.4637467369023942}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,327] Trial 73 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.23113708897120847, 'cb_weight': 0.8689716182338078, 'lgbm_weight': 0.9528740442107231, 'hgb_weight': 0.9138881909646522, 'gb_weight': 0.5370740776265562, 'rf_weight': 0.484390682641135}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,391] Trial 74 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.1282355298872218, 'cb_weight': 0.7579096757157995, 'lgbm_weight': 0.9267171039323318, 'hgb_weight': 0.7446962121486269, 'gb_weight': 0.4787410708214019, 'rf_weight': 0.42902957234196015}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,454] Trial 75 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.002179872553903673, 'cb_weight': 0.8297663909043823, 'lgbm_weight': 0.8091366729845547, 'hgb_weight': 0.7781328115299004, 'gb_weight': 0.5467068691411718, 'rf_weight': 0.5176012655340437}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,520] Trial 76 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.21960376073224874, 'cb_weight': 0.7904814267130826, 'lgbm_weight': 0.971140883486072, 'hgb_weight': 0.8773688866679176, 'gb_weight': 0.4215619334729705, 'rf_weight': 0.5394944032998874}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,583] Trial 77 finished with value: 0.8337646044068062 and parameters: {'xgb_weight': 0.034370047449305295, 'cb_weight': 0.9164813501243455, 'lgbm_weight': 0.8676488940863163, 'hgb_weight': 0.9605945180291597, 'gb_weight': 0.3815399583805745, 'rf_weight': 0.0023042002506428183}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,649] Trial 78 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.27593769405713603, 'cb_weight': 0.9475277589880083, 'lgbm_weight': 0.9093182950645846, 'hgb_weight': 0.21191905536253897, 'gb_weight': 0.4876349173417811, 'rf_weight': 0.46157383361361914}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,711] Trial 79 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.1495593797959246, 'cb_weight': 0.8612085774517363, 'lgbm_weight': 0.734857005095881, 'hgb_weight': 0.8476618640082788, 'gb_weight': 0.6394246346751493, 'rf_weight': 0.35510245724642775}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,774] Trial 80 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.1940666731838551, 'cb_weight': 0.8178783911641303, 'lgbm_weight': 0.8566783684026475, 'hgb_weight': 0.4325796856625028, 'gb_weight': 0.34948065385465715, 'rf_weight': 0.49935057911555936}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,836] Trial 81 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.060502365769573914, 'cb_weight': 0.7185500932181347, 'lgbm_weight': 0.8753088981574031, 'hgb_weight': 0.8377926250843678, 'gb_weight': 0.5281595907047845, 'rf_weight': 0.46101991950936194}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,898] Trial 82 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.0822037364116476, 'cb_weight': 0.8018335205723781, 'lgbm_weight': 0.8004127213011134, 'hgb_weight': 0.9199174356474429, 'gb_weight': 0.5843709401842456, 'rf_weight': 0.4064760483478032}. Best is trial 63 with value: 0.8342220131210957.
# [I 2024-06-11 04:59:55,963] Trial 83 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.029963254185657706, 'cb_weight': 0.8861165705430298, 'lgbm_weight': 0.9337805453738205, 'hgb_weight': 0.869131841647671, 'gb_weight': 0.43832460099436776, 'rf_weight': 0.4738429755281218}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,028] Trial 84 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.10618791366270254, 'cb_weight': 0.9070696303617147, 'lgbm_weight': 0.931138056272576, 'hgb_weight': 0.8939283282876418, 'gb_weight': 0.4027471476980266, 'rf_weight': 0.5429006853203144}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,097] Trial 85 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.12513683770495826, 'cb_weight': 0.8828431704129516, 'lgbm_weight': 0.9376612604541372, 'hgb_weight': 0.9735922516283649, 'gb_weight': 0.34679711950260605, 'rf_weight': 0.5467352841252819}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,166] Trial 86 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.12400816241331394, 'cb_weight': 0.8854315375170508, 'lgbm_weight': 0.9329362825636955, 'hgb_weight': 0.9296761350528427, 'gb_weight': 0.33946419581724047, 'rf_weight': 0.56243504479096}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,230] Trial 87 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.034680315591239595, 'cb_weight': 0.8819189986812405, 'lgbm_weight': 0.9347010114235017, 'hgb_weight': 0.9247212542432496, 'gb_weight': 0.38985938164529543, 'rf_weight': 0.542219715842068}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,290] Trial 88 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.03250513594821124, 'cb_weight': 0.9566615272473984, 'lgbm_weight': 0.9724705677092637, 'hgb_weight': 0.9774386375290218, 'gb_weight': 0.40082291254894004, 'rf_weight': 0.5308367687842088}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,364] Trial 89 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.044683742853215615, 'cb_weight': 0.9610374214560254, 'lgbm_weight': 0.9669591181637147, 'hgb_weight': 0.9795989928007511, 'gb_weight': 0.41162885624961165, 'rf_weight': 0.526414886123648}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,429] Trial 90 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.03079071018112554, 'cb_weight': 0.9608437195751428, 'lgbm_weight': 0.9680971709924552, 'hgb_weight': 0.9773543747568555, 'gb_weight': 0.4023802260795271, 'rf_weight': 0.5299836962398211}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,493] Trial 91 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.031021985450555692, 'cb_weight': 0.9614324013027183, 'lgbm_weight': 0.9416629349343558, 'hgb_weight': 0.9742385186023209, 'gb_weight': 0.4018881399748228, 'rf_weight': 0.5411472460701248}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,556] Trial 92 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.033390374208358574, 'cb_weight': 0.9647246612169184, 'lgbm_weight': 0.9703435050122579, 'hgb_weight': 0.9714780030656642, 'gb_weight': 0.4072664736311295, 'rf_weight': 0.47358118264917104}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,624] Trial 93 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.032693091676048266, 'cb_weight': 0.9635303461795337, 'lgbm_weight': 0.9724038557667323, 'hgb_weight': 0.9783256688346067, 'gb_weight': 0.4089706510065899, 'rf_weight': 0.17744155854368304}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,690] Trial 94 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.03008354716586374, 'cb_weight': 0.9555704159038361, 'lgbm_weight': 0.95139050231841, 'hgb_weight': 0.9789549012443998, 'gb_weight': 0.3944193810137679, 'rf_weight': 0.5550424683541785}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,757] Trial 95 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.102805621966793, 'cb_weight': 0.9583909615957357, 'lgbm_weight': 0.9767910578291493, 'hgb_weight': 0.9990456683484151, 'gb_weight': 0.3737436835838388, 'rf_weight': 0.47886404837633717}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,821] Trial 96 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.05228058759645327, 'cb_weight': 0.9992777140578843, 'lgbm_weight': 0.98116702949859, 'hgb_weight': 0.9765443061365995, 'gb_weight': 0.41844102997306654, 'rf_weight': 0.5065394537287153}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,883] Trial 97 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.06517464805794448, 'cb_weight': 0.9990419046475181, 'lgbm_weight': 0.9985809133863479, 'hgb_weight': 0.9392491570525204, 'gb_weight': 0.3595399507219087, 'rf_weight': 0.5016316339623477}. Best is trial 83 with value: 0.8343004260435453.
# [I 2024-06-11 04:59:56,949] Trial 98 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.06287077446644324, 'cb_weight': 0.9144174794591342, 'lgbm_weight': 0.9962684449208037, 'hgb_weight': 0.9379053252680541, 'gb_weight': 0.3590201321100126, 'rf_weight': 0.5051466928598408}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,011] Trial 99 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.07139491147281563, 'cb_weight': 0.9945907558467726, 'lgbm_weight': 0.9997771526173846, 'hgb_weight': 0.9448619175710846, 'gb_weight': 0.36031109604796924, 'rf_weight': 0.4235306390565322}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,077] Trial 100 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.059860524877681766, 'cb_weight': 0.9960770556261801, 'lgbm_weight': 0.9865928203390681, 'hgb_weight': 0.9426854486831556, 'gb_weight': 0.35920067130398453, 'rf_weight': 0.41640809153563446}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,149] Trial 101 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.06583888222042376, 'cb_weight': 0.9934594237774352, 'lgbm_weight': 0.9959660761246593, 'hgb_weight': 0.9442018827612741, 'gb_weight': 0.36109678514691046, 'rf_weight': 0.42349790308083474}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,212] Trial 102 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.06280875186056514, 'cb_weight': 0.9954931928823213, 'lgbm_weight': 0.9998700171617422, 'hgb_weight': 0.9481292097256605, 'gb_weight': 0.3641002231136921, 'rf_weight': 0.42337362149408386}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,274] Trial 103 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.07305346204235516, 'cb_weight': 0.9768438202634726, 'lgbm_weight': 0.9883904166012587, 'hgb_weight': 0.9471824691212908, 'gb_weight': 0.461622706731364, 'rf_weight': 0.37902779603621434}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,336] Trial 104 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.09718629684135818, 'cb_weight': 0.997418599100664, 'lgbm_weight': 0.9538407077940728, 'hgb_weight': 0.85904440533907, 'gb_weight': 0.3728639059537588, 'rf_weight': 0.4245859144821068}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,406] Trial 105 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.10552309141567698, 'cb_weight': 0.9978812742085678, 'lgbm_weight': 0.9532639359038118, 'hgb_weight': 0.8553479303709011, 'gb_weight': 0.3664837059942512, 'rf_weight': 0.42434783939503706}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,475] Trial 106 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.09814445766140399, 'cb_weight': 0.9984973841099641, 'lgbm_weight': 0.9606910391870929, 'hgb_weight': 0.8623198144895221, 'gb_weight': 0.31928088376825275, 'rf_weight': 0.4222047698806037}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,541] Trial 107 finished with value: 0.833411746255783 and parameters: {'xgb_weight': 0.10202409972421808, 'cb_weight': 0.9148758121549241, 'lgbm_weight': 0.06222956198274521, 'hgb_weight': 0.8573923638077156, 'gb_weight': 0.3272338334235123, 'rf_weight': 0.40719050896328535}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,605] Trial 108 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.11196152630991907, 'cb_weight': 0.9773525852134406, 'lgbm_weight': 0.9225028945664155, 'hgb_weight': 0.8049723442881127, 'gb_weight': 0.2789708430241583, 'rf_weight': 0.3232661107179225}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,669] Trial 109 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.05148690008463849, 'cb_weight': 0.9362964243168391, 'lgbm_weight': 0.9564852494763761, 'hgb_weight': 0.8577544586332723, 'gb_weight': 0.3045711557976687, 'rf_weight': 0.3624798425531386}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,736] Trial 110 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.1719714193796839, 'cb_weight': 0.99869995745251, 'lgbm_weight': 0.9859007183317573, 'hgb_weight': 0.8261137697111561, 'gb_weight': 0.3275980096594755, 'rf_weight': 0.3835585337360569}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,805] Trial 111 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.14876469277571108, 'cb_weight': 0.9999703906013084, 'lgbm_weight': 0.9953487579413616, 'hgb_weight': 0.9370185895443477, 'gb_weight': 0.3637434920094665, 'rf_weight': 0.42691416627899403}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,873] Trial 112 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.14179591295625685, 'cb_weight': 0.9790917290298212, 'lgbm_weight': 0.9542311760774544, 'hgb_weight': 0.8738540556675066, 'gb_weight': 0.37335741073959083, 'rf_weight': 0.4277875793199431}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:57,940] Trial 113 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.08535200060001355, 'cb_weight': 0.9130219952283335, 'lgbm_weight': 0.9799006038712894, 'hgb_weight': 0.9185234061686409, 'gb_weight': 0.4259196170361218, 'rf_weight': 0.39586461594782446}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,005] Trial 114 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.008282798908128473, 'cb_weight': 0.9373848290761357, 'lgbm_weight': 0.9626244562696726, 'hgb_weight': 0.5329575127224545, 'gb_weight': 0.2285772880872252, 'rf_weight': 0.3349527465345786}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,074] Trial 115 finished with value: 0.8334248150761913 and parameters: {'xgb_weight': 0.20076894741070456, 'cb_weight': 0.019279414553508678, 'lgbm_weight': 0.9196447827993427, 'hgb_weight': 0.930458636907902, 'gb_weight': 0.3579754874062913, 'rf_weight': 0.43527549600736515}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,140] Trial 116 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.11488650498317543, 'cb_weight': 0.977940534143954, 'lgbm_weight': 0.9427513971892932, 'hgb_weight': 0.9558074741836607, 'gb_weight': 0.3844784231498432, 'rf_weight': 0.4782443943608884}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,205] Trial 117 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.05404011406918062, 'cb_weight': 0.9431210275257113, 'lgbm_weight': 0.9855768112224996, 'hgb_weight': 0.6031456257411039, 'gb_weight': 0.25020350815714587, 'rf_weight': 0.41874795272517}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,274] Trial 118 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.15044083165661878, 'cb_weight': 0.9983795826512957, 'lgbm_weight': 0.9199264066464313, 'hgb_weight': 0.8657274402832793, 'gb_weight': 0.26876712770382705, 'rf_weight': 0.5051515516971163}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,337] Trial 119 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.09226891024181876, 'cb_weight': 0.9763840168973053, 'lgbm_weight': 0.8523648850319789, 'hgb_weight': 0.9994014657863023, 'gb_weight': 0.3234882731193102, 'rf_weight': 0.2603381714623628}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,406] Trial 120 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.015947462885587703, 'cb_weight': 0.9052415837964065, 'lgbm_weight': 0.9987661802429099, 'hgb_weight': 0.7961628775852941, 'gb_weight': 0.29761037792452283, 'rf_weight': 0.37485994498136727}. Best is trial 98 with value: 0.8343527013251784.
# [I 2024-06-11 04:59:58,471] Trial 121 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.01830907963149186, 'cb_weight': 0.9445843247091782, 'lgbm_weight': 0.9571769773213676, 'hgb_weight': 0.7992117026073452, 'gb_weight': 0.30105184625298337, 'rf_weight': 0.38107487314786037}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,539] Trial 122 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.06104515193575892, 'cb_weight': 0.9111045849083582, 'lgbm_weight': 0.995476977642782, 'hgb_weight': 0.7946328505802077, 'gb_weight': 0.29113080786991935, 'rf_weight': 0.3143387618288709}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,607] Trial 123 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.008139793170757414, 'cb_weight': 0.9479690157392444, 'lgbm_weight': 0.9460991180761665, 'hgb_weight': 0.7614419833954078, 'gb_weight': 0.3382992953673424, 'rf_weight': 0.34653095655261634}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,674] Trial 124 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.018506024643101755, 'cb_weight': 0.9358740871597031, 'lgbm_weight': 0.9555208834279836, 'hgb_weight': 0.7151253697069484, 'gb_weight': 0.3105079287861047, 'rf_weight': 0.3477938132135979}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,740] Trial 125 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.016749159817725116, 'cb_weight': 0.9303824514332308, 'lgbm_weight': 0.9569505803219776, 'hgb_weight': 0.6965974305583178, 'gb_weight': 0.3039312213377984, 'rf_weight': 0.2853491664659879}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,807] Trial 126 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.017677306376636684, 'cb_weight': 0.9428317509071381, 'lgbm_weight': 0.8810131751406935, 'hgb_weight': 0.7715533553193129, 'gb_weight': 0.19780361195951854, 'rf_weight': 0.3475888437307838}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,878] Trial 127 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.0041934665285464495, 'cb_weight': 0.9471231591639974, 'lgbm_weight': 0.8756323092226547, 'hgb_weight': 0.7625563824499918, 'gb_weight': 0.19338220708221232, 'rf_weight': 0.356321366133848}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:58,948] Trial 128 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.017754381119161312, 'cb_weight': 0.867352817812558, 'lgbm_weight': 0.8765499613934624, 'hgb_weight': 0.7253981230612458, 'gb_weight': 0.19025729413722403, 'rf_weight': 0.35322606618255703}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:59,017] Trial 129 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.014304831437471209, 'cb_weight': 0.8742066485656212, 'lgbm_weight': 0.876191231208333, 'hgb_weight': 0.725263988630102, 'gb_weight': 0.188453685822897, 'rf_weight': 0.35070652712809003}. Best is trial 121 with value: 0.834378838965995.
# [I 2024-06-11 04:59:59,086] Trial 130 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.002829856080471512, 'cb_weight': 0.8550901376192069, 'lgbm_weight': 0.8211306625594346, 'hgb_weight': 0.7277609457855235, 'gb_weight': 0.19598084944146132, 'rf_weight': 0.36338287412437403}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,152] Trial 131 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.013633695531999942, 'cb_weight': 0.8643756534322373, 'lgbm_weight': 0.8330387599664665, 'hgb_weight': 0.6681208134952178, 'gb_weight': 0.19520798217271304, 'rf_weight': 0.3443071201331446}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,217] Trial 132 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.0036688364635356456, 'cb_weight': 0.8607799248139663, 'lgbm_weight': 0.8766921634921272, 'hgb_weight': 0.7229031287183356, 'gb_weight': 0.20815976973134637, 'rf_weight': 0.3455616497546513}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,280] Trial 133 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 4.231157949500554e-05, 'cb_weight': 0.8634309906134946, 'lgbm_weight': 0.8303865137113371, 'hgb_weight': 0.6634917865134292, 'gb_weight': 0.18977259891665424, 'rf_weight': 0.3443534825426339}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,346] Trial 134 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.016728460607453758, 'cb_weight': 0.8616098802953149, 'lgbm_weight': 0.8247894685989972, 'hgb_weight': 0.6713710794409044, 'gb_weight': 0.18681110563632244, 'rf_weight': 0.34296764340433006}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,415] Trial 135 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.0001996927284622363, 'cb_weight': 0.8582381323807213, 'lgbm_weight': 0.8245129985384603, 'hgb_weight': 0.6749864038146218, 'gb_weight': 0.19260765139177782, 'rf_weight': 0.2483437318317682}. Best is trial 130 with value: 0.8344049766068115.
# [I 2024-06-11 04:59:59,486] Trial 136 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.0008800123713146278, 'cb_weight': 0.8616985597982437, 'lgbm_weight': 0.7790767871218542, 'hgb_weight': 0.7258993595813049, 'gb_weight': 0.17972726818635226, 'rf_weight': 0.3443096373852828}. Best is trial 136 with value: 0.8344180454272198.
# ...
# [I 2024-06-11 05:17:17,981] Trial 4955 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.03146788373793695, 'cb_weight': 0.9142335897237802, 'lgbm_weight': 0.9701243566610686, 'hgb_weight': 0.7079352336931393, 'gb_weight': 0.21354250778691003, 'rf_weight': 0.5182017505043705}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:18,346] Trial 4956 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.01692987812103958, 'cb_weight': 0.9666057198555997, 'lgbm_weight': 0.9506713023638543, 'hgb_weight': 0.6468156491710159, 'gb_weight': 0.2915543687935628, 'rf_weight': 0.447469377995799}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:18,710] Trial 4957 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.04914238131398706, 'cb_weight': 0.9470987956819757, 'lgbm_weight': 0.9645843438473213, 'hgb_weight': 0.7980374994793615, 'gb_weight': 0.3244247695359101, 'rf_weight': 0.49024290400074777}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:19,081] Trial 4958 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.019447808985175598, 'cb_weight': 0.9208572902238276, 'lgbm_weight': 0.6653494339555427, 'hgb_weight': 0.7334413431566122, 'gb_weight': 0.34294174460649196, 'rf_weight': 0.4180462726246298}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:19,451] Trial 4959 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.017532929466527614, 'cb_weight': 0.8928980008413911, 'lgbm_weight': 0.9174205918629128, 'hgb_weight': 0.6842576721707403, 'gb_weight': 0.3070344415742728, 'rf_weight': 0.3392957337880233}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:19,824] Trial 4960 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.05992140322376767, 'cb_weight': 0.9817629860011602, 'lgbm_weight': 0.9360303239970635, 'hgb_weight': 0.7573233374084001, 'gb_weight': 0.3648226200153573, 'rf_weight': 0.4632704196119791}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:20,201] Trial 4961 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.0006205068908060055, 'cb_weight': 0.959260922282108, 'lgbm_weight': 0.981453005931521, 'hgb_weight': 0.45499313574417044, 'gb_weight': 0.32483784004299676, 'rf_weight': 0.454905219997152}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:20,577] Trial 4962 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.00047352290683950153, 'cb_weight': 0.9418178432115417, 'lgbm_weight': 0.9564864587832689, 'hgb_weight': 0.717603316670943, 'gb_weight': 0.2587185175285678, 'rf_weight': 0.43025044577405736}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:20,981] Trial 4963 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.08656219984790664, 'cb_weight': 0.8743564008560706, 'lgbm_weight': 0.8975765636175885, 'hgb_weight': 0.7021631772762188, 'gb_weight': 0.4048586085240139, 'rf_weight': 0.530588256858981}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:21,369] Trial 4964 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.0004748536357596111, 'cb_weight': 0.9814407580443937, 'lgbm_weight': 0.6398604869202373, 'hgb_weight': 0.7396488656266779, 'gb_weight': 0.2348396443697556, 'rf_weight': 0.48142566810139326}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:21,763] Trial 4965 finished with value: 0.8338168796884393 and parameters: {'xgb_weight': 0.6669056575149819, 'cb_weight': 0.9211763983096006, 'lgbm_weight': 0.8195356749456398, 'hgb_weight': 0.7816413847983427, 'gb_weight': 0.28759744925645586, 'rf_weight': 0.406382278637324}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:22,140] Trial 4966 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.0364827116635414, 'cb_weight': 0.9565350672018024, 'lgbm_weight': 0.971296933030037, 'hgb_weight': 0.7566605340001414, 'gb_weight': 0.3470645147394218, 'rf_weight': 0.444080277681464}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:22,514] Trial 4967 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.03253120072887391, 'cb_weight': 0.9371398515776682, 'lgbm_weight': 0.940469971124276, 'hgb_weight': 0.7200711822507158, 'gb_weight': 0.305552905648287, 'rf_weight': 0.4976114159299117}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:22,881] Trial 4968 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.03187362631808347, 'cb_weight': 0.9026250921549369, 'lgbm_weight': 0.8695702321317015, 'hgb_weight': 0.6736440590064445, 'gb_weight': 0.3351475869503937, 'rf_weight': 0.47164282920501577}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:23,257] Trial 4969 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.018096436806045994, 'cb_weight': 0.9664558756779438, 'lgbm_weight': 0.9169014743909446, 'hgb_weight': 0.704667328272475, 'gb_weight': 0.27269183491227544, 'rf_weight': 0.4370252221561212}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:23,615] Trial 4970 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.0005409070655265911, 'cb_weight': 0.8198505415771974, 'lgbm_weight': 0.999842658592282, 'hgb_weight': 0.7355368234909411, 'gb_weight': 0.3842382722204008, 'rf_weight': 0.41562695784427584}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:23,974] Trial 4971 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.047553023303922776, 'cb_weight': 0.9995227281393871, 'lgbm_weight': 0.9823428299677542, 'hgb_weight': 0.6935298997049273, 'gb_weight': 0.31513963009944435, 'rf_weight': 0.4579998135326896}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:24,344] Trial 4972 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.06507578930318245, 'cb_weight': 0.9263531240688748, 'lgbm_weight': 0.9549618033375733, 'hgb_weight': 0.7690273559096339, 'gb_weight': 0.3659638317839083, 'rf_weight': 0.4725088359586263}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:24,717] Trial 4973 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.018164450527569192, 'cb_weight': 0.9530961430663631, 'lgbm_weight': 0.9389464487609116, 'hgb_weight': 0.7222270653983299, 'gb_weight': 0.3362050798536387, 'rf_weight': 0.4381592000683686}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:25,092] Trial 4974 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.0002616706211479927, 'cb_weight': 0.8883830734087971, 'lgbm_weight': 0.9705801009587048, 'hgb_weight': 0.7382527954201117, 'gb_weight': 0.29833747898281693, 'rf_weight': 0.38952904439145697}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:25,461] Trial 4975 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.03289627298340857, 'cb_weight': 0.9807730667339195, 'lgbm_weight': 0.968456716795861, 'hgb_weight': 0.38759455275559757, 'gb_weight': 0.31935984117316085, 'rf_weight': 0.5131758478825037}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:25,817] Trial 4976 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.01665527288909782, 'cb_weight': 0.9133071640956574, 'lgbm_weight': 0.9109750157074494, 'hgb_weight': 0.7573037884899835, 'gb_weight': 0.3568096749151935, 'rf_weight': 0.4896250786703481}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:26,189] Trial 4977 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.4587305749051551, 'cb_weight': 0.9414053272292934, 'lgbm_weight': 0.9447916483236888, 'hgb_weight': 0.791324873483421, 'gb_weight': 0.2827153094550353, 'rf_weight': 0.45073625377591975}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:26,554] Trial 4978 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.045871555777542636, 'cb_weight': 0.9648470447477635, 'lgbm_weight': 0.9836176595728398, 'hgb_weight': 0.6619223993251, 'gb_weight': 0.3424228955790816, 'rf_weight': 0.9018630429204739}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:26,919] Trial 4979 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.00035556198736408487, 'cb_weight': 0.9307755148692282, 'lgbm_weight': 0.9994510348383477, 'hgb_weight': 0.6964747333102889, 'gb_weight': 0.31709743075224117, 'rf_weight': 0.4215824450373253}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:27,285] Trial 4980 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.40497047691957444, 'cb_weight': 0.9827510349613285, 'lgbm_weight': 0.9551175745599463, 'hgb_weight': 0.7478695305622499, 'gb_weight': 0.3759069668048845, 'rf_weight': 0.4710178307825538}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:27,646] Trial 4981 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.018857834459995174, 'cb_weight': 0.9095261235697135, 'lgbm_weight': 0.9277780181630426, 'hgb_weight': 0.7185390773993593, 'gb_weight': 0.3008118687904013, 'rf_weight': 0.4403497288773427}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:28,028] Trial 4982 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.03207718913575419, 'cb_weight': 0.8609218232419071, 'lgbm_weight': 0.9677806717107863, 'hgb_weight': 0.6805434601219016, 'gb_weight': 0.3323345125300387, 'rf_weight': 0.4037362998956505}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:28,405] Trial 4983 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.01883040854943657, 'cb_weight': 0.9500733291141985, 'lgbm_weight': 0.9834062427528146, 'hgb_weight': 0.7709100813946947, 'gb_weight': 0.2575906012537639, 'rf_weight': 0.367078235841883}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:28,776] Trial 4984 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.05644378577984942, 'cb_weight': 0.9685210418295113, 'lgbm_weight': 0.9999566087596348, 'hgb_weight': 0.7306958784395929, 'gb_weight': 0.34802693284763414, 'rf_weight': 0.45702223569910005}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:29,139] Trial 4985 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.018465254517294027, 'cb_weight': 0.999914067876899, 'lgbm_weight': 0.9366308709946892, 'hgb_weight': 0.634377892882092, 'gb_weight': 0.2861353407308393, 'rf_weight': 0.5035926496339984}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:29,501] Trial 4986 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.6233387846707682, 'cb_weight': 0.9347454089024292, 'lgbm_weight': 0.9999658328533994, 'hgb_weight': 0.5272134432708284, 'gb_weight': 0.3196522851620294, 'rf_weight': 0.4317342578953599}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:29,869] Trial 4987 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.035685510659154554, 'cb_weight': 0.882129673287057, 'lgbm_weight': 0.9520085795888106, 'hgb_weight': 0.7083189251920202, 'gb_weight': 0.36145813552653694, 'rf_weight': 0.4810903591401181}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:30,250] Trial 4988 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.07221227565234845, 'cb_weight': 0.9658754881388545, 'lgbm_weight': 0.8861409852804626, 'hgb_weight': 0.7474734602456242, 'gb_weight': 0.30766883224920427, 'rf_weight': 0.45736068712988326}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:30,620] Trial 4989 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.04586646168123182, 'cb_weight': 0.7158495687687796, 'lgbm_weight': 0.9170814521587054, 'hgb_weight': 0.8978180422340891, 'gb_weight': 0.3893796292389341, 'rf_weight': 0.41362488843085915}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:31,102] Trial 4990 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.01609541244081117, 'cb_weight': 0.9064980163303272, 'lgbm_weight': 0.7030774507642008, 'hgb_weight': 0.7250422010760116, 'gb_weight': 0.33436506703787594, 'rf_weight': 0.43318822419765984}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:31,486] Trial 4991 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.017744619648213802, 'cb_weight': 0.9419077009862565, 'lgbm_weight': 0.9703582153734059, 'hgb_weight': 0.6902559853853978, 'gb_weight': 0.42391816389910864, 'rf_weight': 0.47165912393775294}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:31,867] Trial 4992 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.0003116051736701697, 'cb_weight': 0.9999971178509306, 'lgbm_weight': 0.9557533856830976, 'hgb_weight': 0.8322328478995898, 'gb_weight': 0.2736080743033166, 'rf_weight': 0.44752443004836595}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:32,251] Trial 4993 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.7359900566691164, 'cb_weight': 0.9238996423573265, 'lgbm_weight': 0.9318168294865202, 'hgb_weight': 0.7817852252632272, 'gb_weight': 0.3003168679382787, 'rf_weight': 0.38805198478730135}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:32,612] Trial 4994 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.03649325383814499, 'cb_weight': 0.9697915490373197, 'lgbm_weight': 0.9820742053999204, 'hgb_weight': 0.7534631954279957, 'gb_weight': 0.34829715568977077, 'rf_weight': 0.4918922292884925}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:32,976] Trial 4995 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.01834005696235086, 'cb_weight': 0.951978055596264, 'lgbm_weight': 0.9490364419966589, 'hgb_weight': 0.7105551393336487, 'gb_weight': 0.3237890734975211, 'rf_weight': 0.5681881626074627}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:33,350] Trial 4996 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.0005644090505517544, 'cb_weight': 0.8962234547475582, 'lgbm_weight': 0.9084063583881976, 'hgb_weight': 0.7303035487933907, 'gb_weight': 0.36667401023773255, 'rf_weight': 0.4245720020871047}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:33,713] Trial 4997 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.04845311920905182, 'cb_weight': 0.9831508166328192, 'lgbm_weight': 0.9681532007984629, 'hgb_weight': 0.6675469174403649, 'gb_weight': 0.4558243969358732, 'rf_weight': 0.46465790493482667}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:34,077] Trial 4998 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.03509059104123122, 'cb_weight': 0.9996399393575872, 'lgbm_weight': 0.9818954136800914, 'hgb_weight': 0.7644815924601261, 'gb_weight': 0.29414475938404694, 'rf_weight': 0.404503048981452}. Best is trial 667 with value: 0.8345748712721189.
# [I 2024-06-11 05:17:34,440] Trial 4999 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.018325677707299336, 'cb_weight': 0.920485980145057, 'lgbm_weight': 0.9348728104180413, 'hgb_weight': 0.6985027222781522, 'gb_weight': 0.3249816831605403, 'rf_weight': 0.4469110729715906}. Best is trial 667 with value: 0.8345748712721189.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.836121, AUC: 0.930657
# --- Fold 2 - Accuracy: 0.836448, AUC: 0.932447
# --- Fold 3 - Accuracy: 0.835533, AUC: 0.929916
# --- Fold 4 - Accuracy: 0.834477, AUC: 0.930267
# --- Fold 5 - Accuracy: 0.825851, AUC: 0.924950
#
# ------ Accuracy: 0.833686 ± 0.003974
# ------ AUC:      0.929648 ± 0.002505

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.837232, AUC: 0.930795
# --- Fold 2 - Accuracy: 0.836775, AUC: 0.932590
# --- Fold 3 - Accuracy: 0.836448, AUC: 0.930068
# --- Fold 4 - Accuracy: 0.835065, AUC: 0.930240
# --- Fold 5 - Accuracy: 0.825786, AUC: 0.925059
#
# ------ Accuracy: 0.834261 ± 0.004299
# ------ AUC:      0.929750 ± 0.002510

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
