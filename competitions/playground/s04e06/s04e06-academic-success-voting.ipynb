# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-07 13:37:52,514] A new study created in memory with name: no-name-01eeb7f2-d20a-4664-aa45-439470cca50c
# [I 2024-06-07 13:37:52,532] Trial 0 finished with value: 0.8331373010272093 and parameters: {'xgb_weight': 0.8071208507098011, 'cb_weight': 0.12389451430060194, 'lgbm_weight': 0.06437417675294044, 'hgb_weight': 0.18936512890736334, 'gb_weight': 0.8273108767019286, 'rf_weight': 0.19735212541601266}. Best is trial 0 with value: 0.8331373010272093.
# [I 2024-06-07 13:37:52,547] Trial 1 finished with value: 0.8333333333333334 and parameters: {'xgb_weight': 0.15925072490926406, 'cb_weight': 0.256196870471776, 'lgbm_weight': 0.3945311083370937, 'hgb_weight': 0.00048131560879427493, 'gb_weight': 0.16258142302597345, 'rf_weight': 0.7503196213513279}. Best is trial 1 with value: 0.8333333333333334.
# [I 2024-06-07 13:37:52,563] Trial 2 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.6360199880225669, 'cb_weight': 0.6695878694189689, 'lgbm_weight': 0.6819486279132005, 'hgb_weight': 0.3624863505328607, 'gb_weight': 0.9200774265782439, 'rf_weight': 0.5305935075234317}. Best is trial 2 with value: 0.8340651872761965.
# [I 2024-06-07 13:37:52,577] Trial 3 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.558224866604475, 'cb_weight': 0.8715667493084485, 'lgbm_weight': 0.3767824968328424, 'hgb_weight': 0.4158389161225903, 'gb_weight': 0.3014208642200197, 'rf_weight': 0.29888070515090714}. Best is trial 3 with value: 0.8341697378394626.
# [I 2024-06-07 13:37:52,590] Trial 4 finished with value: 0.833803810868031 and parameters: {'xgb_weight': 0.9557172574951512, 'cb_weight': 0.7731948415819196, 'lgbm_weight': 0.12256509474346422, 'hgb_weight': 0.08658723402222934, 'gb_weight': 0.2593758933516205, 'rf_weight': 0.6344376193034799}. Best is trial 3 with value: 0.8341697378394626.
# [I 2024-06-07 13:37:52,604] Trial 5 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.590147665530749, 'cb_weight': 0.6822792395520072, 'lgbm_weight': 0.595681178813379, 'hgb_weight': 0.3053156172214191, 'gb_weight': 0.20140668526396233, 'rf_weight': 0.37841682921609265}. Best is trial 3 with value: 0.8341697378394626.
# [I 2024-06-07 13:37:52,618] Trial 6 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.1739011111772767, 'cb_weight': 0.8352276247205419, 'lgbm_weight': 0.9393827548690145, 'hgb_weight': 0.12383026213110804, 'gb_weight': 0.3771122479780137, 'rf_weight': 0.40676789839154437}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,632] Trial 7 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.3681711641996853, 'cb_weight': 0.9439885146525854, 'lgbm_weight': 0.66529204989047, 'hgb_weight': 0.13720307734310266, 'gb_weight': 0.7323514693005894, 'rf_weight': 0.8326112331934205}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,646] Trial 8 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.033715385097889405, 'cb_weight': 0.5752334691076859, 'lgbm_weight': 0.22980141765457995, 'hgb_weight': 0.05237581722889506, 'gb_weight': 0.8142469101946086, 'rf_weight': 0.15123208713186176}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,660] Trial 9 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.4517926695057599, 'cb_weight': 0.8722724909846702, 'lgbm_weight': 0.8654022571170699, 'hgb_weight': 0.4698685745295498, 'gb_weight': 0.902231348263746, 'rf_weight': 0.9968081504234624}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,701] Trial 10 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.21109152689318678, 'cb_weight': 0.4304720502079601, 'lgbm_weight': 0.9973038561046648, 'hgb_weight': 0.8155404536577741, 'gb_weight': 0.5412942522213123, 'rf_weight': 0.016761990570718477}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,742] Trial 11 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.34005770292344123, 'cb_weight': 0.9647131380852443, 'lgbm_weight': 0.7625632138909243, 'hgb_weight': 0.7029961813511226, 'gb_weight': 0.5505011810450142, 'rf_weight': 0.8551521836707109}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,784] Trial 12 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.3004065362790975, 'cb_weight': 0.9982232723549698, 'lgbm_weight': 0.9948509997805635, 'hgb_weight': 0.22520851286005195, 'gb_weight': 0.6661235009509693, 'rf_weight': 0.46985643447380643}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,826] Trial 13 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.20937696834156946, 'cb_weight': 0.42218395718582247, 'lgbm_weight': 0.9957636982486642, 'hgb_weight': 0.244781124975036, 'gb_weight': 0.4070166656993921, 'rf_weight': 0.46018225385170297}. Best is trial 6 with value: 0.834483389529261.
# [I 2024-06-07 13:37:52,868] Trial 14 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.011873869082265398, 'cb_weight': 0.9922112202653907, 'lgbm_weight': 0.8604416061110565, 'hgb_weight': 0.6102614463042259, 'gb_weight': 0.023033142326063016, 'rf_weight': 0.562198278624434}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:52,911] Trial 15 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.053085035444344675, 'cb_weight': 0.7611471883674329, 'lgbm_weight': 0.8323243215798783, 'hgb_weight': 0.5988657425814108, 'gb_weight': 0.067797417841306, 'rf_weight': 0.6234725987872003}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:52,952] Trial 16 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.005895347722533778, 'cb_weight': 0.719190231471657, 'lgbm_weight': 0.8282340966916839, 'hgb_weight': 0.6331625724888339, 'gb_weight': 0.016318400885879214, 'rf_weight': 0.6309527136224202}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:52,993] Trial 17 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.0837559503041777, 'cb_weight': 0.5675085233584758, 'lgbm_weight': 0.5321525519126811, 'hgb_weight': 0.9953582085155965, 'gb_weight': 0.004125819086514326, 'rf_weight': 0.602014503601742}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:53,036] Trial 18 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.09893394035776099, 'cb_weight': 0.7963768478574247, 'lgbm_weight': 0.7652700339089868, 'hgb_weight': 0.5951215329786065, 'gb_weight': 0.09110324431808167, 'rf_weight': 0.7478167838309197}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:53,078] Trial 19 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.7200562708144325, 'cb_weight': 0.5938483461755841, 'lgbm_weight': 0.4198181124384097, 'hgb_weight': 0.816986717237121, 'gb_weight': 0.11397886628958614, 'rf_weight': 0.5453046441711594}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:53,119] Trial 20 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.2508547387415506, 'cb_weight': 0.30618862676181335, 'lgbm_weight': 0.8493684486271814, 'hgb_weight': 0.5565554060944382, 'gb_weight': 0.4116306082384513, 'rf_weight': 0.7122956169702557}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:53,162] Trial 21 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.127188454338525, 'cb_weight': 0.8586766145705563, 'lgbm_weight': 0.8966949211786447, 'hgb_weight': 0.7239495230148436, 'gb_weight': 0.3389109858922093, 'rf_weight': 0.37207038048552216}. Best is trial 14 with value: 0.8345356648108941.
# [I 2024-06-07 13:37:53,205] Trial 22 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.00873986306067113, 'cb_weight': 0.7952182798756762, 'lgbm_weight': 0.7404182391374707, 'hgb_weight': 0.45735386568375586, 'gb_weight': 0.08155711352859163, 'rf_weight': 0.3876128416241168}. Best is trial 22 with value: 0.8346402153741603.
# [I 2024-06-07 13:37:53,246] Trial 23 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.035535899354996354, 'cb_weight': 0.7388195971820296, 'lgbm_weight': 0.7496692936828854, 'hgb_weight': 0.47369371511181924, 'gb_weight': 0.06963099937463732, 'rf_weight': 0.26345563787955384}. Best is trial 23 with value: 0.8347447659374265.
# [I 2024-06-07 13:37:53,289] Trial 24 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.002438877916882345, 'cb_weight': 0.9187672123115734, 'lgbm_weight': 0.7059743897109888, 'hgb_weight': 0.5028802395786998, 'gb_weight': 0.19975078706827318, 'rf_weight': 0.24820398766508345}. Best is trial 23 with value: 0.8347447659374265.
# [I 2024-06-07 13:37:53,332] Trial 25 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.427544024826763, 'cb_weight': 0.646489555977826, 'lgbm_weight': 0.6776375795453567, 'hgb_weight': 0.48523854242773024, 'gb_weight': 0.2184164736357271, 'rf_weight': 0.24360804796177823}. Best is trial 23 with value: 0.8347447659374265.
# [I 2024-06-07 13:37:53,374] Trial 26 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.1140626339969763, 'cb_weight': 0.8735043684722974, 'lgbm_weight': 0.5772697090937553, 'hgb_weight': 0.38298363497047805, 'gb_weight': 0.1548093688118775, 'rf_weight': 0.09402288900524802}. Best is trial 26 with value: 0.834770903578243.
# [I 2024-06-07 13:37:53,417] Trial 27 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.2706178989938414, 'cb_weight': 0.9193822540214118, 'lgbm_weight': 0.558141127039105, 'hgb_weight': 0.3513265508948816, 'gb_weight': 0.17029200266017283, 'rf_weight': 0.05290944669027076}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,460] Trial 28 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.28040150631483224, 'cb_weight': 0.4940295675132333, 'lgbm_weight': 0.5514802327186413, 'hgb_weight': 0.340431089619201, 'gb_weight': 0.15739261817367145, 'rf_weight': 0.004432812130060748}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,503] Trial 29 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.15298291438959521, 'cb_weight': 0.10420224059857341, 'lgbm_weight': 0.45932876778191006, 'hgb_weight': 0.28079168573742763, 'gb_weight': 0.26114559381388047, 'rf_weight': 0.1468395418976803}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,546] Trial 30 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.37424192259705885, 'cb_weight': 0.909622929440985, 'lgbm_weight': 0.30809224924837614, 'hgb_weight': 0.39238497106943054, 'gb_weight': 0.4555093587201222, 'rf_weight': 0.0981527093567298}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,589] Trial 31 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.24361343481080683, 'cb_weight': 0.46660769116783196, 'lgbm_weight': 0.565558156769243, 'hgb_weight': 0.3314242841561298, 'gb_weight': 0.15018881362630654, 'rf_weight': 0.07219335721767128}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,632] Trial 32 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.23828835327917772, 'cb_weight': 0.20070517673022892, 'lgbm_weight': 0.598685572588027, 'hgb_weight': 0.19539198360924803, 'gb_weight': 0.13187688294432823, 'rf_weight': 0.07677429573321959}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,675] Trial 33 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.1262132978726836, 'cb_weight': 0.44026474348671774, 'lgbm_weight': 0.6115228321715233, 'hgb_weight': 0.4055235940004065, 'gb_weight': 0.27244571254417127, 'rf_weight': 0.0700611447344896}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,719] Trial 34 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.18867161715695813, 'cb_weight': 0.3643415212941199, 'lgbm_weight': 0.4862859068563513, 'hgb_weight': 0.3313563580025275, 'gb_weight': 0.1644272413574947, 'rf_weight': 0.18989287179944825}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,762] Trial 35 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.44257614037126747, 'cb_weight': 0.01565064882814038, 'lgbm_weight': 0.30990819848669293, 'hgb_weight': 0.26861834891882064, 'gb_weight': 0.31422372367707524, 'rf_weight': 0.11624499651910566}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,806] Trial 36 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.5224127497415771, 'cb_weight': 0.7204234627264401, 'lgbm_weight': 0.6325511338157203, 'hgb_weight': 0.37768012997688005, 'gb_weight': 0.215179583495958, 'rf_weight': 0.29121570127550417}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,850] Trial 37 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.9517869804034227, 'cb_weight': 0.49458867580719246, 'lgbm_weight': 0.5572614772482831, 'hgb_weight': 0.5085464816379168, 'gb_weight': 0.05413013773250168, 'rf_weight': 0.03847470331155299}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,894] Trial 38 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.31679324098382516, 'cb_weight': 0.6496453840737384, 'lgbm_weight': 0.4370008307726574, 'hgb_weight': 0.4221927123995234, 'gb_weight': 0.1444328485621479, 'rf_weight': 0.19230957082854144}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,938] Trial 39 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.07677749305809703, 'cb_weight': 0.831751882649576, 'lgbm_weight': 0.3295761015197681, 'hgb_weight': 0.15408773050289548, 'gb_weight': 0.33674012893685495, 'rf_weight': 0.3230482405463223}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:53,982] Trial 40 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.13362021523542394, 'cb_weight': 0.8976440737695847, 'lgbm_weight': 0.5007011828891558, 'hgb_weight': 0.3180914260800134, 'gb_weight': 0.24535843822891595, 'rf_weight': 0.23649633632898837}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,027] Trial 41 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.27565603867356736, 'cb_weight': 0.5168700550865769, 'lgbm_weight': 0.5515027367550758, 'hgb_weight': 0.35124055191004117, 'gb_weight': 0.1621862382137762, 'rf_weight': 0.005016455867132936}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,073] Trial 42 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.3737073489908951, 'cb_weight': 0.5031066064250828, 'lgbm_weight': 0.38702482611803446, 'hgb_weight': 0.44422267702193363, 'gb_weight': 0.16226893075702492, 'rf_weight': 0.1409598817737776}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,117] Trial 43 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.17926362486038155, 'cb_weight': 0.3924201518070828, 'lgbm_weight': 0.6505078182400374, 'hgb_weight': 0.3146845331949052, 'gb_weight': 0.10738846421113578, 'rf_weight': 0.04250440908810599}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,161] Trial 44 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.1940189641370697, 'cb_weight': 0.3457792561650738, 'lgbm_weight': 0.6474787828267092, 'hgb_weight': 0.5411675617918116, 'gb_weight': 0.04862835723071694, 'rf_weight': 0.04536174659231407}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,207] Trial 45 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.1741688644148694, 'cb_weight': 0.2242007616045506, 'lgbm_weight': 0.7237665912122736, 'hgb_weight': 0.20506554971202753, 'gb_weight': 0.10138893187101612, 'rf_weight': 0.18187597345551282}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,252] Trial 46 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.6298053112910972, 'cb_weight': 0.39614230626781893, 'lgbm_weight': 0.786808332164728, 'hgb_weight': 0.2940309264231073, 'gb_weight': 0.19154832524842286, 'rf_weight': 0.10156477011166187}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,297] Trial 47 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.2276891579154443, 'cb_weight': 0.286944779990737, 'lgbm_weight': 0.5838196256771219, 'hgb_weight': 0.24178864376718384, 'gb_weight': 0.29509913945566235, 'rf_weight': 0.06953451508743742}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,343] Trial 48 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.07393843868466604, 'cb_weight': 0.9548889161562594, 'lgbm_weight': 0.6565847315432053, 'hgb_weight': 0.09893542994554536, 'gb_weight': 0.10720765156692838, 'rf_weight': 0.14129582439433996}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,388] Trial 49 finished with value: 0.833803810868031 and parameters: {'xgb_weight': 0.08881242796586443, 'cb_weight': 0.9524602007241397, 'lgbm_weight': 0.15483911973189646, 'hgb_weight': 0.11084220796676092, 'gb_weight': 0.646591574535707, 'rf_weight': 0.13343655546525462}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,434] Trial 50 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.338667936121355, 'cb_weight': 0.8393932052370077, 'lgbm_weight': 0.49993644007467786, 'hgb_weight': 0.01483088727142945, 'gb_weight': 0.24065369653121682, 'rf_weight': 0.04974303892479884}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,479] Trial 51 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.05799131800474122, 'cb_weight': 0.9973535967158359, 'lgbm_weight': 0.653932093008664, 'hgb_weight': 0.1708574772423296, 'gb_weight': 0.11183088489671195, 'rf_weight': 0.16083597250408943}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,525] Trial 52 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.06561744484566352, 'cb_weight': 0.9897310687393976, 'lgbm_weight': 0.6894038157011128, 'hgb_weight': 0.07278560040083845, 'gb_weight': 0.10349566226636471, 'rf_weight': 0.17787974268875137}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,573] Trial 53 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.11501238481271854, 'cb_weight': 0.9424968468292689, 'lgbm_weight': 0.6333211903452918, 'hgb_weight': 0.024580710157973584, 'gb_weight': 0.9780875198783505, 'rf_weight': 0.0009200388514830349}. Best is trial 27 with value: 0.8348362476802844.
# [I 2024-06-07 13:37:54,619] Trial 54 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.16005745239639424, 'cb_weight': 0.8790441173396846, 'lgbm_weight': 0.6623926257277306, 'hgb_weight': 0.14984733384090856, 'gb_weight': 0.041761788124080296, 'rf_weight': 0.11079295914813181}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:54,684] Trial 55 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.05554138232906505, 'cb_weight': 0.881586854490945, 'lgbm_weight': 0.5746524446236263, 'hgb_weight': 0.16243381223468997, 'gb_weight': 0.0023614973083634916, 'rf_weight': 0.21128512708483033}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:54,752] Trial 56 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.14702183325033302, 'cb_weight': 0.8076845706864602, 'lgbm_weight': 0.5236021689912068, 'hgb_weight': 0.09485294959876833, 'gb_weight': 0.03533320155839001, 'rf_weight': 0.3386767114778934}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:54,821] Trial 57 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.10223384674711883, 'cb_weight': 0.9306465385778335, 'lgbm_weight': 0.8066625920284811, 'hgb_weight': 0.1356207048572458, 'gb_weight': 0.1889180321166611, 'rf_weight': 0.15567191509526174}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:54,889] Trial 58 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.25173065835166036, 'cb_weight': 0.9286006016825485, 'lgbm_weight': 0.7966944205392612, 'hgb_weight': 0.06671692088385682, 'gb_weight': 0.2089496536178552, 'rf_weight': 0.10458525355819315}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:54,956] Trial 59 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.26661207190236774, 'cb_weight': 0.9322748783688848, 'lgbm_weight': 0.00013822460169654605, 'hgb_weight': 0.1281291097371378, 'gb_weight': 0.20647370731406262, 'rf_weight': 0.21994510747813797}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,006] Trial 60 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.21558108471590726, 'cb_weight': 0.9533936790184518, 'lgbm_weight': 0.9273197333374871, 'hgb_weight': 0.08163397231823596, 'gb_weight': 0.560323638493041, 'rf_weight': 0.976952760091219}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,052] Trial 61 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.09965184059732378, 'cb_weight': 0.8801729201238502, 'lgbm_weight': 0.7975100035493352, 'hgb_weight': 0.0551353045447428, 'gb_weight': 0.17103392707262574, 'rf_weight': 0.07873278928118152}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,098] Trial 62 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.4117269253582907, 'cb_weight': 0.7634603057583025, 'lgbm_weight': 0.826294110415577, 'hgb_weight': 0.04737746584658264, 'gb_weight': 0.17778263234062547, 'rf_weight': 0.12617573539162102}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,148] Trial 63 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.5195137884717603, 'cb_weight': 0.7579446637432729, 'lgbm_weight': 0.7985221740824069, 'hgb_weight': 0.046336051021934443, 'gb_weight': 0.37653657822098696, 'rf_weight': 0.11931257796858269}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,202] Trial 64 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.3017141962866337, 'cb_weight': 0.8485832875617679, 'lgbm_weight': 0.9044547543169855, 'hgb_weight': 0.052631229112983305, 'gb_weight': 0.18235810140379266, 'rf_weight': 0.15698660334185047}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,248] Trial 65 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.39751629859337556, 'cb_weight': 0.8416806155366292, 'lgbm_weight': 0.9049050963984316, 'hgb_weight': 0.010035915000691287, 'gb_weight': 0.08319574900700133, 'rf_weight': 0.43879276369611064}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,293] Trial 66 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.4747398023704753, 'cb_weight': 0.7845612182639442, 'lgbm_weight': 0.8600486337057991, 'hgb_weight': 0.12798085307007748, 'gb_weight': 0.2799426116178223, 'rf_weight': 0.1593000960923775}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,339] Trial 67 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.3410815208802558, 'cb_weight': 0.6944084393482723, 'lgbm_weight': 0.9705195146194303, 'hgb_weight': 0.034621176519508856, 'gb_weight': 0.8347392776505923, 'rf_weight': 0.21906106850743295}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,385] Trial 68 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.4115232173914203, 'cb_weight': 0.8953498112063566, 'lgbm_weight': 0.9037426179937947, 'hgb_weight': 0.22076630981711662, 'gb_weight': 0.18487608666522143, 'rf_weight': 0.3032125000526612}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,431] Trial 69 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.3066035154706617, 'cb_weight': 0.8179132859387082, 'lgbm_weight': 0.8273132066260096, 'hgb_weight': 0.1037812759408836, 'gb_weight': 0.2394279938139751, 'rf_weight': 0.2858375519861436}. Best is trial 54 with value: 0.8349930735251836.
# [I 2024-06-07 13:37:55,477] Trial 70 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.03068866039359988, 'cb_weight': 0.8525298649790047, 'lgbm_weight': 0.7704483943928583, 'hgb_weight': 0.1821245907717758, 'gb_weight': 0.05997960010539885, 'rf_weight': 0.14562931109658203}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,523] Trial 71 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.03609110825167833, 'cb_weight': 0.8649431956379496, 'lgbm_weight': 0.7322632840399137, 'hgb_weight': 0.18993942473103848, 'gb_weight': 0.12810145299724113, 'rf_weight': 0.1300133358609364}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,569] Trial 72 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.1587600827265414, 'cb_weight': 0.8603217029291855, 'lgbm_weight': 0.7708974816340821, 'hgb_weight': 0.18587625798204904, 'gb_weight': 0.06376247007794487, 'rf_weight': 0.09270704188943177}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,614] Trial 73 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.0387325087645201, 'cb_weight': 0.8603804933682936, 'lgbm_weight': 0.7664321763432983, 'hgb_weight': 0.17990685952777224, 'gb_weight': 0.06628636120596736, 'rf_weight': 0.0924857172095042}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,662] Trial 74 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.03416778127595983, 'cb_weight': 0.8716073241239314, 'lgbm_weight': 0.7318396284380347, 'hgb_weight': 0.18182578820175468, 'gb_weight': 0.04235521682675886, 'rf_weight': 0.08555482596547252}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,708] Trial 75 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.029983860239283733, 'cb_weight': 0.8550579587992307, 'lgbm_weight': 0.7189794706378939, 'hgb_weight': 0.1835728961925054, 'gb_weight': 0.034945799655224284, 'rf_weight': 0.26504122268199665}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,754] Trial 76 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.0312172075745165, 'cb_weight': 0.8111137189008694, 'lgbm_weight': 0.7455989196087245, 'hgb_weight': 0.25306945318381313, 'gb_weight': 0.05831775603221015, 'rf_weight': 0.16603810044476608}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,799] Trial 77 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.008104081907327053, 'cb_weight': 0.8648241330370249, 'lgbm_weight': 0.8821202866281269, 'hgb_weight': 0.20139675143921987, 'gb_weight': 0.01596441991571966, 'rf_weight': 0.024405034277364193}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,845] Trial 78 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.04048675749193835, 'cb_weight': 0.9050922940524144, 'lgbm_weight': 0.6953891379986823, 'hgb_weight': 0.14185741619666156, 'gb_weight': 0.06427543195176812, 'rf_weight': 0.09465812943061433}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,892] Trial 79 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.14888942627058543, 'cb_weight': 0.7414479772747212, 'lgbm_weight': 0.7685976099737536, 'hgb_weight': 0.21828774267432172, 'gb_weight': 0.08050735737922657, 'rf_weight': 0.2032763093429366}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,939] Trial 80 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.15443762359647684, 'cb_weight': 0.7020495323919947, 'lgbm_weight': 0.7711727680117, 'hgb_weight': 0.2286884069125465, 'gb_weight': 0.13051385737612195, 'rf_weight': 0.18895258135811296}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:55,984] Trial 81 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.10722398459247165, 'cb_weight': 0.786209665268426, 'lgbm_weight': 0.7612420480105925, 'hgb_weight': 0.163258622830926, 'gb_weight': 0.00021445392609982517, 'rf_weight': 0.11474459979560145}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,032] Trial 82 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.10602664957159964, 'cb_weight': 0.7331295598956106, 'lgbm_weight': 0.754975665603056, 'hgb_weight': 0.151312461810716, 'gb_weight': 0.017136847070909886, 'rf_weight': 0.12568934057437517}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,079] Trial 83 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.11983682242431831, 'cb_weight': 0.7762063160739744, 'lgbm_weight': 0.7679116724116298, 'hgb_weight': 0.1479414390937072, 'gb_weight': 0.08288787312327654, 'rf_weight': 0.13173439408467266}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,126] Trial 84 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.1159518594349936, 'cb_weight': 0.6713571599452857, 'lgbm_weight': 0.8144118122067102, 'hgb_weight': 0.2647792991219437, 'gb_weight': 0.0063904527315395004, 'rf_weight': 0.11806036334528774}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,173] Trial 85 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.16127893549325925, 'cb_weight': 0.7448777643864273, 'lgbm_weight': 0.7122184823399795, 'hgb_weight': 0.1468428541599726, 'gb_weight': 0.08070554977089, 'rf_weight': 0.20435666465737817}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,221] Trial 86 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.1671462369567898, 'cb_weight': 0.6160621124392583, 'lgbm_weight': 0.6904387287059213, 'hgb_weight': 0.15467173919141242, 'gb_weight': 0.07863442327542303, 'rf_weight': 0.243533243174693}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,269] Trial 87 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.20300262274516923, 'cb_weight': 0.7238939631443901, 'lgbm_weight': 0.8439787412655744, 'hgb_weight': 0.2181610194540311, 'gb_weight': 0.02956377918782593, 'rf_weight': 0.6934205026236434}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,316] Trial 88 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.1355732249960556, 'cb_weight': 0.7525353529525072, 'lgbm_weight': 0.752277199155181, 'hgb_weight': 0.11398701850873724, 'gb_weight': 0.1281533658660586, 'rf_weight': 0.20313154975096603}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,363] Trial 89 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.73666596935911, 'cb_weight': 0.7939306204558194, 'lgbm_weight': 0.7121615412915889, 'hgb_weight': 0.289382202854094, 'gb_weight': 0.09136649978140997, 'rf_weight': 0.0606427915714986}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,411] Trial 90 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.08039291057856865, 'cb_weight': 0.7708857456494631, 'lgbm_weight': 0.7791151652797177, 'hgb_weight': 0.9357239240082819, 'gb_weight': 6.804882328122208e-05, 'rf_weight': 0.02525321742487481}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,459] Trial 91 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.09589227122562378, 'cb_weight': 0.7255343714514257, 'lgbm_weight': 0.6752494743333382, 'hgb_weight': 0.14628770863810012, 'gb_weight': 0.12638452646740195, 'rf_weight': 0.13337494199740485}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,506] Trial 92 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.15747373849982527, 'cb_weight': 0.6529837365470863, 'lgbm_weight': 0.7269117421052587, 'hgb_weight': 0.200390482246877, 'gb_weight': 0.04888903521510094, 'rf_weight': 0.2281874457186936}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,554] Trial 93 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.0984455130738229, 'cb_weight': 0.8332744610879682, 'lgbm_weight': 0.8114078054998816, 'hgb_weight': 0.23089729852829266, 'gb_weight': 0.08318837427236751, 'rf_weight': 0.16368846621033}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,603] Trial 94 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.18453470780107162, 'cb_weight': 0.8237635292479127, 'lgbm_weight': 0.7543949335384706, 'hgb_weight': 0.23435218700104676, 'gb_weight': 0.08162421949167742, 'rf_weight': 0.18724588303172915}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,650] Trial 95 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.17875260045210875, 'cb_weight': 0.7416048140885495, 'lgbm_weight': 0.7534486160938741, 'hgb_weight': 0.25117757980120925, 'gb_weight': 0.02581566286902002, 'rf_weight': 0.19428704772298366}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,697] Trial 96 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.13995178457373528, 'cb_weight': 0.7833878633767783, 'lgbm_weight': 0.7025771085353385, 'hgb_weight': 0.1737746358744484, 'gb_weight': 0.07169745947033575, 'rf_weight': 0.26431908730771525}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,745] Trial 97 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.21565942431062754, 'cb_weight': 0.8177533038444732, 'lgbm_weight': 0.6157409912606879, 'hgb_weight': 0.15930454555015305, 'gb_weight': 0.13844585086233377, 'rf_weight': 0.10942755134720629}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,792] Trial 98 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.1211132452361337, 'cb_weight': 0.6994089994772056, 'lgbm_weight': 0.7731869776304023, 'hgb_weight': 0.08427462760766372, 'gb_weight': 0.021188753412676994, 'rf_weight': 0.13893760500537236}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,840] Trial 99 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.19491913801377594, 'cb_weight': 0.8010448576248073, 'lgbm_weight': 0.8495518478767969, 'hgb_weight': 0.20372649899522133, 'gb_weight': 0.04963148034829981, 'rf_weight': 0.1798035980827853}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,888] Trial 100 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.05887985110535514, 'cb_weight': 0.7749218645017706, 'lgbm_weight': 0.7524269269216183, 'hgb_weight': 0.27046329200413405, 'gb_weight': 0.0958933523190437, 'rf_weight': 0.06225322957017157}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,934] Trial 101 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.08044285656814672, 'cb_weight': 0.8298698037750527, 'lgbm_weight': 0.8715567135352116, 'hgb_weight': 0.2389243674230105, 'gb_weight': 0.10420118031870773, 'rf_weight': 0.17259726950369936}. Best is trial 70 with value: 0.8350322799864084.
# [I 2024-06-07 13:37:56,982] Trial 102 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.10964969652096244, 'cb_weight': 0.889729345256173, 'lgbm_weight': 0.8160848650866925, 'hgb_weight': 0.12318940806404993, 'gb_weight': 0.08216024965641404, 'rf_weight': 0.2073225668751583}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,029] Trial 103 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.9227776902908245, 'cb_weight': 0.561355633260019, 'lgbm_weight': 0.7353912843636053, 'hgb_weight': 0.128057576131522, 'gb_weight': 0.040535523475020624, 'rf_weight': 0.207983519215545}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,077] Trial 104 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.16723508476368207, 'cb_weight': 0.8880827155927625, 'lgbm_weight': 0.6720988998439802, 'hgb_weight': 0.15683676990502168, 'gb_weight': 0.0698760761719342, 'rf_weight': 0.35336841792634976}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,124] Trial 105 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.1335001477391419, 'cb_weight': 0.9766387726140786, 'lgbm_weight': 0.8336189505103864, 'hgb_weight': 0.09938243610253969, 'gb_weight': 0.11908399913634456, 'rf_weight': 0.4933856280075523}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,171] Trial 106 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.10923140673919014, 'cb_weight': 0.9158136994136192, 'lgbm_weight': 0.7847334375055093, 'hgb_weight': 0.11407392041796294, 'gb_weight': 0.14474578338606833, 'rf_weight': 0.11363701750260646}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,219] Trial 107 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.017788932106524647, 'cb_weight': 0.7539171604345032, 'lgbm_weight': 0.7080561101131406, 'hgb_weight': 0.21061922988602458, 'gb_weight': 0.027446276580359887, 'rf_weight': 0.14461702305637725}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,266] Trial 108 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.0692826972491159, 'cb_weight': 0.7365461459831149, 'lgbm_weight': 0.7844939367529715, 'hgb_weight': 0.18453935067855348, 'gb_weight': 0.08357625693045899, 'rf_weight': 0.2786072718986826}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,315] Trial 109 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.23793026999748396, 'cb_weight': 0.8138286148536017, 'lgbm_weight': 0.7331864646519939, 'hgb_weight': 0.1460882130444973, 'gb_weight': 0.05552604027787708, 'rf_weight': 0.31148716384630704}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,363] Trial 110 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.1522402325430156, 'cb_weight': 0.8535393277422136, 'lgbm_weight': 0.8127617761745953, 'hgb_weight': 0.6560826433297197, 'gb_weight': 0.4858795525725161, 'rf_weight': 0.23513730109991238}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,412] Trial 111 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.09201744980135454, 'cb_weight': 0.8358389219631782, 'lgbm_weight': 0.7602894480316317, 'hgb_weight': 0.22914707636366596, 'gb_weight': 0.09199179015355705, 'rf_weight': 0.1684908241288985}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,459] Trial 112 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.05439464708946305, 'cb_weight': 0.7907131365017686, 'lgbm_weight': 0.7511194986943519, 'hgb_weight': 0.1721934988763093, 'gb_weight': 0.015873888983210196, 'rf_weight': 0.12532256771663386}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,507] Trial 113 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.05516546529999186, 'cb_weight': 0.8993546556665855, 'lgbm_weight': 0.721283353781495, 'hgb_weight': 0.18722607639905495, 'gb_weight': 0.11516628200031657, 'rf_weight': 0.084991822478211}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,555] Trial 114 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.18619193486357782, 'cb_weight': 0.7940407564462946, 'lgbm_weight': 0.7671200462207391, 'hgb_weight': 0.3015249886519456, 'gb_weight': 0.09175413527401778, 'rf_weight': 0.21478045431294326}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,602] Trial 115 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.08541060896827712, 'cb_weight': 0.8255109502718326, 'lgbm_weight': 0.7979225325063791, 'hgb_weight': 0.2189663997417328, 'gb_weight': 0.0023351615913344403, 'rf_weight': 0.17842555638097182}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,649] Trial 116 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.0019621582033563234, 'cb_weight': 0.8312470980887525, 'lgbm_weight': 0.796617090604824, 'hgb_weight': 0.17275112994008684, 'gb_weight': 0.005772857248653421, 'rf_weight': 0.14795873305766685}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,695] Trial 117 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.08973387349864118, 'cb_weight': 0.8737547912667094, 'lgbm_weight': 0.6842696803517622, 'hgb_weight': 0.12496110928490474, 'gb_weight': 0.04609098147472623, 'rf_weight': 0.5806730206050746}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,742] Trial 118 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.12359640678564882, 'cb_weight': 0.8428905380935189, 'lgbm_weight': 0.8385917377258031, 'hgb_weight': 0.24431570329891694, 'gb_weight': 0.05744561493522364, 'rf_weight': 0.18172080810887029}. Best is trial 102 with value: 0.8350714864476332.
# [I 2024-06-07 13:37:57,789] Trial 119 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.05358278738375782, 'cb_weight': 0.819924814903603, 'lgbm_weight': 0.8583324806883545, 'hgb_weight': 0.2673107315205189, 'gb_weight': 0.024401202889886203, 'rf_weight': 0.17622098860752097}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:57,839] Trial 120 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.12490616644267626, 'cb_weight': 0.8877721802054126, 'lgbm_weight': 0.8645033239167397, 'hgb_weight': 0.2638044665809778, 'gb_weight': 0.14940606019588348, 'rf_weight': 0.17832757677195651}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:57,887] Trial 121 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.04861990588917577, 'cb_weight': 0.8387793202605713, 'lgbm_weight': 0.9344964393718476, 'hgb_weight': 0.2824580749243919, 'gb_weight': 0.03167949896122755, 'rf_weight': 0.1872196496291172}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:57,935] Trial 122 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.0727183012032537, 'cb_weight': 0.7823075278405976, 'lgbm_weight': 0.8335437025242073, 'hgb_weight': 0.24292259780997655, 'gb_weight': 0.003120660056715789, 'rf_weight': 0.25501970025584475}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:57,983] Trial 123 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.0443683067166927, 'cb_weight': 0.8083626471139672, 'lgbm_weight': 0.8821372527833159, 'hgb_weight': 0.22865967503290566, 'gb_weight': 0.04434291309944176, 'rf_weight': 0.16337619040790935}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,030] Trial 124 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.023880204346794248, 'cb_weight': 0.8242045795690579, 'lgbm_weight': 0.8187317097037912, 'hgb_weight': 0.32136675690621397, 'gb_weight': 0.06116764571093373, 'rf_weight': 0.12216260771133847}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,078] Trial 125 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.0772321126628754, 'cb_weight': 0.8462511167463006, 'lgbm_weight': 0.8404846818600381, 'hgb_weight': 0.19336065170964267, 'gb_weight': 0.10319199067303637, 'rf_weight': 0.22389200891399935}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,129] Trial 126 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.11750127552975859, 'cb_weight': 0.9126416121841621, 'lgbm_weight': 0.7487849168001058, 'hgb_weight': 0.0735745659583685, 'gb_weight': 0.023679378600081256, 'rf_weight': 0.14242509909742684}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,176] Trial 127 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.11980726711824327, 'cb_weight': 0.9375550069299506, 'lgbm_weight': 0.7873755158691929, 'hgb_weight': 0.0698696637230275, 'gb_weight': 0.6467014361221186, 'rf_weight': 0.14671934463100092}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,227] Trial 128 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.09473816102209531, 'cb_weight': 0.9184393969379065, 'lgbm_weight': 0.804370842089264, 'hgb_weight': 0.08146054409559306, 'gb_weight': 0.0003877848432368358, 'rf_weight': 0.18709297245031922}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,275] Trial 129 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.13958607548715488, 'cb_weight': 0.8744200066065132, 'lgbm_weight': 0.8883845113600045, 'hgb_weight': 0.36025731703049835, 'gb_weight': 0.5740019918407377, 'rf_weight': 0.20135598369192448}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,336] Trial 130 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.11047103889663847, 'cb_weight': 0.9620128784636469, 'lgbm_weight': 0.8554105896517286, 'hgb_weight': 0.10794497191508204, 'gb_weight': 0.06753181774169721, 'rf_weight': 0.24400348243260134}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,390] Trial 131 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.11087772510920367, 'cb_weight': 0.9735697531471935, 'lgbm_weight': 0.8546151241476483, 'hgb_weight': 0.10984465581952707, 'gb_weight': 0.06744063106571174, 'rf_weight': 0.242486770846624}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,439] Trial 132 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.11226697753508787, 'cb_weight': 0.962175268591485, 'lgbm_weight': 0.9629414924668339, 'hgb_weight': 0.09673080292421549, 'gb_weight': 0.07132209087302038, 'rf_weight': 0.2333777314142487}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,486] Trial 133 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.11216197674074536, 'cb_weight': 0.965079544109625, 'lgbm_weight': 0.9137038219021701, 'hgb_weight': 0.1030966049063298, 'gb_weight': 0.07731878618813953, 'rf_weight': 0.2759133925432663}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,534] Trial 134 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.10766930731684407, 'cb_weight': 0.9567248164532702, 'lgbm_weight': 0.9587247834515401, 'hgb_weight': 0.0897415089171224, 'gb_weight': 0.06323882604479414, 'rf_weight': 0.27939347283067567}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,582] Trial 135 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.0839368655666979, 'cb_weight': 0.9756291958331428, 'lgbm_weight': 0.9679025283579956, 'hgb_weight': 0.06502521447825646, 'gb_weight': 0.02646873307873439, 'rf_weight': 0.24601414136223954}. Best is trial 119 with value: 0.8350845552680415.
# [I 2024-06-07 13:37:58,630] Trial 136 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.132023163246359, 'cb_weight': 0.974470314625316, 'lgbm_weight': 0.9114892832381352, 'hgb_weight': 0.028506229458240634, 'gb_weight': 0.7353436372681367, 'rf_weight': 0.224862587672962}. Best is trial 119 with value: 0.8350845552680415.
# ...
# [I 2024-06-07 13:38:52,545] Trial 955 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.30728003001848186, 'cb_weight': 0.9996003954150505, 'lgbm_weight': 0.46116892215379446, 'hgb_weight': 0.07334215828688642, 'gb_weight': 0.0006184456476194613, 'rf_weight': 0.1340535302629956}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:52,627] Trial 956 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.20960752331127339, 'cb_weight': 0.9810420808203238, 'lgbm_weight': 0.7337932540018997, 'hgb_weight': 0.0024069814750208446, 'gb_weight': 0.02037346878124842, 'rf_weight': 0.18046741301529762}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:52,709] Trial 957 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.24120888985876054, 'cb_weight': 0.9135813712783001, 'lgbm_weight': 0.9047586219621138, 'hgb_weight': 0.17047011200953316, 'gb_weight': 0.05090364908647981, 'rf_weight': 0.15982103141791468}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:52,791] Trial 958 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.3458312873247348, 'cb_weight': 0.9694289834212139, 'lgbm_weight': 0.8130558649478442, 'hgb_weight': 0.13518987986687836, 'gb_weight': 0.01852061129634909, 'rf_weight': 0.20384160954182937}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:52,875] Trial 959 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.2773019315681504, 'cb_weight': 0.9412087016562176, 'lgbm_weight': 0.789373949441416, 'hgb_weight': 0.11375264507729002, 'gb_weight': 0.07321020272825678, 'rf_weight': 0.10780154910044995}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:52,958] Trial 960 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.32095468013851247, 'cb_weight': 0.9813757846297385, 'lgbm_weight': 0.8578820773702173, 'hgb_weight': 0.0562522205589169, 'gb_weight': 0.034932561883898976, 'rf_weight': 0.13524269797885602}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,042] Trial 961 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.29866599606967614, 'cb_weight': 0.7719298745771881, 'lgbm_weight': 0.8918669290388894, 'hgb_weight': 0.5196591071298063, 'gb_weight': 0.0001679947365948113, 'rf_weight': 0.16692226404676475}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,125] Trial 962 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.17775375894404793, 'cb_weight': 0.9568959618564253, 'lgbm_weight': 0.6939814119273473, 'hgb_weight': 0.09025923156355108, 'gb_weight': 0.01766517052325843, 'rf_weight': 0.1214401524333547}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,206] Trial 963 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.2557611194898942, 'cb_weight': 0.9822462120103126, 'lgbm_weight': 0.8415259813104428, 'hgb_weight': 0.14658925527700625, 'gb_weight': 0.6722588897427668, 'rf_weight': 0.1916029554270699}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,289] Trial 964 finished with value: 0.8351368305496746 and parameters: {'xgb_weight': 0.22874721623404745, 'cb_weight': 0.9316909132641843, 'lgbm_weight': 0.9208953101704763, 'hgb_weight': 0.12154476759536195, 'gb_weight': 0.051854884373500255, 'rf_weight': 0.2407848596570405}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,371] Trial 965 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.20126582802394133, 'cb_weight': 0.9998199275595502, 'lgbm_weight': 0.8754683083809012, 'hgb_weight': 0.10280501899114919, 'gb_weight': 0.0003788656341080984, 'rf_weight': 0.1505994350455509}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,456] Trial 966 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.3211917955492998, 'cb_weight': 0.9553944994019065, 'lgbm_weight': 0.7646003468595507, 'hgb_weight': 0.07601929644099689, 'gb_weight': 0.8960091342331041, 'rf_weight': 0.2203967867778588}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,543] Trial 967 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.27528036504438846, 'cb_weight': 0.9675681691713519, 'lgbm_weight': 0.8202390271939834, 'hgb_weight': 0.15597399390448718, 'gb_weight': 0.03504768043605912, 'rf_weight': 0.07691230934364804}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,625] Trial 968 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.3560452470058932, 'cb_weight': 0.9163712620513947, 'lgbm_weight': 0.8622486787193803, 'hgb_weight': 0.043426820150345366, 'gb_weight': 0.020000541169268204, 'rf_weight': 0.1742242765560129}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,706] Trial 969 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.29516617668704864, 'cb_weight': 0.5353900278598857, 'lgbm_weight': 0.8983520574256537, 'hgb_weight': 0.13268138536768925, 'gb_weight': 0.033000671816769044, 'rf_weight': 0.10786818211451396}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,790] Trial 970 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.24790074502949538, 'cb_weight': 0.9828665130733166, 'lgbm_weight': 0.8411859133583738, 'hgb_weight': 0.09665714727260169, 'gb_weight': 0.058291626132701, 'rf_weight': 0.1462714917038731}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,873] Trial 971 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.21317663523910407, 'cb_weight': 0.9428725961003969, 'lgbm_weight': 0.23512258657144736, 'hgb_weight': 0.11839089727166674, 'gb_weight': 0.017354234173342392, 'rf_weight': 0.12644333185635315}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:53,956] Trial 972 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.16305495317756366, 'cb_weight': 0.9680186097562041, 'lgbm_weight': 0.938417154716187, 'hgb_weight': 0.06726821855796204, 'gb_weight': 0.017048730424640467, 'rf_weight': 0.18774891380812966}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,039] Trial 973 finished with value: 0.8351368305496746 and parameters: {'xgb_weight': 0.3275746854899801, 'cb_weight': 0.9829149254776066, 'lgbm_weight': 0.8048171543500288, 'hgb_weight': 0.08819900478879651, 'gb_weight': 0.04538299340946554, 'rf_weight': 0.15877328549698919}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,123] Trial 974 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.18905390061428484, 'cb_weight': 0.9521169770042481, 'lgbm_weight': 0.8815569318500495, 'hgb_weight': 0.14020890637346903, 'gb_weight': 0.07190036544516303, 'rf_weight': 0.14078828087062709}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,208] Trial 975 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.30431140193337913, 'cb_weight': 0.3647507343620028, 'lgbm_weight': 0.9066500459624899, 'hgb_weight': 0.17638046145851777, 'gb_weight': 0.036952043702979685, 'rf_weight': 0.17092301562178752}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,291] Trial 976 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.2266964121628435, 'cb_weight': 0.9996757146776486, 'lgbm_weight': 0.8546120346696501, 'hgb_weight': 0.1095245587456602, 'gb_weight': 0.017033130497549818, 'rf_weight': 0.09607294305556335}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,374] Trial 977 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.26683753915311625, 'cb_weight': 0.9664101066460102, 'lgbm_weight': 0.8298934838066325, 'hgb_weight': 0.07831376231633107, 'gb_weight': 0.16367753080973102, 'rf_weight': 0.8155934022220434}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,460] Trial 978 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.37161682935524065, 'cb_weight': 0.9324025337457909, 'lgbm_weight': 0.9222728851677832, 'hgb_weight': 0.053766870834877904, 'gb_weight': 0.017968275600791648, 'rf_weight': 0.11507178769739024}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,545] Trial 979 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.337695201949719, 'cb_weight': 0.9821550578214657, 'lgbm_weight': 0.8860754474179007, 'hgb_weight': 0.1575380802542079, 'gb_weight': 0.08372326207664797, 'rf_weight': 0.48034224830436534}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,631] Trial 980 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.28501895957394974, 'cb_weight': 0.9516644087803465, 'lgbm_weight': 0.7903119875216142, 'hgb_weight': 0.12078143555102414, 'gb_weight': 0.051667949510505434, 'rf_weight': 0.20600771108765464}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,715] Trial 981 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.24486646505384277, 'cb_weight': 0.980138548183362, 'lgbm_weight': 0.8731037293366543, 'hgb_weight': 0.09209763852404558, 'gb_weight': 0.30765881090008895, 'rf_weight': 0.15215143995760366}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,799] Trial 982 finished with value: 0.8352283122925325 and parameters: {'xgb_weight': 0.3104014383404639, 'cb_weight': 0.9167861866400865, 'lgbm_weight': 0.8469700873780184, 'hgb_weight': 0.10559868154579345, 'gb_weight': 0.0008697226225111145, 'rf_weight': 0.1824005934970734}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,883] Trial 983 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.3109346468043735, 'cb_weight': 0.9123361487664908, 'lgbm_weight': 0.8318186310075837, 'hgb_weight': 0.13566196185820853, 'gb_weight': 0.03386477965458823, 'rf_weight': 0.19568565986334788}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:54,966] Trial 984 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.3373615813600418, 'cb_weight': 0.9119029579165345, 'lgbm_weight': 0.8492022608439456, 'hgb_weight': 0.10840209029419172, 'gb_weight': 0.0012708890970228202, 'rf_weight': 0.23058060099357017}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,050] Trial 985 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.31406515330098855, 'cb_weight': 0.9283463252401566, 'lgbm_weight': 0.8230964058322319, 'hgb_weight': 0.19124931814002183, 'gb_weight': 0.00040252701885195414, 'rf_weight': 0.18450816116776325}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,133] Trial 986 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.32539362089667206, 'cb_weight': 0.9359668280301854, 'lgbm_weight': 0.8020531974959662, 'hgb_weight': 0.14834896818933815, 'gb_weight': 0.03346620053152925, 'rf_weight': 0.13108954098529488}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,215] Trial 987 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.35226274108550604, 'cb_weight': 0.9469676854216323, 'lgbm_weight': 0.8490428308753618, 'hgb_weight': 0.12631944513946433, 'gb_weight': 0.5143924134205696, 'rf_weight': 0.161759983071545}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,299] Trial 988 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.30856620667661977, 'cb_weight': 0.911509222154244, 'lgbm_weight': 0.8226542146485366, 'hgb_weight': 0.10602019177055233, 'gb_weight': 0.01836842346673571, 'rf_weight': 0.04675053255427582}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,382] Trial 989 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.34489379384716806, 'cb_weight': 0.9345833694790088, 'lgbm_weight': 0.8594810391349073, 'hgb_weight': 0.16681224387282761, 'gb_weight': 0.05306221566751652, 'rf_weight': 0.2530262277196127}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,470] Trial 990 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.28767381301792533, 'cb_weight': 0.9569111001781768, 'lgbm_weight': 0.8509627796464074, 'hgb_weight': 0.07529650685539589, 'gb_weight': 0.0008554534407383383, 'rf_weight': 0.14177468920844885}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,552] Trial 991 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.3748577575137547, 'cb_weight': 0.9623483779085252, 'lgbm_weight': 0.8342170516738009, 'hgb_weight': 0.13218587061735906, 'gb_weight': 0.00034639463959025216, 'rf_weight': 0.21556845418893336}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,635] Trial 992 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.29744234317855883, 'cb_weight': 0.9244472106181298, 'lgbm_weight': 0.8043267019127267, 'hgb_weight': 0.09776210356526586, 'gb_weight': 0.029416698752425488, 'rf_weight': 0.11838215091361026}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,719] Trial 993 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.32638963273417804, 'cb_weight': 0.9496811383781668, 'lgbm_weight': 0.7772143838216671, 'hgb_weight': 0.11900266426871903, 'gb_weight': 0.06425447051268779, 'rf_weight': 0.18610745308298093}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,801] Trial 994 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.30165793507123007, 'cb_weight': 0.9673123510180689, 'lgbm_weight': 0.8702312676166567, 'hgb_weight': 0.03939109917421487, 'gb_weight': 0.03517934403720819, 'rf_weight': 0.07276918133874478}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,884] Trial 995 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.3977056827458465, 'cb_weight': 0.9995137250331619, 'lgbm_weight': 0.8429937713506105, 'hgb_weight': 0.1456212196383506, 'gb_weight': 0.018651504212249616, 'rf_weight': 0.16893771884417141}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:55,965] Trial 996 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.011788080343737128, 'cb_weight': 0.9380113392509274, 'lgbm_weight': 0.8150906786287376, 'hgb_weight': 0.08024358086094696, 'gb_weight': 0.019138289687584204, 'rf_weight': 0.09834210788629615}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:56,047] Trial 997 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.34380676390548726, 'cb_weight': 0.9676216485004342, 'lgbm_weight': 0.8618265280368457, 'hgb_weight': 0.06431400880921365, 'gb_weight': 0.04775025095533093, 'rf_weight': 0.15193430232936397}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:56,128] Trial 998 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.5738109351245141, 'cb_weight': 0.9998790790315704, 'lgbm_weight': 0.8330934053343669, 'hgb_weight': 0.7065284386328574, 'gb_weight': 0.01667802992195888, 'rf_weight': 0.1282494196915556}. Best is trial 638 with value: 0.8352413811129408.
# [I 2024-06-07 13:38:56,210] Trial 999 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.32211117435908293, 'cb_weight': 0.9689670787335347, 'lgbm_weight': 0.8712209280282576, 'hgb_weight': 0.10798985512116396, 'gb_weight': 0.03556035287645243, 'rf_weight': 0.681347499363966}. Best is trial 638 with value: 0.8352413811129408.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835860, AUC: 0.930895
# --- Fold 2 - Accuracy: 0.835925, AUC: 0.932476
# --- Fold 3 - Accuracy: 0.835664, AUC: 0.930151
# --- Fold 4 - Accuracy: 0.834346, AUC: 0.930300
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.925123
#
# ------ Accuracy: 0.833751 ± 0.003443
# ------ AUC:      0.929789 ± 0.002474

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838278, AUC: 0.931273
# --- Fold 2 - Accuracy: 0.837689, AUC: 0.933061
# --- Fold 3 - Accuracy: 0.836317, AUC: 0.930609
# --- Fold 4 - Accuracy: 0.835065, AUC: 0.930489
# --- Fold 5 - Accuracy: 0.827485, AUC: 0.925406
#
# ------ Accuracy: 0.834967 ± 0.003904
# ------ AUC:      0.930168 ± 0.002552

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
