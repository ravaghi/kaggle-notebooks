# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.base import clone
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]
            
            model = clone(self.model)
            model.fit(X_train, y_train)

            y_pred_probs = model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return oof_pred_probs, oof_preds, accs, aucs
    
    def fit_predict_proba(self, X, y, X_test):            
        model = clone(self.model)
        model.fit(X, y)
        return model.predict_proba(X_test)

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    "learning_rate": 0.03723266557925465,
    "max_depth": 24,
    "max_features": 0.6266103788107601,
    "max_leaf_nodes": 67,
    "min_impurity_decrease": 0.021507241003024057,
    "min_samples_leaf": 0.0029046797466403635,
    "min_samples_split": 0.29296996770068356,
    "n_estimators": 2546,
    "random_state": SEED,
    "subsample": 0.8497194158610936,
    "verbose": 0
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_trainer = Trainer(xgb_model)
xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = xgb_trainer.fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_trainer.fit_predict_proba(X, y, test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_trainer = Trainer(cb_model)
cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = cb_trainer.fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_trainer.fit_predict_proba(X, y, test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.836513, AUC: 0.931919
# --- Fold 3 - Accuracy: 0.834618, AUC: 0.929599
# --- Fold 4 - Accuracy: 0.833366, AUC: 0.929235
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.924700
#
# ------ Accuracy: 0.833582 ± 0.003514
# ------ AUC:      0.929121 ± 0.002395

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_trainer = Trainer(lgbm_model)
lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = lgbm_trainer.fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_trainer.fit_predict_proba(X, y, test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_trainer = Trainer(hgb_model)
hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = hgb_trainer.fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_trainer.fit_predict_proba(X, y, test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_trainer = Trainer(gb_model)
gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = gb_trainer.fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_trainer.fit_predict_proba(X, y, test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930418
# --- Fold 2 - Accuracy: 0.835664, AUC: 0.931982
# --- Fold 3 - Accuracy: 0.835795, AUC: 0.930053
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929623
# --- Fold 5 - Accuracy: 0.823629, AUC: 0.925156
#
# ------ Accuracy: 0.832954 ± 0.004788
# ------ AUC:      0.929446 ± 0.002288

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_trainer = Trainer(rf_model)
rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = rf_trainer.fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_trainer.fit_predict_proba(X, y, test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight,
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-10-12 06:43:20,691] A new study created in memory with name: no-name-f1903a86-2678-44e8-bf92-6ac7f4c0fd69
# [I 2024-10-12 06:43:20,709] Trial 0 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.4257214105188958, 'cb_weight': 0.8145837404945526, 'lgbm_weight': 0.7353972901996796, 'hgb_weight': 0.8680031998797357, 'gb_weight': 0.3833807728726202, 'rf_weight': 0.9794566321445206}. Best is trial 0 with value: 0.8341174625578295.
# [I 2024-10-12 06:43:20,726] Trial 1 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.8931943467151353, 'cb_weight': 0.20971516975437543, 'lgbm_weight': 0.7418276474127408, 'hgb_weight': 0.6631433191297429, 'gb_weight': 0.8868014614919371, 'rf_weight': 0.8580127121355462}. Best is trial 0 with value: 0.8341174625578295.
# [I 2024-10-12 06:43:20,743] Trial 2 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.7492622137435189, 'cb_weight': 0.8701447200552547, 'lgbm_weight': 0.18675584347141305, 'hgb_weight': 0.325566716994249, 'gb_weight': 0.3729374349544643, 'rf_weight': 0.7937130250836765}. Best is trial 0 with value: 0.8341174625578295.
# [I 2024-10-12 06:43:20,759] Trial 3 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.15106026954808938, 'cb_weight': 0.16994269903780979, 'lgbm_weight': 0.08116909294984564, 'hgb_weight': 0.30517534166979365, 'gb_weight': 0.7832898018188742, 'rf_weight': 0.16290618197894668}. Best is trial 0 with value: 0.8341174625578295.
# [I 2024-10-12 06:43:20,777] Trial 4 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.07064129588532642, 'cb_weight': 0.701071172891538, 'lgbm_weight': 0.18097987910036895, 'hgb_weight': 0.5989172503787585, 'gb_weight': 0.41526364919539516, 'rf_weight': 0.5135722490632681}. Best is trial 0 with value: 0.8341174625578295.
# [I 2024-10-12 06:43:20,793] Trial 5 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.22065617294616224, 'cb_weight': 0.7255730076351293, 'lgbm_weight': 0.8494349483095229, 'hgb_weight': 0.9288928280136141, 'gb_weight': 0.7359400395657129, 'rf_weight': 0.4765872407403199}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-10-12 06:43:20,810] Trial 6 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.4928929732595768, 'cb_weight': 0.5945202717681869, 'lgbm_weight': 0.07603696537169113, 'hgb_weight': 0.11747691934552718, 'gb_weight': 0.9664656660240684, 'rf_weight': 0.5833222904330377}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-10-12 06:43:20,827] Trial 7 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.0924219138777983, 'cb_weight': 0.013629501631003293, 'lgbm_weight': 0.8369301084678846, 'hgb_weight': 0.9147878993953196, 'gb_weight': 0.7045862607036278, 'rf_weight': 0.38700659769417056}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-10-12 06:43:20,843] Trial 8 finished with value: 0.833803810868031 and parameters: {'xgb_weight': 0.705693904972807, 'cb_weight': 0.9233111565425577, 'lgbm_weight': 0.28815289454812154, 'hgb_weight': 0.6840198457708746, 'gb_weight': 0.5202924997698993, 'rf_weight': 0.8773657752485579}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-10-12 06:43:20,860] Trial 9 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.9238893110931801, 'cb_weight': 0.4892301565307503, 'lgbm_weight': 0.5962139627641655, 'hgb_weight': 0.2642754157843866, 'gb_weight': 0.9917108968630512, 'rf_weight': 0.21039796338844785}. Best is trial 9 with value: 0.834483389529261.
# [I 2024-10-12 06:43:20,920] Trial 10 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.9799232661300472, 'cb_weight': 0.39954983281657325, 'lgbm_weight': 0.4498341111753913, 'hgb_weight': 0.012774145473566922, 'gb_weight': 0.09034716425602418, 'rf_weight': 0.1455504257570366}. Best is trial 9 with value: 0.834483389529261.
# [I 2024-10-12 06:43:20,983] Trial 11 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.9872446299515436, 'cb_weight': 0.41960342584917293, 'lgbm_weight': 0.4987605459846187, 'hgb_weight': 0.0016508503883345196, 'gb_weight': 0.004211713017925556, 'rf_weight': 0.01254891820895565}. Best is trial 9 with value: 0.834483389529261.
# [I 2024-10-12 06:43:21,046] Trial 12 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.7457512172139169, 'cb_weight': 0.3763582992803486, 'lgbm_weight': 0.5025740618409457, 'hgb_weight': 0.2212349945839881, 'gb_weight': 0.11456050840019556, 'rf_weight': 0.23988062016795242}. Best is trial 9 with value: 0.834483389529261.
# [I 2024-10-12 06:43:21,110] Trial 13 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.9904501472444259, 'cb_weight': 0.5321722428987024, 'lgbm_weight': 0.501829431015851, 'hgb_weight': 0.40953867010520795, 'gb_weight': 0.2083338633034276, 'rf_weight': 0.01905221075897326}. Best is trial 13 with value: 0.8345095271700776.
# [I 2024-10-12 06:43:21,171] Trial 14 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.8401897036395232, 'cb_weight': 0.5512881016925536, 'lgbm_weight': 0.63768668257225, 'hgb_weight': 0.4652497054040114, 'gb_weight': 0.2430966116664216, 'rf_weight': 0.016380263546057656}. Best is trial 14 with value: 0.8346794218353851.
# [I 2024-10-12 06:43:21,233] Trial 15 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.6387406480853829, 'cb_weight': 0.6024092534665881, 'lgbm_weight': 0.9581725282366245, 'hgb_weight': 0.45143760013632134, 'gb_weight': 0.26125491563471714, 'rf_weight': 0.01328854540993923}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,296] Trial 16 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.6371044651967576, 'cb_weight': 0.6465192217442458, 'lgbm_weight': 0.9609514197388385, 'hgb_weight': 0.5159763335523059, 'gb_weight': 0.2518477569083929, 'rf_weight': 0.3688541063096366}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,363] Trial 17 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.31968895660639146, 'cb_weight': 0.2877685229512891, 'lgbm_weight': 0.9582782750507305, 'hgb_weight': 0.4697416540530274, 'gb_weight': 0.5565842626962918, 'rf_weight': 0.07601837244948637}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,425] Trial 18 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.5975435701163155, 'cb_weight': 0.9976808266486656, 'lgbm_weight': 0.6655506468384259, 'hgb_weight': 0.7231196432256728, 'gb_weight': 0.2748434890651738, 'rf_weight': 0.3025776974339795}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,487] Trial 19 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.8309266530769942, 'cb_weight': 0.7740906411434352, 'lgbm_weight': 0.8381922511917155, 'hgb_weight': 0.8004343561666087, 'gb_weight': 0.17540317479017087, 'rf_weight': 0.0953604574612903}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,549] Trial 20 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.5839992923170934, 'cb_weight': 0.585464014382731, 'lgbm_weight': 0.3725351584595367, 'hgb_weight': 0.561069609029482, 'gb_weight': 0.5982724625037132, 'rf_weight': 0.7036618657018955}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,616] Trial 21 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.8438209855979161, 'cb_weight': 0.7759787412287097, 'lgbm_weight': 0.8705679022540294, 'hgb_weight': 0.7985317212409975, 'gb_weight': 0.15765950774188459, 'rf_weight': 0.1026740980124306}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,679] Trial 22 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.8247584692806168, 'cb_weight': 0.6450694437134379, 'lgbm_weight': 0.988794197031085, 'hgb_weight': 0.38831528040742813, 'gb_weight': 0.3168972464282573, 'rf_weight': 0.06248018750834605}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,741] Trial 23 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.7914295994516769, 'cb_weight': 0.6583911816837185, 'lgbm_weight': 0.9896801559149018, 'hgb_weight': 0.3990706086374869, 'gb_weight': 0.30660592118351976, 'rf_weight': 0.26698942888597155}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,804] Trial 24 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.6743213943732023, 'cb_weight': 0.4985020453399469, 'lgbm_weight': 0.7131707820183886, 'hgb_weight': 0.4190321184386485, 'gb_weight': 0.4743245177835926, 'rf_weight': 0.004325369434397989}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,867] Trial 25 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.6814901423314588, 'cb_weight': 0.45343329777201663, 'lgbm_weight': 0.7529782818011239, 'hgb_weight': 0.16834316261200516, 'gb_weight': 0.46958396114576134, 'rf_weight': 0.1612931703795789}. Best is trial 15 with value: 0.8347839723986513.
# [I 2024-10-12 06:43:21,930] Trial 26 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.5133643490049322, 'cb_weight': 0.6355606814887584, 'lgbm_weight': 0.914890584459269, 'hgb_weight': 0.3758019268532804, 'gb_weight': 0.34679150357952365, 'rf_weight': 0.3236300334271878}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:21,992] Trial 27 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.5147012909468067, 'cb_weight': 0.5014043888383203, 'lgbm_weight': 0.9089929527109616, 'hgb_weight': 0.5728069465562527, 'gb_weight': 0.5990270181079418, 'rf_weight': 0.32963027378024556}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:22,060] Trial 28 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.36003264870980517, 'cb_weight': 0.34483219352873234, 'lgbm_weight': 0.783014972061608, 'hgb_weight': 0.3346304281779871, 'gb_weight': 0.4511290515438264, 'rf_weight': 0.4419346352556199}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:22,123] Trial 29 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.4509894206336953, 'cb_weight': 0.830537355111422, 'lgbm_weight': 0.6447667179203465, 'hgb_weight': 0.4891212715158718, 'gb_weight': 0.37552412226372556, 'rf_weight': 0.6179420003378752}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:22,185] Trial 30 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.5421087470342107, 'cb_weight': 0.6035260952410967, 'lgbm_weight': 0.9033626934234069, 'hgb_weight': 0.9954295674310744, 'gb_weight': 0.34580689306081175, 'rf_weight': 0.19945696142096137}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:22,248] Trial 31 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.6592355301861876, 'cb_weight': 0.6671186498137707, 'lgbm_weight': 0.9959026023782194, 'hgb_weight': 0.40937532834824847, 'gb_weight': 0.4222090289017829, 'rf_weight': 0.0021712278831557685}. Best is trial 26 with value: 0.8348754541415092.
# [I 2024-10-12 06:43:22,312] Trial 32 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.6522708180478595, 'cb_weight': 0.7076769867594772, 'lgbm_weight': 0.7844241655473667, 'hgb_weight': 0.43454088421636766, 'gb_weight': 0.42173987241448246, 'rf_weight': 0.11737589063569671}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,376] Trial 33 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.3598030168651695, 'cb_weight': 0.7331075971329521, 'lgbm_weight': 0.7829015985752085, 'hgb_weight': 0.3503021945122348, 'gb_weight': 0.4187925577539151, 'rf_weight': 0.11856996272673127}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,441] Trial 34 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.39553910024286787, 'cb_weight': 0.7625978970482621, 'lgbm_weight': 0.7752177785567806, 'hgb_weight': 0.31512406771471757, 'gb_weight': 0.3649938539909685, 'rf_weight': 0.14940660720276738}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,510] Trial 35 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.3411211136567313, 'cb_weight': 0.8671357279942347, 'lgbm_weight': 0.7903285446942699, 'hgb_weight': 0.33902769388501314, 'gb_weight': 0.3722194123515886, 'rf_weight': 0.2777689197758462}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,574] Trial 36 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.2636406246926244, 'cb_weight': 0.7451798237700034, 'lgbm_weight': 0.7187625964183846, 'hgb_weight': 0.2545992869215255, 'gb_weight': 0.5402104016253061, 'rf_weight': 0.18562159188033212}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,643] Trial 37 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.220465882625479, 'cb_weight': 0.7646806259515321, 'lgbm_weight': 0.584811025097791, 'hgb_weight': 0.2559888461162944, 'gb_weight': 0.6878808992144394, 'rf_weight': 0.1298311571449282}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,711] Trial 38 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.27244973495698666, 'cb_weight': 0.9358414470961811, 'lgbm_weight': 0.7197382366267265, 'hgb_weight': 0.11220441447431226, 'gb_weight': 0.5568423703974673, 'rf_weight': 0.19351205112266262}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,775] Trial 39 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.41242181930425637, 'cb_weight': 0.7185456148808912, 'lgbm_weight': 0.8033195035553085, 'hgb_weight': 0.19750381644205361, 'gb_weight': 0.8172763716963412, 'rf_weight': 0.22332960327215792}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,843] Trial 40 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.13137229994550367, 'cb_weight': 0.8364588060374452, 'lgbm_weight': 0.7077160057417622, 'hgb_weight': 0.28760253402475144, 'gb_weight': 0.6421602731307474, 'rf_weight': 0.37227923832492554}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,909] Trial 41 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.21620151811946195, 'cb_weight': 0.9373427807787111, 'lgbm_weight': 0.7312574417814393, 'hgb_weight': 0.12428579034395856, 'gb_weight': 0.542462655539252, 'rf_weight': 0.17861096725643402}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:22,975] Trial 42 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.010260671862499904, 'cb_weight': 0.9032507723108926, 'lgbm_weight': 0.5707641423667825, 'hgb_weight': 0.06778415178789185, 'gb_weight': 0.504367775482145, 'rf_weight': 0.11302140995382107}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,043] Trial 43 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.28589426953172364, 'cb_weight': 0.9988151871060998, 'lgbm_weight': 0.6840600551086016, 'hgb_weight': 0.13796755142297012, 'gb_weight': 0.41577093884427435, 'rf_weight': 0.17509630208336327}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,108] Trial 44 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.27578772478420954, 'cb_weight': 0.735554908760469, 'lgbm_weight': 0.7694437060906023, 'hgb_weight': 0.07168126279416565, 'gb_weight': 0.5910755555645314, 'rf_weight': 0.24396087618349627}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,174] Trial 45 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.39395745252301034, 'cb_weight': 0.8677421927726443, 'lgbm_weight': 0.8098616601225098, 'hgb_weight': 0.2559036655850565, 'gb_weight': 0.6513943731932681, 'rf_weight': 0.07631212310731549}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,239] Trial 46 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.46690625571462846, 'cb_weight': 0.9454184912826686, 'lgbm_weight': 0.6140677138592862, 'hgb_weight': 0.215738149212206, 'gb_weight': 0.5078280693359429, 'rf_weight': 0.9929757339631744}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,305] Trial 47 finished with value: 0.8335816409210904 and parameters: {'xgb_weight': 0.17163749672991363, 'cb_weight': 0.8045268157134584, 'lgbm_weight': 0.005298893989934661, 'hgb_weight': 0.32496390718700296, 'gb_weight': 0.44110958630311964, 'rf_weight': 0.9243812023976512}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,372] Trial 48 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.256029906179091, 'cb_weight': 0.712555136867978, 'lgbm_weight': 0.5512680697285497, 'hgb_weight': 0.2866085265398391, 'gb_weight': 0.7600597558348046, 'rf_weight': 0.5459714933067666}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,440] Trial 49 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.3868213575995883, 'cb_weight': 0.1564783492299998, 'lgbm_weight': 0.868807905209363, 'hgb_weight': 0.061870131926249246, 'gb_weight': 0.5554433919676931, 'rf_weight': 0.4449248661369906}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,508] Trial 50 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.3009327477608232, 'cb_weight': 0.7534844058611007, 'lgbm_weight': 0.6841909116357292, 'hgb_weight': 0.1911098771976901, 'gb_weight': 0.39735253188850805, 'rf_weight': 0.14301607963595023}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,577] Trial 51 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.31150090331453195, 'cb_weight': 0.8129370074846151, 'lgbm_weight': 0.6990038426150484, 'hgb_weight': 0.15423463977306018, 'gb_weight': 0.4024536611298184, 'rf_weight': 0.1357798450577563}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,651] Trial 52 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.3015575994164194, 'cb_weight': 0.6905542486397109, 'lgbm_weight': 0.6609671320816718, 'hgb_weight': 0.1790899965039995, 'gb_weight': 0.4043519330394778, 'rf_weight': 0.13232698109295477}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,719] Trial 53 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.3547265962526967, 'cb_weight': 0.8056660113837707, 'lgbm_weight': 0.7461662146003097, 'hgb_weight': 0.2390274966654917, 'gb_weight': 0.29763197798589724, 'rf_weight': 0.15859524468091346}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,795] Trial 54 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.43964988635735397, 'cb_weight': 0.7526889461275525, 'lgbm_weight': 0.8195386256793201, 'hgb_weight': 0.36454101952096696, 'gb_weight': 0.338938023796932, 'rf_weight': 0.06095201843212503}. Best is trial 32 with value: 0.8349538670639588.
# [I 2024-10-12 06:43:23,862] Trial 55 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.4457319517635177, 'cb_weight': 0.741356919073834, 'lgbm_weight': 0.8361821906674588, 'hgb_weight': 0.36001198269988754, 'gb_weight': 0.34457885968435886, 'rf_weight': 0.06278783523389204}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:23,931] Trial 56 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.5577197247754787, 'cb_weight': 0.7374132051832324, 'lgbm_weight': 0.8295360126551682, 'hgb_weight': 0.35437340386538135, 'gb_weight': 0.33417809076205507, 'rf_weight': 0.0534252705867336}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,018] Trial 57 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.5570277545290827, 'cb_weight': 0.6878536881629524, 'lgbm_weight': 0.8313160769682932, 'hgb_weight': 0.5221224325774091, 'gb_weight': 0.21255578092941557, 'rf_weight': 0.05194351973315558}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,093] Trial 58 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.44843355821298675, 'cb_weight': 0.5503168428367835, 'lgbm_weight': 0.8742878512256219, 'hgb_weight': 0.3692676537310714, 'gb_weight': 0.3155963373735144, 'rf_weight': 0.04439869942502356}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,162] Trial 59 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.603791544023244, 'cb_weight': 0.6246106011440815, 'lgbm_weight': 0.933697530559881, 'hgb_weight': 0.44381057967087245, 'gb_weight': 0.27156038422709655, 'rf_weight': 0.09547809505161324}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,229] Trial 60 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.48568118753019646, 'cb_weight': 0.5809256463978123, 'lgbm_weight': 0.8366962478489072, 'hgb_weight': 0.6324193465064007, 'gb_weight': 0.2194628274663455, 'rf_weight': 0.05066414853023406}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,296] Trial 61 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.4344238338531706, 'cb_weight': 0.7749699155100919, 'lgbm_weight': 0.8115727472463293, 'hgb_weight': 0.3080961036286633, 'gb_weight': 0.34047096895870194, 'rf_weight': 0.07803905552302798}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,364] Trial 62 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.7340802448511706, 'cb_weight': 0.7361488610647572, 'lgbm_weight': 0.7548349685164035, 'hgb_weight': 0.36451517692908963, 'gb_weight': 0.4805170375787511, 'rf_weight': 0.78638692503649}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,433] Trial 63 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.5562074030389412, 'cb_weight': 0.6827280664449404, 'lgbm_weight': 0.8827685545215763, 'hgb_weight': 0.44507249648818414, 'gb_weight': 0.44686461048284065, 'rf_weight': 0.030457954847225133}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,504] Trial 64 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.3809455388421888, 'cb_weight': 0.858213775267478, 'lgbm_weight': 0.3720633963844189, 'hgb_weight': 0.3322103456167938, 'gb_weight': 0.3564258677602663, 'rf_weight': 0.09688609411273241}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,571] Trial 65 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.422406110854878, 'cb_weight': 0.7916723899841264, 'lgbm_weight': 0.8575159067814699, 'hgb_weight': 0.29382160038402777, 'gb_weight': 0.16111431943639576, 'rf_weight': 0.22274569854980142}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,642] Trial 66 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.4848725840448997, 'cb_weight': 0.742638610362543, 'lgbm_weight': 0.7748085867738488, 'hgb_weight': 0.3551067534650822, 'gb_weight': 0.2951297963879063, 'rf_weight': 0.11738151045447605}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,708] Trial 67 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.49425860849931536, 'cb_weight': 0.7123674543970652, 'lgbm_weight': 0.8398143856882724, 'hgb_weight': 0.3563584503451213, 'gb_weight': 0.2905960640979518, 'rf_weight': 0.07070353775365366}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,777] Trial 68 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.630050064666415, 'cb_weight': 0.6679198446530192, 'lgbm_weight': 0.9328673187175809, 'hgb_weight': 0.5377765017205814, 'gb_weight': 0.11043235686256891, 'rf_weight': 0.0343303392740027}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,846] Trial 69 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.5335638026951769, 'cb_weight': 0.7087336126354472, 'lgbm_weight': 0.8431535538162631, 'hgb_weight': 0.48013513600725066, 'gb_weight': 0.2889265497132295, 'rf_weight': 0.07096235932898781}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,914] Trial 70 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.488695982382455, 'cb_weight': 0.8963669888956697, 'lgbm_weight': 0.8112344448289094, 'hgb_weight': 0.4014351162349481, 'gb_weight': 0.22733258891816907, 'rf_weight': 0.10112669746589398}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:24,981] Trial 71 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.5888839486953941, 'cb_weight': 0.7418517542037348, 'lgbm_weight': 0.8980954729746016, 'hgb_weight': 0.3677649846389744, 'gb_weight': 0.3372140289564857, 'rf_weight': 0.12385403000861718}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,053] Trial 72 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.47792524477357307, 'cb_weight': 0.8348910659555111, 'lgbm_weight': 0.7761184872168615, 'hgb_weight': 0.4270051319812904, 'gb_weight': 0.250324964254968, 'rf_weight': 0.057863055358649176}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,123] Trial 73 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.5010270845091981, 'cb_weight': 0.6291059133750576, 'lgbm_weight': 0.7527139643391728, 'hgb_weight': 0.36512979407061785, 'gb_weight': 0.1905458729926579, 'rf_weight': 0.19058517184958967}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,191] Trial 74 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.6191244159656938, 'cb_weight': 0.7055021125650222, 'lgbm_weight': 0.8282442389556147, 'hgb_weight': 0.27185157939637294, 'gb_weight': 0.32702490382252947, 'rf_weight': 0.009731744068799113}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,258] Trial 75 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.7099743374675196, 'cb_weight': 0.0061545415159984795, 'lgbm_weight': 0.9341340619979711, 'hgb_weight': 0.49892781039750755, 'gb_weight': 0.38285849300795904, 'rf_weight': 0.2703349295691381}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,328] Trial 76 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.33866637847348907, 'cb_weight': 0.7809783396036377, 'lgbm_weight': 0.23262815994212216, 'hgb_weight': 0.42903877573530785, 'gb_weight': 0.29034354098703463, 'rf_weight': 0.10550723316892391}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,397] Trial 77 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.5746654465699798, 'cb_weight': 0.7322280704048151, 'lgbm_weight': 0.7804231662299274, 'hgb_weight': 0.3891118865574667, 'gb_weight': 0.45807886467526293, 'rf_weight': 0.17334105289417154}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,464] Trial 78 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.580178958617146, 'cb_weight': 0.6069699161744191, 'lgbm_weight': 0.7286151374242081, 'hgb_weight': 0.4717599769507062, 'gb_weight': 0.9239693121952882, 'rf_weight': 0.24127027136047213}. Best is trial 55 with value: 0.8349930735251836.
# [I 2024-10-12 06:43:25,533] Trial 79 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.5254374285584136, 'cb_weight': 0.672016223119771, 'lgbm_weight': 0.7974537973279678, 'hgb_weight': 0.39755116610396685, 'gb_weight': 0.4659428011087559, 'rf_weight': 0.1754813242544664}. Best is trial 79 with value: 0.8350061423455919.
# [I 2024-10-12 06:43:25,602] Trial 80 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.5391428789758672, 'cb_weight': 0.6549533090102124, 'lgbm_weight': 0.6225603189152786, 'hgb_weight': 0.34203946518374595, 'gb_weight': 0.532905825559011, 'rf_weight': 0.6345424706549266}. Best is trial 79 with value: 0.8350061423455919.
# [I 2024-10-12 06:43:25,672] Trial 81 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.5166803822362718, 'cb_weight': 0.7527128249683175, 'lgbm_weight': 0.7990312504611692, 'hgb_weight': 0.40345050249907505, 'gb_weight': 0.4786987622315053, 'rf_weight': 0.1654772653245696}. Best is trial 81 with value: 0.835058417627225.
# [I 2024-10-12 06:43:25,739] Trial 82 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.5268706982901439, 'cb_weight': 0.6684705097174616, 'lgbm_weight': 0.8600086965699238, 'hgb_weight': 0.40492562774214236, 'gb_weight': 0.4926562198272486, 'rf_weight': 0.08224076438066767}. Best is trial 81 with value: 0.835058417627225.
# [I 2024-10-12 06:43:25,806] Trial 83 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.4560301814275498, 'cb_weight': 0.7579964405389069, 'lgbm_weight': 0.8905461544420694, 'hgb_weight': 0.3048589735746367, 'gb_weight': 0.431686657168117, 'rf_weight': 0.21572185936476182}. Best is trial 81 with value: 0.835058417627225.
# [I 2024-10-12 06:43:25,873] Trial 84 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.44727002397681753, 'cb_weight': 0.7644278849254945, 'lgbm_weight': 0.9634715492863397, 'hgb_weight': 0.30483633059965615, 'gb_weight': 0.4301994668849389, 'rf_weight': 0.22074046058905158}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:25,940] Trial 85 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.5134359858861527, 'cb_weight': 0.8393067008376873, 'lgbm_weight': 0.9723781963341841, 'hgb_weight': 0.23079949123061816, 'gb_weight': 0.4286640614693721, 'rf_weight': 0.225098006722994}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,007] Trial 86 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.7822885819325734, 'cb_weight': 0.6864412446777575, 'lgbm_weight': 0.8949685414434247, 'hgb_weight': 0.26773396926064325, 'gb_weight': 0.5746512133244156, 'rf_weight': 0.2859872135328759}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,080] Trial 87 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.4634094783953337, 'cb_weight': 0.786161965268446, 'lgbm_weight': 0.961340503064848, 'hgb_weight': 0.3064675463913299, 'gb_weight': 0.47433857025356013, 'rf_weight': 0.20407353724049676}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,150] Trial 88 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.6576877526367522, 'cb_weight': 0.8220245076398384, 'lgbm_weight': 0.9184949640075054, 'hgb_weight': 0.3196676818184945, 'gb_weight': 0.5170463811783119, 'rf_weight': 0.3164310020555584}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,218] Trial 89 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.4138958623711242, 'cb_weight': 0.7677397227615462, 'lgbm_weight': 0.7937735839189777, 'hgb_weight': 0.3905442902184286, 'gb_weight': 0.3680731286692175, 'rf_weight': 0.1516240218707638}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,289] Trial 90 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.40787154334535886, 'cb_weight': 0.8920723358726658, 'lgbm_weight': 0.7887488766600232, 'hgb_weight': 0.4302789423192115, 'gb_weight': 0.38773419776436474, 'rf_weight': 0.24979438691638284}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,360] Trial 91 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.4008360840299244, 'cb_weight': 0.9122923451948867, 'lgbm_weight': 0.7354451493379985, 'hgb_weight': 0.45365523337335417, 'gb_weight': 0.38604043630193113, 'rf_weight': 0.1756587844295907}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,429] Trial 92 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.4201966578439834, 'cb_weight': 0.9580383913505015, 'lgbm_weight': 0.7998456901471892, 'hgb_weight': 0.3856101040755653, 'gb_weight': 0.4366328912949272, 'rf_weight': 0.3490052370596062}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,500] Trial 93 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.46667019135770166, 'cb_weight': 0.8919150015789479, 'lgbm_weight': 0.6882271067424302, 'hgb_weight': 0.42322125930234467, 'gb_weight': 0.4984116917094363, 'rf_weight': 0.2557188301898542}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,568] Trial 94 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.46527887853791944, 'cb_weight': 0.8543770167624782, 'lgbm_weight': 0.760513960030023, 'hgb_weight': 0.41019755604019464, 'gb_weight': 0.4580683368546382, 'rf_weight': 0.2565035319660241}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,641] Trial 95 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.3699583849606708, 'cb_weight': 0.9662643585306028, 'lgbm_weight': 0.681760696345419, 'hgb_weight': 0.412932408037057, 'gb_weight': 0.4969956428950344, 'rf_weight': 0.25357396602186355}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,711] Trial 96 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.4595060425625819, 'cb_weight': 0.889976166664489, 'lgbm_weight': 0.7615766700112742, 'hgb_weight': 0.5109992952312672, 'gb_weight': 0.4638787173372542, 'rf_weight': 0.2846921998674911}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,781] Trial 97 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.43846315091957183, 'cb_weight': 0.8499181924085341, 'lgbm_weight': 0.8819936636932568, 'hgb_weight': 0.4667348469923513, 'gb_weight': 0.36806380590668736, 'rf_weight': 0.2567762055187094}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,850] Trial 98 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.4374342292802528, 'cb_weight': 0.8533557807051839, 'lgbm_weight': 0.8688622924910121, 'hgb_weight': 0.4726812292377981, 'gb_weight': 0.36121576762902774, 'rf_weight': 0.3443111499049872}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,920] Trial 99 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.40011488450460214, 'cb_weight': 0.8831977150352264, 'lgbm_weight': 0.8800735819701779, 'hgb_weight': 0.5782239234924786, 'gb_weight': 0.400427017440563, 'rf_weight': 0.3039249352524022}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:26,990] Trial 100 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.4594115548178986, 'cb_weight': 0.800086125597936, 'lgbm_weight': 0.9469831913895532, 'hgb_weight': 0.4199664832132336, 'gb_weight': 0.4406229871267911, 'rf_weight': 0.4202230624251041}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,060] Trial 101 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.5114983562101761, 'cb_weight': 0.9207522021329158, 'lgbm_weight': 0.904382403625435, 'hgb_weight': 0.3867392906556387, 'gb_weight': 0.37499843842834785, 'rf_weight': 0.2111739031746943}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,130] Trial 102 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.4173008639531788, 'cb_weight': 0.8753947725479537, 'lgbm_weight': 0.801765918985019, 'hgb_weight': 0.4635047030270621, 'gb_weight': 0.41802525007599867, 'rf_weight': 0.1416409959146749}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,200] Trial 103 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.4755460004972706, 'cb_weight': 0.7643051203717203, 'lgbm_weight': 0.8502491912115349, 'hgb_weight': 0.4416349603709839, 'gb_weight': 0.49321605385689105, 'rf_weight': 0.26621608127375684}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,271] Trial 104 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.4450050560453099, 'cb_weight': 0.8496938911408664, 'lgbm_weight': 0.9128808892956718, 'hgb_weight': 0.5303717428757208, 'gb_weight': 0.5307851085712473, 'rf_weight': 0.2620749144892319}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,343] Trial 105 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.47583324545518085, 'cb_weight': 0.8130536809526953, 'lgbm_weight': 0.8473690001166307, 'hgb_weight': 0.43222871942904106, 'gb_weight': 0.46701361953772724, 'rf_weight': 0.22318741886798538}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,413] Trial 106 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.41312930168143797, 'cb_weight': 0.8171196648984266, 'lgbm_weight': 0.8561789156643311, 'hgb_weight': 0.4451917351725363, 'gb_weight': 0.48996066134910754, 'rf_weight': 0.23170624952432997}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,484] Trial 107 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.3474013643319513, 'cb_weight': 0.7693795907737238, 'lgbm_weight': 0.983174139883008, 'hgb_weight': 0.5512532552779019, 'gb_weight': 0.4768016658488651, 'rf_weight': 0.15681452882408053}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,553] Trial 108 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.38361306900157244, 'cb_weight': 0.9779977408374235, 'lgbm_weight': 0.4661733843176064, 'hgb_weight': 0.5013584164399472, 'gb_weight': 0.5174117690413735, 'rf_weight': 0.30091667255396426}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,625] Trial 109 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.522878781010176, 'cb_weight': 0.7605699606291194, 'lgbm_weight': 0.8829425081881651, 'hgb_weight': 0.48667026381397904, 'gb_weight': 0.6239927525857354, 'rf_weight': 0.2114938262637296}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,698] Trial 110 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.4760111782294944, 'cb_weight': 0.7953606287871958, 'lgbm_weight': 0.9284959145880213, 'hgb_weight': 0.32991682625607077, 'gb_weight': 0.5660123506669589, 'rf_weight': 0.1945934667881856}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,768] Trial 111 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.4956777134888961, 'cb_weight': 0.8265640753361881, 'lgbm_weight': 0.8490632782867046, 'hgb_weight': 0.42982808126171435, 'gb_weight': 0.455535794057958, 'rf_weight': 0.2444564796120765}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,842] Trial 112 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.43213445502251047, 'cb_weight': 0.8197361020952905, 'lgbm_weight': 0.8422183187043235, 'hgb_weight': 0.42971375040961507, 'gb_weight': 0.4033543847163546, 'rf_weight': 0.2495086859469976}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,916] Trial 113 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.5002454154282773, 'cb_weight': 0.8122402440640405, 'lgbm_weight': 0.8906072311238526, 'hgb_weight': 0.427946640669675, 'gb_weight': 0.3950436245385746, 'rf_weight': 0.23206765421716893}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:27,987] Trial 114 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.5466634547412056, 'cb_weight': 0.8210040507186804, 'lgbm_weight': 0.8887703275443591, 'hgb_weight': 0.4633996959386512, 'gb_weight': 0.40178256170454285, 'rf_weight': 0.2422148250194394}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,059] Trial 115 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.4963837393828407, 'cb_weight': 0.8720223805590319, 'lgbm_weight': 0.819763179259773, 'hgb_weight': 0.42665522036922504, 'gb_weight': 0.4347059858610257, 'rf_weight': 0.28463402985679254}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,130] Trial 116 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.42870384657871047, 'cb_weight': 0.9295356869134022, 'lgbm_weight': 0.7952148871617342, 'hgb_weight': 0.39014373511643363, 'gb_weight': 0.4173310391009383, 'rf_weight': 0.2102306116447037}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,204] Trial 117 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.42937989798662324, 'cb_weight': 0.9299345903879161, 'lgbm_weight': 0.7995064210761762, 'hgb_weight': 0.43332122087562697, 'gb_weight': 0.39012498821379393, 'rf_weight': 0.1711102542750652}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,278] Trial 118 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.32153871215327917, 'cb_weight': 0.9007212926933283, 'lgbm_weight': 0.9534983021604393, 'hgb_weight': 0.38879479736463496, 'gb_weight': 0.36267514322510835, 'rf_weight': 0.23505394766243048}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,351] Trial 119 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.5017448441175542, 'cb_weight': 0.8356205594233455, 'lgbm_weight': 0.788799587639386, 'hgb_weight': 0.49094154102750315, 'gb_weight': 0.4148848374358799, 'rf_weight': 0.3837137882843875}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,427] Trial 120 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.3680274189389076, 'cb_weight': 0.9146825420024693, 'lgbm_weight': 0.8499142661538941, 'hgb_weight': 0.3961295786450656, 'gb_weight': 0.3856050871737734, 'rf_weight': 0.19356136180950742}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,497] Trial 121 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.4046833595994083, 'cb_weight': 0.8010174166656507, 'lgbm_weight': 0.8208636053580401, 'hgb_weight': 0.45279106694908305, 'gb_weight': 0.4673312085230831, 'rf_weight': 0.15624878883401724}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,569] Trial 122 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.44840698220635383, 'cb_weight': 0.8805393949693553, 'lgbm_weight': 0.8597762524567748, 'hgb_weight': 0.3773566594506992, 'gb_weight': 0.00064585192570632, 'rf_weight': 0.214581806002889}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,638] Trial 123 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.4302532362281663, 'cb_weight': 0.9470960752618722, 'lgbm_weight': 0.8972864102247271, 'hgb_weight': 0.41056939069575754, 'gb_weight': 0.4492094720373329, 'rf_weight': 0.3015089719919051}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,709] Trial 124 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.5616513344941642, 'cb_weight': 0.08537546706705246, 'lgbm_weight': 0.5332618065801895, 'hgb_weight': 0.2915346047219655, 'gb_weight': 0.4229721176306439, 'rf_weight': 0.246707447253997}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,779] Trial 125 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.52250777774214, 'cb_weight': 0.2675321105250724, 'lgbm_weight': 0.7417340041522966, 'hgb_weight': 0.3416521973022395, 'gb_weight': 0.4501816734271484, 'rf_weight': 0.33329197145575606}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,850] Trial 126 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.4804308214168646, 'cb_weight': 0.8579160655393198, 'lgbm_weight': 0.8320605180372792, 'hgb_weight': 0.42303895126649305, 'gb_weight': 0.36457063131825457, 'rf_weight': 0.21964760448296847}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,920] Trial 127 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.5014515237527579, 'cb_weight': 0.8213340273747859, 'lgbm_weight': 0.705592500595741, 'hgb_weight': 0.4788342643520497, 'gb_weight': 0.5078325013721741, 'rf_weight': 0.18516180202576338}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:28,990] Trial 128 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.3840752079750017, 'cb_weight': 0.8385781855940737, 'lgbm_weight': 0.7930511578827452, 'hgb_weight': 0.37921685379333653, 'gb_weight': 0.41121729255100453, 'rf_weight': 0.2773269959221032}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,060] Trial 129 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.3907606657680171, 'cb_weight': 0.8397101117816759, 'lgbm_weight': 0.7946660839272632, 'hgb_weight': 0.3838546913881467, 'gb_weight': 0.3993164135307131, 'rf_weight': 0.2784811859454087}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,130] Trial 130 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.37318630864030083, 'cb_weight': 0.8966147857621485, 'lgbm_weight': 0.10380690773613122, 'hgb_weight': 0.3811802368069602, 'gb_weight': 0.3173388396910123, 'rf_weight': 0.314712883629377}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,202] Trial 131 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.3872314204779786, 'cb_weight': 0.8431064372045983, 'lgbm_weight': 0.7921802081133656, 'hgb_weight': 0.39963570995867076, 'gb_weight': 0.4069643410424374, 'rf_weight': 0.27671726961452564}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,273] Trial 132 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.3312466744577914, 'cb_weight': 0.8389797071993239, 'lgbm_weight': 0.7825162386475722, 'hgb_weight': 0.43726718719291974, 'gb_weight': 0.40666368157077837, 'rf_weight': 0.28105403574849536}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,344] Trial 133 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.39298628369334765, 'cb_weight': 0.7876287667939328, 'lgbm_weight': 0.8146857594899944, 'hgb_weight': 0.4531189967074926, 'gb_weight': 0.37789136796629136, 'rf_weight': 0.3566273523354315}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,418] Trial 134 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.3516593689728399, 'cb_weight': 0.8708632736954013, 'lgbm_weight': 0.7661836693820493, 'hgb_weight': 0.4049073471631983, 'gb_weight': 0.39827110170769287, 'rf_weight': 0.25877114433459886}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,490] Trial 135 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.4146474834962429, 'cb_weight': 0.8139039939760787, 'lgbm_weight': 0.7366872559866038, 'hgb_weight': 0.35190639844108457, 'gb_weight': 0.36024079129118325, 'rf_weight': 0.29560076148551817}. Best is trial 84 with value: 0.8350845552680415.
# [I 2024-10-12 06:43:29,561] Trial 136 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.38663100651345067, 'cb_weight': 0.8456224997592261, 'lgbm_weight': 0.8750043457770049, 'hgb_weight': 0.5128561099766146, 'gb_weight': 0.4188137171650688, 'rf_weight': 0.2675885991540768}. Best is trial 84 with value: 0.8350845552680415.
# ...
# [I 2024-10-12 06:44:52,116] Trial 955 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.29227333047861387, 'cb_weight': 0.6507907192563962, 'lgbm_weight': 0.9158669867195598, 'hgb_weight': 0.34026840558462945, 'gb_weight': 0.34191783810648496, 'rf_weight': 0.4596283854688853}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,245] Trial 956 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.24428057229871897, 'cb_weight': 0.6161828396526936, 'lgbm_weight': 0.9475132808389688, 'hgb_weight': 0.3028508570029359, 'gb_weight': 0.4473856130969739, 'rf_weight': 0.18909836966818064}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,369] Trial 957 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.32428995609985567, 'cb_weight': 0.674018966638627, 'lgbm_weight': 0.9712038958287939, 'hgb_weight': 0.35192986165905893, 'gb_weight': 0.3659185724935794, 'rf_weight': 0.21696695101591532}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,496] Trial 958 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.2642657648801611, 'cb_weight': 0.6370940958359012, 'lgbm_weight': 0.9288458213791082, 'hgb_weight': 0.24288083142318742, 'gb_weight': 0.3886155213039551, 'rf_weight': 0.2469771405267225}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,624] Trial 959 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.2959954721416242, 'cb_weight': 0.7601373656059385, 'lgbm_weight': 0.977885179396932, 'hgb_weight': 0.3272446020357687, 'gb_weight': 0.3498675117246603, 'rf_weight': 0.2266903989660999}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,750] Trial 960 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.2331597825515861, 'cb_weight': 0.3235163224479201, 'lgbm_weight': 0.9560451847734464, 'hgb_weight': 0.2730313949667518, 'gb_weight': 0.42125736004969816, 'rf_weight': 0.01936962080404525}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:52,875] Trial 961 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.27456502255898285, 'cb_weight': 0.6986411413737535, 'lgbm_weight': 0.9012162102797948, 'hgb_weight': 0.39931312915631884, 'gb_weight': 0.2609858123488247, 'rf_weight': 0.2641501266303033}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,001] Trial 962 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.366955018571715, 'cb_weight': 0.6569914996147664, 'lgbm_weight': 0.983058745886762, 'hgb_weight': 0.29903029701839146, 'gb_weight': 0.32317491211131283, 'rf_weight': 0.8152925223688043}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,134] Trial 963 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.2134180474886332, 'cb_weight': 0.6152337453030955, 'lgbm_weight': 0.9342661084425704, 'hgb_weight': 0.3705047287760631, 'gb_weight': 0.3728751813459072, 'rf_weight': 0.19779782651585423}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,262] Trial 964 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.25523902334375353, 'cb_weight': 0.6378076837927918, 'lgbm_weight': 0.9539753609066348, 'hgb_weight': 0.3433322821220875, 'gb_weight': 0.4052020463708564, 'rf_weight': 0.10804700799852948}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,388] Trial 965 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.31023284569736087, 'cb_weight': 0.5767007352632895, 'lgbm_weight': 0.9130405320259398, 'hgb_weight': 0.6976867498158394, 'gb_weight': 0.34450001547931314, 'rf_weight': 0.2397123590563312}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,514] Trial 966 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.04836458221269524, 'cb_weight': 0.6796647777993077, 'lgbm_weight': 0.8854591290658141, 'hgb_weight': 0.31557242844621647, 'gb_weight': 0.3590942947493103, 'rf_weight': 0.17843402762857505}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,641] Trial 967 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.2742559939780272, 'cb_weight': 0.5985427635916365, 'lgbm_weight': 0.9796241119821011, 'hgb_weight': 0.36032735095005936, 'gb_weight': 0.301897930825317, 'rf_weight': 0.14542064546132177}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,773] Trial 968 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.231383422099343, 'cb_weight': 0.6542214531377674, 'lgbm_weight': 0.931876335752414, 'hgb_weight': 0.14995034246934524, 'gb_weight': 0.3855183214619379, 'rf_weight': 0.21214243956128914}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:53,900] Trial 969 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.2906481478146209, 'cb_weight': 0.7083186203511473, 'lgbm_weight': 0.961015216579763, 'hgb_weight': 0.3303255365486337, 'gb_weight': 0.3252271581712232, 'rf_weight': 0.2569234622858443}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,063] Trial 970 finished with value: 0.8351760370108994 and parameters: {'xgb_weight': 0.25336799554490336, 'cb_weight': 0.6254308647870276, 'lgbm_weight': 0.8593169620799748, 'hgb_weight': 0.2918332712114575, 'gb_weight': 0.3627987045326741, 'rf_weight': 0.2049069264318715}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,194] Trial 971 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.6154345851274057, 'cb_weight': 0.6730920465450018, 'lgbm_weight': 0.9061067371094289, 'hgb_weight': 0.38136928482959936, 'gb_weight': 0.4031072851696599, 'rf_weight': 0.22931219382495394}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,321] Trial 972 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.33754246539987015, 'cb_weight': 0.6427477503353103, 'lgbm_weight': 0.9824837760351453, 'hgb_weight': 0.31152227477477107, 'gb_weight': 0.43159809568973223, 'rf_weight': 0.29058334323833107}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,446] Trial 973 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.19691686316037144, 'cb_weight': 0.6915969610035003, 'lgbm_weight': 0.20053824967524703, 'hgb_weight': 0.26517104492627724, 'gb_weight': 0.34290444645843704, 'rf_weight': 0.18437513281665308}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,572] Trial 974 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.28785598130336854, 'cb_weight': 0.6187302801800673, 'lgbm_weight': 0.9999091260005214, 'hgb_weight': 0.3458707963231781, 'gb_weight': 0.37951528030559395, 'rf_weight': 0.23936401413638375}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,697] Trial 975 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.24655235482591847, 'cb_weight': 0.6614054707296052, 'lgbm_weight': 0.941646007503669, 'hgb_weight': 0.33359333364163696, 'gb_weight': 0.28164418231076754, 'rf_weight': 0.16144566347891984}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,824] Trial 976 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.316421168787753, 'cb_weight': 0.7314581271079713, 'lgbm_weight': 0.9595230726035566, 'hgb_weight': 0.3577547859170394, 'gb_weight': 0.30925004026601377, 'rf_weight': 0.2148855037860639}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:54,952] Trial 977 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.21679425318803086, 'cb_weight': 0.6012463156457007, 'lgbm_weight': 0.9232087822479755, 'hgb_weight': 0.2841776347445675, 'gb_weight': 0.46666913665155324, 'rf_weight': 0.5152712255071565}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,084] Trial 978 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.2669858292633302, 'cb_weight': 0.640724537489322, 'lgbm_weight': 0.4322039377099222, 'hgb_weight': 0.3114999906062106, 'gb_weight': 0.3347888012487442, 'rf_weight': 0.2588857134509315}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,213] Trial 979 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.29936768155357646, 'cb_weight': 0.6857654934908116, 'lgbm_weight': 0.8910676034660016, 'hgb_weight': 0.42995995727927455, 'gb_weight': 0.3571961596083395, 'rf_weight': 0.19458331937986031}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,342] Trial 980 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.23181941645209125, 'cb_weight': 0.6618797925377704, 'lgbm_weight': 0.9467886018251557, 'hgb_weight': 0.3922309118326308, 'gb_weight': 0.38993596830263105, 'rf_weight': 0.22064026657227215}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,471] Trial 981 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.2663599259368952, 'cb_weight': 0.6255996604290118, 'lgbm_weight': 0.9691402243162376, 'hgb_weight': 0.3273785930916123, 'gb_weight': 0.37448169285123634, 'rf_weight': 0.2789132765047935}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,608] Trial 982 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.28227531155500585, 'cb_weight': 0.7121848200901624, 'lgbm_weight': 0.9173894014386245, 'hgb_weight': 0.2955549650090499, 'gb_weight': 0.4061876472789696, 'rf_weight': 0.12841537457644508}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,735] Trial 983 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.25090595027191, 'cb_weight': 0.6429631537527177, 'lgbm_weight': 0.9825859272877848, 'hgb_weight': 0.1038160518843203, 'gb_weight': 0.32448151283116244, 'rf_weight': 0.4067469504956597}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,864] Trial 984 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.3157097577599819, 'cb_weight': 0.5726947741056713, 'lgbm_weight': 0.8784882943943266, 'hgb_weight': 0.37059001809197906, 'gb_weight': 0.3654572545946602, 'rf_weight': 0.2449022265319136}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:55,990] Trial 985 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.22211276722207096, 'cb_weight': 0.46659705389518535, 'lgbm_weight': 0.9416718507403736, 'hgb_weight': 0.23733411385349829, 'gb_weight': 0.3514296139159664, 'rf_weight': 0.20450130370699882}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,120] Trial 986 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.24323041625533523, 'cb_weight': 0.6669428251569822, 'lgbm_weight': 0.9629420626291322, 'hgb_weight': 0.22278173304145704, 'gb_weight': 0.3084446226289706, 'rf_weight': 0.17148418096642884}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,248] Trial 987 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.17489925611369328, 'cb_weight': 0.535425760459682, 'lgbm_weight': 0.9040420025252894, 'hgb_weight': 0.34710172032934283, 'gb_weight': 0.3867291142476823, 'rf_weight': 0.22890139919626196}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,379] Trial 988 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.2703665253143356, 'cb_weight': 0.6029851647570301, 'lgbm_weight': 0.9229178075628681, 'hgb_weight': 0.31504131887416914, 'gb_weight': 0.33934845048263795, 'rf_weight': 0.19203219280820216}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,507] Trial 989 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.28989948547183914, 'cb_weight': 0.6276052933073495, 'lgbm_weight': 0.983035723307945, 'hgb_weight': 0.33594241921481377, 'gb_weight': 0.41378204741752755, 'rf_weight': 0.26812278776394366}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,634] Trial 990 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.3371946330644646, 'cb_weight': 0.680618973874658, 'lgbm_weight': 0.9487786451720196, 'hgb_weight': 0.26633443553385105, 'gb_weight': 0.36687683999951637, 'rf_weight': 0.21979330916146703}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,759] Trial 991 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.2655230047238497, 'cb_weight': 0.6437239930706143, 'lgbm_weight': 0.9360562508493913, 'hgb_weight': 0.3669460012491858, 'gb_weight': 0.4369258922786913, 'rf_weight': 0.24050503375421692}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:56,887] Trial 992 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.20210489159529132, 'cb_weight': 0.7482734731085532, 'lgbm_weight': 0.9644491390344583, 'hgb_weight': 0.2991923431007636, 'gb_weight': 0.34723972881992166, 'rf_weight': 0.2085294039111742}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,013] Trial 993 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.30571356865282795, 'cb_weight': 0.6155022220270386, 'lgbm_weight': 0.9810066548321305, 'hgb_weight': 0.32624567413526706, 'gb_weight': 0.2878525617372041, 'rf_weight': 0.3075553221436003}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,142] Trial 994 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.24405263815313652, 'cb_weight': 0.6916966082815559, 'lgbm_weight': 0.9028378474210892, 'hgb_weight': 0.3504495693879601, 'gb_weight': 0.3272112313254337, 'rf_weight': 0.17943798787923407}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,267] Trial 995 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.2808549984952054, 'cb_weight': 0.6583322602632328, 'lgbm_weight': 0.92361154696104, 'hgb_weight': 0.2803589843319819, 'gb_weight': 0.38898228181392364, 'rf_weight': 0.2464605484151582}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,395] Trial 996 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.22915222210235522, 'cb_weight': 0.5885640289374575, 'lgbm_weight': 0.3736327487911538, 'hgb_weight': 0.4047605985837457, 'gb_weight': 0.36918182753320333, 'rf_weight': 0.1566902072218677}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,522] Trial 997 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.25188723977101113, 'cb_weight': 0.6696846593804425, 'lgbm_weight': 0.9984052759986567, 'hgb_weight': 0.3109694258469505, 'gb_weight': 0.41554267851087107, 'rf_weight': 0.22686438107140938}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,649] Trial 998 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.2948247148996624, 'cb_weight': 0.7038311320372396, 'lgbm_weight': 0.8723415527115038, 'hgb_weight': 0.6435203592741621, 'gb_weight': 0.351629814189829, 'rf_weight': 0.1970805508103609}. Best is trial 779 with value: 0.8353197940353904.
# [I 2024-10-12 06:44:57,774] Trial 999 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.35718756500558024, 'cb_weight': 0.6352362087181453, 'lgbm_weight': 0.9491397401591357, 'hgb_weight': 0.7366164060200739, 'gb_weight': 0.3133232065979062, 'rf_weight': 0.266354070434036}. Best is trial 779 with value: 0.8353197940353904.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_trainer = Trainer(voting_model)
voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = voting_trainer.fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_trainer.fit_predict_proba(X, y, test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.836252, AUC: 0.931217
# --- Fold 2 - Accuracy: 0.836644, AUC: 0.932848
# --- Fold 3 - Accuracy: 0.837101, AUC: 0.930486
# --- Fold 4 - Accuracy: 0.834085, AUC: 0.930505
# --- Fold 5 - Accuracy: 0.827289, AUC: 0.925489
#
# ------ Accuracy: 0.834274 ± 0.003643
# ------ AUC:      0.930109 ± 0.002465

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_trainer = Trainer(weighted_voting_model)
weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = weighted_voting_trainer.fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_trainer.fit_predict_proba(X, y, test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838408, AUC: 0.931461
# --- Fold 2 - Accuracy: 0.838016, AUC: 0.933155
# --- Fold 3 - Accuracy: 0.837297, AUC: 0.930814
# --- Fold 4 - Accuracy: 0.835392, AUC: 0.930714
# --- Fold 5 - Accuracy: 0.827485, AUC: 0.925669
#
# ------ Accuracy: 0.835320 ± 0.004052
# ------ AUC:      0.930363 ± 0.002504

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
