# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    "learning_rate": 0.03723266557925465,
    "max_depth": 24,
    "max_features": 0.6266103788107601,
    "max_leaf_nodes": 67,
    "min_impurity_decrease": 0.021507241003024057,
    "min_samples_leaf": 0.0029046797466403635,
    "min_samples_split": 0.29296996770068356,
    "n_estimators": 2546,
    "random_state": SEED,
    "subsample": 0.8497194158610936,
    "verbose": 0
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930418
# --- Fold 2 - Accuracy: 0.835664, AUC: 0.931982
# --- Fold 3 - Accuracy: 0.835795, AUC: 0.930053
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929623
# --- Fold 5 - Accuracy: 0.823629, AUC: 0.925156
#
# ------ Accuracy: 0.832954 ± 0.004788
# ------ AUC:      0.929446 ± 0.002288

# %%
# rf_model = RandomForestClassifier(**rf_params)
# rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
# oof_pred_probs['RF'] = rf_oof_pred_probs
# oof_preds['RF'] = rf_oof_preds
# test_pred_probs['RF'] = rf_model.predict_proba(test)
# accuracies['RF'] = rf_accs
# aucs['RF'] = rf_aucs

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
#     ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
#     rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight,
        hgb_weight, 
        gb_weight, 
#         rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-20 19:33:45,269] A new study created in memory with name: no-name-2db0d919-6b28-4cbc-a736-a375399cda6e
# [I 2024-06-20 19:33:45,283] Trial 0 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.4257214105188958, 'cb_weight': 0.8145837404945526, 'lgbm_weight': 0.7353972901996796, 'hgb_weight': 0.8680031998797357, 'gb_weight': 0.3833807728726202}. Best is trial 0 with value: 0.8345618024517107.
# [I 2024-06-20 19:33:45,297] Trial 1 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.9794566321445206, 'cb_weight': 0.8931943467151353, 'lgbm_weight': 0.20971516975437543, 'hgb_weight': 0.7418276474127408, 'gb_weight': 0.6631433191297429}. Best is trial 0 with value: 0.8345618024517107.
# [I 2024-06-20 19:33:45,309] Trial 2 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.8868014614919371, 'cb_weight': 0.8580127121355462, 'lgbm_weight': 0.7492622137435189, 'hgb_weight': 0.8701447200552547, 'gb_weight': 0.18675584347141305}. Best is trial 2 with value: 0.834627146553752.
# [I 2024-06-20 19:33:45,322] Trial 3 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.325566716994249, 'cb_weight': 0.3729374349544643, 'lgbm_weight': 0.7937130250836765, 'hgb_weight': 0.15106026954808938, 'gb_weight': 0.16994269903780979}. Best is trial 2 with value: 0.834627146553752.
# [I 2024-06-20 19:33:45,335] Trial 4 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.08116909294984564, 'cb_weight': 0.30517534166979365, 'lgbm_weight': 0.7832898018188742, 'hgb_weight': 0.16290618197894668, 'gb_weight': 0.07064129588532642}. Best is trial 2 with value: 0.834627146553752.
# [I 2024-06-20 19:33:45,348] Trial 5 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.701071172891538, 'cb_weight': 0.18097987910036895, 'lgbm_weight': 0.5989172503787585, 'hgb_weight': 0.41526364919539516, 'gb_weight': 0.5135722490632681}. Best is trial 2 with value: 0.834627146553752.
# [I 2024-06-20 19:33:45,361] Trial 6 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.22065617294616224, 'cb_weight': 0.7255730076351293, 'lgbm_weight': 0.8494349483095229, 'hgb_weight': 0.9288928280136141, 'gb_weight': 0.7359400395657129}. Best is trial 2 with value: 0.834627146553752.
# [I 2024-06-20 19:33:45,374] Trial 7 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.4765872407403199, 'cb_weight': 0.4928929732595768, 'lgbm_weight': 0.5945202717681869, 'hgb_weight': 0.07603696537169113, 'gb_weight': 0.11747691934552718}. Best is trial 7 with value: 0.8346402153741603.
# [I 2024-06-20 19:33:45,387] Trial 8 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.9664656660240684, 'cb_weight': 0.5833222904330377, 'lgbm_weight': 0.0924219138777983, 'hgb_weight': 0.013629501631003293, 'gb_weight': 0.8369301084678846}. Best is trial 7 with value: 0.8346402153741603.
# [I 2024-06-20 19:33:45,399] Trial 9 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.9147878993953196, 'cb_weight': 0.7045862607036278, 'lgbm_weight': 0.38700659769417056, 'hgb_weight': 0.705693904972807, 'gb_weight': 0.9233111565425577}. Best is trial 7 with value: 0.8346402153741603.
# [I 2024-06-20 19:33:45,436] Trial 10 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.5950888691819313, 'cb_weight': 0.016344190382097223, 'lgbm_weight': 0.4498341111753913, 'hgb_weight': 0.46254671166743405, 'gb_weight': 0.3809653320531152}. Best is trial 7 with value: 0.8346402153741603.
# [I 2024-06-20 19:33:45,473] Trial 11 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.7214564861982329, 'cb_weight': 0.986752730063357, 'lgbm_weight': 0.9539566089728277, 'hgb_weight': 0.6047695042947498, 'gb_weight': 0.0023894474737008176}. Best is trial 11 with value: 0.834770903578243.
# [I 2024-06-20 19:33:45,510] Trial 12 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.7267988657648983, 'cb_weight': 0.9927483062162223, 'lgbm_weight': 0.9935052724009241, 'hgb_weight': 0.5974246836240658, 'gb_weight': 0.02763237365998994}. Best is trial 11 with value: 0.834770903578243.
# [I 2024-06-20 19:33:45,546] Trial 13 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.7224933170583485, 'cb_weight': 0.9518696276046485, 'lgbm_weight': 0.9946726919411853, 'hgb_weight': 0.6046545558483203, 'gb_weight': 0.04678909514851841}. Best is trial 11 with value: 0.834770903578243.
# [I 2024-06-20 19:33:45,583] Trial 14 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.7610676049580282, 'cb_weight': 0.9596758868799529, 'lgbm_weight': 0.9929014713511937, 'hgb_weight': 0.3318626283813041, 'gb_weight': 0.28676087899577224}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,620] Trial 15 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.6139918609832242, 'cb_weight': 0.7045303482020429, 'lgbm_weight': 0.9146768078956145, 'hgb_weight': 0.31797140271433694, 'gb_weight': 0.3058004292651476}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,657] Trial 16 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.8170885507135777, 'cb_weight': 0.998354736070845, 'lgbm_weight': 0.6360448142771443, 'hgb_weight': 0.3308681147096241, 'gb_weight': 0.2790966528943193}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,695] Trial 17 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.5583414197243839, 'cb_weight': 0.7916774336050647, 'lgbm_weight': 0.32054202335522364, 'hgb_weight': 0.2863661425002799, 'gb_weight': 0.5243837906224817}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,733] Trial 18 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.5895180349664686, 'cb_weight': 0.5552244088101725, 'lgbm_weight': 0.2996791845933388, 'hgb_weight': 0.29111546175441944, 'gb_weight': 0.5677452611817346}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,772] Trial 19 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.3566917416953179, 'cb_weight': 0.7801162259074721, 'lgbm_weight': 0.04452603618893902, 'hgb_weight': 0.20258980409990573, 'gb_weight': 0.4425302370692251}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,810] Trial 20 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.5317739573033382, 'cb_weight': 0.6221607375172186, 'lgbm_weight': 0.19822568760188286, 'hgb_weight': 0.4168267747730878, 'gb_weight': 0.6465786666026099}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,847] Trial 21 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.8053854902654493, 'cb_weight': 0.8786320682384873, 'lgbm_weight': 0.8897938731794253, 'hgb_weight': 0.576843161180991, 'gb_weight': 0.25379366685820726}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,887] Trial 22 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.660937245685621, 'cb_weight': 0.9008806410123201, 'lgbm_weight': 0.3725351584595367, 'hgb_weight': 0.2840566795899414, 'gb_weight': 0.5470937503146892}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,925] Trial 23 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.8171267239836685, 'cb_weight': 0.8291776446544648, 'lgbm_weight': 0.521953398517533, 'hgb_weight': 0.510770547261278, 'gb_weight': 0.4160178558398292}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:45,963] Trial 24 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.5117101278599081, 'cb_weight': 0.9492107713537038, 'lgbm_weight': 0.6693593607069641, 'hgb_weight': 0.671396392350826, 'gb_weight': 0.15593368310006714}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,001] Trial 25 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.7998992421446297, 'cb_weight': 0.7586468426141068, 'lgbm_weight': 0.8946317746294447, 'hgb_weight': 0.21858234293658302, 'gb_weight': 0.32093184693570603}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,039] Trial 26 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.7461688427876907, 'cb_weight': 0.6610906785592976, 'lgbm_weight': 0.2474892677029809, 'hgb_weight': 0.375227436160055, 'gb_weight': 0.21358815445707452}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,077] Trial 27 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.6532535263181127, 'cb_weight': 0.9076061773009458, 'lgbm_weight': 0.5153580582525586, 'hgb_weight': 0.5050548423366443, 'gb_weight': 0.005794653327422341}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,116] Trial 28 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.887317493487946, 'cb_weight': 0.5032071684486494, 'lgbm_weight': 0.14265466884156178, 'hgb_weight': 0.7710744675090253, 'gb_weight': 0.46958396114576134}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,155] Trial 29 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.3953935231389287, 'cb_weight': 0.8124065855507074, 'lgbm_weight': 0.6961063334612125, 'hgb_weight': 0.2408666242337668, 'gb_weight': 0.7615125470045425}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,194] Trial 30 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.3962042935932598, 'cb_weight': 0.8169425591211978, 'lgbm_weight': 0.3370507128562526, 'hgb_weight': 0.07426532935341235, 'gb_weight': 0.9859957289097836}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,235] Trial 31 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.25090177144381764, 'cb_weight': 0.7976107284611805, 'lgbm_weight': 0.7086917714301255, 'hgb_weight': 0.2455062083280367, 'gb_weight': 0.817374876101838}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,275] Trial 32 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.2533380187248133, 'cb_weight': 0.7953724652550179, 'lgbm_weight': 0.6829949364340577, 'hgb_weight': 0.25866951205307226, 'gb_weight': 0.7704740938919585}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,314] Trial 33 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.16064796008876867, 'cb_weight': 0.8441034924618198, 'lgbm_weight': 0.701249495959746, 'hgb_weight': 0.13196706705577596, 'gb_weight': 0.6233137438646768}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,353] Trial 34 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.02056522689013024, 'cb_weight': 0.8925885447425866, 'lgbm_weight': 0.4531071752885296, 'hgb_weight': 0.1474095662611784, 'gb_weight': 0.6060164725139818}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,391] Trial 35 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.19010440002353424, 'cb_weight': 0.8457558114916732, 'lgbm_weight': 0.7551699325372329, 'hgb_weight': 0.10106047710450766, 'gb_weight': 0.6542281298511039}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,430] Trial 36 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.2739068185946679, 'cb_weight': 0.6586306672389991, 'lgbm_weight': 0.7805322426102166, 'hgb_weight': 0.35863069282933235, 'gb_weight': 0.6999122360244773}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,469] Trial 37 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.1281782337801769, 'cb_weight': 0.42173987241448246, 'lgbm_weight': 0.8265960623159743, 'hgb_weight': 0.07744914683631425, 'gb_weight': 0.8345497078623193}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,508] Trial 38 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.45529635763030296, 'cb_weight': 0.728554782803593, 'lgbm_weight': 0.7436843537023102, 'hgb_weight': 0.19696542064809722, 'gb_weight': 0.36008924744568505}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,547] Trial 39 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.1920374399449545, 'cb_weight': 0.9235233469253161, 'lgbm_weight': 0.5739107545416627, 'hgb_weight': 0.3949687428036275, 'gb_weight': 0.8430324314824631}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,587] Trial 40 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.3089988751086227, 'cb_weight': 0.22769545765704402, 'lgbm_weight': 0.861718192763173, 'hgb_weight': 0.9855563564577856, 'gb_weight': 0.5092245244740631}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,625] Trial 41 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.19553562830535176, 'cb_weight': 0.9307756346240563, 'lgbm_weight': 0.5880323915376438, 'hgb_weight': 0.4315563525127268, 'gb_weight': 0.8474340562202559}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,664] Trial 42 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.07978904524163433, 'cb_weight': 0.8736269045323349, 'lgbm_weight': 0.5849522665992664, 'hgb_weight': 0.38024956716577346, 'gb_weight': 0.8960136225539568}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,705] Trial 43 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.2129499749908462, 'cb_weight': 0.7595041009484166, 'lgbm_weight': 0.45039543310833685, 'hgb_weight': 0.03001603712855834, 'gb_weight': 0.6935761833493238}. Best is trial 14 with value: 0.8349277294231423.
# [I 2024-06-20 19:33:46,745] Trial 44 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.10555316556490094, 'cb_weight': 0.8611187036295493, 'lgbm_weight': 0.5456964528600428, 'hgb_weight': 0.11484413254903214, 'gb_weight': 0.9975057410819325}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,784] Trial 45 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.008952557437376774, 'cb_weight': 0.8447819148232825, 'lgbm_weight': 0.6362040557373103, 'hgb_weight': 0.112296671932406, 'gb_weight': 0.9992991556143238}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,823] Trial 46 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.03136492344935807, 'cb_weight': 0.8539814316147303, 'lgbm_weight': 0.6435131457071465, 'hgb_weight': 0.09434793827692149, 'gb_weight': 0.9709330650788817}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,863] Trial 47 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.009742097879454376, 'cb_weight': 0.6909527182925519, 'lgbm_weight': 0.5420870894107829, 'hgb_weight': 0.010659428241535096, 'gb_weight': 0.979484590214298}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,903] Trial 48 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.07426717812676016, 'cb_weight': 0.9591865618410639, 'lgbm_weight': 0.4150130718018779, 'hgb_weight': 0.18599978523399008, 'gb_weight': 0.9351325785132341}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,942] Trial 49 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.11730418189575034, 'cb_weight': 0.8610643741747525, 'lgbm_weight': 0.6238384269552737, 'hgb_weight': 0.11940721073881422, 'gb_weight': 0.8969758186088952}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:46,982] Trial 50 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.036543102172763214, 'cb_weight': 0.0793608281106074, 'lgbm_weight': 0.4842284858752353, 'hgb_weight': 0.12774085953266265, 'gb_weight': 0.9375971596535935}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:47,022] Trial 51 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.1300554716518937, 'cb_weight': 0.7483157038119879, 'lgbm_weight': 0.6357486762081509, 'hgb_weight': 0.05194870562928136, 'gb_weight': 0.8899418391500095}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:47,062] Trial 52 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.12544835017015754, 'cb_weight': 0.8610790640507744, 'lgbm_weight': 0.6343977008529565, 'hgb_weight': 0.04512829911900938, 'gb_weight': 0.9972221286773194}. Best is trial 44 with value: 0.8350322799864084.
# [I 2024-06-20 19:33:47,101] Trial 53 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.11802344178699095, 'cb_weight': 0.969876203204812, 'lgbm_weight': 0.6399560276859851, 'hgb_weight': 0.11692356472018958, 'gb_weight': 0.9938699376080815}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,140] Trial 54 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.12006189689493654, 'cb_weight': 0.8529501545813912, 'lgbm_weight': 0.6456958014928876, 'hgb_weight': 0.10745893360331261, 'gb_weight': 0.997060664824442}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,178] Trial 55 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.12241626006443221, 'cb_weight': 0.8709558562838714, 'lgbm_weight': 0.643078486937233, 'hgb_weight': 0.003563811611770995, 'gb_weight': 0.9627663640634821}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,216] Trial 56 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.06511210828898494, 'cb_weight': 0.9867323904664121, 'lgbm_weight': 0.5548730872346765, 'hgb_weight': 0.16568784065699738, 'gb_weight': 0.9079146141325332}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,255] Trial 57 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.10419616935650118, 'cb_weight': 0.9220994946802005, 'lgbm_weight': 0.6093599981841252, 'hgb_weight': 0.05107246586241902, 'gb_weight': 0.9534430989147037}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,295] Trial 58 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.11082427517652735, 'cb_weight': 0.9332618248778655, 'lgbm_weight': 0.6064500158415558, 'hgb_weight': 0.051599257403972656, 'gb_weight': 0.8803898647513282}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,334] Trial 59 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.15362926126942833, 'cb_weight': 0.9702808981918656, 'lgbm_weight': 0.5095875199175975, 'hgb_weight': 0.046903316187412836, 'gb_weight': 0.951271565734794}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,374] Trial 60 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.09655422179440284, 'cb_weight': 0.9028591041274213, 'lgbm_weight': 0.8106756477545177, 'hgb_weight': 0.1450069288148621, 'gb_weight': 0.7874626372572097}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,413] Trial 61 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.1464675952413108, 'cb_weight': 0.9985308607804494, 'lgbm_weight': 0.4833599599464264, 'hgb_weight': 0.038739688284255794, 'gb_weight': 0.9412814174239825}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,453] Trial 62 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.17703913146198608, 'cb_weight': 0.959384978053849, 'lgbm_weight': 0.6118662671892928, 'hgb_weight': 0.08384822123961144, 'gb_weight': 0.9526025094239963}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,494] Trial 63 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.061940670180324675, 'cb_weight': 0.934309048073514, 'lgbm_weight': 0.599743776493387, 'hgb_weight': 0.17282243945933368, 'gb_weight': 0.8662571797038978}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,532] Trial 64 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.169131808844446, 'cb_weight': 0.9043754508768445, 'lgbm_weight': 0.5485447931448801, 'hgb_weight': 0.08062039777185306, 'gb_weight': 0.9161564869322495}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,571] Trial 65 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.1749864623696865, 'cb_weight': 0.8721307319428223, 'lgbm_weight': 0.5477033630791733, 'hgb_weight': 0.08901160640365766, 'gb_weight': 0.9993018526638653}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,611] Trial 66 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.30294661908968634, 'cb_weight': 0.8910792398818573, 'lgbm_weight': 0.5401985896912342, 'hgb_weight': 0.08270398119326801, 'gb_weight': 0.9965792726585607}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,651] Trial 67 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.17134632093154556, 'cb_weight': 0.9573759191099981, 'lgbm_weight': 0.7253877320067721, 'hgb_weight': 0.21896609951420493, 'gb_weight': 0.9255339463358314}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,691] Trial 68 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.2337154880257854, 'cb_weight': 0.7757269793782439, 'lgbm_weight': 0.5624643449707275, 'hgb_weight': 0.1570209370792851, 'gb_weight': 0.9982330059552423}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,731] Trial 69 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.2272157706544823, 'cb_weight': 0.8156719964663623, 'lgbm_weight': 0.6702012761908861, 'hgb_weight': 0.005181213510720845, 'gb_weight': 0.8070185262856988}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,770] Trial 70 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.05155554497697451, 'cb_weight': 0.9691592893762488, 'lgbm_weight': 0.42462879738045034, 'hgb_weight': 0.08388250273759135, 'gb_weight': 0.9161902305470877}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,810] Trial 71 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.16658219820856013, 'cb_weight': 0.8767410863623192, 'lgbm_weight': 0.6630081091389043, 'hgb_weight': 0.11920387282345161, 'gb_weight': 0.8648434978147701}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,849] Trial 72 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.27416088245794124, 'cb_weight': 0.886954149806366, 'lgbm_weight': 0.6635282763457813, 'hgb_weight': 0.11274966255945823, 'gb_weight': 0.9661671153604693}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,889] Trial 73 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.3479057964797252, 'cb_weight': 0.9053168801232009, 'lgbm_weight': 0.49405358010615963, 'hgb_weight': 0.17541449875721024, 'gb_weight': 0.8672621498137121}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,929] Trial 74 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.17855534493128164, 'cb_weight': 0.8274942831369938, 'lgbm_weight': 0.7712206085456468, 'hgb_weight': 0.0661910819773381, 'gb_weight': 0.9202952433582646}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:47,969] Trial 75 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.14858801032228763, 'cb_weight': 0.3720633963844189, 'lgbm_weight': 0.7169115489440464, 'hgb_weight': 0.21261211634492183, 'gb_weight': 0.9679258356667131}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,009] Trial 76 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.08835059615507018, 'cb_weight': 0.8683134010777707, 'lgbm_weight': 0.5374105024256504, 'hgb_weight': 0.8309749628575719, 'gb_weight': 0.8661740757333702}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,048] Trial 77 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.21182702855221358, 'cb_weight': 0.7851304310423016, 'lgbm_weight': 0.6642251780920805, 'hgb_weight': 0.02938403849168661, 'gb_weight': 0.9445189662349115}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,087] Trial 78 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.27698623989637833, 'cb_weight': 0.9499277781769844, 'lgbm_weight': 0.6868873872551562, 'hgb_weight': 0.1377225408795055, 'gb_weight': 0.9976591961747284}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,127] Trial 79 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.25680664741684806, 'cb_weight': 0.9359576925638533, 'lgbm_weight': 0.5843501628074785, 'hgb_weight': 0.14447476997771266, 'gb_weight': 0.9952739707132274}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,167] Trial 80 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.9986818884320827, 'cb_weight': 0.9776863129922023, 'lgbm_weight': 0.7424308014836558, 'hgb_weight': 0.2657275050122749, 'gb_weight': 0.9129365693282937}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,206] Trial 81 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.17258324868564232, 'cb_weight': 0.9078936758627686, 'lgbm_weight': 0.6904854223218675, 'hgb_weight': 0.1035020951473198, 'gb_weight': 0.9691630456470306}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,248] Trial 82 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.13299548781863252, 'cb_weight': 0.9104977472933649, 'lgbm_weight': 0.6905720233551439, 'hgb_weight': 0.09645402146256188, 'gb_weight': 0.9614361842802958}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,291] Trial 83 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.19140572418959922, 'cb_weight': 0.9448184755072985, 'lgbm_weight': 0.6190685356869012, 'hgb_weight': 0.06458578020262495, 'gb_weight': 0.9756240109876558}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,331] Trial 84 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.28784381788525654, 'cb_weight': 0.836276497311264, 'lgbm_weight': 0.5613579518064169, 'hgb_weight': 0.025354701894746645, 'gb_weight': 0.9992072489624297}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,372] Trial 85 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.23883361019227087, 'cb_weight': 0.9686945874928454, 'lgbm_weight': 0.5223276096482148, 'hgb_weight': 0.09587799021422823, 'gb_weight': 0.9363806156297552}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,412] Trial 86 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.0487411683786777, 'cb_weight': 0.5555638481355353, 'lgbm_weight': 0.6967594397175149, 'hgb_weight': 0.19353254861829605, 'gb_weight': 0.9719547140088121}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,454] Trial 87 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.20665874738147605, 'cb_weight': 0.8086100301934133, 'lgbm_weight': 0.4683555847352652, 'hgb_weight': 0.13711254588700847, 'gb_weight': 0.8932320168354098}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,493] Trial 88 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.09211424383856989, 'cb_weight': 0.9187920654009293, 'lgbm_weight': 0.5820734270241299, 'hgb_weight': 0.23587351367082626, 'gb_weight': 0.9182856627665965}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,532] Trial 89 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.14299315049273326, 'cb_weight': 0.7355262083235024, 'lgbm_weight': 0.6252195841097427, 'hgb_weight': 0.06622920176372785, 'gb_weight': 0.9493956948067516}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,583] Trial 90 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.17544118112670087, 'cb_weight': 0.8560371163147602, 'lgbm_weight': 0.7290737079929406, 'hgb_weight': 0.5351511339018196, 'gb_weight': 0.08875955853800754}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,646] Trial 91 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.16959665320074666, 'cb_weight': 0.8844524294940078, 'lgbm_weight': 0.6594589132861289, 'hgb_weight': 0.12155695791809673, 'gb_weight': 0.9743460378300378}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,707] Trial 92 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.11070847761177072, 'cb_weight': 0.9970866369687231, 'lgbm_weight': 0.646334538151012, 'hgb_weight': 0.10814169235652944, 'gb_weight': 0.9704408142650905}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,758] Trial 93 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.16145109684793288, 'cb_weight': 0.8903973396644702, 'lgbm_weight': 0.6838905547687688, 'hgb_weight': 0.15196727872598664, 'gb_weight': 0.9791558965249529}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,799] Trial 94 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.21625988072531252, 'cb_weight': 0.8903006365916933, 'lgbm_weight': 0.8037777301912241, 'hgb_weight': 0.15892606361623773, 'gb_weight': 0.9358672887685524}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,840] Trial 95 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.1623488056705962, 'cb_weight': 0.9494968650558568, 'lgbm_weight': 0.7650561832140035, 'hgb_weight': 0.13019284104953732, 'gb_weight': 0.8986931236115739}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,888] Trial 96 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.33265969951066643, 'cb_weight': 0.9078130695912857, 'lgbm_weight': 0.6851707026410819, 'hgb_weight': 0.18352690100031693, 'gb_weight': 0.9606759254357748}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,928] Trial 97 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.38370579868675414, 'cb_weight': 0.9484285370015685, 'lgbm_weight': 0.6075886341508199, 'hgb_weight': 0.0849764558340681, 'gb_weight': 0.8277195010007933}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:48,969] Trial 98 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.18734487440533676, 'cb_weight': 0.8391854111291831, 'lgbm_weight': 0.7139437279832186, 'hgb_weight': 0.06307657055582694, 'gb_weight': 0.9788803006616176}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,010] Trial 99 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.08113475321619001, 'cb_weight': 0.922755632811488, 'lgbm_weight': 0.5505405738569107, 'hgb_weight': 0.31227192047321983, 'gb_weight': 0.8847753652603678}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,059] Trial 100 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.24612502549946433, 'cb_weight': 0.8798915386238855, 'lgbm_weight': 0.5306090335209942, 'hgb_weight': 0.15458643237374214, 'gb_weight': 0.9264965533574832}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,101] Trial 101 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.12338994384119012, 'cb_weight': 0.8562856593629445, 'lgbm_weight': 0.6580025322357624, 'hgb_weight': 0.029297946736903755, 'gb_weight': 0.9892773292497742}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,143] Trial 102 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.1348607023007195, 'cb_weight': 0.8248742663283759, 'lgbm_weight': 0.6830025527350997, 'hgb_weight': 0.10606935962303286, 'gb_weight': 0.982576428404749}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,184] Trial 103 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.14539366426375533, 'cb_weight': 0.9799720833057936, 'lgbm_weight': 0.5766682197846545, 'hgb_weight': 0.12803645335862734, 'gb_weight': 0.9491744132202085}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,225] Trial 104 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.20686278724975488, 'cb_weight': 0.8004509498411764, 'lgbm_weight': 0.689834912879142, 'hgb_weight': 0.09233650807982674, 'gb_weight': 0.9851391310262314}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,267] Trial 105 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.16357112904528406, 'cb_weight': 0.8992786796092328, 'lgbm_weight': 0.6256237941988847, 'hgb_weight': 0.04289974033388953, 'gb_weight': 0.9110220700301079}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,308] Trial 106 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.10020817573775834, 'cb_weight': 0.8242767192808673, 'lgbm_weight': 0.7510290535063318, 'hgb_weight': 0.20259746202174012, 'gb_weight': 0.9436091153563944}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,350] Trial 107 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.03817991415488199, 'cb_weight': 0.7618987077718125, 'lgbm_weight': 0.5989904492680553, 'hgb_weight': 0.07646039670734654, 'gb_weight': 0.9756560938178791}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,392] Trial 108 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.26541923350785146, 'cb_weight': 0.4791223815317296, 'lgbm_weight': 0.010723072796071764, 'hgb_weight': 0.17362629152493264, 'gb_weight': 0.9580275839024117}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,433] Trial 109 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.23059174596803841, 'cb_weight': 0.9313966934486884, 'lgbm_weight': 0.5690984627528348, 'hgb_weight': 0.6888533031675952, 'gb_weight': 0.9989955344636606}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,474] Trial 110 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.06967455203169907, 'cb_weight': 0.8772389004203996, 'lgbm_weight': 0.6781600576266846, 'hgb_weight': 0.10902254115036354, 'gb_weight': 0.927292792513276}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,518] Trial 111 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.06189340641479053, 'cb_weight': 0.8647005412071483, 'lgbm_weight': 0.7119328779644181, 'hgb_weight': 0.12932026324381746, 'gb_weight': 0.8526145247697514}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,560] Trial 112 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.0031308514020314537, 'cb_weight': 0.8937240728634498, 'lgbm_weight': 0.6845772892401455, 'hgb_weight': 0.012941611315082535, 'gb_weight': 0.9333591324738207}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,604] Trial 113 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.13562304757242222, 'cb_weight': 0.9504274026262769, 'lgbm_weight': 0.5059696396249709, 'hgb_weight': 0.1062586761952219, 'gb_weight': 0.9760553146172987}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,646] Trial 114 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.07624542284879703, 'cb_weight': 0.8774715135873219, 'lgbm_weight': 0.6677717666778296, 'hgb_weight': 0.14452059309142828, 'gb_weight': 0.8818092869339427}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,688] Trial 115 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.10399760253699897, 'cb_weight': 0.9151599657823544, 'lgbm_weight': 0.7818489479767485, 'hgb_weight': 0.05392780830008986, 'gb_weight': 0.9129057878301474}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,733] Trial 116 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.18481091020106893, 'cb_weight': 0.8317166465051101, 'lgbm_weight': 0.6484816808688949, 'hgb_weight': 0.11577924492253681, 'gb_weight': 0.9533183264466304}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,780] Trial 117 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.19312057147232112, 'cb_weight': 0.709097453242416, 'lgbm_weight': 0.634595096104146, 'hgb_weight': 0.0763221727751224, 'gb_weight': 0.9503963239642321}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,821] Trial 118 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.17644658841233152, 'cb_weight': 0.8349868494371068, 'lgbm_weight': 0.6037771633522988, 'hgb_weight': 0.0006929755280917632, 'gb_weight': 0.9807148315668481}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,864] Trial 119 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.1531057354795616, 'cb_weight': 0.7864419968824262, 'lgbm_weight': 0.621498505236266, 'hgb_weight': 0.23034414579169302, 'gb_weight': 0.9610413428121395}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,905] Trial 120 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.12203924012986027, 'cb_weight': 0.28327540213130453, 'lgbm_weight': 0.6502170763738869, 'hgb_weight': 0.1605617659500888, 'gb_weight': 0.9020654060352262}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,947] Trial 121 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.47479151474735615, 'cb_weight': 0.8165597595123136, 'lgbm_weight': 0.7347275874427851, 'hgb_weight': 0.11490769891991479, 'gb_weight': 0.9995108705303128}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:49,988] Trial 122 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.136887326445681, 'cb_weight': 0.9648902572548911, 'lgbm_weight': 0.6704053681204917, 'hgb_weight': 0.08713831973626376, 'gb_weight': 0.9313017301777852}. Best is trial 53 with value: 0.8350714864476332.
# [I 2024-06-20 19:33:50,029] Trial 123 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.16145745630366784, 'cb_weight': 0.870895218775596, 'lgbm_weight': 0.5867999913628121, 'hgb_weight': 0.10510143157523084, 'gb_weight': 0.9560197256992318}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,070] Trial 124 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.1707117910033723, 'cb_weight': 0.8479584791925127, 'lgbm_weight': 0.5673949374681602, 'hgb_weight': 0.03166222796506078, 'gb_weight': 0.9627166896107783}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,112] Trial 125 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.2029936048587395, 'cb_weight': 0.9304198432809939, 'lgbm_weight': 0.587731706575723, 'hgb_weight': 0.14400121056029372, 'gb_weight': 0.9799921879113676}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,153] Trial 126 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.2220880416628863, 'cb_weight': 0.9114212785246453, 'lgbm_weight': 0.6508688555672599, 'hgb_weight': 0.6291418106956138, 'gb_weight': 0.9491654679307755}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,196] Trial 127 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.1833761190598166, 'cb_weight': 0.9868576446621421, 'lgbm_weight': 0.7097849504609768, 'hgb_weight': 0.056008954804312346, 'gb_weight': 0.586011914305921}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,239] Trial 128 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.284446812926065, 'cb_weight': 0.8885075294932604, 'lgbm_weight': 0.5420219686067758, 'hgb_weight': 0.4581649135115617, 'gb_weight': 0.7269202202882139}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,281] Trial 129 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.15604907705206644, 'cb_weight': 0.1450727341217637, 'lgbm_weight': 0.6197606819128336, 'hgb_weight': 0.1815830122869098, 'gb_weight': 0.9840876076875562}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,322] Trial 130 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.10938934019228556, 'cb_weight': 0.8645581197554144, 'lgbm_weight': 0.5094125371991404, 'hgb_weight': 0.12352720734883477, 'gb_weight': 0.9169603868854246}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,364] Trial 131 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.09442469766672565, 'cb_weight': 0.8750593435894533, 'lgbm_weight': 0.6729591210856501, 'hgb_weight': 0.09703761302337326, 'gb_weight': 0.9360137734811746}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,407] Trial 132 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.13145442882060254, 'cb_weight': 0.824222082615197, 'lgbm_weight': 0.6374175505457725, 'hgb_weight': 0.10886500342650653, 'gb_weight': 0.9993859956190545}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,450] Trial 133 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.14752720376767164, 'cb_weight': 0.941234220691716, 'lgbm_weight': 0.595643525293783, 'hgb_weight': 0.07473013539454278, 'gb_weight': 0.9624926068564096}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,494] Trial 134 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.06748997534129979, 'cb_weight': 0.8957623082294958, 'lgbm_weight': 0.6914476656926268, 'hgb_weight': 0.129401249028949, 'gb_weight': 0.9232571921183017}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,536] Trial 135 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.0334531619346804, 'cb_weight': 0.8476456186331027, 'lgbm_weight': 0.7256415062897554, 'hgb_weight': 0.09498821682054923, 'gb_weight': 0.948824674135406}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,577] Trial 136 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.19545708750009422, 'cb_weight': 0.801277386938225, 'lgbm_weight': 0.6515779350942551, 'hgb_weight': 0.16094286252565748, 'gb_weight': 0.8977583890788393}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,620] Trial 137 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.0883375729645286, 'cb_weight': 0.9195637567513273, 'lgbm_weight': 0.5567822056336008, 'hgb_weight': 0.036707133805546396, 'gb_weight': 0.8770575961337296}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,661] Trial 138 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.1666651834441092, 'cb_weight': 0.9595963627942872, 'lgbm_weight': 0.6992652610067004, 'hgb_weight': 0.06916468947108718, 'gb_weight': 0.9738966181694302}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,704] Trial 139 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.247470373755008, 'cb_weight': 0.9973856579251437, 'lgbm_weight': 0.7055378372881885, 'hgb_weight': 0.060319392891585846, 'gb_weight': 0.9792845355058326}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,746] Trial 140 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.16614958478563477, 'cb_weight': 0.964645933104802, 'lgbm_weight': 0.6073486624708295, 'hgb_weight': 0.020789766032700538, 'gb_weight': 0.9645854302185494}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,789] Trial 141 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.12737965178164076, 'cb_weight': 0.6059075172365964, 'lgbm_weight': 0.6791993985727215, 'hgb_weight': 0.11310087763872106, 'gb_weight': 0.9313180287001116}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,831] Trial 142 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.2132286112975526, 'cb_weight': 0.9530090101462553, 'lgbm_weight': 0.7595406607509655, 'hgb_weight': 0.1411967517953809, 'gb_weight': 0.9827108178148785}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,878] Trial 143 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.1732212559886584, 'cb_weight': 0.9064609692757193, 'lgbm_weight': 0.6957725425073358, 'hgb_weight': 0.08769557206195142, 'gb_weight': 0.9987717858185263}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,921] Trial 144 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.1797313133688726, 'cb_weight': 0.9078641332616761, 'lgbm_weight': 0.7351964491806815, 'hgb_weight': 0.07304011728895113, 'gb_weight': 0.9992113191610721}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:50,964] Trial 145 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.1796973336050148, 'cb_weight': 0.9067402451756698, 'lgbm_weight': 0.7353659525962705, 'hgb_weight': 0.07359717339941448, 'gb_weight': 0.9974945758097316}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,010] Trial 146 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.23160465485922144, 'cb_weight': 0.9373332056626681, 'lgbm_weight': 0.7456850572701567, 'hgb_weight': 0.08103253512822181, 'gb_weight': 0.9967432538764952}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,053] Trial 147 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.18976576105291193, 'cb_weight': 0.9671335242315259, 'lgbm_weight': 0.8292424649143818, 'hgb_weight': 0.04663114458142655, 'gb_weight': 0.9516086311734403}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,097] Trial 148 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.1562461198811167, 'cb_weight': 0.9065805007554116, 'lgbm_weight': 0.7241240465157107, 'hgb_weight': 0.06598418701662508, 'gb_weight': 0.9993851168215665}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,140] Trial 149 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.2131293112320379, 'cb_weight': 0.9261599451505967, 'lgbm_weight': 0.7857977413190704, 'hgb_weight': 0.07758140240399197, 'gb_weight': 0.9659503383999477}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,185] Trial 150 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.1773919635344833, 'cb_weight': 0.8919189722949166, 'lgbm_weight': 0.6311431830963274, 'hgb_weight': 0.023032793945913066, 'gb_weight': 0.9497625754877428}. Best is trial 123 with value: 0.8350976240884498.
# [I 2024-06-20 19:33:51,230] Trial 151 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.5539136642204854, 'cb_weight': 0.9104101670333515, 'lgbm_weight': 0.7040388464719641, 'hgb_weight': 0.08732496742972588, 'gb_weight': 0.9731579423912382}. Best is trial 123 with value: 0.8350976240884498.
# ...
# [I 2024-06-20 19:34:37,480] Trial 950 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.6486476607870101, 'cb_weight': 0.5659182193697359, 'lgbm_weight': 0.5378510822485967, 'hgb_weight': 0.05220385000944935, 'gb_weight': 0.9683507151632702}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,553] Trial 951 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.12014640030590974, 'cb_weight': 0.9226309344317826, 'lgbm_weight': 0.5774333001996038, 'hgb_weight': 0.0775751653318063, 'gb_weight': 0.8360064367637203}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,626] Trial 952 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.08719485107080156, 'cb_weight': 0.8609947646745895, 'lgbm_weight': 0.6141047728430972, 'hgb_weight': 0.3771975722023867, 'gb_weight': 0.894106611574407}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,700] Trial 953 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.1630469333622726, 'cb_weight': 0.8940258663819822, 'lgbm_weight': 0.5200256986160204, 'hgb_weight': 0.1088517998092443, 'gb_weight': 0.9429298197347823}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,772] Trial 954 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.10821989863495488, 'cb_weight': 0.9341773004942442, 'lgbm_weight': 0.5607949298174215, 'hgb_weight': 0.02562545529126186, 'gb_weight': 0.448001455780512}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,844] Trial 955 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.07437338455930048, 'cb_weight': 0.8388540055437027, 'lgbm_weight': 0.5930580360278679, 'hgb_weight': 0.08984071855001165, 'gb_weight': 0.9819822687957429}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,917] Trial 956 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.24164862355320482, 'cb_weight': 0.8773919528178588, 'lgbm_weight': 0.57158314775557, 'hgb_weight': 0.06699587042025607, 'gb_weight': 0.9214639881942621}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:37,989] Trial 957 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.1476493499692725, 'cb_weight': 0.9060293599177964, 'lgbm_weight': 0.5365562951041354, 'hgb_weight': 0.2786108215888744, 'gb_weight': 0.9999982730129583}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,060] Trial 958 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.03432043616862893, 'cb_weight': 0.8499105571042762, 'lgbm_weight': 0.6303477421189195, 'hgb_weight': 0.11432721664632164, 'gb_weight': 0.9611637456724104}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,132] Trial 959 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.19088139469025733, 'cb_weight': 0.8724445382001104, 'lgbm_weight': 0.5008528609267273, 'hgb_weight': 0.04612831488798898, 'gb_weight': 0.942537934167042}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,203] Trial 960 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.13025038903995412, 'cb_weight': 0.9543160318198498, 'lgbm_weight': 0.6000627225000235, 'hgb_weight': 0.08697304549923605, 'gb_weight': 0.9739868669083155}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,274] Trial 961 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.0999798008763852, 'cb_weight': 0.9192056015727189, 'lgbm_weight': 0.6622058890286114, 'hgb_weight': 0.5706191408178533, 'gb_weight': 0.9554292440147347}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,347] Trial 962 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.056778984964021215, 'cb_weight': 0.884501521029458, 'lgbm_weight': 0.5551476079711775, 'hgb_weight': 0.13659853489396245, 'gb_weight': 0.9826975830919145}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,418] Trial 963 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.15099865310712066, 'cb_weight': 0.8207198415821058, 'lgbm_weight': 0.5864820283250112, 'hgb_weight': 0.00018745413142164102, 'gb_weight': 0.9198116444920782}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,489] Trial 964 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.17280161183917522, 'cb_weight': 0.8997753189562323, 'lgbm_weight': 0.6171440907294227, 'hgb_weight': 0.4717238273988925, 'gb_weight': 0.935560541419074}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,560] Trial 965 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.018077933652279707, 'cb_weight': 0.8619362268159175, 'lgbm_weight': 0.5713828962334728, 'hgb_weight': 0.07071961846661573, 'gb_weight': 0.9999705289727074}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,632] Trial 966 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.11666530701244585, 'cb_weight': 0.9774833457467675, 'lgbm_weight': 0.5283694404154812, 'hgb_weight': 0.09915522978197146, 'gb_weight': 0.9665203190666016}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,704] Trial 967 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.5707998811679027, 'cb_weight': 0.9399671976552907, 'lgbm_weight': 0.5523479980985851, 'hgb_weight': 0.5356789940304073, 'gb_weight': 0.9048357986735643}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,776] Trial 968 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.08598814405369139, 'cb_weight': 0.8394091352833056, 'lgbm_weight': 0.5991824708522877, 'hgb_weight': 0.16476039627557504, 'gb_weight': 0.9523163019715686}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,848] Trial 969 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.1363741445277342, 'cb_weight': 0.9049808222094213, 'lgbm_weight': 0.6389170496121135, 'hgb_weight': 0.1178202515136404, 'gb_weight': 0.98275567978944}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,921] Trial 970 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.16489116824327194, 'cb_weight': 0.8846801098430592, 'lgbm_weight': 0.570811213794165, 'hgb_weight': 0.037200227651747284, 'gb_weight': 0.29151710837746786}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:38,992] Trial 971 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.06691040804092933, 'cb_weight': 0.9258226281624453, 'lgbm_weight': 0.6129182490352414, 'hgb_weight': 0.056490361298419084, 'gb_weight': 0.9290063304853495}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,064] Trial 972 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.10929842831261583, 'cb_weight': 0.05714182487074493, 'lgbm_weight': 0.48974011181706206, 'hgb_weight': 0.08168113874970614, 'gb_weight': 0.9685870109042382}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,135] Trial 973 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.20927618344986826, 'cb_weight': 0.7412310600191896, 'lgbm_weight': 0.5455180710076157, 'hgb_weight': 0.5006074135804395, 'gb_weight': 0.9494208390085638}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,205] Trial 974 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.04217025230014227, 'cb_weight': 0.9988029031031045, 'lgbm_weight': 0.5864696152574491, 'hgb_weight': 0.09547279943306816, 'gb_weight': 0.978663468779385}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,278] Trial 975 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.13370161379379297, 'cb_weight': 0.8585832463396125, 'lgbm_weight': 0.5279580170063951, 'hgb_weight': 0.13704192144735922, 'gb_weight': 0.8926103924181022}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,350] Trial 976 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.09178376091682343, 'cb_weight': 0.8811335006854826, 'lgbm_weight': 0.5646084198279809, 'hgb_weight': 0.11616562054091625, 'gb_weight': 0.9369813787140882}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,424] Trial 977 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.47890395350784354, 'cb_weight': 0.7944569618964642, 'lgbm_weight': 0.5895717858979366, 'hgb_weight': 0.06833931955365784, 'gb_weight': 0.9540703644534525}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,495] Trial 978 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.17771750254218785, 'cb_weight': 0.9508017348136467, 'lgbm_weight': 0.6235061410950468, 'hgb_weight': 0.01695039784815927, 'gb_weight': 0.9853286130356658}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,566] Trial 979 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.1525036087843681, 'cb_weight': 0.9085779886875964, 'lgbm_weight': 0.3610822619490936, 'hgb_weight': 0.09647352368008189, 'gb_weight': 0.9228259555429549}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,639] Trial 980 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.12475825035332697, 'cb_weight': 0.8220017350116461, 'lgbm_weight': 0.5065804771432636, 'hgb_weight': 0.04650908296213861, 'gb_weight': 0.9657164934034892}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,712] Trial 981 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.07598056693033976, 'cb_weight': 0.868857927048119, 'lgbm_weight': 0.6706366129580799, 'hgb_weight': 0.08404597795701971, 'gb_weight': 0.48703743028104807}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,785] Trial 982 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.5455577819715567, 'cb_weight': 0.842181629468038, 'lgbm_weight': 0.5447300703376888, 'hgb_weight': 0.12327287701758848, 'gb_weight': 0.6676763545808018}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,858] Trial 983 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.10645486999371086, 'cb_weight': 0.9271753922192751, 'lgbm_weight': 0.6473888053086918, 'hgb_weight': 0.061736046215898135, 'gb_weight': 0.9443607780754666}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:39,931] Trial 984 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.18614861288508563, 'cb_weight': 0.8932292971566621, 'lgbm_weight': 0.579491575199538, 'hgb_weight': 0.705185369258946, 'gb_weight': 0.983850423975462}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,004] Trial 985 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.054978062568941846, 'cb_weight': 0.9671218084253652, 'lgbm_weight': 0.6016238245533185, 'hgb_weight': 0.19126307414491217, 'gb_weight': 0.9591516356908837}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,076] Trial 986 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.14560941741742806, 'cb_weight': 0.8553667678992101, 'lgbm_weight': 0.558811145553048, 'hgb_weight': 0.14996471424863878, 'gb_weight': 0.9141221312238498}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,150] Trial 987 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.026047584511080652, 'cb_weight': 0.9058335456215475, 'lgbm_weight': 0.6131121195680858, 'hgb_weight': 0.10137258932607027, 'gb_weight': 0.968948641457769}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,221] Trial 988 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.12361647980461113, 'cb_weight': 0.8737655984362992, 'lgbm_weight': 0.5224874905158335, 'hgb_weight': 0.03085856489050485, 'gb_weight': 0.008888611285557846}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,295] Trial 989 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.00239183619222514, 'cb_weight': 0.9279088480243369, 'lgbm_weight': 0.578333972986919, 'hgb_weight': 0.07391827884332752, 'gb_weight': 0.9379077798229364}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,370] Trial 990 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.10081369336842462, 'cb_weight': 0.8907898248158223, 'lgbm_weight': 0.5482585927268612, 'hgb_weight': 0.10837799362017421, 'gb_weight': 0.8794357409334028}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,445] Trial 991 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.07880593827767514, 'cb_weight': 0.8426290339762869, 'lgbm_weight': 0.6290199386775873, 'hgb_weight': 0.04991624480303827, 'gb_weight': 0.9999859173022907}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,519] Trial 992 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.15628544485926463, 'cb_weight': 0.9403268628267663, 'lgbm_weight': 0.5956759156364984, 'hgb_weight': 0.08451316419634153, 'gb_weight': 0.9713266649524288}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,593] Trial 993 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.12207910631820079, 'cb_weight': 0.9126229206294029, 'lgbm_weight': 0.5666425944903922, 'hgb_weight': 0.12657202179079988, 'gb_weight': 0.9075487046123158}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,666] Trial 994 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.21740100052988234, 'cb_weight': 0.8680526807779281, 'lgbm_weight': 0.6056342583621372, 'hgb_weight': 0.07023893787616786, 'gb_weight': 0.95117669553096}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,740] Trial 995 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.053783339414261784, 'cb_weight': 0.8876357024229395, 'lgbm_weight': 0.537450423500818, 'hgb_weight': 0.09767246918035594, 'gb_weight': 0.9327459579463787}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,814] Trial 996 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.16727200069390286, 'cb_weight': 0.8229514730252281, 'lgbm_weight': 0.5797744364643179, 'hgb_weight': 0.05220725226201019, 'gb_weight': 0.9858416358314204}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,887] Trial 997 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.1405349988596078, 'cb_weight': 0.8552479087994828, 'lgbm_weight': 0.6422990155799333, 'hgb_weight': 0.10883663005776423, 'gb_weight': 0.9630642652741912}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:40,963] Trial 998 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.08300378564022937, 'cb_weight': 0.9458469575335966, 'lgbm_weight': 0.5557471587361723, 'hgb_weight': 0.07915679069312756, 'gb_weight': 0.9248752902525872}. Best is trial 274 with value: 0.8351368305496746.
# [I 2024-06-20 19:34:41,041] Trial 999 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.10850429505339004, 'cb_weight': 0.9004572811067657, 'lgbm_weight': 0.5164230468941245, 'hgb_weight': 0.14661531808925538, 'gb_weight': 0.9828805358027061}. Best is trial 274 with value: 0.8351368305496746.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.837363, AUC: 0.931489
# --- Fold 2 - Accuracy: 0.837232, AUC: 0.933143
# --- Fold 3 - Accuracy: 0.836644, AUC: 0.930909
# --- Fold 4 - Accuracy: 0.834085, AUC: 0.930679
# --- Fold 5 - Accuracy: 0.827419, AUC: 0.925800
#
# ------ Accuracy: 0.834549 ± 0.003756
# ------ AUC:      0.930404 ± 0.002458

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.837951, AUC: 0.931542
# --- Fold 2 - Accuracy: 0.837036, AUC: 0.933244
# --- Fold 3 - Accuracy: 0.836905, AUC: 0.931045
# --- Fold 4 - Accuracy: 0.834673, AUC: 0.930709
# --- Fold 5 - Accuracy: 0.827616, AUC: 0.925954
#
# ------ Accuracy: 0.834836 ± 0.003768
# ------ AUC:      0.930499 ± 0.002434

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 15))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 15))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
