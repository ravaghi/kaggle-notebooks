# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=5000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-11 09:01:02,479] A new study created in memory with name: no-name-d3a31fba-dc32-41c1-9438-b376196db52e
# [I 2024-06-11 09:01:02,495] Trial 0 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.3993274935151323, 'cb_weight': 0.502995589724841, 'lgbm_weight': 0.5955164447441751, 'hgb_weight': 0.676546685919339, 'gb_weight': 0.6636733093657915, 'rf_weight': 0.2897349131076681}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-11 09:01:02,508] Trial 1 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.8529905865414344, 'cb_weight': 0.5261549837689596, 'lgbm_weight': 0.6201736614352559, 'hgb_weight': 0.17376859589083005, 'gb_weight': 0.2484602182610186, 'rf_weight': 0.26014736975540553}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,522] Trial 2 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.04967795474665959, 'cb_weight': 0.9055876685534039, 'lgbm_weight': 0.05064705232855238, 'hgb_weight': 0.7968767016923716, 'gb_weight': 0.7731404749187764, 'rf_weight': 0.06486780260312153}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,535] Trial 3 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.9145210066940556, 'cb_weight': 0.39396760883271587, 'lgbm_weight': 0.40520091319900675, 'hgb_weight': 0.23388570576095435, 'gb_weight': 0.7079477123157265, 'rf_weight': 0.9167779067361864}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,549] Trial 4 finished with value: 0.8333333333333334 and parameters: {'xgb_weight': 0.7601782055406818, 'cb_weight': 0.07373468276917816, 'lgbm_weight': 0.04512663531352612, 'hgb_weight': 0.9627822263162715, 'gb_weight': 0.5156940274530939, 'rf_weight': 0.3759201408491466}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,563] Trial 5 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.8265836591764308, 'cb_weight': 0.6081524222799095, 'lgbm_weight': 0.8713586141615093, 'hgb_weight': 0.7981213802078941, 'gb_weight': 0.5426100453176275, 'rf_weight': 0.09147531369992912}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,576] Trial 6 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.4879033667064139, 'cb_weight': 0.5881821754509236, 'lgbm_weight': 0.8366173926937286, 'hgb_weight': 0.6156674570291558, 'gb_weight': 0.8240495622014553, 'rf_weight': 0.8779024667308833}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,590] Trial 7 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.8743452879745444, 'cb_weight': 0.7985994499020551, 'lgbm_weight': 0.5971061888361865, 'hgb_weight': 0.8344922940348396, 'gb_weight': 0.9873168230543145, 'rf_weight': 0.3202275368556433}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,604] Trial 8 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.7353197575847013, 'cb_weight': 0.3992381500524689, 'lgbm_weight': 0.7841549533215116, 'hgb_weight': 0.9741629813045005, 'gb_weight': 0.5680185096920974, 'rf_weight': 0.7637895210576038}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,618] Trial 9 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.04284184722335205, 'cb_weight': 0.3793835872126272, 'lgbm_weight': 0.322399552673063, 'hgb_weight': 0.7353549521257531, 'gb_weight': 0.39155987883854204, 'rf_weight': 0.027363750883860116}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,668] Trial 10 finished with value: 0.8332287827700672 and parameters: {'xgb_weight': 0.6175530098628235, 'cb_weight': 0.07576430957767433, 'lgbm_weight': 0.2716076959202982, 'hgb_weight': 0.02421372159450702, 'gb_weight': 0.06615386742339635, 'rf_weight': 0.6063980217790798}. Best is trial 1 with value: 0.8342089443006874.
# [I 2024-06-11 09:01:02,720] Trial 11 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.9974669285714977, 'cb_weight': 0.716623208401671, 'lgbm_weight': 0.9771660633294528, 'hgb_weight': 0.3923095141183661, 'gb_weight': 0.2842661882168305, 'rf_weight': 0.17470906004435935}. Best is trial 11 with value: 0.8342481507619123.
# [I 2024-06-11 09:01:02,773] Trial 12 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.9788763720594924, 'cb_weight': 0.7860269211310609, 'lgbm_weight': 0.9755617397784371, 'hgb_weight': 0.36797818684294303, 'gb_weight': 0.23983014626098093, 'rf_weight': 0.2065676543210824}. Best is trial 11 with value: 0.8342481507619123.
# [I 2024-06-11 09:01:02,826] Trial 13 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.9919340946619688, 'cb_weight': 0.788719601955468, 'lgbm_weight': 0.9976881208982981, 'hgb_weight': 0.426978739996725, 'gb_weight': 0.22315441998270313, 'rf_weight': 0.48957862785624406}. Best is trial 13 with value: 0.834378838965995.
# [I 2024-06-11 09:01:02,876] Trial 14 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.23121228180477738, 'cb_weight': 0.9649671146053332, 'lgbm_weight': 0.9899771390614015, 'hgb_weight': 0.4734812120594508, 'gb_weight': 0.0368770164789512, 'rf_weight': 0.4911201558374926}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:02,928] Trial 15 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.27902995519293555, 'cb_weight': 0.9779822819005782, 'lgbm_weight': 0.7420614914039234, 'hgb_weight': 0.5344067972455678, 'gb_weight': 0.052778798287342575, 'rf_weight': 0.5109784850647205}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:02,979] Trial 16 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.23280064993330074, 'cb_weight': 0.9338206946473635, 'lgbm_weight': 0.7210453406113, 'hgb_weight': 0.5255200090035885, 'gb_weight': 0.007031611253876857, 'rf_weight': 0.6081770189269786}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,031] Trial 17 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.2526625796649228, 'cb_weight': 0.9926752511997066, 'lgbm_weight': 0.7150158541618851, 'hgb_weight': 0.5262718254600934, 'gb_weight': 0.08727045265531005, 'rf_weight': 0.48369339473540346}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,082] Trial 18 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.24016057794851597, 'cb_weight': 0.2556390698609281, 'lgbm_weight': 0.8583984475216232, 'hgb_weight': 0.2731505618495743, 'gb_weight': 0.38767680039852964, 'rf_weight': 0.6692070826027257}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,133] Trial 19 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.3884917967034983, 'cb_weight': 0.900216036888442, 'lgbm_weight': 0.5040908546495098, 'hgb_weight': 0.630692646545632, 'gb_weight': 0.1217082843249841, 'rf_weight': 0.37667301825573263}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,184] Trial 20 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.10499829526009902, 'cb_weight': 0.6624433098717142, 'lgbm_weight': 0.7166830914134975, 'hgb_weight': 0.48955780668213084, 'gb_weight': 0.3634617268840214, 'rf_weight': 0.7550065054849485}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,236] Trial 21 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.3880994748283878, 'cb_weight': 0.8469478572287715, 'lgbm_weight': 0.4825854438067396, 'hgb_weight': 0.6125212983090292, 'gb_weight': 0.12512386451521787, 'rf_weight': 0.41749991737146064}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,290] Trial 22 finished with value: 0.8337384667659897 and parameters: {'xgb_weight': 0.36767395404151354, 'cb_weight': 0.9933336025131819, 'lgbm_weight': 0.20239829253281216, 'hgb_weight': 0.6081774308947498, 'gb_weight': 0.1517002883253979, 'rf_weight': 0.5467786180409817}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,342] Trial 23 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.14240291048651743, 'cb_weight': 0.8831713427796974, 'lgbm_weight': 0.5091307520832955, 'hgb_weight': 0.32970818384402634, 'gb_weight': 0.009800142174738027, 'rf_weight': 0.40650211251658674}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,396] Trial 24 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.32032520333511677, 'cb_weight': 0.9216204898697031, 'lgbm_weight': 0.90900316380006, 'hgb_weight': 0.4889199859410127, 'gb_weight': 0.168826836669672, 'rf_weight': 0.5218490933253809}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,449] Trial 25 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.5605717406376592, 'cb_weight': 0.6928272546232063, 'lgbm_weight': 0.7708742342562416, 'hgb_weight': 0.6959431317503944, 'gb_weight': 0.06591319122290205, 'rf_weight': 0.7163953147891565}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,502] Trial 26 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.4798826566130766, 'cb_weight': 0.9934243319708628, 'lgbm_weight': 0.5027592813143276, 'hgb_weight': 0.5781839192584515, 'gb_weight': 0.31920933957074, 'rf_weight': 0.3598180655073347}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,554] Trial 27 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.3031606464046136, 'cb_weight': 0.8424639196675807, 'lgbm_weight': 0.39059908542080357, 'hgb_weight': 0.42571726152124656, 'gb_weight': 0.18375049442520935, 'rf_weight': 0.4488833508143334}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,606] Trial 28 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.17569528915392865, 'cb_weight': 0.7437310753169544, 'lgbm_weight': 0.6536319670855598, 'hgb_weight': 0.882711775333996, 'gb_weight': 0.01584717156172201, 'rf_weight': 0.6082847010603276}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,659] Trial 29 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.4262088850878922, 'cb_weight': 0.9432263573197746, 'lgbm_weight': 0.9124482899583919, 'hgb_weight': 0.7122219972798994, 'gb_weight': 0.4408223766301444, 'rf_weight': 0.24781348538071402}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,712] Trial 30 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.5651556606949715, 'cb_weight': 0.8505791593627682, 'lgbm_weight': 0.5589692516894617, 'hgb_weight': 0.6366856353366225, 'gb_weight': 0.11401666095575651, 'rf_weight': 0.33677204859930143}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,765] Trial 31 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.2573922293967107, 'cb_weight': 0.9734178368212573, 'lgbm_weight': 0.6798873446139281, 'hgb_weight': 0.5272662504880915, 'gb_weight': 0.0774356726939083, 'rf_weight': 0.4617954890649192}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,819] Trial 32 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.1874704604557855, 'cb_weight': 0.8960641064147066, 'lgbm_weight': 0.7650713775468377, 'hgb_weight': 0.5526105395419734, 'gb_weight': 0.09268282301471781, 'rf_weight': 0.5440343179266522}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,873] Trial 33 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.3258913140728079, 'cb_weight': 0.9935453771253433, 'lgbm_weight': 0.628255474708149, 'hgb_weight': 0.4922170936122692, 'gb_weight': 0.1891753704132902, 'rf_weight': 0.27528776652116194}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,926] Trial 34 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.33061053505876586, 'cb_weight': 0.8844741139819557, 'lgbm_weight': 0.5780406510695495, 'hgb_weight': 0.44247716676601717, 'gb_weight': 0.2193076550392486, 'rf_weight': 0.2748397208519682}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:03,982] Trial 35 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.40279097916737827, 'cb_weight': 0.876154691932119, 'lgbm_weight': 0.42771268190566003, 'hgb_weight': 0.1610025331361465, 'gb_weight': 0.27507319231686456, 'rf_weight': 0.20384883995857495}. Best is trial 14 with value: 0.8345748712721189.
# [I 2024-06-11 09:01:04,036] Trial 36 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.4444647678612699, 'cb_weight': 0.7584134810096012, 'lgbm_weight': 0.5728181661538441, 'hgb_weight': 0.29902288592448306, 'gb_weight': 0.1930686707571961, 'rf_weight': 0.15834900193323706}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,091] Trial 37 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.09473002182942128, 'cb_weight': 0.5168081771888485, 'lgbm_weight': 0.5737421659192877, 'hgb_weight': 0.1908348724147905, 'gb_weight': 0.6178437665274505, 'rf_weight': 0.10315156581429547}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,145] Trial 38 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.4477403221365692, 'cb_weight': 0.6256653308162965, 'lgbm_weight': 0.5551106376090504, 'hgb_weight': 0.3222342225821667, 'gb_weight': 0.4523336899720921, 'rf_weight': 0.1580361935685265}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,200] Trial 39 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.6893075853352709, 'cb_weight': 0.7746237540249455, 'lgbm_weight': 0.8207627282664381, 'hgb_weight': 0.11308496130745616, 'gb_weight': 0.32675313977757336, 'rf_weight': 0.29731597429957807}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,255] Trial 40 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.0068140503473422265, 'cb_weight': 0.4590689261570523, 'lgbm_weight': 0.10645425345305581, 'hgb_weight': 0.2799224252826953, 'gb_weight': 0.042588165902648634, 'rf_weight': 0.04027057697266201}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,313] Trial 41 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.3569413513066643, 'cb_weight': 0.9279208871260544, 'lgbm_weight': 0.46370657517701785, 'hgb_weight': 0.43697865026369537, 'gb_weight': 0.20581450311287977, 'rf_weight': 0.38413108124151274}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,368] Trial 42 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.2891139102373286, 'cb_weight': 0.8238877530712118, 'lgbm_weight': 0.37049717661682, 'hgb_weight': 0.6577912826644656, 'gb_weight': 0.13610722251087426, 'rf_weight': 0.13895273330737806}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,423] Trial 43 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.5110791050603702, 'cb_weight': 0.890881806113119, 'lgbm_weight': 0.6094859228841056, 'hgb_weight': 0.462699594173783, 'gb_weight': 0.2526693242778869, 'rf_weight': 0.9956546245690925}. Best is trial 36 with value: 0.8346532841945686.
# [I 2024-06-11 09:01:04,477] Trial 44 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.18786725862047016, 'cb_weight': 0.7413965381385439, 'lgbm_weight': 0.5357112890195199, 'hgb_weight': 0.36740827062010506, 'gb_weight': 0.14677011315918062, 'rf_weight': 0.24081608701719154}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,532] Trial 45 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.20431707937754293, 'cb_weight': 0.5887191003543322, 'lgbm_weight': 0.3332203186329265, 'hgb_weight': 0.3712094722515477, 'gb_weight': 0.895704380863495, 'rf_weight': 0.2547966812895972}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,586] Trial 46 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.1336303461010153, 'cb_weight': 0.7328082849845674, 'lgbm_weight': 0.662077885424617, 'hgb_weight': 0.33150926172531425, 'gb_weight': 0.7448434160022039, 'rf_weight': 0.003907348287548684}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,641] Trial 47 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.2823997443831073, 'cb_weight': 0.6588774905509382, 'lgbm_weight': 0.4438551274334291, 'hgb_weight': 0.2442364916987357, 'gb_weight': 0.3135815018824505, 'rf_weight': 0.08075826972984401}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,698] Trial 48 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.20868523104198677, 'cb_weight': 0.6821968482731676, 'lgbm_weight': 0.24304811652205496, 'hgb_weight': 0.2359756426387441, 'gb_weight': 0.3044466671303885, 'rf_weight': 0.09428685657103442}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,754] Trial 49 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.3340208124075999, 'cb_weight': 0.6396488998040141, 'lgbm_weight': 0.43342229372778296, 'hgb_weight': 0.03465613399883649, 'gb_weight': 0.24228450770817458, 'rf_weight': 0.20846913894381652}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,810] Trial 50 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.34014434644420577, 'cb_weight': 0.5425774792947444, 'lgbm_weight': 0.5449541698485989, 'hgb_weight': 0.05704851024854679, 'gb_weight': 0.22230002256480894, 'rf_weight': 0.2157068104257942}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,866] Trial 51 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.44371750901642326, 'cb_weight': 0.4642744512362087, 'lgbm_weight': 0.5434757191133337, 'hgb_weight': 0.025367401451357095, 'gb_weight': 0.2196456903095254, 'rf_weight': 0.216158187335806}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,923] Trial 52 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.3281414521835954, 'cb_weight': 0.5840881191286829, 'lgbm_weight': 0.5290513386493123, 'hgb_weight': 0.05803394157120285, 'gb_weight': 0.25398177881655526, 'rf_weight': 0.13404142754602894}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:04,981] Trial 53 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.1670157951357547, 'cb_weight': 0.5592300843182663, 'lgbm_weight': 0.3221237086303435, 'hgb_weight': 0.09287480965860542, 'gb_weight': 0.36264551065037914, 'rf_weight': 0.13061581993230303}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,038] Trial 54 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.530242926829471, 'cb_weight': 0.636548624263336, 'lgbm_weight': 0.4129564456428112, 'hgb_weight': 0.15419863201916112, 'gb_weight': 0.26301247342097445, 'rf_weight': 0.18436716664072367}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,096] Trial 55 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.23540981714914821, 'cb_weight': 0.7484281626136629, 'lgbm_weight': 0.594259602931531, 'hgb_weight': 0.11032604047078409, 'gb_weight': 0.16041303624303038, 'rf_weight': 0.31294031022246627}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,154] Trial 56 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.0891949375175346, 'cb_weight': 0.7591356897927505, 'lgbm_weight': 0.5983196485615874, 'hgb_weight': 0.10829633646423989, 'gb_weight': 0.15289043442443534, 'rf_weight': 0.3062354518582966}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,212] Trial 57 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.23008128523853352, 'cb_weight': 0.8236197555762248, 'lgbm_weight': 0.6777424401675406, 'hgb_weight': 0.19664576088604302, 'gb_weight': 0.17273923380982775, 'rf_weight': 0.3379032082502492}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,270] Trial 58 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.2244472467786549, 'cb_weight': 0.8127350038265793, 'lgbm_weight': 0.6775716922414523, 'hgb_weight': 0.2847510070475796, 'gb_weight': 0.10857758248801025, 'rf_weight': 0.33277226638221835}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,327] Trial 59 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.051170121586005535, 'cb_weight': 0.030852562817617835, 'lgbm_weight': 0.6336622635613811, 'hgb_weight': 0.2053508404613919, 'gb_weight': 0.043373457777885094, 'rf_weight': 0.4223790425482101}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,384] Trial 60 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.14190970270585684, 'cb_weight': 0.7142816311325504, 'lgbm_weight': 0.5271790625211721, 'hgb_weight': 0.13406705222380963, 'gb_weight': 0.17045872841622614, 'rf_weight': 0.24211523365150883}. Best is trial 44 with value: 0.8346924906557934.
# [I 2024-06-11 09:01:05,442] Trial 61 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.1475291154982996, 'cb_weight': 0.7088618139794459, 'lgbm_weight': 0.5096329819625997, 'hgb_weight': 0.1287197538765345, 'gb_weight': 0.16877767282220923, 'rf_weight': 0.1302733958041985}. Best is trial 61 with value: 0.8347839723986513.
# [I 2024-06-11 09:01:05,498] Trial 62 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.13481669653709727, 'cb_weight': 0.7181708098585712, 'lgbm_weight': 0.5213639190485935, 'hgb_weight': 0.1395726282688825, 'gb_weight': 0.16969422186241856, 'rf_weight': 0.1282321486110109}. Best is trial 62 with value: 0.8348231788598761.
# [I 2024-06-11 09:01:05,555] Trial 63 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.1452430821722562, 'cb_weight': 0.7137543249535239, 'lgbm_weight': 0.5123775890264289, 'hgb_weight': 0.14783380481593394, 'gb_weight': 0.1791915752929944, 'rf_weight': 0.11837113342169546}. Best is trial 62 with value: 0.8348231788598761.
# [I 2024-06-11 09:01:05,611] Trial 64 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.1386672820408101, 'cb_weight': 0.7046601168129166, 'lgbm_weight': 0.5261531192194626, 'hgb_weight': 0.13876938585671308, 'gb_weight': 0.1317858980084185, 'rf_weight': 0.11927176576630093}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,669] Trial 65 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.06591853398846041, 'cb_weight': 0.703175070226377, 'lgbm_weight': 0.4853166542628436, 'hgb_weight': 0.06885786931494144, 'gb_weight': 0.09585025170932124, 'rf_weight': 0.03652034605618956}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,726] Trial 66 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.02523839576081907, 'cb_weight': 0.6866825506875515, 'lgbm_weight': 0.47927131192251515, 'hgb_weight': 0.00038512395777645647, 'gb_weight': 0.09556402431743538, 'rf_weight': 0.05404938306776519}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,782] Trial 67 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.056663579834852484, 'cb_weight': 0.7190665012709204, 'lgbm_weight': 0.4663187879854293, 'hgb_weight': 0.0719372201319003, 'gb_weight': 0.13383371055571888, 'rf_weight': 0.008957088355558633}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,849] Trial 68 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.07029320995327258, 'cb_weight': 0.7176606406267311, 'lgbm_weight': 0.4579608409217051, 'hgb_weight': 0.06257016649862751, 'gb_weight': 0.07185512685017889, 'rf_weight': 0.00022297217734534858}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,910] Trial 69 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.06522955080228046, 'cb_weight': 0.7131188558826059, 'lgbm_weight': 0.36179161852346875, 'hgb_weight': 0.06537974423894392, 'gb_weight': 0.07068055254833559, 'rf_weight': 0.019295373358422307}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:05,968] Trial 70 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.12161503519925959, 'cb_weight': 0.25446292660504316, 'lgbm_weight': 0.46395848425053354, 'hgb_weight': 0.07844856713473908, 'gb_weight': 0.009640032156801967, 'rf_weight': 0.06191750208148958}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:06,023] Trial 71 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.12032817789068326, 'cb_weight': 0.7916666249785562, 'lgbm_weight': 0.4829776588778718, 'hgb_weight': 0.0754404742681134, 'gb_weight': 0.021425508734044363, 'rf_weight': 0.05812658057055234}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:06,080] Trial 72 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.1270290936692846, 'cb_weight': 0.2684199662520494, 'lgbm_weight': 0.45511980644068106, 'hgb_weight': 0.1403723724798575, 'gb_weight': 0.005949282038148956, 'rf_weight': 0.06769105017522924}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:06,136] Trial 73 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.09234823877544364, 'cb_weight': 0.26887860181390405, 'lgbm_weight': 0.5019665939378846, 'hgb_weight': 0.08548088286496702, 'gb_weight': 0.03017362199719803, 'rf_weight': 0.04739286162469937}. Best is trial 64 with value: 0.8349800047047753.
# [I 2024-06-11 09:01:06,193] Trial 74 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.08102318570210124, 'cb_weight': 0.2333005702022434, 'lgbm_weight': 0.38676079474709846, 'hgb_weight': 0.004662143906202017, 'gb_weight': 0.03221275440341673, 'rf_weight': 0.046306795717245774}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,250] Trial 75 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.08609277049951408, 'cb_weight': 0.20208190226175127, 'lgbm_weight': 0.39807126744751725, 'hgb_weight': 0.0004026087162088132, 'gb_weight': 0.04686284414474132, 'rf_weight': 0.04418729939529752}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,307] Trial 76 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.017123295509786668, 'cb_weight': 0.2052389447059864, 'lgbm_weight': 0.30893119193548446, 'hgb_weight': 0.0897555180785023, 'gb_weight': 0.030250418261141977, 'rf_weight': 0.06806147170100366}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,363] Trial 77 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.11201349843440506, 'cb_weight': 0.3610091290773934, 'lgbm_weight': 0.4869705093898614, 'hgb_weight': 0.04172635229072471, 'gb_weight': 0.06665012390076613, 'rf_weight': 0.03274437264246921}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,420] Trial 78 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.07677436146882027, 'cb_weight': 0.3411287645198887, 'lgbm_weight': 0.3619192651994936, 'hgb_weight': 0.03991276467032822, 'gb_weight': 0.07235549905136865, 'rf_weight': 0.03110316333108004}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,477] Trial 79 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.07089608835172515, 'cb_weight': 0.33535748798712717, 'lgbm_weight': 0.3597018561779654, 'hgb_weight': 0.04385166835214478, 'gb_weight': 0.06735018836144017, 'rf_weight': 0.03065928210116911}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,533] Trial 80 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.030119197423097488, 'cb_weight': 0.34343611213198677, 'lgbm_weight': 0.2568018137962174, 'hgb_weight': 0.04897472875766967, 'gb_weight': 0.07639786005081398, 'rf_weight': 0.028154211137526274}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,589] Trial 81 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.0032382775204577753, 'cb_weight': 0.3151261639920285, 'lgbm_weight': 0.19867015277913413, 'hgb_weight': 0.034592395448059324, 'gb_weight': 0.0895773608271229, 'rf_weight': 0.02956381884009156}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,646] Trial 82 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.07357229224122562, 'cb_weight': 0.3593140597242014, 'lgbm_weight': 0.27919474329186766, 'hgb_weight': 0.047207737055688793, 'gb_weight': 0.05555952645586334, 'rf_weight': 0.005046424885992176}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,702] Trial 83 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.03949616727864891, 'cb_weight': 0.35302261545493974, 'lgbm_weight': 0.28048297641540243, 'hgb_weight': 0.03455150185648237, 'gb_weight': 0.06669030264114391, 'rf_weight': 0.0025777282155150724}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,758] Trial 84 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.09270029687228161, 'cb_weight': 0.4157357583541529, 'lgbm_weight': 0.2883742402341517, 'hgb_weight': 0.015605522613985488, 'gb_weight': 0.06130741965404783, 'rf_weight': 0.0933409169984436}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,815] Trial 85 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.04099577964103056, 'cb_weight': 0.36381944472316935, 'lgbm_weight': 0.35630646977558544, 'hgb_weight': 0.03505592953906619, 'gb_weight': 0.11067473512716101, 'rf_weight': 0.013236604847866039}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,872] Trial 86 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.0742163205256087, 'cb_weight': 0.3002266465199103, 'lgbm_weight': 0.2047097814788653, 'hgb_weight': 0.10421700887887556, 'gb_weight': 0.0518183021269365, 'rf_weight': 0.00386720601312273}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,927] Trial 87 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.1055902857678903, 'cb_weight': 0.28246821696374974, 'lgbm_weight': 0.20945555966321777, 'hgb_weight': 0.17349955871163605, 'gb_weight': 0.03690660173632081, 'rf_weight': 0.10373360816819141}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:06,984] Trial 88 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.16610774327408506, 'cb_weight': 0.19939584122037327, 'lgbm_weight': 0.15297394642155043, 'hgb_weight': 0.10692606231392766, 'gb_weight': 0.12736323843441164, 'rf_weight': 0.08342280128015295}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,041] Trial 89 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.03288375616785508, 'cb_weight': 0.1368662902639266, 'lgbm_weight': 0.29296685273177364, 'hgb_weight': 0.021247768286830095, 'gb_weight': 0.0005095294739820705, 'rf_weight': 0.04295937338984886}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,098] Trial 90 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.1120180174498785, 'cb_weight': 0.4146586218290454, 'lgbm_weight': 0.22870492610026616, 'hgb_weight': 0.011634627382139575, 'gb_weight': 0.061970467059966367, 'rf_weight': 0.16011052662551106}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,155] Trial 91 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.07850312184610107, 'cb_weight': 0.31517234646960746, 'lgbm_weight': 0.3840191859023227, 'hgb_weight': 0.049632233375335566, 'gb_weight': 0.0559461980556249, 'rf_weight': 0.0011629579694558397}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,212] Trial 92 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.06407005151979792, 'cb_weight': 0.37802661906492846, 'lgbm_weight': 0.3431034703384541, 'hgb_weight': 0.09046132392373281, 'gb_weight': 0.08241837156072615, 'rf_weight': 0.07823439831354148}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,271] Trial 93 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.7955521427552961, 'cb_weight': 0.23056208198026681, 'lgbm_weight': 0.13955500101979912, 'hgb_weight': 0.043895210263800215, 'gb_weight': 0.03351957607092138, 'rf_weight': 0.02455353373767294}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,330] Trial 94 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.0778048361042842, 'cb_weight': 0.31450009942061, 'lgbm_weight': 0.4217830667950228, 'hgb_weight': 0.1130646825228593, 'gb_weight': 0.11675940292631029, 'rf_weight': 0.0023285515736614013}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,387] Trial 95 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.0016620576423610062, 'cb_weight': 0.3381077799117156, 'lgbm_weight': 0.2757922151181784, 'hgb_weight': 0.16968353593602736, 'gb_weight': 0.031018741726382845, 'rf_weight': 0.10047359060162225}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,445] Trial 96 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.043036157411780136, 'cb_weight': 0.15406950001418568, 'lgbm_weight': 0.3837491364741873, 'hgb_weight': 0.024094654431222846, 'gb_weight': 0.06938327497312761, 'rf_weight': 0.050352380969291094}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,502] Trial 97 finished with value: 0.833803810868031 and parameters: {'xgb_weight': 0.0924835727817067, 'cb_weight': 0.30040123944035024, 'lgbm_weight': 0.3168535041944958, 'hgb_weight': 0.7599226360898325, 'gb_weight': 0.6425982901916137, 'rf_weight': 0.0310449901566386}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,560] Trial 98 finished with value: 0.8334378838965995 and parameters: {'xgb_weight': 0.9038928313456819, 'cb_weight': 0.34264042223931157, 'lgbm_weight': 0.005714091505099661, 'hgb_weight': 0.9212938472200926, 'gb_weight': 0.10460031815547857, 'rf_weight': 0.11059054236372189}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,619] Trial 99 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.19675800314673175, 'cb_weight': 0.43760934140798213, 'lgbm_weight': 0.16916457000031837, 'hgb_weight': 0.098899115009851, 'gb_weight': 0.5245937218679062, 'rf_weight': 0.07798655333521545}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,675] Trial 100 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.1610550029362801, 'cb_weight': 0.4718829345830118, 'lgbm_weight': 0.41124251154371033, 'hgb_weight': 0.054786941832788025, 'gb_weight': 0.13301780818294437, 'rf_weight': 0.004173693990419544}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,733] Trial 101 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.05975183783590986, 'cb_weight': 0.3953971908189204, 'lgbm_weight': 0.2477725232969335, 'hgb_weight': 0.08688475206104856, 'gb_weight': 0.07876610101522354, 'rf_weight': 0.07981738167788041}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,792] Trial 102 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.10814747626316545, 'cb_weight': 0.3742560385270261, 'lgbm_weight': 0.36523403678582145, 'hgb_weight': 0.1187491051654134, 'gb_weight': 0.0005565799247444908, 'rf_weight': 0.055050691086286054}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,850] Trial 103 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.10493311178507614, 'cb_weight': 0.3644874708666317, 'lgbm_weight': 0.354289590842088, 'hgb_weight': 0.12489524414216568, 'gb_weight': 0.02220186387981872, 'rf_weight': 0.05247569845735044}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,908] Trial 104 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.021578509068182723, 'cb_weight': 0.29341603164353514, 'lgbm_weight': 0.30091158243744653, 'hgb_weight': 0.20842381533826754, 'gb_weight': 0.055982252382398665, 'rf_weight': 0.028554617762249497}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:07,968] Trial 105 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.07392788895073912, 'cb_weight': 0.23389331164050364, 'lgbm_weight': 0.3347219134866822, 'hgb_weight': 0.06619514852126544, 'gb_weight': 0.003613660603428777, 'rf_weight': 0.0613836268685725}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:08,026] Trial 106 finished with value: 0.8330196816435349 and parameters: {'xgb_weight': 0.17699576591796407, 'cb_weight': 0.24381191332910782, 'lgbm_weight': 0.2675313941859104, 'hgb_weight': 0.036991292504005555, 'gb_weight': 0.016695878352559104, 'rf_weight': 0.8688040382511586}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:08,085] Trial 107 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.11211984241581614, 'cb_weight': 0.26969803419791294, 'lgbm_weight': 0.337514201851157, 'hgb_weight': 0.0004523699103889667, 'gb_weight': 0.0009874700797721713, 'rf_weight': 0.14711579579791478}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:08,145] Trial 108 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.15245932887840435, 'cb_weight': 0.224729792360864, 'lgbm_weight': 0.21794517408462094, 'hgb_weight': 0.15461981100096234, 'gb_weight': 0.04449907939452604, 'rf_weight': 0.17318943400223158}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:08,203] Trial 109 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.04538354859300658, 'cb_weight': 0.16936118632044367, 'lgbm_weight': 0.18676096647475807, 'hgb_weight': 0.18345952140343308, 'gb_weight': 0.10371310907944477, 'rf_weight': 0.11362308761401074}. Best is trial 74 with value: 0.8350061423455919.
# [I 2024-06-11 09:01:08,262] Trial 110 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.0774518819287363, 'cb_weight': 0.49228086786777725, 'lgbm_weight': 0.3775446107779896, 'hgb_weight': 0.12181379721542009, 'gb_weight': 0.0504089249208438, 'rf_weight': 0.0559080074181959}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,320] Trial 111 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.08677055359035114, 'cb_weight': 0.32886284273270205, 'lgbm_weight': 0.382370828066441, 'hgb_weight': 0.12524416339261213, 'gb_weight': 0.5753171350919859, 'rf_weight': 0.05213171867869445}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,378] Trial 112 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.12792701754302913, 'cb_weight': 0.3547849877608445, 'lgbm_weight': 0.4325964977083905, 'hgb_weight': 0.07509523978982047, 'gb_weight': 0.0473590420388991, 'rf_weight': 0.07113913618937073}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,436] Trial 113 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.11261045411321241, 'cb_weight': 0.36144326140402216, 'lgbm_weight': 0.44114057832126624, 'hgb_weight': 0.07751899046660429, 'gb_weight': 0.021618312532867053, 'rf_weight': 0.06923008792905462}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,498] Trial 114 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.12593758411182293, 'cb_weight': 0.36919069394308307, 'lgbm_weight': 0.4379184441980062, 'hgb_weight': 0.07109121744788152, 'gb_weight': 0.8430963286439503, 'rf_weight': 0.07132906697611703}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,556] Trial 115 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.04604939879347482, 'cb_weight': 0.43644926357131375, 'lgbm_weight': 0.40163846972795497, 'hgb_weight': 0.10677094235479315, 'gb_weight': 0.04790453621018067, 'rf_weight': 0.09446410330214201}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,614] Trial 116 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.05098581624343941, 'cb_weight': 0.4850410988846709, 'lgbm_weight': 0.3988716166057029, 'hgb_weight': 0.12345956264864846, 'gb_weight': 0.09097555423120374, 'rf_weight': 0.1064520623495154}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,672] Trial 117 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.0209542215671844, 'cb_weight': 0.5017594362469165, 'lgbm_weight': 0.4031062405315901, 'hgb_weight': 0.24639247974025286, 'gb_weight': 0.14560123857727378, 'rf_weight': 0.18831398771662416}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,731] Trial 118 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.0482986171460108, 'cb_weight': 0.4803604289233099, 'lgbm_weight': 0.3290304634085681, 'hgb_weight': 0.12319631176535997, 'gb_weight': 0.001127909078989305, 'rf_weight': 0.09676179817808318}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,791] Trial 119 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.6375867955731311, 'cb_weight': 0.4375396630148143, 'lgbm_weight': 0.3729226750916938, 'hgb_weight': 0.1663324394725785, 'gb_weight': 0.09053133516468989, 'rf_weight': 0.11792727681507326}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,851] Trial 120 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.0012825822662749023, 'cb_weight': 0.5296423819881723, 'lgbm_weight': 0.40152118045690627, 'hgb_weight': 0.018874637633925374, 'gb_weight': 0.998435479977443, 'rf_weight': 0.08818761562413902}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,912] Trial 121 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.10637504584583063, 'cb_weight': 0.40699543056672177, 'lgbm_weight': 0.28457748682652284, 'hgb_weight': 0.10328070544259578, 'gb_weight': 0.023848282710649756, 'rf_weight': 0.027083617794094676}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:08,973] Trial 122 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.038334162201648744, 'cb_weight': 0.4429398585627518, 'lgbm_weight': 0.3064699302611247, 'hgb_weight': 0.15199391585480362, 'gb_weight': 0.01993807908018403, 'rf_weight': 0.14056848738471792}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:09,034] Trial 123 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.1007139505681545, 'cb_weight': 0.4053959557459972, 'lgbm_weight': 0.35241641282969416, 'hgb_weight': 0.057394366402564484, 'gb_weight': 0.028526079804299723, 'rf_weight': 0.025311155932936015}. Best is trial 110 with value: 0.8350845552680415.
# [I 2024-06-11 09:01:09,095] Trial 124 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.10545664907504754, 'cb_weight': 0.40221026024955353, 'lgbm_weight': 0.34399119790769306, 'hgb_weight': 0.09553366779519909, 'gb_weight': 0.01914406338412311, 'rf_weight': 0.06423998099548431}. Best is trial 124 with value: 0.8350976240884498.
# [I 2024-06-11 09:01:09,156] Trial 125 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.10485418078937905, 'cb_weight': 0.41062731710784545, 'lgbm_weight': 0.35588736174544094, 'hgb_weight': 0.10147284805037016, 'gb_weight': 0.028383596778820446, 'rf_weight': 0.05823419561568971}. Best is trial 124 with value: 0.8350976240884498.
# [I 2024-06-11 09:01:09,216] Trial 126 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.10658245356531096, 'cb_weight': 0.40350419265120174, 'lgbm_weight': 0.3246663765784564, 'hgb_weight': 0.21224702867618328, 'gb_weight': 0.02721094598715158, 'rf_weight': 0.05829613574645309}. Best is trial 124 with value: 0.8350976240884498.
# [I 2024-06-11 09:01:09,276] Trial 127 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.15318592524509184, 'cb_weight': 0.4194175618005828, 'lgbm_weight': 0.3466066901080609, 'hgb_weight': 0.09796071367704404, 'gb_weight': 0.018104371557975542, 'rf_weight': 0.04854346638353562}. Best is trial 124 with value: 0.8350976240884498.
# [I 2024-06-11 09:01:09,335] Trial 128 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.1504722213629076, 'cb_weight': 0.4273897147751825, 'lgbm_weight': 0.34817286738100567, 'hgb_weight': 0.09433909777016028, 'gb_weight': 4.830916961456183e-05, 'rf_weight': 0.0657671735653334}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,395] Trial 129 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.18372231120236127, 'cb_weight': 0.39312632748279097, 'lgbm_weight': 0.41975178434165883, 'hgb_weight': 0.1345421160319198, 'gb_weight': 0.00172525061487706, 'rf_weight': 0.1269853554826114}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,455] Trial 130 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.13749599956368216, 'cb_weight': 0.4511041258664589, 'lgbm_weight': 0.37361393072417376, 'hgb_weight': 0.08668516487392375, 'gb_weight': 0.03640975824416891, 'rf_weight': 0.16189215468544327}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,515] Trial 131 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.1680608687346246, 'cb_weight': 0.42796946344555736, 'lgbm_weight': 0.33267889127302863, 'hgb_weight': 0.09963756543506368, 'gb_weight': 0.022537010582875376, 'rf_weight': 0.05614505614706542}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,576] Trial 132 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.1659996898353882, 'cb_weight': 0.39567579211363524, 'lgbm_weight': 0.33688099849219977, 'hgb_weight': 0.06465959761071471, 'gb_weight': 0.041809993450597174, 'rf_weight': 0.08426312307765677}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,637] Trial 133 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.11144570413958263, 'cb_weight': 0.4351364790590524, 'lgbm_weight': 0.44957674472919573, 'hgb_weight': 0.10830521301019867, 'gb_weight': 0.019896244173406227, 'rf_weight': 0.061881425607008406}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,698] Trial 134 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.21814974783091154, 'cb_weight': 0.459203217125939, 'lgbm_weight': 0.30936951557173764, 'hgb_weight': 0.14538657396027843, 'gb_weight': 0.04199397975271553, 'rf_weight': 0.02656970370043049}. Best is trial 128 with value: 0.8351106929088581.
# [I 2024-06-11 09:01:09,759] Trial 135 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.19743368538008288, 'cb_weight': 0.4971124974558339, 'lgbm_weight': 0.3665961847336581, 'hgb_weight': 0.18559149736841601, 'gb_weight': 0.0034384854248869674, 'rf_weight': 0.0972861230387804}. Best is trial 128 with value: 0.8351106929088581.
# ...
# [I 2024-06-11 09:16:52,848] Trial 4955 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.01805260493359824, 'cb_weight': 0.638989872907697, 'lgbm_weight': 0.5855328528469157, 'hgb_weight': 0.10475595787548286, 'gb_weight': 0.08388457747466224, 'rf_weight': 0.0647166422961403}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:53,176] Trial 4956 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.26439217309665186, 'cb_weight': 0.7009577611426335, 'lgbm_weight': 0.6193737489738249, 'hgb_weight': 0.14675100998739576, 'gb_weight': 0.01968994147745919, 'rf_weight': 0.01589743725429931}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:53,503] Trial 4957 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.12254850291478193, 'cb_weight': 0.6112355959877307, 'lgbm_weight': 0.539826819700258, 'hgb_weight': 0.13164412032661457, 'gb_weight': 7.412994384160473e-05, 'rf_weight': 0.12966886754974336}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:53,830] Trial 4958 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.2083760056359848, 'cb_weight': 0.6664641004372217, 'lgbm_weight': 0.46720997770776623, 'hgb_weight': 0.07982040301331927, 'gb_weight': 0.046411052223193694, 'rf_weight': 0.16727258382206195}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:54,159] Trial 4959 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.14946788143328793, 'cb_weight': 0.6292255393127429, 'lgbm_weight': 0.59752569658581, 'hgb_weight': 0.1118834557969228, 'gb_weight': 0.313447553034483, 'rf_weight': 0.10831474331819446}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:54,489] Trial 4960 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.18095728016956794, 'cb_weight': 0.7422025813833736, 'lgbm_weight': 0.6792490357782669, 'hgb_weight': 0.045824290511635286, 'gb_weight': 0.0178891419603784, 'rf_weight': 0.0005682426814650567}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:54,820] Trial 4961 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.24459574001674195, 'cb_weight': 0.6818455975297187, 'lgbm_weight': 0.6462627486737199, 'hgb_weight': 0.08605542817913225, 'gb_weight': 0.031350899662585766, 'rf_weight': 0.046651371763396884}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:55,150] Trial 4962 finished with value: 0.8351760370108994 and parameters: {'xgb_weight': 0.11151482287776855, 'cb_weight': 0.5118189973956697, 'lgbm_weight': 0.4409026428700706, 'hgb_weight': 0.06230629589123056, 'gb_weight': 0.0002450543899946179, 'rf_weight': 0.08143372992893555}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:55,479] Trial 4963 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.045433613200070555, 'cb_weight': 0.707299706736997, 'lgbm_weight': 0.584988061032369, 'hgb_weight': 0.15015455675554484, 'gb_weight': 0.047468544256260736, 'rf_weight': 0.032950673114874644}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:55,816] Trial 4964 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.1610444739259461, 'cb_weight': 0.5537606209283026, 'lgbm_weight': 0.5603554491248539, 'hgb_weight': 0.10135599087915853, 'gb_weight': 0.07157830356386374, 'rf_weight': 0.1377564820883405}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:56,158] Trial 4965 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.13441274019257968, 'cb_weight': 0.6472925264312172, 'lgbm_weight': 0.41094666494575016, 'hgb_weight': 0.12228026693434424, 'gb_weight': 0.018654416529082028, 'rf_weight': 0.06908810167121572}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:56,488] Trial 4966 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.20060128764354124, 'cb_weight': 0.5807546916692395, 'lgbm_weight': 0.6184315805505527, 'hgb_weight': 0.013780176399038661, 'gb_weight': 0.029888307847479475, 'rf_weight': 0.11348409944727315}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:56,813] Trial 4967 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.06654008678054413, 'cb_weight': 0.4834483550741228, 'lgbm_weight': 0.38532056879220333, 'hgb_weight': 0.8851174963704823, 'gb_weight': 0.1083749821156931, 'rf_weight': 0.08723079214958786}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:57,139] Trial 4968 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.293303156365421, 'cb_weight': 0.6881247991601719, 'lgbm_weight': 0.49049942665694773, 'hgb_weight': 0.040149575476261745, 'gb_weight': 0.00016031001912470907, 'rf_weight': 0.016895248685401272}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:57,468] Trial 4969 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.21895515734917761, 'cb_weight': 0.6244001909305568, 'lgbm_weight': 0.5746486848609317, 'hgb_weight': 0.1704832581139304, 'gb_weight': 0.05080330042453969, 'rf_weight': 0.05518330671369653}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:57,800] Trial 4970 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.16415474870542665, 'cb_weight': 0.42903809961318823, 'lgbm_weight': 0.653251999583477, 'hgb_weight': 0.718185512518265, 'gb_weight': 0.027992740511242804, 'rf_weight': 0.1012234023635694}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:58,129] Trial 4971 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.086798075594811, 'cb_weight': 0.6038177542255053, 'lgbm_weight': 0.6085427496136803, 'hgb_weight': 0.20158073425002127, 'gb_weight': 0.01858379887267788, 'rf_weight': 0.0004339984380918975}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:58,456] Trial 4972 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.1429322882057027, 'cb_weight': 0.6688137993292484, 'lgbm_weight': 0.6328049992309966, 'hgb_weight': 0.1337619907429214, 'gb_weight': 0.01824722547051156, 'rf_weight': 0.13038920203144155}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:58,786] Trial 4973 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.952074601130652, 'cb_weight': 0.7188398319398088, 'lgbm_weight': 0.5290475684979555, 'hgb_weight': 0.07400561360370903, 'gb_weight': 0.04688986260152702, 'rf_weight': 0.03684900131609177}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:59,117] Trial 4974 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.19035234308871135, 'cb_weight': 0.6483161522142492, 'lgbm_weight': 0.5963786884704175, 'hgb_weight': 0.09806390777566518, 'gb_weight': 0.017034870947885153, 'rf_weight': 0.1537296184432274}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:59,447] Trial 4975 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.10834824623069089, 'cb_weight': 0.4489876597203291, 'lgbm_weight': 0.5487154261620318, 'hgb_weight': 0.11989983783990579, 'gb_weight': 0.06672256395275158, 'rf_weight': 0.11312466479527314}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:16:59,774] Trial 4976 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.228488420799488, 'cb_weight': 0.6898009136238743, 'lgbm_weight': 0.6309764122736337, 'hgb_weight': 0.058656267852781316, 'gb_weight': 0.034306569220915184, 'rf_weight': 0.07425633522731895}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:00,097] Trial 4977 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.17488097325426769, 'cb_weight': 0.6618019112795729, 'lgbm_weight': 0.5758732211575338, 'hgb_weight': 0.15284227357812166, 'gb_weight': 0.045107311558671426, 'rf_weight': 0.5646980825967105}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:00,426] Trial 4978 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.1283017849455491, 'cb_weight': 0.7557726244506622, 'lgbm_weight': 0.6847799527429338, 'hgb_weight': 0.09680599864411728, 'gb_weight': 0.00029153726703030967, 'rf_weight': 3.879848965150645e-05}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:00,752] Trial 4979 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.24946758232546978, 'cb_weight': 0.630077637716875, 'lgbm_weight': 0.6075222404712266, 'hgb_weight': 0.07321700353454606, 'gb_weight': 0.01870518131695987, 'rf_weight': 0.17762627623802485}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:01,078] Trial 4980 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.14813170741440132, 'cb_weight': 0.70910629603299, 'lgbm_weight': 0.6573578650751523, 'hgb_weight': 0.12173382824213164, 'gb_weight': 0.03330356866966648, 'rf_weight': 0.0944140387259746}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:01,406] Trial 4981 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.1985605364788512, 'cb_weight': 0.5946124827273476, 'lgbm_weight': 0.459354517147587, 'hgb_weight': 0.031121385255016402, 'gb_weight': 0.06012857755562989, 'rf_weight': 0.03205782682243227}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:01,734] Trial 4982 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.16503078316090738, 'cb_weight': 0.6675066811849452, 'lgbm_weight': 0.019386883683930822, 'hgb_weight': 0.08817631955678942, 'gb_weight': 0.00019508301946241993, 'rf_weight': 0.056338207473319676}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:02,061] Trial 4983 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.12279561614870232, 'cb_weight': 0.7367883673582766, 'lgbm_weight': 0.5645514603493549, 'hgb_weight': 0.13638490804184972, 'gb_weight': 0.019584940842023616, 'rf_weight': 0.138287849314549}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:02,390] Trial 4984 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.09602668984234958, 'cb_weight': 0.6416356104372853, 'lgbm_weight': 0.633220781532601, 'hgb_weight': 0.04914631330581201, 'gb_weight': 0.017912116196794777, 'rf_weight': 0.01932907231118338}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:02,718] Trial 4985 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.18505579990644763, 'cb_weight': 0.692762300514294, 'lgbm_weight': 0.5870534355021044, 'hgb_weight': 0.10957017699462741, 'gb_weight': 0.09102621780017442, 'rf_weight': 0.25475030688913924}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:03,044] Trial 4986 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.2223344899607184, 'cb_weight': 0.52186455906109, 'lgbm_weight': 0.6649220392555795, 'hgb_weight': 0.18096136246986924, 'gb_weight': 0.04119615562593884, 'rf_weight': 0.11703574214905949}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:03,372] Trial 4987 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.14530972693010424, 'cb_weight': 0.4643395767577239, 'lgbm_weight': 0.5113633086566004, 'hgb_weight': 0.15165686569469386, 'gb_weight': 0.019220107866562263, 'rf_weight': 0.07325012266617402}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:03,701] Trial 4988 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.20924990549799816, 'cb_weight': 0.6091103641476664, 'lgbm_weight': 0.6132368408272775, 'hgb_weight': 0.07512906615957174, 'gb_weight': 0.03486260609340085, 'rf_weight': 0.08842439748312148}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:04,027] Trial 4989 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.16222719075843708, 'cb_weight': 0.5738025496744226, 'lgbm_weight': 0.5447361094211809, 'hgb_weight': 0.264839018997936, 'gb_weight': 0.07147896063186363, 'rf_weight': 0.05205417014351392}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:04,355] Trial 4990 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.11761406193662267, 'cb_weight': 0.6807570237537304, 'lgbm_weight': 0.6430783345188115, 'hgb_weight': 0.10784920569519726, 'gb_weight': 0.017978821506721455, 'rf_weight': 0.12660243523177964}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:04,689] Trial 4991 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.26907938987212465, 'cb_weight': 0.49722720038478097, 'lgbm_weight': 0.5962213811029201, 'hgb_weight': 0.0159126885159856, 'gb_weight': 0.04966880462712229, 'rf_weight': 0.16078068067882276}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:05,027] Trial 4992 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.18430104492289628, 'cb_weight': 0.6560631857556274, 'lgbm_weight': 0.43106256825444283, 'hgb_weight': 0.06039247305557655, 'gb_weight': 0.00030098229357938464, 'rf_weight': 0.1062454842493078}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:05,359] Trial 4993 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.00012133841747009183, 'cb_weight': 0.6247911352359413, 'lgbm_weight': 0.6209094013139429, 'hgb_weight': 0.09073996939923348, 'gb_weight': 0.00011187017297785441, 'rf_weight': 0.01881029266260533}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:05,690] Trial 4994 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.24316567930779517, 'cb_weight': 0.3918998233707335, 'lgbm_weight': 0.5722330509871755, 'hgb_weight': 0.13316971708520187, 'gb_weight': 0.033629398513230394, 'rf_weight': 0.6396014861044685}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:06,041] Trial 4995 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.13786867328318128, 'cb_weight': 0.5377374292951959, 'lgbm_weight': 0.6034359327975279, 'hgb_weight': 0.04118622212305606, 'gb_weight': 0.06138892741366284, 'rf_weight': 0.047331977819908846}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:06,377] Trial 4996 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.051434159351132935, 'cb_weight': 0.6987303590353884, 'lgbm_weight': 0.6814680966074725, 'hgb_weight': 0.11420621875773415, 'gb_weight': 0.019072707840078647, 'rf_weight': 0.09808437197578976}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:06,707] Trial 4997 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.07395024884072054, 'cb_weight': 0.7193660689911517, 'lgbm_weight': 0.6433822171687317, 'hgb_weight': 0.16357831681968277, 'gb_weight': 0.018088117845395896, 'rf_weight': 0.39984226804720635}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:07,036] Trial 4998 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.15947776218888288, 'cb_weight': 0.6450605565217509, 'lgbm_weight': 0.579382150315823, 'hgb_weight': 0.0844060093946649, 'gb_weight': 0.03519759839257339, 'rf_weight': 0.141333860922433}. Best is trial 949 with value: 0.8352805875741656.
# [I 2024-06-11 09:17:07,368] Trial 4999 finished with value: 0.8351368305496746 and parameters: {'xgb_weight': 0.20051025971796993, 'cb_weight': 0.6742885676203372, 'lgbm_weight': 0.552934574987436, 'hgb_weight': 0.13635073589886282, 'gb_weight': 0.0002053157927926286, 'rf_weight': 0.07766185477162169}. Best is trial 949 with value: 0.8352805875741656.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835860, AUC: 0.930895
# --- Fold 2 - Accuracy: 0.835925, AUC: 0.932476
# --- Fold 3 - Accuracy: 0.835664, AUC: 0.930151
# --- Fold 4 - Accuracy: 0.834346, AUC: 0.930300
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.925123
#
# ------ Accuracy: 0.833751 ± 0.003443
# ------ AUC:      0.929789 ± 0.002474

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838343, AUC: 0.931335
# --- Fold 2 - Accuracy: 0.837755, AUC: 0.933104
# --- Fold 3 - Accuracy: 0.836448, AUC: 0.930701
# --- Fold 4 - Accuracy: 0.834738, AUC: 0.930524
# --- Fold 5 - Accuracy: 0.827419, AUC: 0.925465
#
# ------ Accuracy: 0.834941 ± 0.003959
# ------ AUC:      0.930226 ± 0.002549

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
