# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
train["is_train"] = True
test["is_train"] = False
combined = pd.concat([train, test], sort=False)

for col in combined.columns:
    counts = combined[col].value_counts()
    to_replace = counts[counts < 20].index
    if len(to_replace) > 0:
        max_val = combined[col].max()
        combined[col] = combined[col].replace(to_replace, max_val + 1)
        
train = combined[combined["is_train"]].drop(columns="is_train")
test = combined[~combined["is_train"]].drop(columns=["is_train", TARGET])

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.834945, AUC: 0.929829
# --- Fold 2 - Accuracy: 0.835795, AUC: 0.931963
# --- Fold 3 - Accuracy: 0.833704, AUC: 0.929998
# --- Fold 4 - Accuracy: 0.833431, AUC: 0.929561
# --- Fold 5 - Accuracy: 0.825720, AUC: 0.923593
#
# ------ Accuracy: 0.832719 ± 0.003602
# ------ AUC:      0.928989 ± 0.002829

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836317, AUC: 0.929566
# --- Fold 2 - Accuracy: 0.835860, AUC: 0.931549
# --- Fold 3 - Accuracy: 0.835010, AUC: 0.929426
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.929491
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.924235
#
# ------ Accuracy: 0.833163 ± 0.003762
# ------ AUC:      0.928853 ± 0.002443

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.835991, AUC: 0.930641
# --- Fold 2 - Accuracy: 0.835076, AUC: 0.932044
# --- Fold 3 - Accuracy: 0.835272, AUC: 0.929516
# --- Fold 4 - Accuracy: 0.833889, AUC: 0.929969
# --- Fold 5 - Accuracy: 0.825263, AUC: 0.924265
#
# ------ Accuracy: 0.833098 ± 0.003975
# ------ AUC:      0.929287 ± 0.002652

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.833573, AUC: 0.928884
# --- Fold 2 - Accuracy: 0.835729, AUC: 0.929761
# --- Fold 3 - Accuracy: 0.834357, AUC: 0.928220
# --- Fold 4 - Accuracy: 0.831275, AUC: 0.928618
# --- Fold 5 - Accuracy: 0.824087, AUC: 0.923383
#
# ------ Accuracy: 0.831804 ± 0.004120
# ------ AUC:      0.927773 ± 0.002253

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834357, AUC: 0.928966
# --- Fold 2 - Accuracy: 0.834618, AUC: 0.930518
# --- Fold 3 - Accuracy: 0.833050, AUC: 0.928615
# --- Fold 4 - Accuracy: 0.830295, AUC: 0.929292
# --- Fold 5 - Accuracy: 0.824283, AUC: 0.923850
#
# ------ Accuracy: 0.831321 ± 0.003838
# ------ AUC:      0.928248 ± 0.002291

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.829064, AUC: 0.923036
# --- Fold 2 - Accuracy: 0.831286, AUC: 0.924469
# --- Fold 3 - Accuracy: 0.828607, AUC: 0.921311
# --- Fold 4 - Accuracy: 0.826309, AUC: 0.923319
# --- Fold 5 - Accuracy: 0.822584, AUC: 0.917584
#
# ------ Accuracy: 0.827570 ± 0.002952
# ------ AUC:      0.921944 ± 0.002403

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=5000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-10 19:48:20,929] A new study created in memory with name: no-name-58ef593b-6b47-48f0-b670-3b0ceebb8265
# [I 2024-06-10 19:48:20,945] Trial 0 finished with value: 0.8330719569251679 and parameters: {'xgb_weight': 0.02334381668135077, 'cb_weight': 0.000259829891489316, 'lgbm_weight': 0.3675104048220723, 'hgb_weight': 0.515490124133539, 'gb_weight': 0.6574749036158051, 'rf_weight': 0.5941149176270848}. Best is trial 0 with value: 0.8330719569251679.
# [I 2024-06-10 19:48:20,960] Trial 1 finished with value: 0.8329674063619018 and parameters: {'xgb_weight': 0.6951497056955545, 'cb_weight': 0.03480350081834449, 'lgbm_weight': 0.1425142309333539, 'hgb_weight': 0.9215902464853457, 'gb_weight': 0.079775267077421, 'rf_weight': 0.9836939418887833}. Best is trial 0 with value: 0.8330719569251679.
# [I 2024-06-10 19:48:20,975] Trial 2 finished with value: 0.8332941268721086 and parameters: {'xgb_weight': 0.566137256427435, 'cb_weight': 0.2751800121149608, 'lgbm_weight': 0.10132310672764866, 'hgb_weight': 0.4354025669131746, 'gb_weight': 0.14813226538826474, 'rf_weight': 0.03280207999500362}. Best is trial 2 with value: 0.8332941268721086.
# [I 2024-06-10 19:48:20,989] Trial 3 finished with value: 0.8335032279986408 and parameters: {'xgb_weight': 0.873959004272829, 'cb_weight': 0.2930197774131489, 'lgbm_weight': 0.9755058990075339, 'hgb_weight': 0.21272089771190106, 'gb_weight': 0.398083407164439, 'rf_weight': 0.9689742469075081}. Best is trial 3 with value: 0.8335032279986408.
# [I 2024-06-10 19:48:21,004] Trial 4 finished with value: 0.8332026451292507 and parameters: {'xgb_weight': 0.20946720075867276, 'cb_weight': 0.9675116742890076, 'lgbm_weight': 0.2585779616249988, 'hgb_weight': 0.7291644068943914, 'gb_weight': 0.5252580715993458, 'rf_weight': 0.020596923308482507}. Best is trial 3 with value: 0.8335032279986408.
# [I 2024-06-10 19:48:21,019] Trial 5 finished with value: 0.8332549204108837 and parameters: {'xgb_weight': 0.5741658784051531, 'cb_weight': 0.5583776871457071, 'lgbm_weight': 0.12095607187632629, 'hgb_weight': 0.7991293106357846, 'gb_weight': 0.09118380344170274, 'rf_weight': 0.060157683639367354}. Best is trial 3 with value: 0.8335032279986408.
# [I 2024-06-10 19:48:21,033] Trial 6 finished with value: 0.8336339162027235 and parameters: {'xgb_weight': 0.9663755425395706, 'cb_weight': 0.91532448801395, 'lgbm_weight': 0.7333497110763343, 'hgb_weight': 0.7062255235783963, 'gb_weight': 0.2679218464344074, 'rf_weight': 0.27878139160780246}. Best is trial 6 with value: 0.8336339162027235.
# [I 2024-06-10 19:48:21,048] Trial 7 finished with value: 0.8324577223659793 and parameters: {'xgb_weight': 0.224354346120886, 'cb_weight': 0.007572402616959462, 'lgbm_weight': 0.019521326322005428, 'hgb_weight': 0.6916596930442203, 'gb_weight': 0.8302045743269613, 'rf_weight': 0.2966126573509704}. Best is trial 6 with value: 0.8336339162027235.
# [I 2024-06-10 19:48:21,062] Trial 8 finished with value: 0.833464021537416 and parameters: {'xgb_weight': 0.05045964320333518, 'cb_weight': 0.4118040321193249, 'lgbm_weight': 0.676858580712328, 'hgb_weight': 0.25771452794956007, 'gb_weight': 0.8141593587788992, 'rf_weight': 0.6774932305210015}. Best is trial 6 with value: 0.8336339162027235.
# [I 2024-06-10 19:48:21,077] Trial 9 finished with value: 0.8332157139496589 and parameters: {'xgb_weight': 0.6786683057298756, 'cb_weight': 0.1580191988552052, 'lgbm_weight': 0.22494412125916297, 'hgb_weight': 0.66972392674353, 'gb_weight': 0.6934138678248828, 'rf_weight': 0.8052299664043656}. Best is trial 6 with value: 0.8336339162027235.
# [I 2024-06-10 19:48:21,119] Trial 10 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.9215669538172924, 'cb_weight': 0.9278872588534793, 'lgbm_weight': 0.6418558447474393, 'hgb_weight': 0.9920081765075959, 'gb_weight': 0.30024843019129477, 'rf_weight': 0.3408217132581258}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,161] Trial 11 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.9990631774419053, 'cb_weight': 0.9933706046465502, 'lgbm_weight': 0.6833107745895641, 'hgb_weight': 0.953279108085226, 'gb_weight': 0.36853235926921635, 'rf_weight': 0.35130664422690594}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,204] Trial 12 finished with value: 0.8336992603047649 and parameters: {'xgb_weight': 0.9978828886636644, 'cb_weight': 0.7421723906653159, 'lgbm_weight': 0.6569414012875279, 'hgb_weight': 0.989378789581804, 'gb_weight': 0.35336278181977426, 'rf_weight': 0.3661757783810609}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,245] Trial 13 finished with value: 0.8337384667659897 and parameters: {'xgb_weight': 0.8100333371898778, 'cb_weight': 0.7843421645949679, 'lgbm_weight': 0.5079527223667124, 'hgb_weight': 0.016968421773936426, 'gb_weight': 0.999497202700479, 'rf_weight': 0.44655343554657956}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,288] Trial 14 finished with value: 0.8336469850231318 and parameters: {'xgb_weight': 0.3922574226889497, 'cb_weight': 0.7496962438943813, 'lgbm_weight': 0.8816388593733246, 'hgb_weight': 0.8846370804129873, 'gb_weight': 0.28004808218456884, 'rf_weight': 0.23804413743721264}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,330] Trial 15 finished with value: 0.8335032279986408 and parameters: {'xgb_weight': 0.8146729728889726, 'cb_weight': 0.8787352215403551, 'lgbm_weight': 0.5439525051905997, 'hgb_weight': 0.9765859523145813, 'gb_weight': 0.47129577613621426, 'rf_weight': 0.17884649014236265}. Best is trial 10 with value: 0.8337776732272145.
# [I 2024-06-10 19:48:21,373] Trial 16 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.911530471959326, 'cb_weight': 0.6093836738410481, 'lgbm_weight': 0.8087216579765715, 'hgb_weight': 0.5212852582236788, 'gb_weight': 0.2048034937793119, 'rf_weight': 0.49178768420705254}. Best is trial 16 with value: 0.8338299485088476.
# [I 2024-06-10 19:48:21,416] Trial 17 finished with value: 0.833803810868031 and parameters: {'xgb_weight': 0.6956332754906127, 'cb_weight': 0.6038792287210107, 'lgbm_weight': 0.8255903388736519, 'hgb_weight': 0.5108779250096399, 'gb_weight': 0.20933757865939895, 'rf_weight': 0.5196338064042608}. Best is trial 16 with value: 0.8338299485088476.
# [I 2024-06-10 19:48:21,460] Trial 18 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.7267536556659855, 'cb_weight': 0.5765804644715581, 'lgbm_weight': 0.8233908082931394, 'hgb_weight': 0.5200235477775493, 'gb_weight': 0.1868084136465292, 'rf_weight': 0.5877787356799353}. Best is trial 18 with value: 0.8338691549700724.
# [I 2024-06-10 19:48:21,502] Trial 19 finished with value: 0.8335947097414987 and parameters: {'xgb_weight': 0.4192866852794252, 'cb_weight': 0.4575616279600533, 'lgbm_weight': 0.9944793401250248, 'hgb_weight': 0.39052386195079924, 'gb_weight': 0.04464864374213737, 'rf_weight': 0.7399556622425965}. Best is trial 18 with value: 0.8338691549700724.
# [I 2024-06-10 19:48:21,545] Trial 20 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.8060068820037477, 'cb_weight': 0.6301222447630664, 'lgbm_weight': 0.8169001994815783, 'hgb_weight': 0.5890892815199678, 'gb_weight': 0.009650304439452667, 'rf_weight': 0.5836219316697885}. Best is trial 18 with value: 0.8338691549700724.
# [I 2024-06-10 19:48:21,588] Trial 21 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.7863308859963415, 'cb_weight': 0.6378889026685154, 'lgbm_weight': 0.822998969822928, 'hgb_weight': 0.5756602521182596, 'gb_weight': 0.0037832308284548016, 'rf_weight': 0.5826245828269574}. Best is trial 18 with value: 0.8338691549700724.
# [I 2024-06-10 19:48:21,631] Trial 22 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.7644865749881807, 'cb_weight': 0.5053435365878154, 'lgbm_weight': 0.8925322033384047, 'hgb_weight': 0.6067770688562132, 'gb_weight': 0.0008018884614713305, 'rf_weight': 0.6150634428187447}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,674] Trial 23 finished with value: 0.83366005384354 and parameters: {'xgb_weight': 0.6215529232965978, 'cb_weight': 0.38466852098060955, 'lgbm_weight': 0.9104912143744953, 'hgb_weight': 0.35456442091107626, 'gb_weight': 0.13965118087027473, 'rf_weight': 0.7988989082163451}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,717] Trial 24 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.7724454806850352, 'cb_weight': 0.5273876292866057, 'lgbm_weight': 0.7811657897482773, 'hgb_weight': 0.6097900807995145, 'gb_weight': 0.04467247944844033, 'rf_weight': 0.6651504169543406}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,759] Trial 25 finished with value: 0.833267989231292 and parameters: {'xgb_weight': 0.49276172834893545, 'cb_weight': 0.6785552015743294, 'lgbm_weight': 0.5842472099483023, 'hgb_weight': 0.7969051870856184, 'gb_weight': 0.003605469739633479, 'rf_weight': 0.8731548792602701}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,800] Trial 26 finished with value: 0.8334770903578244 and parameters: {'xgb_weight': 0.7051170601428888, 'cb_weight': 0.4820014217620459, 'lgbm_weight': 0.42076748548835197, 'hgb_weight': 0.6125579377698251, 'gb_weight': 0.15647807804902936, 'rf_weight': 0.4357760539121348}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,843] Trial 27 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.8528572735468044, 'cb_weight': 0.8462425565739276, 'lgbm_weight': 0.9184701708890995, 'hgb_weight': 0.29071003995611183, 'gb_weight': 0.20996496073446574, 'rf_weight': 0.6021897001715615}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,885] Trial 28 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.8704068316927057, 'cb_weight': 0.8408112931580589, 'lgbm_weight': 0.9084190567658758, 'hgb_weight': 0.2884025946195948, 'gb_weight': 0.21054782803516486, 'rf_weight': 0.6591642749856802}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,927] Trial 29 finished with value: 0.8337646044068062 and parameters: {'xgb_weight': 0.8543399451915178, 'cb_weight': 0.8342454857492261, 'lgbm_weight': 0.9306564344717297, 'hgb_weight': 0.16910836461005424, 'gb_weight': 0.44751053819952863, 'rf_weight': 0.6748869387072589}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:21,970] Trial 30 finished with value: 0.833607778561907 and parameters: {'xgb_weight': 0.9062974943819988, 'cb_weight': 0.8483503587770914, 'lgbm_weight': 0.8863068920926922, 'hgb_weight': 0.0674222720572148, 'gb_weight': 0.6216726507453708, 'rf_weight': 0.7505334592533339}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:22,012] Trial 31 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.742890471972194, 'cb_weight': 0.7229016445057928, 'lgbm_weight': 0.9321954415570606, 'hgb_weight': 0.3137633249017476, 'gb_weight': 0.21214876884253425, 'rf_weight': 0.6196180390637515}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:22,054] Trial 32 finished with value: 0.8336861914843566 and parameters: {'xgb_weight': 0.6303704998605819, 'cb_weight': 0.7975771308003837, 'lgbm_weight': 0.7539339187437941, 'hgb_weight': 0.44408112216677464, 'gb_weight': 0.08787122971621997, 'rf_weight': 0.5320499376856478}. Best is trial 22 with value: 0.8339737055333386.
# [I 2024-06-10 19:48:22,097] Trial 33 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.8597839028560753, 'cb_weight': 0.3355772515737825, 'lgbm_weight': 0.8686038308690548, 'hgb_weight': 0.14585883458570825, 'gb_weight': 0.14969417874013652, 'rf_weight': 0.6187742068072135}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,140] Trial 34 finished with value: 0.83366005384354 and parameters: {'xgb_weight': 0.8683288203605264, 'cb_weight': 0.27821096283884816, 'lgbm_weight': 0.9957984417628128, 'hgb_weight': 0.12704518059218098, 'gb_weight': 0.11846094164827814, 'rf_weight': 0.886192429892846}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,183] Trial 35 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.9431300115642518, 'cb_weight': 0.2136725493447754, 'lgbm_weight': 0.8607882678205758, 'hgb_weight': 0.2715875707963885, 'gb_weight': 0.25328424020598983, 'rf_weight': 0.7438451990626865}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,227] Trial 36 finished with value: 0.8336208473823152 and parameters: {'xgb_weight': 0.9401018654894735, 'cb_weight': 0.14304866727368298, 'lgbm_weight': 0.7318938423078357, 'hgb_weight': 0.20985487006288045, 'gb_weight': 0.31633332106894896, 'rf_weight': 0.754627008405839}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,270] Trial 37 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.9445536884309803, 'cb_weight': 0.2056827344608425, 'lgbm_weight': 0.859571300478538, 'hgb_weight': 0.10232593099005943, 'gb_weight': 0.08462446538254376, 'rf_weight': 0.9207275649813064}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,314] Trial 38 finished with value: 0.8333594709741499 and parameters: {'xgb_weight': 0.5290557059093739, 'cb_weight': 0.35024480072265696, 'lgbm_weight': 0.33294177945106274, 'hgb_weight': 0.43656354650254864, 'gb_weight': 0.2599925589883082, 'rf_weight': 0.7041992247686085}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,357] Trial 39 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.8746888166719935, 'cb_weight': 0.07129956543641999, 'lgbm_weight': 0.9630373107661218, 'hgb_weight': 0.223657271665144, 'gb_weight': 0.41535194539998543, 'rf_weight': 0.8125620594735393}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,400] Trial 40 finished with value: 0.8335162968190492 and parameters: {'xgb_weight': 0.6485394328124, 'cb_weight': 0.34146119651841755, 'lgbm_weight': 0.6042289276140798, 'hgb_weight': 0.3543548318556886, 'gb_weight': 0.5438796390700674, 'rf_weight': 0.6408472329531901}. Best is trial 33 with value: 0.8340129119945634.
# [I 2024-06-10 19:48:22,443] Trial 41 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.849758834073695, 'cb_weight': 0.2265888163978166, 'lgbm_weight': 0.8716830686634868, 'hgb_weight': 0.285164263968901, 'gb_weight': 0.1593779545728105, 'rf_weight': 0.5404747055542772}. Best is trial 41 with value: 0.8341436001986461.
# [I 2024-06-10 19:48:22,486] Trial 42 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.7603204674324302, 'cb_weight': 0.22046890750574874, 'lgbm_weight': 0.8611719888543268, 'hgb_weight': 0.1554892829321637, 'gb_weight': 0.1402893722989522, 'rf_weight': 0.4704971894406579}. Best is trial 42 with value: 0.8341958754802792.
# [I 2024-06-10 19:48:22,529] Trial 43 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7518517148342054, 'cb_weight': 0.09542420943564534, 'lgbm_weight': 0.726007217540476, 'hgb_weight': 0.1714788035532766, 'gb_weight': 0.13287089701196245, 'rf_weight': 0.4394544618412586}. Best is trial 42 with value: 0.8341958754802792.
# [I 2024-06-10 19:48:22,574] Trial 44 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.7497864137487418, 'cb_weight': 0.09363771270179028, 'lgbm_weight': 0.7407476093731036, 'hgb_weight': 0.15412799165420035, 'gb_weight': 0.13002445636052526, 'rf_weight': 0.42340732973061046}. Best is trial 42 with value: 0.8341958754802792.
# [I 2024-06-10 19:48:22,617] Trial 45 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.5939344247935143, 'cb_weight': 0.0881631460291077, 'lgbm_weight': 0.7159543167356792, 'hgb_weight': 0.027139037404446953, 'gb_weight': 0.12407303632418032, 'rf_weight': 0.40727775214830536}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,661] Trial 46 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.5836556049304513, 'cb_weight': 0.05796802353942235, 'lgbm_weight': 0.7003795034442624, 'hgb_weight': 0.06910103729714222, 'gb_weight': 0.11191037363532823, 'rf_weight': 0.4357626329350336}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,705] Trial 47 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.6563103891189034, 'cb_weight': 0.12692946878593325, 'lgbm_weight': 0.7353058733409811, 'hgb_weight': 0.011176169114077938, 'gb_weight': 0.0663095990535916, 'rf_weight': 0.3741445352766483}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,749] Trial 48 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.4666226203472839, 'cb_weight': 0.10595542389484686, 'lgbm_weight': 0.6129513795840555, 'hgb_weight': 0.010920987319874778, 'gb_weight': 0.05828120087217199, 'rf_weight': 0.40903775180440943}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,793] Trial 49 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.5772562049612575, 'cb_weight': 0.015239947007705978, 'lgbm_weight': 0.7016505391958165, 'hgb_weight': 0.06133373613240453, 'gb_weight': 0.10242973450775152, 'rf_weight': 0.2933568046014293}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,837] Trial 50 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.661733702944846, 'cb_weight': 0.14735442457441694, 'lgbm_weight': 0.7640230441906967, 'hgb_weight': 0.17428052493204485, 'gb_weight': 0.344215236497828, 'rf_weight': 0.1820310769541742}. Best is trial 45 with value: 0.8342089443006874.
# [I 2024-06-10 19:48:22,882] Trial 51 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.7284920738062057, 'cb_weight': 0.21632886429045012, 'lgbm_weight': 0.7375574779014619, 'hgb_weight': 0.10223527366329865, 'gb_weight': 0.17125873859550286, 'rf_weight': 0.4752215963130339}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:22,926] Trial 52 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.7226477367979742, 'cb_weight': 0.1078922520219791, 'lgbm_weight': 0.6514699687367547, 'hgb_weight': 0.10883136041777769, 'gb_weight': 0.24636768045951932, 'rf_weight': 0.3853745505015209}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:22,970] Trial 53 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.6119143810835187, 'cb_weight': 0.09431453667894447, 'lgbm_weight': 0.7311260989505197, 'hgb_weight': 0.005321869711029881, 'gb_weight': 0.062007572935722205, 'rf_weight': 0.48262095245953307}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,014] Trial 54 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.6773012109254244, 'cb_weight': 0.17543972634803018, 'lgbm_weight': 0.4701285942054334, 'hgb_weight': 0.0495124688407855, 'gb_weight': 0.18235637066390364, 'rf_weight': 0.33318926733923215}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,059] Trial 55 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.5324012760133763, 'cb_weight': 0.0049518385590542335, 'lgbm_weight': 0.554299443564288, 'hgb_weight': 0.22079239753283975, 'gb_weight': 0.11864686901033461, 'rf_weight': 0.47481522419948413}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,103] Trial 56 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.2500170433570453, 'cb_weight': 0.26265347729650235, 'lgbm_weight': 0.7730585678006253, 'hgb_weight': 0.1759959407924563, 'gb_weight': 0.3059404010679644, 'rf_weight': 0.22775986519573194}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,146] Trial 57 finished with value: 0.8337515355863979 and parameters: {'xgb_weight': 0.7492148784768349, 'cb_weight': 0.05336466453212811, 'lgbm_weight': 0.694638067355139, 'hgb_weight': 0.08875725276851212, 'gb_weight': 0.7772389385830978, 'rf_weight': 0.3952246853358073}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,190] Trial 58 finished with value: 0.8333856086149665 and parameters: {'xgb_weight': 0.8120773819104189, 'cb_weight': 0.1820757294605064, 'lgbm_weight': 0.6436024324842861, 'hgb_weight': 0.032549912761292626, 'gb_weight': 0.9723260936584022, 'rf_weight': 0.3128256527076708}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,234] Trial 59 finished with value: 0.8337515355863979 and parameters: {'xgb_weight': 0.7012285437177727, 'cb_weight': 0.24556934924844132, 'lgbm_weight': 0.06532209918192111, 'hgb_weight': 0.14373050198963494, 'gb_weight': 0.03983249504853156, 'rf_weight': 0.35900193746811104}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,277] Trial 60 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.3478602608334999, 'cb_weight': 0.1325833523312, 'lgbm_weight': 0.7914904838833912, 'hgb_weight': 0.1978328583303806, 'gb_weight': 0.1562180393887923, 'rf_weight': 0.24941882175971658}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,323] Trial 61 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.7865411723842226, 'cb_weight': 0.23794222434202256, 'lgbm_weight': 0.8390924953826532, 'hgb_weight': 0.23814606702057337, 'gb_weight': 0.1783630393828104, 'rf_weight': 0.5342804493133375}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,368] Trial 62 finished with value: 0.8332287827700672 and parameters: {'xgb_weight': 0.004956283273017892, 'cb_weight': 0.19859084947383313, 'lgbm_weight': 0.7272722858853988, 'hgb_weight': 0.1237552066084275, 'gb_weight': 0.11962669259847956, 'rf_weight': 0.5585276543971852}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,412] Trial 63 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.7333992170671568, 'cb_weight': 0.3065540786122264, 'lgbm_weight': 0.7941026155633977, 'hgb_weight': 0.09271559345034569, 'gb_weight': 0.2387532351129248, 'rf_weight': 0.45985498320421936}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,457] Trial 64 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.829139537959494, 'cb_weight': 0.11795221298692982, 'lgbm_weight': 0.6659682241071879, 'hgb_weight': 0.03640017511064754, 'gb_weight': 0.158581860554793, 'rf_weight': 0.42350034351832333}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,502] Trial 65 finished with value: 0.8333986774353747 and parameters: {'xgb_weight': 0.08351197166712765, 'cb_weight': 0.03752783752736348, 'lgbm_weight': 0.5815822744836745, 'hgb_weight': 0.05384136616568023, 'gb_weight': 0.07739343812202637, 'rf_weight': 0.41733558975204205}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,547] Trial 66 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.599710266923381, 'cb_weight': 0.08452748944470062, 'lgbm_weight': 0.5185846730283784, 'hgb_weight': 0.02875146115231056, 'gb_weight': 0.045163345764497, 'rf_weight': 0.5155571540099857}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,593] Trial 67 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.647779325755228, 'cb_weight': 0.13504941969000692, 'lgbm_weight': 0.6689797746253099, 'hgb_weight': 0.14984578652151628, 'gb_weight': 0.13915903217598888, 'rf_weight': 0.3678248263967711}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,636] Trial 68 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.8242084551399849, 'cb_weight': 0.16635468017061447, 'lgbm_weight': 0.6188150226807205, 'hgb_weight': 0.08638601297646596, 'gb_weight': 0.28437523430080647, 'rf_weight': 0.49748106574441453}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,683] Trial 69 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7695989207116744, 'cb_weight': 0.12282325286675075, 'lgbm_weight': 0.7405964799808051, 'hgb_weight': 0.0008949635093197551, 'gb_weight': 0.1818189309430699, 'rf_weight': 0.43394651398808204}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,727] Trial 70 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.801024871273803, 'cb_weight': 0.029664122385970215, 'lgbm_weight': 0.6748561941599691, 'hgb_weight': 0.040792412566230216, 'gb_weight': 0.19005586720567752, 'rf_weight': 0.45068083346783794}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,772] Trial 71 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.7681833360969283, 'cb_weight': 0.11749697277350374, 'lgbm_weight': 0.7630429402923095, 'hgb_weight': 0.005643689203474224, 'gb_weight': 0.22734506012374622, 'rf_weight': 0.3302796961882965}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,817] Trial 72 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.6854262444674116, 'cb_weight': 0.09317199082794736, 'lgbm_weight': 0.7194315495259083, 'hgb_weight': 0.07361987425146503, 'gb_weight': 0.17538445314027737, 'rf_weight': 0.41077911456422744}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,862] Trial 73 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.7030065893111834, 'cb_weight': 0.07017295151169592, 'lgbm_weight': 0.7146572972048191, 'hgb_weight': 0.11210822791541264, 'gb_weight': 0.18073982888826312, 'rf_weight': 0.43523651604462826}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,908] Trial 74 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.7206688558354744, 'cb_weight': 0.05504593067105651, 'lgbm_weight': 0.7098111491113779, 'hgb_weight': 0.12000708875244286, 'gb_weight': 0.17788423788797128, 'rf_weight': 0.4644715392476904}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,953] Trial 75 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.8954846617839121, 'cb_weight': 0.04494878078439607, 'lgbm_weight': 0.8360470017970574, 'hgb_weight': 0.07987019393963203, 'gb_weight': 0.33606427966805985, 'rf_weight': 0.5631298700286138}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:23,997] Trial 76 finished with value: 0.8336469850231318 and parameters: {'xgb_weight': 0.8278861969433022, 'cb_weight': 0.18765346343134964, 'lgbm_weight': 0.20048374726247287, 'hgb_weight': 0.18336908058012208, 'gb_weight': 0.2789348138036428, 'rf_weight': 0.46754638183477326}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,042] Trial 77 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.5461243095274102, 'cb_weight': 0.1602764663769114, 'lgbm_weight': 0.7977646435430596, 'hgb_weight': 0.12890202954162994, 'gb_weight': 0.3803171505398124, 'rf_weight': 0.4031805976857853}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,087] Trial 78 finished with value: 0.8337253979455814 and parameters: {'xgb_weight': 0.6792616374975773, 'cb_weight': 0.07337410109923129, 'lgbm_weight': 0.656210518691724, 'hgb_weight': 0.2536063588508499, 'gb_weight': 0.22142055111611836, 'rf_weight': 0.08868994050299006}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,133] Trial 79 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.72165173821983, 'cb_weight': 0.3015423641143586, 'lgbm_weight': 0.6868250831831351, 'hgb_weight': 0.044156480551992255, 'gb_weight': 0.024120724219482192, 'rf_weight': 0.49553402940960706}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,177] Trial 80 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.7828786726506647, 'cb_weight': 0.00038330812383494117, 'lgbm_weight': 0.5740406738233369, 'hgb_weight': 0.0706852625512467, 'gb_weight': 0.09165694629916123, 'rf_weight': 0.5055137899930888}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,222] Trial 81 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.6996967442318387, 'cb_weight': 0.07137918017989574, 'lgbm_weight': 0.711585931792595, 'hgb_weight': 0.11678590025918806, 'gb_weight': 0.16764977534784048, 'rf_weight': 0.46368353086712216}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,267] Trial 82 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.6332182012725528, 'cb_weight': 0.11648907833922112, 'lgbm_weight': 0.627927740089546, 'hgb_weight': 0.1148013162005879, 'gb_weight': 0.16527860200988942, 'rf_weight': 0.45646386523906884}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,313] Trial 83 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.68099276589464, 'cb_weight': 0.031667438768431186, 'lgbm_weight': 0.7448677656521356, 'hgb_weight': 0.032080930407144, 'gb_weight': 0.20361210323308318, 'rf_weight': 0.38634373445140896}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,357] Trial 84 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.7604076722977826, 'cb_weight': 0.08443605407979551, 'lgbm_weight': 0.8098647736104687, 'hgb_weight': 0.15487131568277562, 'gb_weight': 0.1407027454991493, 'rf_weight': 0.34558223398584176}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,403] Trial 85 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7575492917153339, 'cb_weight': 0.05714623057357797, 'lgbm_weight': 0.8142317419320063, 'hgb_weight': 0.19334655605426587, 'gb_weight': 0.1394280614864886, 'rf_weight': 0.34275098132418325}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,448] Trial 86 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.7207125760870201, 'cb_weight': 0.15208940720084607, 'lgbm_weight': 0.8410796800157412, 'hgb_weight': 0.15506990945539145, 'gb_weight': 0.1098221600205474, 'rf_weight': 0.559599243234595}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,493] Trial 87 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.7899387467980254, 'cb_weight': 0.15453555341678912, 'lgbm_weight': 0.8443969799203844, 'hgb_weight': 0.15487310794109987, 'gb_weight': 0.10873581751699504, 'rf_weight': 0.5615206339302646}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,540] Trial 88 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.7171574434411447, 'cb_weight': 0.40126387793265594, 'lgbm_weight': 0.9618945193038326, 'hgb_weight': 0.24037186371437685, 'gb_weight': 0.0953050233821219, 'rf_weight': 0.48452544398633457}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,587] Trial 89 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.8360932182028004, 'cb_weight': 0.21574164405837332, 'lgbm_weight': 0.7826534636068725, 'hgb_weight': 0.13278011602998102, 'gb_weight': 0.15495740867304575, 'rf_weight': 0.26362093256231767}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,633] Trial 90 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.7358046351113072, 'cb_weight': 0.44986664459987646, 'lgbm_weight': 0.8941767583912713, 'hgb_weight': 0.3310461900730696, 'gb_weight': 0.5702870953635931, 'rf_weight': 0.3061330103600147}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,679] Trial 91 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7742682867433837, 'cb_weight': 0.1125931265283744, 'lgbm_weight': 0.7595120532335679, 'hgb_weight': 0.10153807089157765, 'gb_weight': 0.13262498624321978, 'rf_weight': 0.43762289424711603}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,725] Trial 92 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.7460435873193851, 'cb_weight': 0.08297523882794855, 'lgbm_weight': 0.707404994188206, 'hgb_weight': 0.1677858819761634, 'gb_weight': 0.1988981180174816, 'rf_weight': 0.516196298437539}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,771] Trial 93 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.8857144473348366, 'cb_weight': 0.13860692797559365, 'lgbm_weight': 0.8059425949553299, 'hgb_weight': 0.00011244392044593154, 'gb_weight': 0.0728284812708126, 'rf_weight': 0.4700022688154203}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,816] Trial 94 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.8047414660943317, 'cb_weight': 0.023513177053229202, 'lgbm_weight': 0.8572420889280516, 'hgb_weight': 0.4866254303522386, 'gb_weight': 0.23425280651814367, 'rf_weight': 0.5471918299917085}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,862] Trial 95 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.7629686250645243, 'cb_weight': 0.1810748216147352, 'lgbm_weight': 0.6818251224163577, 'hgb_weight': 0.05425843109611463, 'gb_weight': 0.030601310523702963, 'rf_weight': 0.5867526153874179}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,908] Trial 96 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.7068161698309733, 'cb_weight': 0.0583461474542183, 'lgbm_weight': 0.7779840157733469, 'hgb_weight': 0.09679391303600016, 'gb_weight': 0.13113780415794335, 'rf_weight': 0.3756387489909361}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:24,953] Trial 97 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.8418246321960929, 'cb_weight': 0.2559669087850871, 'lgbm_weight': 0.7488746675813774, 'hgb_weight': 0.2097631818081269, 'gb_weight': 0.16473553751694126, 'rf_weight': 0.4234186645381538}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,000] Trial 98 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.6625088713922198, 'cb_weight': 0.1986271175912805, 'lgbm_weight': 0.8206304818539514, 'hgb_weight': 0.13511526113564357, 'gb_weight': 0.107196819113961, 'rf_weight': 0.35769308307291053}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,047] Trial 99 finished with value: 0.8336861914843566 and parameters: {'xgb_weight': 0.6147189888078559, 'cb_weight': 0.15786877737677346, 'lgbm_weight': 0.639881988826491, 'hgb_weight': 0.7669835065474782, 'gb_weight': 0.24765568980729388, 'rf_weight': 0.5267835232546881}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,093] Trial 100 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.5936638182419943, 'cb_weight': 0.10469152014151388, 'lgbm_weight': 0.9409648876313426, 'hgb_weight': 0.02168191469346878, 'gb_weight': 0.2674281466834591, 'rf_weight': 0.44487322548951647}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,141] Trial 101 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7506113421846184, 'cb_weight': 0.055511553405844405, 'lgbm_weight': 0.8090999797960302, 'hgb_weight': 0.19320126960480805, 'gb_weight': 0.14689929522089484, 'rf_weight': 0.34127489842864517}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,188] Trial 102 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.7664886806566931, 'cb_weight': 0.07101524080266802, 'lgbm_weight': 0.9014551683384748, 'hgb_weight': 0.16040513256761724, 'gb_weight': 0.12624682953459157, 'rf_weight': 0.2819446914564136}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,234] Trial 103 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.731669523156171, 'cb_weight': 0.1319680309416137, 'lgbm_weight': 0.8767339068648254, 'hgb_weight': 0.19850527464401843, 'gb_weight': 0.19484199160629032, 'rf_weight': 0.3931046771377054}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,280] Trial 104 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.7929851592733831, 'cb_weight': 0.042079927271032, 'lgbm_weight': 0.7705801756789457, 'hgb_weight': 0.11555946710897208, 'gb_weight': 0.08724154081301964, 'rf_weight': 0.3215346117619475}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,327] Trial 105 finished with value: 0.833555503280274 and parameters: {'xgb_weight': 0.699549293733577, 'cb_weight': 0.08482334024558962, 'lgbm_weight': 0.7148174979006461, 'hgb_weight': 0.8669471962220108, 'gb_weight': 0.05841313177566758, 'rf_weight': 0.4837269410831377}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,373] Trial 106 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.8199467494615125, 'cb_weight': 0.23124787317401208, 'lgbm_weight': 0.8294454003795053, 'hgb_weight': 0.06642838241755611, 'gb_weight': 0.21887755202141354, 'rf_weight': 0.42106733363589466}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,420] Trial 107 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.8165121751250579, 'cb_weight': 0.22596063157549073, 'lgbm_weight': 0.8424340954307977, 'hgb_weight': 0.06342677746625663, 'gb_weight': 0.6967198819211526, 'rf_weight': 0.42446475412125756}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,466] Trial 108 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.8554839697584993, 'cb_weight': 0.2862766026516437, 'lgbm_weight': 0.7459231244185629, 'hgb_weight': 0.030081255964723913, 'gb_weight': 0.21617083950128052, 'rf_weight': 0.5062604935935815}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,514] Trial 109 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.6445846152540051, 'cb_weight': 0.17544206488993422, 'lgbm_weight': 0.3129891912789822, 'hgb_weight': 0.08230852766341774, 'gb_weight': 0.17637634549266526, 'rf_weight': 0.46141378804262284}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,561] Trial 110 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.4816903288725563, 'cb_weight': 0.14923794149646843, 'lgbm_weight': 0.6658417885225032, 'hgb_weight': 0.13827715482132716, 'gb_weight': 0.15519578855622154, 'rf_weight': 0.4032971681972234}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,608] Trial 111 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.4459122470481855, 'cb_weight': 0.1517866358467135, 'lgbm_weight': 0.6976866163691332, 'hgb_weight': 0.13730144760216265, 'gb_weight': 0.16149291936584872, 'rf_weight': 0.44423467073159656}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,655] Trial 112 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.49590030219997516, 'cb_weight': 0.12411705506603568, 'lgbm_weight': 0.6665722672059157, 'hgb_weight': 0.10307783615235783, 'gb_weight': 0.19408013794985998, 'rf_weight': 0.4057020325669386}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,703] Trial 113 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.5572090891892281, 'cb_weight': 0.09477359288483447, 'lgbm_weight': 0.7341632621779615, 'hgb_weight': 0.05171729256420468, 'gb_weight': 0.10800915102608652, 'rf_weight': 0.37381853988164093}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,751] Trial 114 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.4015160335500365, 'cb_weight': 0.31951489863672816, 'lgbm_weight': 0.6010067530403767, 'hgb_weight': 0.1730401082903493, 'gb_weight': 0.23310848341184176, 'rf_weight': 0.4009390648923462}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,799] Trial 115 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.5151294917056224, 'cb_weight': 0.21365238258673563, 'lgbm_weight': 0.7899783182402289, 'hgb_weight': 0.08785528128199062, 'gb_weight': 0.13964337553824507, 'rf_weight': 0.4733084970114078}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,846] Trial 116 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.9213599024425441, 'cb_weight': 0.2685430337028475, 'lgbm_weight': 0.6835897339841897, 'hgb_weight': 0.15311616474771067, 'gb_weight': 0.1687096309066974, 'rf_weight': 0.42135743954551963}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,893] Trial 117 finished with value: 0.8336208473823152 and parameters: {'xgb_weight': 0.33252725585031195, 'cb_weight': 0.1946024885836552, 'lgbm_weight': 0.6333993322179047, 'hgb_weight': 0.39695821590287506, 'gb_weight': 0.07934393430516828, 'rf_weight': 0.4970600532921437}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,942] Trial 118 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.4710156488007213, 'cb_weight': 0.23580753728681159, 'lgbm_weight': 0.4514757099261868, 'hgb_weight': 0.2299899575876491, 'gb_weight': 0.21864405705300669, 'rf_weight': 0.35967386632575177}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:25,989] Trial 119 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.6710431336914839, 'cb_weight': 0.016853230827410706, 'lgbm_weight': 0.7596522546151935, 'hgb_weight': 0.11779494553569178, 'gb_weight': 0.47895432472291066, 'rf_weight': 0.4603727084784448}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:26,036] Trial 120 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.9735700765569087, 'cb_weight': 0.16509909618993052, 'lgbm_weight': 0.7219013953703605, 'hgb_weight': 0.02557333870131919, 'gb_weight': 0.2922985313612464, 'rf_weight': 0.6397654358878611}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:26,085] Trial 121 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.7545382402774147, 'cb_weight': 0.10990691211369248, 'lgbm_weight': 0.8224972766145165, 'hgb_weight': 0.1843198331534401, 'gb_weight': 0.14180327489172745, 'rf_weight': 0.3941991508514249}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:26,133] Trial 122 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.720009682772426, 'cb_weight': 0.062309034175629434, 'lgbm_weight': 0.8616701665435674, 'hgb_weight': 0.2630573605821271, 'gb_weight': 0.12100323224689419, 'rf_weight': 0.3493715219991248}. Best is trial 51 with value: 0.834235081941504.
# [I 2024-06-10 19:48:26,179] Trial 123 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.7768422342641504, 'cb_weight': 0.1371888148716667, 'lgbm_weight': 0.8010480342005637, 'hgb_weight': 0.06980272771923009, 'gb_weight': 0.1541027092461341, 'rf_weight': 0.43493826162040405}. Best is trial 123 with value: 0.8342481507619123.
# [I 2024-06-10 19:48:26,226] Trial 124 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.7848375968589929, 'cb_weight': 0.13887640414760166, 'lgbm_weight': 0.7784962572932316, 'hgb_weight': 0.07380533449039345, 'gb_weight': 0.18228260364955395, 'rf_weight': 0.4332545211423519}. Best is trial 123 with value: 0.8342481507619123.
# [I 2024-06-10 19:48:26,273] Trial 125 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.8219886832708674, 'cb_weight': 0.15285544096639306, 'lgbm_weight': 0.7978706668434785, 'hgb_weight': 0.06307409114766936, 'gb_weight': 0.1016403550638026, 'rf_weight': 0.4840841347520225}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,320] Trial 126 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.8163843790319937, 'cb_weight': 0.1409449741792691, 'lgbm_weight': 0.8360008826245922, 'hgb_weight': 0.0776073478643324, 'gb_weight': 0.10204701134520891, 'rf_weight': 0.5195348821740808}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,367] Trial 127 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.8731517091354736, 'cb_weight': 0.1492191158004024, 'lgbm_weight': 0.7915741813959423, 'hgb_weight': 0.044889988664465544, 'gb_weight': 0.09088053786123461, 'rf_weight': 0.5730729706505544}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,415] Trial 128 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.7820347862776091, 'cb_weight': 0.13248831054401197, 'lgbm_weight': 0.9228549977028503, 'hgb_weight': 0.08391973903957907, 'gb_weight': 0.0542840815598586, 'rf_weight': 0.5317616346189442}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,463] Trial 129 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.8349025286140762, 'cb_weight': 0.1717581425583727, 'lgbm_weight': 0.8479385216557229, 'hgb_weight': 0.1255446709122713, 'gb_weight': 0.012451533382901225, 'rf_weight': 0.6020965803990115}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,509] Trial 130 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.8041401459848319, 'cb_weight': 0.19387630738778017, 'lgbm_weight': 0.8787720276078417, 'hgb_weight': 0.10443890420938932, 'gb_weight': 0.10593865748999995, 'rf_weight': 0.5489109251733822}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,555] Trial 131 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.815198193533762, 'cb_weight': 0.14181822519143028, 'lgbm_weight': 0.8074571990694777, 'hgb_weight': 0.10288312049833125, 'gb_weight': 0.10378549094055953, 'rf_weight': 0.5202085413159315}. Best is trial 125 with value: 0.8342873572231371.
# [I 2024-06-10 19:48:26,604] Trial 132 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.7949124619385203, 'cb_weight': 0.18660481289721814, 'lgbm_weight': 0.8834527939534386, 'hgb_weight': 0.10300934332414938, 'gb_weight': 0.14658197907744197, 'rf_weight': 0.5090437591912528}. Best is trial 132 with value: 0.8343657701455867.
# [I 2024-06-10 19:48:26,651] Trial 133 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.8113641345784852, 'cb_weight': 0.20011134409269363, 'lgbm_weight': 0.8729152905111768, 'hgb_weight': 0.0997144730107916, 'gb_weight': 0.09643796094205223, 'rf_weight': 0.518446427690626}. Best is trial 132 with value: 0.8343657701455867.
# [I 2024-06-10 19:48:26,698] Trial 134 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.8048254887061222, 'cb_weight': 0.17814661251622013, 'lgbm_weight': 0.8864252795787082, 'hgb_weight': 0.09847896002768741, 'gb_weight': 0.06408331408371429, 'rf_weight': 0.5435163279423924}. Best is trial 132 with value: 0.8343657701455867.
# [I 2024-06-10 19:48:26,745] Trial 135 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.8472760293225892, 'cb_weight': 0.19107916773720274, 'lgbm_weight': 0.9391877113038605, 'hgb_weight': 0.06747478611965396, 'gb_weight': 0.09493280355597578, 'rf_weight': 0.5111926554820136}. Best is trial 132 with value: 0.8343657701455867.
# [I 2024-06-10 19:48:26,792] Trial 136 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.8042551051552216, 'cb_weight': 0.20812399984069566, 'lgbm_weight': 0.8753588480812678, 'hgb_weight': 0.046195916539937584, 'gb_weight': 0.04008481941762079, 'rf_weight': 0.485506628793497}. Best is trial 136 with value: 0.834378838965995.
# ...
# [I 2024-06-10 20:00:37,454] Trial 4955 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.9082483668551136, 'cb_weight': 0.6644605102011955, 'lgbm_weight': 0.8091411201754332, 'hgb_weight': 0.0001103103441922118, 'gb_weight': 0.10205417735929373, 'rf_weight': 0.4967170295088926}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:37,716] Trial 4956 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.9017656760660845, 'cb_weight': 0.6042403422067288, 'lgbm_weight': 0.8386667390881786, 'hgb_weight': 0.0652831526256976, 'gb_weight': 0.06090959601480235, 'rf_weight': 0.5050826069831534}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:37,977] Trial 4957 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.8979058187666997, 'cb_weight': 0.6480060099932168, 'lgbm_weight': 0.8341379161064513, 'hgb_weight': 0.09982220391237054, 'gb_weight': 0.0803999489565069, 'rf_weight': 0.4772868133952137}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:38,241] Trial 4958 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.84454095757992, 'cb_weight': 0.5850292882675941, 'lgbm_weight': 0.7804666355930048, 'hgb_weight': 0.03169204170708016, 'gb_weight': 0.03760236078608463, 'rf_weight': 0.4964140435969816}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:38,501] Trial 4959 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.8937510408970165, 'cb_weight': 0.6241915488445661, 'lgbm_weight': 0.8369427793136841, 'hgb_weight': 0.0515247364013713, 'gb_weight': 0.0151339802860137, 'rf_weight': 0.5035375407497195}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:38,764] Trial 4960 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.9087254971837554, 'cb_weight': 0.5709535766790577, 'lgbm_weight': 0.761062502634809, 'hgb_weight': 0.031982963787429104, 'gb_weight': 0.05387076143654725, 'rf_weight': 0.4832986655039933}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:39,027] Trial 4961 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.9015404033495299, 'cb_weight': 0.6077907904189238, 'lgbm_weight': 0.8210641293820325, 'hgb_weight': 0.08427646636826083, 'gb_weight': 0.02901294865678148, 'rf_weight': 0.44677200820761404}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:39,291] Trial 4962 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.8883272696127318, 'cb_weight': 0.5418769824055242, 'lgbm_weight': 0.838840526244695, 'hgb_weight': 0.01934158374316733, 'gb_weight': 0.07078799537862275, 'rf_weight': 0.4602444416721697}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:39,566] Trial 4963 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.8991686174481819, 'cb_weight': 0.5210478764530008, 'lgbm_weight': 0.8032847668697631, 'hgb_weight': 0.6860074740647099, 'gb_weight': 0.01799430645060111, 'rf_weight': 0.5080860063118944}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:39,845] Trial 4964 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.9112876031960425, 'cb_weight': 0.6384412328414262, 'lgbm_weight': 0.8434884184784548, 'hgb_weight': 0.05108804708293105, 'gb_weight': 0.04726803249963363, 'rf_weight': 0.5010493522430783}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:40,107] Trial 4965 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.9098786139081784, 'cb_weight': 0.5901560199517405, 'lgbm_weight': 0.8196072534464787, 'hgb_weight': 8.40922825617596e-05, 'gb_weight': 0.03166362252743991, 'rf_weight': 0.4767135924437457}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:40,366] Trial 4966 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.8759534497316522, 'cb_weight': 0.6705607885851537, 'lgbm_weight': 0.84410386343758, 'hgb_weight': 0.06011926325240016, 'gb_weight': 0.08401235339481103, 'rf_weight': 0.5061058569094015}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:40,622] Trial 4967 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.9143961774303483, 'cb_weight': 0.566020561168906, 'lgbm_weight': 0.8443867164567777, 'hgb_weight': 0.03482432332150667, 'gb_weight': 0.05220392979756309, 'rf_weight': 0.5103802542117617}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:40,881] Trial 4968 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.8566056011583189, 'cb_weight': 0.6227897052955367, 'lgbm_weight': 0.8187519492098275, 'hgb_weight': 0.01728120724999403, 'gb_weight': 0.017162178808393047, 'rf_weight': 0.48805659742453644}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:41,141] Trial 4969 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.870168038342824, 'cb_weight': 0.604182619068779, 'lgbm_weight': 0.847820384223833, 'hgb_weight': 0.0753141295740043, 'gb_weight': 0.49891985026196245, 'rf_weight': 0.46863071086980074}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:41,403] Trial 4970 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.8988658994225478, 'cb_weight': 0.6457042147820202, 'lgbm_weight': 0.8284603097911675, 'hgb_weight': 0.04642054260275344, 'gb_weight': 0.06325835294276441, 'rf_weight': 0.5133632804904164}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:41,666] Trial 4971 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.9147513842085071, 'cb_weight': 0.5889634263194097, 'lgbm_weight': 0.8495759172112932, 'hgb_weight': 0.01777232662231292, 'gb_weight': 0.016506207826493136, 'rf_weight': 0.4952200560646458}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:41,928] Trial 4972 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.9097400670483642, 'cb_weight': 0.6228188014710233, 'lgbm_weight': 0.8025836869147258, 'hgb_weight': 0.00015211578338801546, 'gb_weight': 0.03948819167133506, 'rf_weight': 0.5150055862314361}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:42,187] Trial 4973 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.726768483239657, 'cb_weight': 0.3582124060593896, 'lgbm_weight': 0.8531152337548825, 'hgb_weight': 0.06742515324427603, 'gb_weight': 0.10887149829603184, 'rf_weight': 0.48179539196656695}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:42,444] Trial 4974 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.915852193617539, 'cb_weight': 0.5525031448984232, 'lgbm_weight': 0.8278964374314943, 'hgb_weight': 0.04194906084742364, 'gb_weight': 0.030995328867223986, 'rf_weight': 0.5172266906166408}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:42,707] Trial 4975 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.8941127458120278, 'cb_weight': 0.5748878525179543, 'lgbm_weight': 0.7204769039762459, 'hgb_weight': 0.028638689017944873, 'gb_weight': 0.0006283991807134529, 'rf_weight': 0.44471070790509126}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:42,965] Trial 4976 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.9178867555542983, 'cb_weight': 0.4907813534627283, 'lgbm_weight': 0.8532371076426802, 'hgb_weight': 0.09386397987663912, 'gb_weight': 0.0655127391654722, 'rf_weight': 0.5010738216148588}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:43,227] Trial 4977 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.8073926495854449, 'cb_weight': 0.6554982342725116, 'lgbm_weight': 0.8310987439540177, 'hgb_weight': 0.13585947577608073, 'gb_weight': 0.04783546451899552, 'rf_weight': 0.46752313120898026}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:43,490] Trial 4978 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.920758162256852, 'cb_weight': 0.6098930648411234, 'lgbm_weight': 0.8631093998854399, 'hgb_weight': 0.04824056494843243, 'gb_weight': 0.08645530904287357, 'rf_weight': 0.48899125030525503}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:43,756] Trial 4979 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.9211582320971549, 'cb_weight': 0.6310523814737145, 'lgbm_weight': 0.78049911068846, 'hgb_weight': 3.1930490943958556e-05, 'gb_weight': 0.01671357617777654, 'rf_weight': 0.5174866082198382}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:44,012] Trial 4980 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.897833802441182, 'cb_weight': 0.6847208031475163, 'lgbm_weight': 0.808647559141906, 'hgb_weight': 0.0275321093661584, 'gb_weight': 0.03261560217486761, 'rf_weight': 0.5201892402610374}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:44,270] Trial 4981 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.8227376122634089, 'cb_weight': 0.589902489266033, 'lgbm_weight': 0.8405190782410714, 'hgb_weight': 0.0605401262858935, 'gb_weight': 0.05864514723608912, 'rf_weight': 0.49633187215484487}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:44,531] Trial 4982 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.9219381933802526, 'cb_weight': 0.607994567218113, 'lgbm_weight': 0.8584951948778892, 'hgb_weight': 0.032151438831388074, 'gb_weight': 0.019294921626193395, 'rf_weight': 0.5218693080465963}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:44,788] Trial 4983 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.8783725992483881, 'cb_weight': 0.5693176522916168, 'lgbm_weight': 0.8537320820609429, 'hgb_weight': 0.016858541905689625, 'gb_weight': 0.04414655213567071, 'rf_weight': 0.47633941008018366}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:45,046] Trial 4984 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.9203816022894623, 'cb_weight': 0.6451247998915848, 'lgbm_weight': 0.8303077664117287, 'hgb_weight': 0.0737877212801557, 'gb_weight': 0.07018870361985073, 'rf_weight': 0.5068407081195222}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:45,307] Trial 4985 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.8979814698513708, 'cb_weight': 0.623526218123051, 'lgbm_weight': 0.7990765572306204, 'hgb_weight': 0.044288817574497555, 'gb_weight': 0.016505017171336324, 'rf_weight': 0.524680772344296}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:45,570] Trial 4986 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.861236618100199, 'cb_weight': 0.5945149001402332, 'lgbm_weight': 0.8622645199769974, 'hgb_weight': 0.01869264482520684, 'gb_weight': 0.035478274803578375, 'rf_weight': 0.4524404665787247}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:45,829] Trial 4987 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.9170613870463337, 'cb_weight': 0.5396360314834432, 'lgbm_weight': 0.8376851586051083, 'hgb_weight': 1.733500555739509e-05, 'gb_weight': 0.05024089185721564, 'rf_weight': 0.4863926286673754}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:46,085] Trial 4988 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.9227365589022615, 'cb_weight': 0.6687288020137718, 'lgbm_weight': 0.8631014117098013, 'hgb_weight': 0.05625117897104724, 'gb_weight': 0.09191997621036688, 'rf_weight': 0.508641883116774}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:46,343] Trial 4989 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.9294559840822672, 'cb_weight': 0.5755334761647428, 'lgbm_weight': 0.9503328589088591, 'hgb_weight': 0.03374259280369411, 'gb_weight': 0.01751703534541167, 'rf_weight': 0.46344696703342636}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:46,603] Trial 4990 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.897002849468968, 'cb_weight': 0.6072137729174694, 'lgbm_weight': 0.8243526261756018, 'hgb_weight': 0.08699594823105897, 'gb_weight': 0.03302656096360429, 'rf_weight': 0.5256001335145662}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:46,858] Trial 4991 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.9291334871330125, 'cb_weight': 0.6308015738520514, 'lgbm_weight': 0.9794778974410038, 'hgb_weight': 0.04530010429089995, 'gb_weight': 0.07209573816458914, 'rf_weight': 0.4897506434732791}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:47,116] Trial 4992 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.9293171272381076, 'cb_weight': 0.5502103264643194, 'lgbm_weight': 0.856277902872025, 'hgb_weight': 0.017709661169426266, 'gb_weight': 0.0006189343865643845, 'rf_weight': 0.5327539495178063}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:47,375] Trial 4993 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.9010394210127609, 'cb_weight': 0.6510312334183876, 'lgbm_weight': 0.8660793604633636, 'hgb_weight': 0.06916599061533105, 'gb_weight': 0.05386998971343229, 'rf_weight': 0.49939158146719653}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:47,638] Trial 4994 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.9309084946550521, 'cb_weight': 0.58838680921095, 'lgbm_weight': 0.8083552850123478, 'hgb_weight': 0.45477977932196373, 'gb_weight': 0.015577229479029345, 'rf_weight': 0.09816902857113508}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:47,898] Trial 4995 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.9300496670612987, 'cb_weight': 0.6180556885656499, 'lgbm_weight': 0.8335876693670712, 'hgb_weight': 0.03265758154571533, 'gb_weight': 0.0005081007270962348, 'rf_weight': 0.5228865291793985}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:48,158] Trial 4996 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.908330703521952, 'cb_weight': 0.5662035508094398, 'lgbm_weight': 0.8480885833637498, 'hgb_weight': 0.05513383999920157, 'gb_weight': 0.03631095510054816, 'rf_weight': 0.5082902525762176}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:48,417] Trial 4997 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.883736314490385, 'cb_weight': 0.5989310817025527, 'lgbm_weight': 0.8770130795868024, 'hgb_weight': 0.1083983918272457, 'gb_weight': 0.05916655763448117, 'rf_weight': 0.5345116998869288}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:48,680] Trial 4998 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.9351314279160367, 'cb_weight': 0.6361322043423849, 'lgbm_weight': 0.9372265367963952, 'hgb_weight': 0.018389310790955418, 'gb_weight': 0.11589902257873423, 'rf_weight': 0.4763401339034714}. Best is trial 227 with value: 0.834522595990486.
# [I 2024-06-10 20:00:48,939] Trial 4999 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.9337100360851441, 'cb_weight': 0.6594392388298523, 'lgbm_weight': 0.8713402177986554, 'hgb_weight': 0.0452457758962832, 'gb_weight': 0.032864736414691356, 'rf_weight': 0.5004284488092555}. Best is trial 227 with value: 0.834522595990486.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835664, AUC: 0.930484
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.931973
# --- Fold 3 - Accuracy: 0.835010, AUC: 0.929956
# --- Fold 4 - Accuracy: 0.834281, AUC: 0.930322
# --- Fold 5 - Accuracy: 0.825394, AUC: 0.924760
#
# ------ Accuracy: 0.833333 ± 0.004027
# ------ AUC:      0.929499 ± 0.002467

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.836775, AUC: 0.930633
# --- Fold 2 - Accuracy: 0.837886, AUC: 0.932332
# --- Fold 3 - Accuracy: 0.835076, AUC: 0.930119
# --- Fold 4 - Accuracy: 0.835000, AUC: 0.930373
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.924659
#
# ------ Accuracy: 0.834340 ± 0.003845
# ------ AUC:      0.929623 ± 0.002600

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
