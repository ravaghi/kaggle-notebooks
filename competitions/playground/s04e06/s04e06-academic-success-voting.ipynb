# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'booster': 'gbtree',
    'colsample_bylevel': 0.8712566081030306,
    'colsample_bynode': 0.8812717007743852,
    'colsample_bytree': 0.5058256687806578,
    'enable_categorical': True,
    'gamma': 0.11054987292648576,
    'max_bin': 214,
    'max_delta_step': 1.6020120102544444,
    'max_depth': 16,
    'max_leaves': 4,
    'min_child_weight': 9.414288652667947,
    'n_estimators': 909,
    'n_jobs': -1,
    'random_state': SEED,
    'reg_alpha': 6.221650883699895,
    'reg_lambda': 5.268626316325515,
    'subsample': 0.8211514595128722,
    'verbosity': 0
}

cb_params = {
    'bootstrap_type': 'MVS',
    'border_count': 199,
    'colsample_bylevel': 0.4158192426330728,
    'depth': 6,
    'grow_policy': 'Depthwise',
    'iterations': 1631,
    'l2_leaf_reg': 0.4950293286870089,
    'min_child_samples': 21,
    'random_state': SEED,
    'random_strength': 0.10636485340557712,
    'thread_count': -1,
    'verbose': False
}

lgbm_params = {
    'colsample_bytree': 0.25559299162127014,
    'max_depth': 4,
    'min_child_samples': 198,
    'min_child_weight': 0.5477657271676347,
    'n_estimators': 590,
    'n_jobs': -1,
    'num_leaves': 26,
    'random_state': SEED,
    'reg_alpha': 0.11355850961158875,
    'reg_lambda': 0.8922403334656492,
    'subsample': 0.9925516299703928,
    'subsample_freq': 2,
    'verbose': -1
}

hgb_params = {
    'l2_regularization': 0.19552435996764,
    'max_bins': 212,
    'max_depth': 3,
    'max_iter': 1199,
    'max_leaf_nodes': 81,
    'min_samples_leaf': 46,
    'random_state': SEED,
    'verbose': 0,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.833769, AUC: 0.930658
# --- Fold 2 - Accuracy: 0.835272, AUC: 0.932521
# --- Fold 3 - Accuracy: 0.836187, AUC: 0.929906
# --- Fold 4 - Accuracy: 0.833301, AUC: 0.930002
# --- Fold 5 - Accuracy: 0.825328, AUC: 0.924151
#
# ------ Accuracy: 0.832771 ± 0.003862
# ------ AUC:      0.929448 ± 0.002810

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.835141, AUC: 0.930227
# --- Fold 2 - Accuracy: 0.835729, AUC: 0.931899
# --- Fold 3 - Accuracy: 0.835010, AUC: 0.929451
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929306
# --- Fold 5 - Accuracy: 0.826831, AUC: 0.924722
#
# ------ Accuracy: 0.833189 ± 0.003286
# ------ AUC:      0.929121 ± 0.002385

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.835076, AUC: 0.930741
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.932620
# --- Fold 3 - Accuracy: 0.834880, AUC: 0.930585
# --- Fold 4 - Accuracy: 0.833758, AUC: 0.930273
# --- Fold 5 - Accuracy: 0.824806, AUC: 0.924998
#
# ------ Accuracy: 0.832706 ± 0.003979
# ------ AUC:      0.929843 ± 0.002559

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.833116, AUC: 0.929708
# --- Fold 2 - Accuracy: 0.833181, AUC: 0.930683
# --- Fold 3 - Accuracy: 0.834226, AUC: 0.928764
# --- Fold 4 - Accuracy: 0.831863, AUC: 0.928667
# --- Fold 5 - Accuracy: 0.823303, AUC: 0.923708
#
# ------ Accuracy: 0.831138 ± 0.003988
# ------ AUC:      0.928306 ± 0.002412

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-10 08:03:29,606] A new study created in memory with name: no-name-db9139ca-279d-4d1c-83a7-560cdf06947e
# [I 2024-06-10 08:03:29,622] Trial 0 finished with value: 0.8336731226639483 and parameters: {'xgb_weight': 0.35978362765473604, 'cb_weight': 0.9619087290134041, 'lgbm_weight': 0.39269037923443884, 'hgb_weight': 0.9399262761540128, 'gb_weight': 0.2879063547176902, 'rf_weight': 0.46794950474122354}. Best is trial 0 with value: 0.8336731226639483.
# [I 2024-06-10 08:03:29,636] Trial 1 finished with value: 0.833267989231292 and parameters: {'xgb_weight': 0.5784652652428284, 'cb_weight': 0.2358988307605262, 'lgbm_weight': 0.0688910068999844, 'hgb_weight': 0.7430596117445645, 'gb_weight': 0.016995161509441026, 'rf_weight': 0.46838750882783264}. Best is trial 0 with value: 0.8336731226639483.
# [I 2024-06-10 08:03:29,652] Trial 2 finished with value: 0.8337515355863979 and parameters: {'xgb_weight': 0.6386938736525655, 'cb_weight': 0.5641081576100784, 'lgbm_weight': 0.6616387359574896, 'hgb_weight': 0.8983544899022812, 'gb_weight': 0.5038576435164444, 'rf_weight': 0.32006784767397356}. Best is trial 2 with value: 0.8337515355863979.
# [I 2024-06-10 08:03:29,666] Trial 3 finished with value: 0.8337646044068062 and parameters: {'xgb_weight': 0.18580629798896708, 'cb_weight': 0.9634121692309079, 'lgbm_weight': 0.6350105235568194, 'hgb_weight': 0.8510084810380497, 'gb_weight': 0.7610670296832031, 'rf_weight': 0.7553091795385208}. Best is trial 3 with value: 0.8337646044068062.
# [I 2024-06-10 08:03:29,681] Trial 4 finished with value: 0.8338168796884393 and parameters: {'xgb_weight': 0.19167560800626304, 'cb_weight': 0.9577599081531676, 'lgbm_weight': 0.4213625740930216, 'hgb_weight': 0.4574825634259386, 'gb_weight': 0.6772928795721692, 'rf_weight': 0.788523404549755}. Best is trial 4 with value: 0.8338168796884393.
# [I 2024-06-10 08:03:29,695] Trial 5 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.7846640183216042, 'cb_weight': 0.6617948350727272, 'lgbm_weight': 0.4698854764705034, 'hgb_weight': 0.3294588752762063, 'gb_weight': 0.8932440727662513, 'rf_weight': 0.7787454975869406}. Best is trial 5 with value: 0.8339998431741551.
# [I 2024-06-10 08:03:29,710] Trial 6 finished with value: 0.8336992603047649 and parameters: {'xgb_weight': 0.6698071093988587, 'cb_weight': 0.20355289243068686, 'lgbm_weight': 0.5051941810750652, 'hgb_weight': 0.1767385298655909, 'gb_weight': 0.969658007283862, 'rf_weight': 0.0743941611355119}. Best is trial 5 with value: 0.8339998431741551.
# [I 2024-06-10 08:03:29,724] Trial 7 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.1880758576526852, 'cb_weight': 0.7313056128378943, 'lgbm_weight': 0.5645934504188721, 'hgb_weight': 0.06723947774355188, 'gb_weight': 0.2424737965166398, 'rf_weight': 0.6643708148483702}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,738] Trial 8 finished with value: 0.8341305313782378 and parameters: {'xgb_weight': 0.4307856181194317, 'cb_weight': 0.8118477566366334, 'lgbm_weight': 0.2614791669904737, 'hgb_weight': 0.18888022126180526, 'gb_weight': 0.2567357772303286, 'rf_weight': 0.1723692841781811}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,753] Trial 9 finished with value: 0.8334378838965995 and parameters: {'xgb_weight': 0.19672109738961774, 'cb_weight': 0.7623232777855508, 'lgbm_weight': 0.026205307132463496, 'hgb_weight': 0.4526682660152064, 'gb_weight': 0.7169332653539244, 'rf_weight': 0.43024577155326815}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,806] Trial 10 finished with value: 0.8335685721006821 and parameters: {'xgb_weight': 0.012841545725962078, 'cb_weight': 0.36514529233915277, 'lgbm_weight': 0.9246256784898825, 'hgb_weight': 0.02901685496365681, 'gb_weight': 0.028267990139972915, 'rf_weight': 0.9168859938593195}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,860] Trial 11 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.4081569336679123, 'cb_weight': 0.7588214976788921, 'lgbm_weight': 0.24868660626968764, 'hgb_weight': 0.0034864955853552426, 'gb_weight': 0.2818095505445598, 'rf_weight': 0.005778952797132475}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,915] Trial 12 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.3848827992449005, 'cb_weight': 0.03693926221368282, 'lgbm_weight': 0.2177659668037605, 'hgb_weight': 0.2262543330894392, 'gb_weight': 0.24408920258667818, 'rf_weight': 0.26337555129519286}. Best is trial 7 with value: 0.8342089443006874.
# [I 2024-06-10 08:03:29,971] Trial 13 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.04805477610722142, 'cb_weight': 0.7924193146078718, 'lgbm_weight': 0.8411302956938872, 'hgb_weight': 0.16091605822801036, 'gb_weight': 0.4297119907986119, 'rf_weight': 0.602995577789579}. Best is trial 13 with value: 0.8342612195823205.
# [I 2024-06-10 08:03:30,024] Trial 14 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.008403098666004555, 'cb_weight': 0.4757290566121626, 'lgbm_weight': 0.9328623846020576, 'hgb_weight': 0.6312090199150275, 'gb_weight': 0.44347237096862274, 'rf_weight': 0.6050475550897475}. Best is trial 13 with value: 0.8342612195823205.
# [I 2024-06-10 08:03:30,079] Trial 15 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.9400356756162223, 'cb_weight': 0.5831081940050024, 'lgbm_weight': 0.7743885804905506, 'hgb_weight': 0.3092754785777468, 'gb_weight': 0.4346324089391119, 'rf_weight': 0.6255874757507405}. Best is trial 13 with value: 0.8342612195823205.
# [I 2024-06-10 08:03:30,132] Trial 16 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.11592947622419258, 'cb_weight': 0.8257088796957225, 'lgbm_weight': 0.7904403391429602, 'hgb_weight': 0.057598869833909466, 'gb_weight': 0.14202506501365375, 'rf_weight': 0.6167707523732852}. Best is trial 16 with value: 0.834483389529261.
# [I 2024-06-10 08:03:30,187] Trial 17 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.09635488985855505, 'cb_weight': 0.8542634022915241, 'lgbm_weight': 0.7952492501407925, 'hgb_weight': 0.12188132522874173, 'gb_weight': 0.12707858631905627, 'rf_weight': 0.5739341298534971}. Best is trial 17 with value: 0.8345095271700776.
# [I 2024-06-10 08:03:30,241] Trial 18 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.28875298938094696, 'cb_weight': 0.8600275665460049, 'lgbm_weight': 0.7624874931922037, 'hgb_weight': 0.3575656266881043, 'gb_weight': 0.12364270845468293, 'rf_weight': 0.916818898699792}. Best is trial 17 with value: 0.8345095271700776.
# [I 2024-06-10 08:03:30,294] Trial 19 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.09911415286697545, 'cb_weight': 0.653279466422134, 'lgbm_weight': 0.9768015207661906, 'hgb_weight': 0.575708954901261, 'gb_weight': 0.1424379904950868, 'rf_weight': 0.35422911100184673}. Best is trial 17 with value: 0.8345095271700776.
# [I 2024-06-10 08:03:30,347] Trial 20 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.28544474906191153, 'cb_weight': 0.8789376373380976, 'lgbm_weight': 0.7293971952306015, 'hgb_weight': 0.09904748789041476, 'gb_weight': 0.10853887887218805, 'rf_weight': 0.5393363072892028}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,401] Trial 21 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.30356317142347616, 'cb_weight': 0.892607663872087, 'lgbm_weight': 0.7286137202363202, 'hgb_weight': 0.10550816233919988, 'gb_weight': 0.1530551009946162, 'rf_weight': 0.5449044475441096}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,454] Trial 22 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.1330192490642857, 'cb_weight': 0.8641015354725352, 'lgbm_weight': 0.8469745013133233, 'hgb_weight': 0.2611311472014105, 'gb_weight': 0.07755672010619023, 'rf_weight': 0.723455942123987}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,508] Trial 23 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.29236005296923795, 'cb_weight': 0.6725329189606862, 'lgbm_weight': 0.6340445799895522, 'hgb_weight': 0.10230663195243449, 'gb_weight': 0.33920911100975426, 'rf_weight': 0.5319527710486658}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,562] Trial 24 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.10464517195818637, 'cb_weight': 0.9122930969817212, 'lgbm_weight': 0.8427240446392138, 'hgb_weight': 0.39042348881840266, 'gb_weight': 0.16458644289490787, 'rf_weight': 0.8498530012705041}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,617] Trial 25 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.2601591792192727, 'cb_weight': 0.4794357774271796, 'lgbm_weight': 0.748205099752203, 'hgb_weight': 0.12390038989096165, 'gb_weight': 0.5667888668112664, 'rf_weight': 0.41884810964584035}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,672] Trial 26 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.5085776688833745, 'cb_weight': 0.9893636433604113, 'lgbm_weight': 0.6938485964051104, 'hgb_weight': 0.005775739548506187, 'gb_weight': 0.008105074157698788, 'rf_weight': 0.685758718881364}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,727] Trial 27 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.475653980628746, 'cb_weight': 0.9952329630101041, 'lgbm_weight': 0.5670501584903492, 'hgb_weight': 0.2672572687641088, 'gb_weight': 0.00020484316687438553, 'rf_weight': 0.5390818575000451}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,783] Trial 28 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.5406477590011917, 'cb_weight': 0.9137296098241835, 'lgbm_weight': 0.6889034554791974, 'hgb_weight': 0.004496585298728311, 'gb_weight': 0.35671210368792705, 'rf_weight': 0.6980351559837082}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,838] Trial 29 finished with value: 0.8336469850231318 and parameters: {'xgb_weight': 0.47423639346670954, 'cb_weight': 0.9916275944719671, 'lgbm_weight': 0.5586112641252505, 'hgb_weight': 0.9832973196075313, 'gb_weight': 0.07653041687995765, 'rf_weight': 0.9758187388594373}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,895] Trial 30 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.3539724686773816, 'cb_weight': 0.3709332399594833, 'lgbm_weight': 0.3493688508295826, 'hgb_weight': 0.2138535179553398, 'gb_weight': 0.20722563316232137, 'rf_weight': 0.40246590658355463}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:30,952] Trial 31 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.1125543177373578, 'cb_weight': 0.8356975855732683, 'lgbm_weight': 0.8177193478653839, 'hgb_weight': 0.10755295849779892, 'gb_weight': 0.06762515433260904, 'rf_weight': 0.6390864890332122}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,008] Trial 32 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.23961853309568626, 'cb_weight': 0.9171094473854967, 'lgbm_weight': 0.8854709094476712, 'hgb_weight': 0.13491600898920442, 'gb_weight': 0.08994558757413387, 'rf_weight': 0.4959915814982565}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,065] Trial 33 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.6882193028824777, 'cb_weight': 0.7039949324349627, 'lgbm_weight': 0.6846358571420494, 'hgb_weight': 0.07492092119267127, 'gb_weight': 0.03671656629444898, 'rf_weight': 0.6899111709277369}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,121] Trial 34 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.6039472282804728, 'cb_weight': 0.5896468592385625, 'lgbm_weight': 0.8077905108588073, 'hgb_weight': 0.6823181432219778, 'gb_weight': 0.20008705272696994, 'rf_weight': 0.5843771942688464}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,178] Trial 35 finished with value: 0.8337646044068062 and parameters: {'xgb_weight': 0.0730977258245306, 'cb_weight': 0.8491707893414454, 'lgbm_weight': 0.6237387292691864, 'hgb_weight': 0.7983762217407288, 'gb_weight': 0.34102713134471596, 'rf_weight': 0.8203546395254209}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,235] Trial 36 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.348756090788124, 'cb_weight': 0.9455032571161661, 'lgbm_weight': 0.6970979221886203, 'hgb_weight': 0.2663931063385366, 'gb_weight': 0.06542902711194011, 'rf_weight': 0.46993121373447433}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,291] Trial 37 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.7695101275768768, 'cb_weight': 0.7968767280013849, 'lgbm_weight': 0.9041160827369776, 'hgb_weight': 0.16292451077834397, 'gb_weight': 0.602164377876591, 'rf_weight': 0.7416373747841892}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,347] Trial 38 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.15872184877404333, 'cb_weight': 0.9313584416488049, 'lgbm_weight': 0.9613395873366283, 'hgb_weight': 0.037970966908598316, 'gb_weight': 0.00045190873655828745, 'rf_weight': 0.5571730037102198}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,404] Trial 39 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.5427572225050189, 'cb_weight': 0.7257526357368967, 'lgbm_weight': 0.597680142222532, 'hgb_weight': 0.11193373440528409, 'gb_weight': 0.19817970073051674, 'rf_weight': 0.6619986054610741}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,461] Trial 40 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.21605239322883169, 'cb_weight': 0.9971595288528629, 'lgbm_weight': 0.48342278169350594, 'hgb_weight': 0.49780954924654497, 'gb_weight': 0.09229767782044343, 'rf_weight': 0.3279682936467656}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,517] Trial 41 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.15475040776001694, 'cb_weight': 0.8270661955690332, 'lgbm_weight': 0.7996857396949689, 'hgb_weight': 0.05378826848709433, 'gb_weight': 0.12516377856108157, 'rf_weight': 0.6388290601843566}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,574] Trial 42 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.1761466485255015, 'cb_weight': 0.88008756878253, 'lgbm_weight': 0.7231606340973907, 'hgb_weight': 0.06843001212337464, 'gb_weight': 0.11134726485467382, 'rf_weight': 0.6511527099038465}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,632] Trial 43 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.05548091139058366, 'cb_weight': 0.8032188646546691, 'lgbm_weight': 0.8749508096861096, 'hgb_weight': 0.20286787965777509, 'gb_weight': 0.0490008638969789, 'rf_weight': 0.790143460279693}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,689] Trial 44 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.4334341672107349, 'cb_weight': 0.765589863753902, 'lgbm_weight': 0.797787089103547, 'hgb_weight': 0.003305131675840775, 'gb_weight': 0.8887089672979327, 'rf_weight': 0.48316931020406206}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,745] Trial 45 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.14022803548847745, 'cb_weight': 0.8399685464287217, 'lgbm_weight': 0.8219272193409783, 'hgb_weight': 0.057482333545382645, 'gb_weight': 0.1844560581112089, 'rf_weight': 0.7117974551696733}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,801] Trial 46 finished with value: 0.8336339162027235 and parameters: {'xgb_weight': 0.0006890254076434843, 'cb_weight': 0.948939071119317, 'lgbm_weight': 0.12356036905590673, 'hgb_weight': 0.1560259649102764, 'gb_weight': 0.2982845580518246, 'rf_weight': 0.5762154865457496}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,859] Trial 47 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.2046604189773641, 'cb_weight': 0.6346798691145501, 'lgbm_weight': 0.9977245723172956, 'hgb_weight': 0.08892819405431394, 'gb_weight': 0.2348400172519215, 'rf_weight': 0.25611536995858036}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,918] Trial 48 finished with value: 0.8332810580517003 and parameters: {'xgb_weight': 0.042944634445680974, 'cb_weight': 0.09981864938177498, 'lgbm_weight': 0.6513771169352732, 'hgb_weight': 0.1853510857561928, 'gb_weight': 0.03775813018187216, 'rf_weight': 0.7588983435982734}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:31,975] Trial 49 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.32901795431797204, 'cb_weight': 0.709483950277842, 'lgbm_weight': 0.4276935339273653, 'hgb_weight': 0.4242001879847668, 'gb_weight': 0.29924535323791385, 'rf_weight': 0.6299506287647763}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:32,033] Trial 50 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.23582329814752745, 'cb_weight': 0.7576157539291317, 'lgbm_weight': 0.7330868496152264, 'hgb_weight': 0.24770127926759666, 'gb_weight': 0.11683590748237341, 'rf_weight': 0.8665715673073122}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:32,090] Trial 51 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.11009212905234647, 'cb_weight': 0.8387212502226682, 'lgbm_weight': 0.7867435283341868, 'hgb_weight': 0.038528550631520025, 'gb_weight': 0.14361422727314668, 'rf_weight': 0.665764721211557}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:32,147] Trial 52 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.08713755252721161, 'cb_weight': 0.8229981879423902, 'lgbm_weight': 0.8591303560744211, 'hgb_weight': 0.0548597583648853, 'gb_weight': 0.12837856210582982, 'rf_weight': 0.5212385667858003}. Best is trial 20 with value: 0.8345748712721189.
# [I 2024-06-10 08:03:32,206] Trial 53 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.15932730640594794, 'cb_weight': 0.8795046973298015, 'lgbm_weight': 0.9325212713202231, 'hgb_weight': 0.004489168183108041, 'gb_weight': 0.0445007289305307, 'rf_weight': 0.6103492071439546}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,262] Trial 54 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.15697563814876309, 'cb_weight': 0.888308005779647, 'lgbm_weight': 0.9156238713170827, 'hgb_weight': 0.0035128951321430676, 'gb_weight': 0.05282162836017004, 'rf_weight': 0.44898807545524616}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,319] Trial 55 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.400179008918337, 'cb_weight': 0.9681427261541863, 'lgbm_weight': 0.9175630946647154, 'hgb_weight': 0.1352217043741425, 'gb_weight': 0.018029429302788683, 'rf_weight': 0.5966236244627096}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,377] Trial 56 finished with value: 0.8342089443006874 and parameters: {'xgb_weight': 0.26541174812861157, 'cb_weight': 0.7805290445665406, 'lgbm_weight': 0.7604130680150545, 'hgb_weight': 0.32102015593423694, 'gb_weight': 0.17031507316991137, 'rf_weight': 0.37563476449730093}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,436] Trial 57 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.036986491715984435, 'cb_weight': 0.8743212774616907, 'lgbm_weight': 0.9371106188243705, 'hgb_weight': 0.08884900837985982, 'gb_weight': 0.23586958028149246, 'rf_weight': 0.6446897923127688}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,493] Trial 58 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.18361986962777063, 'cb_weight': 0.5278232527059428, 'lgbm_weight': 0.5316337976231068, 'hgb_weight': 0.03426954361031026, 'gb_weight': 0.09145621889636912, 'rf_weight': 0.504786012167849}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,551] Trial 59 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.9146032885355625, 'cb_weight': 0.4013684506010208, 'lgbm_weight': 0.8301701194913722, 'hgb_weight': 0.14689846598010278, 'gb_weight': 0.05660913998706268, 'rf_weight': 0.5713168977755614}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,609] Trial 60 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.12795537354892558, 'cb_weight': 0.9667634990756726, 'lgbm_weight': 0.7095858854522872, 'hgb_weight': 0.1071909739031618, 'gb_weight': 0.27331854549144313, 'rf_weight': 0.6869537514603884}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,667] Trial 61 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.11356929471771646, 'cb_weight': 0.24394017471508644, 'lgbm_weight': 0.7752174354338333, 'hgb_weight': 0.07108334064765706, 'gb_weight': 0.15898255790335966, 'rf_weight': 0.6177153852738241}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,724] Trial 62 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.07700338560546345, 'cb_weight': 0.9059185930069266, 'lgbm_weight': 0.6714916061838871, 'hgb_weight': 0.028506514135013705, 'gb_weight': 0.1068615061790325, 'rf_weight': 0.7262529174322565}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,783] Trial 63 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.1543542260681913, 'cb_weight': 0.8340987800304739, 'lgbm_weight': 0.8814882140667569, 'hgb_weight': 0.19018841823824886, 'gb_weight': 0.024911642428998113, 'rf_weight': 0.5487157404643761}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,842] Trial 64 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.2350942673187716, 'cb_weight': 0.7505295691095941, 'lgbm_weight': 0.8094204567085228, 'hgb_weight': 0.11173559414138579, 'gb_weight': 0.795484885578589, 'rf_weight': 0.622249130543972}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,900] Trial 65 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.3155108795961822, 'cb_weight': 0.6779448761765146, 'lgbm_weight': 0.7558032683405702, 'hgb_weight': 0.2341991066474442, 'gb_weight': 0.1359203221386651, 'rf_weight': 0.7797777705462389}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:32,962] Trial 66 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.2748758065665303, 'cb_weight': 0.8125835883567901, 'lgbm_weight': 0.9485303350654064, 'hgb_weight': 0.894709887339459, 'gb_weight': 0.3778334108522833, 'rf_weight': 0.6700351206827369}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,021] Trial 67 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.02687314397901469, 'cb_weight': 0.8662282303724159, 'lgbm_weight': 0.851040492156792, 'hgb_weight': 0.02854016799093642, 'gb_weight': 0.22135303262852696, 'rf_weight': 0.5935468474828822}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,079] Trial 68 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.5354334534530684, 'cb_weight': 0.9298680321111563, 'lgbm_weight': 0.6160685069726644, 'hgb_weight': 0.08546630756837627, 'gb_weight': 0.07386112808104738, 'rf_weight': 0.4494029436051771}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,150] Trial 69 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.6264599703630471, 'cb_weight': 0.6278058922999784, 'lgbm_weight': 0.8963633257566287, 'hgb_weight': 0.2882976954764024, 'gb_weight': 0.499015605285974, 'rf_weight': 0.5237604984964156}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,213] Trial 70 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.06763249807239581, 'cb_weight': 0.90087360573459, 'lgbm_weight': 0.7360041417812359, 'hgb_weight': 0.17033204354903225, 'gb_weight': 0.1733450388294929, 'rf_weight': 0.7538778408457247}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,271] Trial 71 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.1493243337095541, 'cb_weight': 0.8260070919467231, 'lgbm_weight': 0.8808960669378197, 'hgb_weight': 0.20201032946030567, 'gb_weight': 0.0023539774733667557, 'rf_weight': 0.543485737535472}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,330] Trial 72 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.2054946830721459, 'cb_weight': 0.7852044137900805, 'lgbm_weight': 0.7900036980062345, 'hgb_weight': 0.12593985055746987, 'gb_weight': 0.029220810156507168, 'rf_weight': 0.5652601166803128}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,388] Trial 73 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.20910603904325437, 'cb_weight': 0.7964431701588707, 'lgbm_weight': 0.8206622790211098, 'hgb_weight': 0.5715534755189644, 'gb_weight': 0.01005637828028072, 'rf_weight': 0.5625492006033278}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,447] Trial 74 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.4471589381318479, 'cb_weight': 0.859356160187535, 'lgbm_weight': 0.8676035040028328, 'hgb_weight': 0.1307853531800485, 'gb_weight': 0.03718899875958756, 'rf_weight': 0.501595802000629}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,506] Trial 75 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.1730151804634273, 'cb_weight': 0.9685149678217518, 'lgbm_weight': 0.9735996409500428, 'hgb_weight': 0.21393785924188138, 'gb_weight': 0.07716475541617841, 'rf_weight': 0.640745555902424}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,565] Trial 76 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.13559514322060556, 'cb_weight': 0.7711201233037169, 'lgbm_weight': 0.7922661091923326, 'hgb_weight': 0.0006260135400752449, 'gb_weight': 0.006863824019377147, 'rf_weight': 0.6834364273742366}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,624] Trial 77 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.19429304470980466, 'cb_weight': 0.7297572460519249, 'lgbm_weight': 0.8403937680145787, 'hgb_weight': 0.06167742833030292, 'gb_weight': 0.09522793609037318, 'rf_weight': 0.6001871563634193}. Best is trial 53 with value: 0.8346532841945686.
# [I 2024-06-10 08:03:33,683] Trial 78 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.23988109781149927, 'cb_weight': 0.9338451871238467, 'lgbm_weight': 0.7059600336465419, 'hgb_weight': 0.13090997366024434, 'gb_weight': 0.05621819318210433, 'rf_weight': 0.5263948032713583}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:33,741] Trial 79 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.25239082695059323, 'cb_weight': 0.9307952170039083, 'lgbm_weight': 0.6586632921510842, 'hgb_weight': 0.3608053756231325, 'gb_weight': 0.05742344038012865, 'rf_weight': 0.4131169598254292}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:33,800] Trial 80 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.37469924450196723, 'cb_weight': 0.893794443118036, 'lgbm_weight': 0.7015042449805723, 'hgb_weight': 0.15583816685604834, 'gb_weight': 0.00037264910962878876, 'rf_weight': 0.4710028071959505}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:33,860] Trial 81 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.22582605126007999, 'cb_weight': 0.9491912448053053, 'lgbm_weight': 0.7658202073122448, 'hgb_weight': 0.1272829089832324, 'gb_weight': 0.03761679709933526, 'rf_weight': 0.5361012146773902}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:33,919] Trial 82 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.2864350499614184, 'cb_weight': 0.9839188660991377, 'lgbm_weight': 0.7660699502463286, 'hgb_weight': 0.12377017804687179, 'gb_weight': 0.04674033091326013, 'rf_weight': 0.530132458375582}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:33,980] Trial 83 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.3036154477543218, 'cb_weight': 0.9421835475245395, 'lgbm_weight': 0.7388164409929115, 'hgb_weight': 0.12926146299091318, 'gb_weight': 0.04044155861389698, 'rf_weight': 0.5294709923354757}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,039] Trial 84 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.30180975516657355, 'cb_weight': 0.9423205279939911, 'lgbm_weight': 0.759448992341356, 'hgb_weight': 0.2003395214938825, 'gb_weight': 0.03812402264672699, 'rf_weight': 0.5276176449340457}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,099] Trial 85 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.3372414070704526, 'cb_weight': 0.9735749622858894, 'lgbm_weight': 0.7267276830949031, 'hgb_weight': 0.17209373414083895, 'gb_weight': 0.05848673061980006, 'rf_weight': 0.4435160335413081}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,159] Trial 86 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.22557974189099972, 'cb_weight': 0.9129738634096145, 'lgbm_weight': 0.7663090550013391, 'hgb_weight': 0.13103124032730007, 'gb_weight': 0.10298699149512044, 'rf_weight': 0.550479447703639}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,221] Trial 87 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.290332583631202, 'cb_weight': 0.9968263518899664, 'lgbm_weight': 0.6761329664859493, 'hgb_weight': 0.2354413840064386, 'gb_weight': 0.0713850149891615, 'rf_weight': 0.48522578383833226}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,279] Trial 88 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.27085790693162987, 'cb_weight': 0.9548909927538084, 'lgbm_weight': 0.5920333103828939, 'hgb_weight': 0.1016532906700979, 'gb_weight': 0.027117855989130423, 'rf_weight': 0.38581104280542367}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,342] Trial 89 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.21375186811236063, 'cb_weight': 0.8804063122731154, 'lgbm_weight': 0.647996943782915, 'hgb_weight': 0.18108005428234808, 'gb_weight': 0.03259591857631683, 'rf_weight': 0.5094117353625115}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,400] Trial 90 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.36706385017065335, 'cb_weight': 0.8761004365703926, 'lgbm_weight': 0.7124659807860291, 'hgb_weight': 0.14571829265683023, 'gb_weight': 0.03181173038730915, 'rf_weight': 0.5099309246432415}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,459] Trial 91 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.24991926925455257, 'cb_weight': 0.9274830393020315, 'lgbm_weight': 0.6387080654273163, 'hgb_weight': 0.2890309288669324, 'gb_weight': 0.07886894150527456, 'rf_weight': 0.5720817013344789}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,519] Trial 92 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.21389639280070247, 'cb_weight': 0.8551568985857173, 'lgbm_weight': 0.743723044833791, 'hgb_weight': 0.09096815789693687, 'gb_weight': 0.04722336288254252, 'rf_weight': 0.5293402127340705}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,579] Trial 93 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.193242945180704, 'cb_weight': 0.8535311362321486, 'lgbm_weight': 0.775696104977042, 'hgb_weight': 0.1745251442181293, 'gb_weight': 0.04799150495046095, 'rf_weight': 0.5361733006471856}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,638] Trial 94 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.1867412968802088, 'cb_weight': 0.8529261977788527, 'lgbm_weight': 0.745519607390083, 'hgb_weight': 0.11562437862930404, 'gb_weight': 0.11093196211613882, 'rf_weight': 0.5381194298644434}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,698] Trial 95 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.2849106363013346, 'cb_weight': 0.902511149281374, 'lgbm_weight': 0.33901079770197523, 'hgb_weight': 0.07852148346648923, 'gb_weight': 0.054148532400864716, 'rf_weight': 0.46415718225958463}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,758] Trial 96 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.313020965295625, 'cb_weight': 0.9762735256153011, 'lgbm_weight': 0.7759721560933659, 'hgb_weight': 0.2152524839967692, 'gb_weight': 0.09277842879663745, 'rf_weight': 0.427884145670683}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,817] Trial 97 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.2265501371417444, 'cb_weight': 0.7890083950584961, 'lgbm_weight': 0.8981154940708345, 'hgb_weight': 0.0882321130509028, 'gb_weight': 0.014248431197239897, 'rf_weight': 0.5874143151585249}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,877] Trial 98 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.1640616421663128, 'cb_weight': 0.9478570873848244, 'lgbm_weight': 0.8360745671661841, 'hgb_weight': 0.15273387709909622, 'gb_weight': 0.1452500467923622, 'rf_weight': 0.48166275055948415}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,937] Trial 99 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.192958359238075, 'cb_weight': 0.8217823959372754, 'lgbm_weight': 0.8669645628553571, 'hgb_weight': 0.04002885201981332, 'gb_weight': 0.049619023470802805, 'rf_weight': 0.08799439442500112}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:34,997] Trial 100 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.25111516878148515, 'cb_weight': 0.8527356042848355, 'lgbm_weight': 0.7910012153044153, 'hgb_weight': 0.12242911433576009, 'gb_weight': 0.6246823163327795, 'rf_weight': 0.5543769798111581}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:35,059] Trial 101 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.21449297701539377, 'cb_weight': 0.8855847088748283, 'lgbm_weight': 0.7181687683328307, 'hgb_weight': 0.18359366138314975, 'gb_weight': 0.03360281800265623, 'rf_weight': 0.517330255381082}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:35,119] Trial 102 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.20430660893292607, 'cb_weight': 0.9177979030663341, 'lgbm_weight': 0.7174958793768484, 'hgb_weight': 0.17259688144927238, 'gb_weight': 0.0021995995782862644, 'rf_weight': 0.5299936880299353}. Best is trial 78 with value: 0.8346924906557934.
# [I 2024-06-10 08:03:35,179] Trial 103 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.1425009181370459, 'cb_weight': 0.9125502893002845, 'lgbm_weight': 0.7021406276040943, 'hgb_weight': 0.190300710152613, 'gb_weight': 0.0008614167219134633, 'rf_weight': 0.5267614694825937}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,241] Trial 104 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.3224326493926889, 'cb_weight': 0.9140166661619462, 'lgbm_weight': 0.6976706268894148, 'hgb_weight': 0.17501502264236007, 'gb_weight': 0.08022994699066582, 'rf_weight': 0.5266247268377429}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,303] Trial 105 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.23222519559032168, 'cb_weight': 0.9457880801875146, 'lgbm_weight': 0.6751830312279683, 'hgb_weight': 0.2492106393612265, 'gb_weight': 0.11861916291215877, 'rf_weight': 0.495913240714868}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,363] Trial 106 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.2720716864895345, 'cb_weight': 0.8885023379193605, 'lgbm_weight': 0.7259687398976921, 'hgb_weight': 0.7359494476319912, 'gb_weight': 0.04866964555923248, 'rf_weight': 0.4548890571157848}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,423] Trial 107 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.17175652474074027, 'cb_weight': 0.9820633559888302, 'lgbm_weight': 0.708085273113739, 'hgb_weight': 0.222883360885256, 'gb_weight': 0.9949453783591099, 'rf_weight': 0.5156497104656936}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,485] Trial 108 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.40042711453618135, 'cb_weight': 0.9267810819115323, 'lgbm_weight': 0.7490200831057163, 'hgb_weight': 0.09808179430665871, 'gb_weight': 0.06422353335086992, 'rf_weight': 0.6124771626180899}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,546] Trial 109 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.13164990266564466, 'cb_weight': 0.9565374815773129, 'lgbm_weight': 0.6012737602166128, 'hgb_weight': 0.144882018107048, 'gb_weight': 0.020299320819644806, 'rf_weight': 0.4889396370236083}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,608] Trial 110 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.24776830955316947, 'cb_weight': 0.9978677302177253, 'lgbm_weight': 0.6642143689256885, 'hgb_weight': 0.18787824519490356, 'gb_weight': 0.09545379088675154, 'rf_weight': 0.4358805414489183}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,670] Trial 111 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.14933014247330295, 'cb_weight': 0.873949521584505, 'lgbm_weight': 0.7432602603444672, 'hgb_weight': 0.19293535064831696, 'gb_weight': 0.010464519608094166, 'rf_weight': 0.5405509405141977}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,731] Trial 112 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.21477273560934088, 'cb_weight': 0.9037454214896634, 'lgbm_weight': 0.6903231596244946, 'hgb_weight': 0.28047942343487825, 'gb_weight': 0.041720893486455246, 'rf_weight': 0.5759047632754628}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,793] Trial 113 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.09469938425930878, 'cb_weight': 0.812543756475885, 'lgbm_weight': 0.9919068753876076, 'hgb_weight': 0.1543548881661233, 'gb_weight': 0.003935779892434842, 'rf_weight': 0.5914101880145503}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,857] Trial 114 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.19388637048598567, 'cb_weight': 0.8473340642374679, 'lgbm_weight': 0.7245738972121437, 'hgb_weight': 0.2067747994804668, 'gb_weight': 0.02439335807179007, 'rf_weight': 0.5381792429039484}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,918] Trial 115 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.34884172596847585, 'cb_weight': 0.9304321240970999, 'lgbm_weight': 0.8144055463042955, 'hgb_weight': 0.16659563785921805, 'gb_weight': 0.06734768725907299, 'rf_weight': 0.5519460803080268}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:35,980] Trial 116 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.1212685620716404, 'cb_weight': 0.8675119579438123, 'lgbm_weight': 0.7690854448015647, 'hgb_weight': 0.02308277131437464, 'gb_weight': 0.0008587542874675114, 'rf_weight': 0.47108332599270447}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:36,041] Trial 117 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.29581748156962157, 'cb_weight': 0.8969816889577158, 'lgbm_weight': 0.6231440911257793, 'hgb_weight': 0.054430812465967204, 'gb_weight': 0.04616699052087689, 'rf_weight': 0.513922852130209}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:36,103] Trial 118 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.15188864271463043, 'cb_weight': 0.9674123134108745, 'lgbm_weight': 0.7179567976777855, 'hgb_weight': 0.24873091776079448, 'gb_weight': 0.12534439890148763, 'rf_weight': 0.6134213012491542}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:36,163] Trial 119 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.17933892980854943, 'cb_weight': 0.918303794207979, 'lgbm_weight': 0.937044745657474, 'hgb_weight': 0.08281393579788292, 'gb_weight': 0.08023254623781689, 'rf_weight': 0.49351300901100736}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:36,226] Trial 120 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.27152483495351903, 'cb_weight': 0.9383287483478263, 'lgbm_weight': 0.6816015542263837, 'hgb_weight': 0.1327817419113172, 'gb_weight': 0.021585308775374918, 'rf_weight': 0.584711913175792}. Best is trial 103 with value: 0.8347316971170182.
# [I 2024-06-10 08:03:36,287] Trial 121 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.2635292609061406, 'cb_weight': 0.9467571995297372, 'lgbm_weight': 0.6882924807105211, 'hgb_weight': 0.13557957893659894, 'gb_weight': 0.020131257713073766, 'rf_weight': 0.5670182823874109}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,348] Trial 122 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.23692550923111663, 'cb_weight': 0.9546549696051416, 'lgbm_weight': 0.6784602034114157, 'hgb_weight': 0.11648398565860019, 'gb_weight': 0.026601813324300224, 'rf_weight': 0.5776069963072364}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,410] Trial 123 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.2827807206069674, 'cb_weight': 0.9459088907600759, 'lgbm_weight': 0.5452329068315126, 'hgb_weight': 0.12501422500337822, 'gb_weight': 0.060311635059200765, 'rf_weight': 0.5795774360272521}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,471] Trial 124 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.2660516263992365, 'cb_weight': 0.9812592537474079, 'lgbm_weight': 0.6590803417466262, 'hgb_weight': 0.10721215765759276, 'gb_weight': 0.09933977740021546, 'rf_weight': 0.6038649704890695}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,534] Trial 125 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.24207372106342678, 'cb_weight': 0.9556100500540704, 'lgbm_weight': 0.6789794256723901, 'hgb_weight': 0.06480979744836965, 'gb_weight': 0.02230320057473666, 'rf_weight': 0.5655142993693193}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,595] Trial 126 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.3323801495201971, 'cb_weight': 0.9561972208582815, 'lgbm_weight': 0.5857997572048372, 'hgb_weight': 0.06673679722368517, 'gb_weight': 0.02291448909153908, 'rf_weight': 0.5646691623732271}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,657] Trial 127 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.23915305142999754, 'cb_weight': 0.2662680664264068, 'lgbm_weight': 0.6854611506450936, 'hgb_weight': 0.09410545146283271, 'gb_weight': 0.07901267197118558, 'rf_weight': 0.6409139264281704}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,720] Trial 128 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.30986331656463906, 'cb_weight': 0.9990740776521662, 'lgbm_weight': 0.6412483357390797, 'hgb_weight': 0.04778398963633938, 'gb_weight': 0.7317617312211092, 'rf_weight': 0.6272655004702684}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,781] Trial 129 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.2653196815746216, 'cb_weight': 0.9334268125904885, 'lgbm_weight': 0.6226558166310039, 'hgb_weight': 0.019084053805600465, 'gb_weight': 0.03411912869023225, 'rf_weight': 0.591887903509125}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,842] Trial 130 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.23111388843439978, 'cb_weight': 0.9723416346087985, 'lgbm_weight': 0.685708778495271, 'hgb_weight': 0.07298548893623973, 'gb_weight': 0.01840066316282539, 'rf_weight': 0.562871613822299}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,904] Trial 131 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.2441372928075245, 'cb_weight': 0.9662960475854627, 'lgbm_weight': 0.6871295768597979, 'hgb_weight': 0.07107321783506079, 'gb_weight': 0.0010775569540561521, 'rf_weight': 0.5584266120550532}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:36,966] Trial 132 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.22919041239476814, 'cb_weight': 0.9700699922988372, 'lgbm_weight': 0.6797441050603421, 'hgb_weight': 0.07311880844530626, 'gb_weight': 0.019970556180679305, 'rf_weight': 0.5588005945983922}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:37,029] Trial 133 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.23602192480745543, 'cb_weight': 0.9702243622459253, 'lgbm_weight': 0.6718071100976035, 'hgb_weight': 0.06965248179258188, 'gb_weight': 0.0014275833026341882, 'rf_weight': 0.5625430794249642}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:37,092] Trial 134 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.2550821512081791, 'cb_weight': 0.9796451402300472, 'lgbm_weight': 0.695036339698095, 'hgb_weight': 0.13379184798824423, 'gb_weight': 0.022074775067187323, 'rf_weight': 0.5780694268384488}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:37,154] Trial 135 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.24368281095792022, 'cb_weight': 0.9803353030672568, 'lgbm_weight': 0.644450688896778, 'hgb_weight': 0.04462053362788604, 'gb_weight': 0.023793707823072358, 'rf_weight': 0.6065922240144642}. Best is trial 121 with value: 0.8347578347578347.
# [I 2024-06-10 08:03:37,218] Trial 136 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.22672326432956194, 'cb_weight': 0.9552529198660954, 'lgbm_weight': 0.6969326265723287, 'hgb_weight': 0.11387525711810637, 'gb_weight': 0.060367078511471786, 'rf_weight': 0.6585942159097379}. Best is trial 121 with value: 0.8347578347578347.
# ...
# [I 2024-06-10 08:04:47,533] Trial 955 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.8335907205988093, 'cb_weight': 0.9989243154692338, 'lgbm_weight': 0.7332548510148875, 'hgb_weight': 0.17981921591191383, 'gb_weight': 0.05877898415922632, 'rf_weight': 0.5348277425258268}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:47,639] Trial 956 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.37129865673227797, 'cb_weight': 0.8942664733842053, 'lgbm_weight': 0.7603550885561409, 'hgb_weight': 0.14771849638976625, 'gb_weight': 0.0340954562842448, 'rf_weight': 0.5057538677914203}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:47,746] Trial 957 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.13917939384637987, 'cb_weight': 0.9542609330439908, 'lgbm_weight': 0.704056057853038, 'hgb_weight': 0.6021934726335488, 'gb_weight': 0.0826587861883041, 'rf_weight': 0.48110792029618005}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:47,853] Trial 958 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.21684276701340688, 'cb_weight': 0.9223479652126944, 'lgbm_weight': 0.8215821377875706, 'hgb_weight': 0.09850825754036381, 'gb_weight': 0.6063969033790871, 'rf_weight': 0.5675447256477384}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:47,958] Trial 959 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.26757139307641403, 'cb_weight': 0.9822746706057591, 'lgbm_weight': 0.7242601201308001, 'hgb_weight': 0.1257019646202244, 'gb_weight': 0.01869044042700733, 'rf_weight': 0.5250991514950177}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,068] Trial 960 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.29985948506473775, 'cb_weight': 0.9995672883735185, 'lgbm_weight': 0.7793886016052745, 'hgb_weight': 0.5581347552335055, 'gb_weight': 0.0004050821930053504, 'rf_weight': 0.5476498314232516}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,175] Trial 961 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.05320460814820274, 'cb_weight': 0.874905747460974, 'lgbm_weight': 0.6815357023607433, 'hgb_weight': 0.20391884768626942, 'gb_weight': 0.047134894203641586, 'rf_weight': 0.5041714500110889}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,282] Trial 962 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.24378557478002413, 'cb_weight': 0.9645298926266972, 'lgbm_weight': 0.7511801352621843, 'hgb_weight': 0.1548136489579489, 'gb_weight': 0.017065839285065283, 'rf_weight': 0.5623282674851876}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,391] Trial 963 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.17380545451191343, 'cb_weight': 0.19353288150570158, 'lgbm_weight': 0.6936271993508338, 'hgb_weight': 0.1143907289019, 'gb_weight': 0.04337320143706826, 'rf_weight': 0.5844768657755383}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,500] Trial 964 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.20373235444400284, 'cb_weight': 0.934818124307909, 'lgbm_weight': 0.6443157699821274, 'hgb_weight': 0.13714968514040765, 'gb_weight': 0.05927794590651787, 'rf_weight': 0.5300345227749758}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,607] Trial 965 finished with value: 0.8339214302517055 and parameters: {'xgb_weight': 0.22237205524119924, 'cb_weight': 0.9084240893420925, 'lgbm_weight': 0.6096358389908982, 'hgb_weight': 0.6531149456546715, 'gb_weight': 6.166147853980692e-05, 'rf_weight': 0.49627662185986854}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,714] Trial 966 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.255572744110363, 'cb_weight': 0.9485441847573786, 'lgbm_weight': 0.7163383266759231, 'hgb_weight': 0.17267679392204205, 'gb_weight': 0.02982681445748337, 'rf_weight': 0.4496989530521374}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,820] Trial 967 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.192606945734267, 'cb_weight': 0.9715937225937811, 'lgbm_weight': 0.7922183594831861, 'hgb_weight': 0.09728618334532554, 'gb_weight': 0.018963179439412746, 'rf_weight': 0.5443924304876093}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:48,929] Trial 968 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.15159188313786623, 'cb_weight': 0.9286118136957868, 'lgbm_weight': 0.7357322247307728, 'hgb_weight': 0.1306846241261865, 'gb_weight': 0.034579683386656235, 'rf_weight': 0.47461352215455255}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,036] Trial 969 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.09537905488248463, 'cb_weight': 0.9562434725204576, 'lgbm_weight': 0.6678374393871528, 'hgb_weight': 0.15427286762627454, 'gb_weight': 0.06406499374569478, 'rf_weight': 0.5178454098298746}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,146] Trial 970 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.27813717265880333, 'cb_weight': 0.8947232195032151, 'lgbm_weight': 0.7641198721674484, 'hgb_weight': 0.18931997950388366, 'gb_weight': 0.01849246783321532, 'rf_weight': 0.5729112649546472}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,256] Trial 971 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.23890499696340073, 'cb_weight': 0.8338625239099664, 'lgbm_weight': 0.7422275619974553, 'hgb_weight': 0.10995207466468362, 'gb_weight': 0.00018159514817228488, 'rf_weight': 0.5440410811403168}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,363] Trial 972 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.2165891768595613, 'cb_weight': 0.9727549420513921, 'lgbm_weight': 0.7078913537523712, 'hgb_weight': 0.1340802611325402, 'gb_weight': 0.12151303401603368, 'rf_weight': 0.516893031222117}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,469] Trial 973 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.18011351358479247, 'cb_weight': 0.9343488614291001, 'lgbm_weight': 0.8053252304403885, 'hgb_weight': 0.17025807262375897, 'gb_weight': 0.04623236635274955, 'rf_weight': 0.49330469144303735}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,578] Trial 974 finished with value: 0.8339998431741551 and parameters: {'xgb_weight': 0.2068177927159202, 'cb_weight': 0.9997255314565345, 'lgbm_weight': 0.6924767305089046, 'hgb_weight': 0.09389344262931679, 'gb_weight': 0.08540867333077329, 'rf_weight': 0.13188944880335918}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,685] Trial 975 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.24370696250596688, 'cb_weight': 0.913839522749037, 'lgbm_weight': 0.7766691621077845, 'hgb_weight': 0.14968738264539366, 'gb_weight': 0.019520787999674008, 'rf_weight': 0.5803402223221724}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,793] Trial 976 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.26303108527994795, 'cb_weight': 0.9486508184690644, 'lgbm_weight': 0.72989953639615, 'hgb_weight': 0.1175535087709342, 'gb_weight': 0.03682575979018557, 'rf_weight': 0.5526500655102373}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:49,900] Trial 977 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.8957692627204266, 'cb_weight': 0.9817775088032867, 'lgbm_weight': 0.747296144035519, 'hgb_weight': 0.1298103747343173, 'gb_weight': 0.00013226299100166372, 'rf_weight': 0.5317780251906599}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,008] Trial 978 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.16364822017864672, 'cb_weight': 0.9642120203236494, 'lgbm_weight': 0.5133406969079931, 'hgb_weight': 0.16435826479956667, 'gb_weight': 0.060598291253208966, 'rf_weight': 0.5028156668999181}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,117] Trial 979 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.3348546343544126, 'cb_weight': 0.8872373528815969, 'lgbm_weight': 0.7151990201683496, 'hgb_weight': 0.09574030309046977, 'gb_weight': 0.030163361763232668, 'rf_weight': 0.559616677828466}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,225] Trial 980 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.12097686466715847, 'cb_weight': 0.9166030727893689, 'lgbm_weight': 0.6649232227496584, 'hgb_weight': 0.19621478973251877, 'gb_weight': 0.023107984422500262, 'rf_weight': 0.5295814377229657}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,331] Trial 981 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.22738355249686804, 'cb_weight': 0.9382574455824012, 'lgbm_weight': 0.753667938002837, 'hgb_weight': 0.14232961117590734, 'gb_weight': 0.0003069403015433375, 'rf_weight': 0.4791531073460593}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,438] Trial 982 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.19615381933019194, 'cb_weight': 0.8628716126621218, 'lgbm_weight': 0.6963898356230439, 'hgb_weight': 0.11779599764291954, 'gb_weight': 0.048007922621343825, 'rf_weight': 0.5825062758795262}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,547] Trial 983 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.29517927248496545, 'cb_weight': 0.9648480169172408, 'lgbm_weight': 0.819548846947899, 'hgb_weight': 0.15500972820876438, 'gb_weight': 0.07333563744464502, 'rf_weight': 0.5150697304864605}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,654] Trial 984 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.22952288476647736, 'cb_weight': 0.9825385971987408, 'lgbm_weight': 0.7652693727024955, 'hgb_weight': 0.17993946168917757, 'gb_weight': 0.00017885050368426328, 'rf_weight': 0.54550349905817}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,762] Trial 985 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.9564560031269765, 'cb_weight': 0.9453143454844762, 'lgbm_weight': 0.6283802168035078, 'hgb_weight': 0.07245238339317651, 'gb_weight': 0.03291967475149264, 'rf_weight': 0.5635408079707444}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,870] Trial 986 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.2621821438875871, 'cb_weight': 0.9085300104371881, 'lgbm_weight': 0.7230002835178123, 'hgb_weight': 0.10481195983681318, 'gb_weight': 0.022226238414078312, 'rf_weight': 0.5006872437630295}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:50,977] Trial 987 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.1897782240507958, 'cb_weight': 0.9294324055015818, 'lgbm_weight': 0.7878030556872191, 'hgb_weight': 0.14156809586482702, 'gb_weight': 0.047084725656612335, 'rf_weight': 0.23092990123612367}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,087] Trial 988 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.20938606538589927, 'cb_weight': 0.9565723419324955, 'lgbm_weight': 0.6813746563084087, 'hgb_weight': 0.12316913518510043, 'gb_weight': 0.10257145168112855, 'rf_weight': 0.5333888505816995}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,197] Trial 989 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.1373516675652171, 'cb_weight': 0.43807693599214587, 'lgbm_weight': 0.7293990330051385, 'hgb_weight': 0.16943274020326932, 'gb_weight': 0.0185018859109515, 'rf_weight': 0.46604598255498086}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,305] Trial 990 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.2471753359264573, 'cb_weight': 0.9810788017214243, 'lgbm_weight': 0.7081010969904575, 'hgb_weight': 0.0862388087471472, 'gb_weight': 0.00010764090468382264, 'rf_weight': 0.5902445015146398}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,412] Trial 991 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.16882171045941, 'cb_weight': 0.9222945628116002, 'lgbm_weight': 0.8465916065808397, 'hgb_weight': 0.7204329074004989, 'gb_weight': 0.047572190813726364, 'rf_weight': 0.5189867151341488}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,521] Trial 992 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.2757146298681544, 'cb_weight': 0.8823497799245755, 'lgbm_weight': 0.7666085117011535, 'hgb_weight': 0.20656319595859857, 'gb_weight': 0.06460477848930173, 'rf_weight': 0.562846683197179}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,629] Trial 993 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.22947357690360812, 'cb_weight': 0.9532702644772044, 'lgbm_weight': 0.7364843412618172, 'hgb_weight': 0.14920819102562932, 'gb_weight': 0.016649434987055158, 'rf_weight': 0.5446751610716841}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,737] Trial 994 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.21307777340295825, 'cb_weight': 0.9686038753195703, 'lgbm_weight': 0.6663603881887147, 'hgb_weight': 0.11641224290858325, 'gb_weight': 0.02685139906946256, 'rf_weight': 0.43903211651426294}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,846] Trial 995 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.18921692173461896, 'cb_weight': 0.8991535800532985, 'lgbm_weight': 0.5681141477006785, 'hgb_weight': 0.12894312243997452, 'gb_weight': 0.04087539707506402, 'rf_weight': 0.4851902641344063}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:51,954] Trial 996 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.249516619857711, 'cb_weight': 0.9384413191872515, 'lgbm_weight': 0.7861942360295582, 'hgb_weight': 0.16163939930556462, 'gb_weight': 1.0214428820496183e-05, 'rf_weight': 0.508985484442606}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:52,065] Trial 997 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.22836276122812363, 'cb_weight': 0.9841977072578025, 'lgbm_weight': 0.6901633886101608, 'hgb_weight': 0.18875967620782882, 'gb_weight': 0.08548366657848874, 'rf_weight': 0.5743927377769996}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:52,174] Trial 998 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.15109647524556863, 'cb_weight': 0.9315237164085259, 'lgbm_weight': 0.7495684214526918, 'hgb_weight': 0.0938004227220685, 'gb_weight': 0.020731955891458848, 'rf_weight': 0.5354361323133854}. Best is trial 314 with value: 0.834770903578243.
# [I 2024-06-10 08:04:52,281] Trial 999 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.26540636481632135, 'cb_weight': 0.9984958864927426, 'lgbm_weight': 0.7168710745635706, 'hgb_weight': 0.14286618728944186, 'gb_weight': 0.06302087072714382, 'rf_weight': 0.550704213997877}. Best is trial 314 with value: 0.834770903578243.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835468, AUC: 0.931066
# --- Fold 2 - Accuracy: 0.834684, AUC: 0.932627
# --- Fold 3 - Accuracy: 0.836840, AUC: 0.930291
# --- Fold 4 - Accuracy: 0.835130, AUC: 0.930466
# --- Fold 5 - Accuracy: 0.825851, AUC: 0.925143
#
# ------ Accuracy: 0.833595 ± 0.003938
# ------ AUC:      0.929919 ± 0.002526

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.837428, AUC: 0.931025
# --- Fold 2 - Accuracy: 0.836383, AUC: 0.932731
# --- Fold 3 - Accuracy: 0.836905, AUC: 0.930266
# --- Fold 4 - Accuracy: 0.835784, AUC: 0.930390
# --- Fold 5 - Accuracy: 0.826570, AUC: 0.925201
#
# ------ Accuracy: 0.834614 ± 0.004059
# ------ AUC:      0.929923 ± 0.002519

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
