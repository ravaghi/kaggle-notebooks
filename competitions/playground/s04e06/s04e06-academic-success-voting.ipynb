# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight,
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-18 08:10:18,387] A new study created in memory with name: no-name-4f2cb78c-afde-4fbe-b837-680a9e600261
# [I 2024-06-18 08:10:18,403] Trial 0 finished with value: 0.8341566690190544 and parameters: {'xgb_weight': 0.4257214105188958, 'cb_weight': 0.8145837404945526, 'lgbm_weight': 0.7353972901996796, 'hgb_weight': 0.8680031998797357, 'gb_weight': 0.3833807728726202, 'rf_weight': 0.9794566321445206}. Best is trial 0 with value: 0.8341566690190544.
# [I 2024-06-18 08:10:18,418] Trial 1 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.8931943467151353, 'cb_weight': 0.20971516975437543, 'lgbm_weight': 0.7418276474127408, 'hgb_weight': 0.6631433191297429, 'gb_weight': 0.8868014614919371, 'rf_weight': 0.8580127121355462}. Best is trial 0 with value: 0.8341566690190544.
# [I 2024-06-18 08:10:18,432] Trial 2 finished with value: 0.833607778561907 and parameters: {'xgb_weight': 0.7492622137435189, 'cb_weight': 0.8701447200552547, 'lgbm_weight': 0.18675584347141305, 'hgb_weight': 0.325566716994249, 'gb_weight': 0.3729374349544643, 'rf_weight': 0.7937130250836765}. Best is trial 0 with value: 0.8341566690190544.
# [I 2024-06-18 08:10:18,446] Trial 3 finished with value: 0.8333202645129251 and parameters: {'xgb_weight': 0.15106026954808938, 'cb_weight': 0.16994269903780979, 'lgbm_weight': 0.08116909294984564, 'hgb_weight': 0.30517534166979365, 'gb_weight': 0.7832898018188742, 'rf_weight': 0.16290618197894668}. Best is trial 0 with value: 0.8341566690190544.
# [I 2024-06-18 08:10:18,461] Trial 4 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.07064129588532642, 'cb_weight': 0.701071172891538, 'lgbm_weight': 0.18097987910036895, 'hgb_weight': 0.5989172503787585, 'gb_weight': 0.41526364919539516, 'rf_weight': 0.5135722490632681}. Best is trial 0 with value: 0.8341566690190544.
# [I 2024-06-18 08:10:18,475] Trial 5 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.22065617294616224, 'cb_weight': 0.7255730076351293, 'lgbm_weight': 0.8494349483095229, 'hgb_weight': 0.9288928280136141, 'gb_weight': 0.7359400395657129, 'rf_weight': 0.4765872407403199}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-06-18 08:10:18,489] Trial 6 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.4928929732595768, 'cb_weight': 0.5945202717681869, 'lgbm_weight': 0.07603696537169113, 'hgb_weight': 0.11747691934552718, 'gb_weight': 0.9664656660240684, 'rf_weight': 0.5833222904330377}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-06-18 08:10:18,504] Trial 7 finished with value: 0.8338430173292558 and parameters: {'xgb_weight': 0.0924219138777983, 'cb_weight': 0.013629501631003293, 'lgbm_weight': 0.8369301084678846, 'hgb_weight': 0.9147878993953196, 'gb_weight': 0.7045862607036278, 'rf_weight': 0.38700659769417056}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-06-18 08:10:18,518] Trial 8 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.705693904972807, 'cb_weight': 0.9233111565425577, 'lgbm_weight': 0.28815289454812154, 'hgb_weight': 0.6840198457708746, 'gb_weight': 0.5202924997698993, 'rf_weight': 0.8773657752485579}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-06-18 08:10:18,533] Trial 9 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.9238893110931801, 'cb_weight': 0.4892301565307503, 'lgbm_weight': 0.5962139627641655, 'hgb_weight': 0.2642754157843866, 'gb_weight': 0.9917108968630512, 'rf_weight': 0.21039796338844785}. Best is trial 5 with value: 0.8343396325047702.
# [I 2024-06-18 08:10:18,585] Trial 10 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.2707756621069694, 'cb_weight': 0.41814529786990345, 'lgbm_weight': 0.9572186218304451, 'hgb_weight': 0.9401562227072523, 'gb_weight': 0.11856439846205591, 'rf_weight': 0.36522823551875394}. Best is trial 10 with value: 0.834378838965995.
# [I 2024-06-18 08:10:18,637] Trial 11 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.3043365568430404, 'cb_weight': 0.41960342584917293, 'lgbm_weight': 0.9278352829167918, 'hgb_weight': 0.9896104680569491, 'gb_weight': 0.004276830329171033, 'rf_weight': 0.34422229723026526}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,690] Trial 12 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.3257492120930324, 'cb_weight': 0.39289740370246773, 'lgbm_weight': 0.9324789274355016, 'hgb_weight': 0.9807650940901366, 'gb_weight': 0.05857936458998024, 'rf_weight': 0.3062390185839179}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,742] Trial 13 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.30717952242679863, 'cb_weight': 0.38215845834034223, 'lgbm_weight': 0.9908080015563759, 'hgb_weight': 0.7974089360348111, 'gb_weight': 0.05373991379450331, 'rf_weight': 0.04046305539393569}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,796] Trial 14 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.6391391800691294, 'cb_weight': 0.2923354274853372, 'lgbm_weight': 0.5140015520751604, 'hgb_weight': 0.4652497054040114, 'gb_weight': 0.19071166810498613, 'rf_weight': 0.6952789535779136}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,848] Trial 15 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.007061197906280681, 'cb_weight': 0.5485144978409597, 'lgbm_weight': 0.6239747431570675, 'hgb_weight': 0.7848722978311345, 'gb_weight': 0.187131124525676, 'rf_weight': 0.33552795138995595}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,903] Trial 16 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.0018540538930660322, 'cb_weight': 0.5917370223622577, 'lgbm_weight': 0.3856748433472367, 'hgb_weight': 0.7584038254230397, 'gb_weight': 0.22319724296331217, 'rf_weight': 0.2290348813173924}. Best is trial 11 with value: 0.8345748712721189.
# [I 2024-06-18 08:10:18,956] Trial 17 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.43019292104601464, 'cb_weight': 0.5988090987513599, 'lgbm_weight': 0.6421424599994521, 'hgb_weight': 0.5274468107839652, 'gb_weight': 0.17478193877160547, 'rf_weight': 0.047987966394534176}. Best is trial 17 with value: 0.8345879400925272.
# [I 2024-06-18 08:10:19,010] Trial 18 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.42004540038521454, 'cb_weight': 0.9976808266486656, 'lgbm_weight': 0.6941008031536204, 'hgb_weight': 0.4527957506474665, 'gb_weight': 0.011244793472081294, 'rf_weight': 0.004149794162270182}. Best is trial 18 with value: 0.8347578347578347.
# [I 2024-06-18 08:10:19,066] Trial 19 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.6069995962709285, 'cb_weight': 0.9416926234998018, 'lgbm_weight': 0.43707693767379585, 'hgb_weight': 0.4509521021222375, 'gb_weight': 0.29966851903853087, 'rf_weight': 0.016691896885982604}. Best is trial 18 with value: 0.8347578347578347.
# [I 2024-06-18 08:10:19,119] Trial 20 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.41584040959474444, 'cb_weight': 0.9956908395340599, 'lgbm_weight': 0.6333553410445374, 'hgb_weight': 0.5400412448133662, 'gb_weight': 0.5620027287096931, 'rf_weight': 0.08988636547305731}. Best is trial 18 with value: 0.8347578347578347.
# [I 2024-06-18 08:10:19,172] Trial 21 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.40195031380753843, 'cb_weight': 0.7527037031690911, 'lgbm_weight': 0.7251542090299249, 'hgb_weight': 0.06758781827819849, 'gb_weight': 0.003265743161626422, 'rf_weight': 0.10890393316569785}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,226] Trial 22 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.54557561202709, 'cb_weight': 0.6660208778253563, 'lgbm_weight': 0.7425195544775359, 'hgb_weight': 0.0004577734951184409, 'gb_weight': 0.11837434029219772, 'rf_weight': 0.13316995712703972}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,280] Trial 23 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.5435317067011727, 'cb_weight': 0.7548924615292293, 'lgbm_weight': 0.7484853972447818, 'hgb_weight': 0.028001555796157797, 'gb_weight': 0.001562516822859461, 'rf_weight': 0.12173621808255036}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,333] Trial 24 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.5309534849908746, 'cb_weight': 0.7942922636350396, 'lgbm_weight': 0.8121699233945724, 'hgb_weight': 0.144722346703822, 'gb_weight': 0.022276673904878617, 'rf_weight': 0.23800971280122585}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,387] Trial 25 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.35696734251477635, 'cb_weight': 0.8220568933846141, 'lgbm_weight': 0.8410028954756886, 'hgb_weight': 0.17955606380271985, 'gb_weight': 0.2900402079580193, 'rf_weight': 0.24306949071175404}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,442] Trial 26 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.768904999911031, 'cb_weight': 0.9784765742452258, 'lgbm_weight': 0.5316004785856872, 'hgb_weight': 0.13160257891473853, 'gb_weight': 0.06264540677816746, 'rf_weight': 0.17015661686544084}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,497] Trial 27 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.4886353113472017, 'cb_weight': 0.8659408438852301, 'lgbm_weight': 0.6959856034685364, 'hgb_weight': 0.23987026420741206, 'gb_weight': 0.11430619548369556, 'rf_weight': 0.267677953927044}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,553] Trial 28 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.19690730446425758, 'cb_weight': 0.7992986094801545, 'lgbm_weight': 0.5543427338348907, 'hgb_weight': 0.4140830270679807, 'gb_weight': 0.2688846837353227, 'rf_weight': 0.002791781554640646}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,609] Trial 29 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.3884888352122051, 'cb_weight': 0.8839682197555543, 'lgbm_weight': 0.7939301022207765, 'hgb_weight': 0.3857789217114762, 'gb_weight': 0.42576687907265864, 'rf_weight': 0.4453469241324323}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,664] Trial 30 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.6099087698878419, 'cb_weight': 0.782096354991825, 'lgbm_weight': 0.4531071752885296, 'hgb_weight': 0.07208725200314894, 'gb_weight': 0.12714368896002076, 'rf_weight': 0.08808235959565809}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,719] Trial 31 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.5524903280456576, 'cb_weight': 0.7560251780208929, 'lgbm_weight': 0.6860554045348957, 'hgb_weight': 0.04229637604691332, 'gb_weight': 0.009491837080383925, 'rf_weight': 0.10928150219938337}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,773] Trial 32 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.46336855168902563, 'cb_weight': 0.6540019302676865, 'lgbm_weight': 0.7691240358296387, 'hgb_weight': 0.19378416010702929, 'gb_weight': 8.257324669931967e-05, 'rf_weight': 0.17739161693824246}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,830] Trial 33 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.46376601354219493, 'cb_weight': 0.6570909128411269, 'lgbm_weight': 0.7799990762023591, 'hgb_weight': 0.20128236386160067, 'gb_weight': 0.07954609056772302, 'rf_weight': 0.20782925176196737}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,887] Trial 34 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.8552392654003331, 'cb_weight': 0.8509627725277146, 'lgbm_weight': 0.8855447817878784, 'hgb_weight': 0.3379278047004543, 'gb_weight': 0.6308428241107685, 'rf_weight': 0.17288916989773223}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,942] Trial 35 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.6858419864076195, 'cb_weight': 0.6524011909203336, 'lgbm_weight': 0.6926359440638724, 'hgb_weight': 0.11686671454421246, 'gb_weight': 0.34311622140240794, 'rf_weight': 0.06068472567354337}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:19,997] Trial 36 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.41028432455794533, 'cb_weight': 0.9136800290975052, 'lgbm_weight': 0.8004881360884727, 'hgb_weight': 0.17528856296325107, 'gb_weight': 0.2285790090620725, 'rf_weight': 0.29863205951650307}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,054] Trial 37 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.24445485692982766, 'cb_weight': 0.7155467902451411, 'lgbm_weight': 0.8892370910954218, 'hgb_weight': 0.2858404302710651, 'gb_weight': 0.1600634074628329, 'rf_weight': 0.595900471240947}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,110] Trial 38 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.3657481172625414, 'cb_weight': 0.5239988059116594, 'lgbm_weight': 0.7042507061007884, 'hgb_weight': 0.36637036697599307, 'gb_weight': 0.0532751511776581, 'rf_weight': 0.16987521220198776}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,166] Trial 39 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.47240607063124274, 'cb_weight': 0.8341175831052626, 'lgbm_weight': 0.5893305530628492, 'hgb_weight': 0.08852692076874497, 'gb_weight': 0.8487363064484323, 'rf_weight': 0.44443049833367393}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,222] Trial 40 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.5420903010586573, 'cb_weight': 0.6956762930617504, 'lgbm_weight': 0.8830655614351669, 'hgb_weight': 0.23096083753235208, 'gb_weight': 0.00018051024506871537, 'rf_weight': 0.1428245696395018}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,278] Trial 41 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.5424989647144918, 'cb_weight': 0.6890875343455942, 'lgbm_weight': 0.010659428241535096, 'hgb_weight': 0.21558061179368082, 'gb_weight': 0.012887856617299374, 'rf_weight': 0.13715549383307912}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,334] Trial 42 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.4427097159730824, 'cb_weight': 0.6150818264383884, 'lgbm_weight': 0.8745627912687846, 'hgb_weight': 0.15930360741031774, 'gb_weight': 0.08290592750626251, 'rf_weight': 0.00148900793647541}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,392] Trial 43 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.5075864853768138, 'cb_weight': 0.7265072721652148, 'lgbm_weight': 0.8175253440000437, 'hgb_weight': 0.2766784500637751, 'gb_weight': 0.13894545130108094, 'rf_weight': 0.06672071774526178}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,450] Trial 44 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.5910099847486711, 'cb_weight': 0.4625631437450261, 'lgbm_weight': 0.7620003362463244, 'hgb_weight': 0.6575824223168185, 'gb_weight': 0.03313102774275585, 'rf_weight': 0.20411781933102713}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,508] Trial 45 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.6634784291001428, 'cb_weight': 0.7716216387754216, 'lgbm_weight': 0.9941215474682683, 'hgb_weight': 0.31135858208743983, 'gb_weight': 0.11058986218246876, 'rf_weight': 0.3932460100334195}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,565] Trial 46 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.7390141841469339, 'cb_weight': 0.5647123122756355, 'lgbm_weight': 0.9350871390380887, 'hgb_weight': 0.24094438565065912, 'gb_weight': 0.08187420229514686, 'rf_weight': 0.9929757339631744}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,622] Trial 47 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.33267390800090213, 'cb_weight': 0.09423552076515906, 'lgbm_weight': 0.8874148991877148, 'hgb_weight': 0.07141169527420758, 'gb_weight': 0.22872924671348538, 'rf_weight': 0.25225435014894315}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,679] Trial 48 finished with value: 0.8340390496353799 and parameters: {'xgb_weight': 0.5156359559393986, 'cb_weight': 0.939765134364963, 'lgbm_weight': 0.7226503110509911, 'hgb_weight': 0.14178410918273932, 'gb_weight': 0.0020690828699850925, 'rf_weight': 0.9349144440357136}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,736] Trial 49 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.15386890752672588, 'cb_weight': 0.6362784297184151, 'lgbm_weight': 0.8253241423454933, 'hgb_weight': 0.0975938502525454, 'gb_weight': 0.04544444283758434, 'rf_weight': 0.2845150922169628}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,793] Trial 50 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.10886180759152306, 'cb_weight': 0.635118497076996, 'lgbm_weight': 0.840418846401318, 'hgb_weight': 0.09930240502772036, 'gb_weight': 0.05211651538380574, 'rf_weight': 0.28842794430210833}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,852] Trial 51 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.11079994543746643, 'cb_weight': 0.6255996259120702, 'lgbm_weight': 0.8492678672509872, 'hgb_weight': 0.10207526311574025, 'gb_weight': 0.0504703421829675, 'rf_weight': 0.2960997735939391}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,908] Trial 52 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.12659487050285356, 'cb_weight': 0.6374168764965724, 'lgbm_weight': 0.8597460106117913, 'hgb_weight': 0.10220814068878592, 'gb_weight': 0.077666655431559, 'rf_weight': 0.3282491968180895}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:20,969] Trial 53 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.11752818014451431, 'cb_weight': 0.4785216944021883, 'lgbm_weight': 0.8541838787741043, 'hgb_weight': 0.09798509354467409, 'gb_weight': 0.1562643375230535, 'rf_weight': 0.3020420747234841}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,026] Trial 54 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.060719332227137116, 'cb_weight': 0.6134806565262962, 'lgbm_weight': 0.9385321423364429, 'hgb_weight': 0.035551822284743434, 'gb_weight': 0.08699472294353988, 'rf_weight': 0.5290882660803556}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,082] Trial 55 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.1728342806778016, 'cb_weight': 0.5556885141797852, 'lgbm_weight': 0.9066555317231123, 'hgb_weight': 0.06478883323340846, 'gb_weight': 0.05133519884128499, 'rf_weight': 0.37143385081980584}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,152] Trial 56 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.15270207698733523, 'cb_weight': 0.5591850018525959, 'lgbm_weight': 0.9611692952273282, 'hgb_weight': 0.05488360227046957, 'gb_weight': 0.19317661609939327, 'rf_weight': 0.3989456667576711}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,214] Trial 57 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.1854558311409982, 'cb_weight': 0.5082291589637881, 'lgbm_weight': 0.9067940416783001, 'hgb_weight': 0.02242585827694235, 'gb_weight': 0.048091147237829465, 'rf_weight': 0.2818618467940455}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,271] Trial 58 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.05612719230001806, 'cb_weight': 0.7106439300817826, 'lgbm_weight': 0.2864104466672471, 'hgb_weight': 0.12066468413342993, 'gb_weight': 0.4768629353456244, 'rf_weight': 0.36274347208716284}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,327] Trial 59 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.2715975578891706, 'cb_weight': 0.6858143572327121, 'lgbm_weight': 0.8382614569593968, 'hgb_weight': 0.06947415807007315, 'gb_weight': 0.10533793675613938, 'rf_weight': 0.4161975983577403}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,384] Trial 60 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.03615638829214668, 'cb_weight': 0.43975995697954073, 'lgbm_weight': 0.9603242605540194, 'hgb_weight': 0.006941783461118248, 'gb_weight': 0.18983975958187738, 'rf_weight': 0.3358164036620258}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,440] Trial 61 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.10806191646363107, 'cb_weight': 0.6337431003159836, 'lgbm_weight': 0.906061216020394, 'hgb_weight': 0.10559415593436862, 'gb_weight': 0.047069723469968766, 'rf_weight': 0.32678580844284383}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,497] Trial 62 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.09566752796105932, 'cb_weight': 0.5638666500453896, 'lgbm_weight': 0.9121471736127935, 'hgb_weight': 0.14960851928948593, 'gb_weight': 0.045719872687974006, 'rf_weight': 0.493936912462976}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,555] Trial 63 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.1593528491156542, 'cb_weight': 0.3507222712522751, 'lgbm_weight': 0.8220818665240216, 'hgb_weight': 0.227266928213343, 'gb_weight': 0.05658167629263989, 'rf_weight': 0.3695945806384804}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,611] Trial 64 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.221278508574987, 'cb_weight': 0.5896838011713819, 'lgbm_weight': 0.9696915213919087, 'hgb_weight': 0.0855980751083788, 'gb_weight': 0.14513774668800972, 'rf_weight': 0.26012381995262346}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,668] Trial 65 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.10894118145656878, 'cb_weight': 0.7387792378472292, 'lgbm_weight': 0.9124486234123527, 'hgb_weight': 0.048802999373854725, 'gb_weight': 0.10073158477628819, 'rf_weight': 0.20920633285241655}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,727] Trial 66 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.19241318821059322, 'cb_weight': 0.5302802587748598, 'lgbm_weight': 0.6596661109264452, 'hgb_weight': 0.04911832995750843, 'gb_weight': 0.10045693390596294, 'rf_weight': 0.21107524600780334}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,784] Trial 67 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.033008183705637004, 'cb_weight': 0.7385897433590997, 'lgbm_weight': 0.8502464382118098, 'hgb_weight': 0.008076676575280724, 'gb_weight': 0.03616166067049611, 'rf_weight': 0.14154677093257215}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,843] Trial 68 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.1427188105586063, 'cb_weight': 0.6936859722467608, 'lgbm_weight': 0.9986818884320827, 'hgb_weight': 0.18142876745947856, 'gb_weight': 0.2609476512979124, 'rf_weight': 0.282594490304878}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,901] Trial 69 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.0779278356662868, 'cb_weight': 0.6680461953041521, 'lgbm_weight': 0.7829888089850613, 'hgb_weight': 0.14034195718024456, 'gb_weight': 0.13025479159520986, 'rf_weight': 0.2232546054264611}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:21,958] Trial 70 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.2775111754384633, 'cb_weight': 0.591249408905837, 'lgbm_weight': 0.7410454661861919, 'hgb_weight': 0.051614154582563375, 'gb_weight': 0.6204253560246293, 'rf_weight': 0.18586581511022104}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:22,016] Trial 71 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.0973619257299656, 'cb_weight': 0.6340170416150416, 'lgbm_weight': 0.9166536193582235, 'hgb_weight': 0.10841973599904246, 'gb_weight': 0.032700269375047594, 'rf_weight': 0.32329952369264586}. Best is trial 21 with value: 0.8349538670639588.
# [I 2024-06-18 08:10:22,074] Trial 72 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.21817072936651713, 'cb_weight': 0.7421846268822248, 'lgbm_weight': 0.8758303494111505, 'hgb_weight': 0.16809933099910424, 'gb_weight': 0.06947365487582649, 'rf_weight': 0.0993898044571935}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,132] Trial 73 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.23473627731670235, 'cb_weight': 0.7960904834553897, 'lgbm_weight': 0.8702770083205926, 'hgb_weight': 0.1703276442772799, 'gb_weight': 0.08611871966124326, 'rf_weight': 0.09919254903893135}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,190] Trial 74 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.17386386244196933, 'cb_weight': 0.7575998491215852, 'lgbm_weight': 0.8140053194268658, 'hgb_weight': 0.2556140287301941, 'gb_weight': 0.17598970190614793, 'rf_weight': 0.14164478247078546}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,249] Trial 75 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.20040460795790527, 'cb_weight': 0.7423611981598397, 'lgbm_weight': 0.9415625492384686, 'hgb_weight': 0.0009434594280142428, 'gb_weight': 0.02591570640185327, 'rf_weight': 0.03306315579200901}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,308] Trial 76 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.24707514559236055, 'cb_weight': 0.6845526766755846, 'lgbm_weight': 0.8344191037124238, 'hgb_weight': 0.856879913397094, 'gb_weight': 0.1213241069839465, 'rf_weight': 0.23947627014460277}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,367] Trial 77 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.13454522533963392, 'cb_weight': 0.7099901362691626, 'lgbm_weight': 0.7956549312455854, 'hgb_weight': 0.19829501080108305, 'gb_weight': 0.933758511738889, 'rf_weight': 0.06851409199265254}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,426] Trial 78 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.008645458606310885, 'cb_weight': 0.8231118455075829, 'lgbm_weight': 0.8803757517599973, 'hgb_weight': 0.07396036552511867, 'gb_weight': 0.02402231588115977, 'rf_weight': 0.100008395142345}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,484] Trial 79 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.29943640079256656, 'cb_weight': 0.7752360823476827, 'lgbm_weight': 0.7615290100540695, 'hgb_weight': 0.1267191184491292, 'gb_weight': 0.07046075535083036, 'rf_weight': 0.19325111984448454}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,543] Trial 80 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.3796581737253396, 'cb_weight': 0.8988924373015177, 'lgbm_weight': 0.7199131681009489, 'hgb_weight': 0.13568444770680035, 'gb_weight': 0.21260632905299826, 'rf_weight': 0.143692108766707}. Best is trial 72 with value: 0.8349669358843671.
# [I 2024-06-18 08:10:22,601] Trial 81 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.21415578672290383, 'cb_weight': 0.8463185058087703, 'lgbm_weight': 0.7641113504099751, 'hgb_weight': 0.0369775341434677, 'gb_weight': 0.06959649219677579, 'rf_weight': 0.19343791535328003}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,659] Trial 82 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.30466769819512324, 'cb_weight': 0.8628397630961547, 'lgbm_weight': 0.6674985107248459, 'hgb_weight': 0.04992658247787385, 'gb_weight': 0.07012263981300902, 'rf_weight': 0.17831046858007993}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,717] Trial 83 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.3444197327624699, 'cb_weight': 0.8551518360219484, 'lgbm_weight': 0.609385990096718, 'hgb_weight': 0.03647558363112419, 'gb_weight': 0.14877062786585382, 'rf_weight': 0.19126063202509874}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,778] Trial 84 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.3042206615294116, 'cb_weight': 0.8783760517330735, 'lgbm_weight': 0.6677777843756851, 'hgb_weight': 0.0610939050028204, 'gb_weight': 0.07903244637977641, 'rf_weight': 0.2638351615899376}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,839] Trial 85 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.29624995834432655, 'cb_weight': 0.7727325993967493, 'lgbm_weight': 0.7620584347158654, 'hgb_weight': 0.030225929566451874, 'gb_weight': 0.11836970370100515, 'rf_weight': 0.1656598087240663}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,899] Trial 86 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.21300139701690138, 'cb_weight': 0.8418399001143062, 'lgbm_weight': 0.7362777158022856, 'hgb_weight': 0.07910818823216687, 'gb_weight': 0.06361947458210238, 'rf_weight': 0.2378236814532007}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:22,958] Trial 87 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.2545285999573447, 'cb_weight': 0.8480240903964938, 'lgbm_weight': 0.7245310024302509, 'hgb_weight': 0.1244137298469363, 'gb_weight': 0.05996444459533179, 'rf_weight': 0.23570932511743278}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,018] Trial 88 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.21206648334445966, 'cb_weight': 0.8041968626814605, 'lgbm_weight': 0.5804661598965281, 'hgb_weight': 0.08356773069282697, 'gb_weight': 0.06490608128721351, 'rf_weight': 0.15721134627445144}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,077] Trial 89 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.27961654749985676, 'cb_weight': 0.8260955166039433, 'lgbm_weight': 0.7500137797926371, 'hgb_weight': 0.16229856255220526, 'gb_weight': 0.3536184867244799, 'rf_weight': 0.085293952881916}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,137] Trial 90 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.32615583590841246, 'cb_weight': 0.9493563247383839, 'lgbm_weight': 0.6472647400267756, 'hgb_weight': 0.5900154283256424, 'gb_weight': 0.14822789704898792, 'rf_weight': 0.10838471640710841}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,198] Trial 91 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.16621334109578442, 'cb_weight': 0.7844034381841665, 'lgbm_weight': 0.7761444330655, 'hgb_weight': 0.052784873011821866, 'gb_weight': 0.09846488856740601, 'rf_weight': 0.1975138042622211}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,258] Trial 92 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.1625996038312409, 'cb_weight': 0.8840460618698158, 'lgbm_weight': 0.7874767796134217, 'hgb_weight': 0.024810101961269634, 'gb_weight': 0.7597252416984387, 'rf_weight': 0.19565587225271153}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,318] Trial 93 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.21998180283085136, 'cb_weight': 0.7862411131913336, 'lgbm_weight': 0.6796352983904754, 'hgb_weight': 0.07648577564711519, 'gb_weight': 0.10149080351564868, 'rf_weight': 0.12788813700642832}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,378] Trial 94 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.22813565434270483, 'cb_weight': 0.7798396635393066, 'lgbm_weight': 0.6755639332089204, 'hgb_weight': 0.08647743317416269, 'gb_weight': 0.1663187701952718, 'rf_weight': 0.12422733688841969}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,438] Trial 95 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.26064862666950833, 'cb_weight': 0.8128761143387018, 'lgbm_weight': 0.7006895503079326, 'hgb_weight': 0.11359415459625213, 'gb_weight': 0.09363217770936334, 'rf_weight': 0.7722195707998516}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,499] Trial 96 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.21704005365113185, 'cb_weight': 0.9264027941677346, 'lgbm_weight': 0.6240059872648241, 'hgb_weight': 0.15158145565406667, 'gb_weight': 0.025871945638061958, 'rf_weight': 0.22676325872659092}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,559] Trial 97 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.28665096130791423, 'cb_weight': 0.8500009233950204, 'lgbm_weight': 0.7694764718589968, 'hgb_weight': 0.0193533477996259, 'gb_weight': 0.0727080546168092, 'rf_weight': 0.031999633654194615}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,619] Trial 98 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.9985940864987107, 'cb_weight': 0.8443565173867817, 'lgbm_weight': 0.773631260985289, 'hgb_weight': 0.020437383530157793, 'gb_weight': 0.07158912902554736, 'rf_weight': 0.031002522307761182}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,680] Trial 99 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.39195348531122465, 'cb_weight': 0.9686777164165269, 'lgbm_weight': 0.7378268242118274, 'hgb_weight': 0.06600453876708554, 'gb_weight': 0.12485131599567563, 'rf_weight': 0.06118343849641204}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,741] Trial 100 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.29277360691395704, 'cb_weight': 0.9041071347395259, 'lgbm_weight': 0.7072097219121937, 'hgb_weight': 0.0015576910982520176, 'gb_weight': 0.10454117970375629, 'rf_weight': 0.08644754823322376}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,800] Trial 101 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.29388664724936964, 'cb_weight': 0.9045077488080547, 'lgbm_weight': 0.7071692811042013, 'hgb_weight': 0.040924296025196406, 'gb_weight': 0.09997894800306309, 'rf_weight': 0.07199078263998053}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,864] Trial 102 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.314983646616529, 'cb_weight': 0.8728524975813466, 'lgbm_weight': 0.7560259931517654, 'hgb_weight': 0.0009084499872877225, 'gb_weight': 0.015986566219890214, 'rf_weight': 0.11828747958084393}. Best is trial 81 with value: 0.8350976240884498.
# [I 2024-06-18 08:10:23,927] Trial 103 finished with value: 0.8351760370108994 and parameters: {'xgb_weight': 0.3172224462607254, 'cb_weight': 0.871116595720291, 'lgbm_weight': 0.756665598502021, 'hgb_weight': 0.02478321884219694, 'gb_weight': 0.020852698376029197, 'rf_weight': 0.11822909836059478}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:23,990] Trial 104 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.3429110297113563, 'cb_weight': 0.8739931294622512, 'lgbm_weight': 0.8108426129422293, 'hgb_weight': 0.01890891747093393, 'gb_weight': 0.019444188070095427, 'rf_weight': 0.021956924019325565}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,052] Trial 105 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.3511203927410423, 'cb_weight': 0.8681759991428134, 'lgbm_weight': 0.8043095312372441, 'hgb_weight': 0.020737500678953056, 'gb_weight': 0.00205942672697898, 'rf_weight': 0.11867418503148593}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,117] Trial 106 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.3174417914782405, 'cb_weight': 0.8899258425160046, 'lgbm_weight': 0.8036941835778374, 'hgb_weight': 0.02325727170099119, 'gb_weight': 0.012383482725979804, 'rf_weight': 0.04580141454592306}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,179] Trial 107 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.3570753654843913, 'cb_weight': 0.8754009529905826, 'lgbm_weight': 0.8017450040543532, 'hgb_weight': 0.028281209213104883, 'gb_weight': 0.021502454635616078, 'rf_weight': 0.019403301074048453}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,240] Trial 108 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.34259654289325625, 'cb_weight': 0.8808279973026324, 'lgbm_weight': 0.801899703142749, 'hgb_weight': 0.016502334272205904, 'gb_weight': 0.018891670446508614, 'rf_weight': 0.044968857130881563}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,301] Trial 109 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.36958178840991096, 'cb_weight': 0.9254478288038999, 'lgbm_weight': 0.8008804648294008, 'hgb_weight': 0.025248694423074293, 'gb_weight': 0.007171342429525647, 'rf_weight': 0.0456222942680594}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,362] Trial 110 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.432785618173522, 'cb_weight': 0.8360003170255109, 'lgbm_weight': 0.7529420951642054, 'hgb_weight': 0.0009462979383768749, 'gb_weight': 0.0330431437169436, 'rf_weight': 0.010536770505474725}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,424] Trial 111 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.3497712867376083, 'cb_weight': 0.8828824941132145, 'lgbm_weight': 0.8051107911460108, 'hgb_weight': 0.014211677205444993, 'gb_weight': 0.01900524443807768, 'rf_weight': 0.02818876532344091}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,485] Trial 112 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.31996107361062964, 'cb_weight': 0.8894518005509147, 'lgbm_weight': 0.7813917746863049, 'hgb_weight': 0.038799671652511886, 'gb_weight': 0.01968917312904444, 'rf_weight': 0.04658916920232112}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,546] Trial 113 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.4100802139390228, 'cb_weight': 0.9664277358934279, 'lgbm_weight': 0.7815012034116675, 'hgb_weight': 0.03779284224447105, 'gb_weight': 0.0015968743151617143, 'rf_weight': 0.12183448821342518}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,607] Trial 114 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.32081348476544386, 'cb_weight': 0.8895597617672655, 'lgbm_weight': 0.7998685380258205, 'hgb_weight': 0.07922204441833716, 'gb_weight': 0.02633770441432826, 'rf_weight': 0.05687890171648744}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,668] Trial 115 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.35731644232510634, 'cb_weight': 0.9423906826826296, 'lgbm_weight': 0.8254403133248913, 'hgb_weight': 0.06048767657987053, 'gb_weight': 0.0013454028923535477, 'rf_weight': 0.04723920501755599}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,730] Trial 116 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.34766391920592254, 'cb_weight': 0.9531460183029373, 'lgbm_weight': 0.8171241044683066, 'hgb_weight': 0.051597221430509155, 'gb_weight': 0.0014549267245077963, 'rf_weight': 0.04675452197287654}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,792] Trial 117 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.35930610551110226, 'cb_weight': 0.9925200048051278, 'lgbm_weight': 0.8222191166202144, 'hgb_weight': 0.04722308374398962, 'gb_weight': 0.003423316004225869, 'rf_weight': 0.05032547772556738}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,853] Trial 118 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.3612069172674541, 'cb_weight': 0.9576841059375599, 'lgbm_weight': 0.8247731901842271, 'hgb_weight': 0.05754264513414328, 'gb_weight': 0.00036002060355189874, 'rf_weight': 0.00152987893342163}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,913] Trial 119 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.3491633976991719, 'cb_weight': 0.9998644512711741, 'lgbm_weight': 0.8555560979195139, 'hgb_weight': 0.044169957604342336, 'gb_weight': 0.038520428065781105, 'rf_weight': 0.07680395947536373}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:24,976] Trial 120 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.4475137364395976, 'cb_weight': 0.929958166418768, 'lgbm_weight': 0.8594238287422856, 'hgb_weight': 0.05347005677789311, 'gb_weight': 0.039132880513764526, 'rf_weight': 0.08090297010348083}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,040] Trial 121 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.34608352267179515, 'cb_weight': 0.9807487335202071, 'lgbm_weight': 0.8195751477754033, 'hgb_weight': 0.03778886979468057, 'gb_weight': 0.02173218661932081, 'rf_weight': 0.04523800412636425}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,102] Trial 122 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.38506189359981097, 'cb_weight': 0.9450195346566633, 'lgbm_weight': 0.8317640515815031, 'hgb_weight': 0.0072576046298090426, 'gb_weight': 0.042592721065196966, 'rf_weight': 0.02399931348514571}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,163] Trial 123 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.3682605118328558, 'cb_weight': 0.9969223733704805, 'lgbm_weight': 0.7832486427257812, 'hgb_weight': 0.09523548961344808, 'gb_weight': 0.021516243914274424, 'rf_weight': 0.0650367057449066}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,226] Trial 124 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.3947264990490468, 'cb_weight': 0.9237750162015346, 'lgbm_weight': 0.8506133632439978, 'hgb_weight': 0.04629314459876084, 'gb_weight': 0.0015288906067410235, 'rf_weight': 0.10536349947441483}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,288] Trial 125 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.33377140423713425, 'cb_weight': 0.9827082157009198, 'lgbm_weight': 0.16818516078833157, 'hgb_weight': 0.05971405476864942, 'gb_weight': 0.04815950296700065, 'rf_weight': 0.01990589754691757}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,352] Trial 126 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.42328972604033044, 'cb_weight': 0.9162471274870743, 'lgbm_weight': 0.3734142069265874, 'hgb_weight': 0.0005372803875764168, 'gb_weight': 0.035458138661835725, 'rf_weight': 0.07872556127740782}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,414] Trial 127 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.35426490748443773, 'cb_weight': 0.9529589785891337, 'lgbm_weight': 0.7624295434597951, 'hgb_weight': 0.03235670727899319, 'gb_weight': 0.021489593616013797, 'rf_weight': 0.05401711531964708}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,475] Trial 128 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.324644007483359, 'cb_weight': 0.8707324008508757, 'lgbm_weight': 0.835316468940731, 'hgb_weight': 0.020544796439949765, 'gb_weight': 0.04960084158574628, 'rf_weight': 0.004394924015597726}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,537] Trial 129 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.2616491524136143, 'cb_weight': 0.9989333355621772, 'lgbm_weight': 0.7939895400739272, 'hgb_weight': 0.4794757121566323, 'gb_weight': 0.40913942176695417, 'rf_weight': 0.15901101994653313}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,598] Trial 130 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.40955459560708474, 'cb_weight': 0.9405707522822857, 'lgbm_weight': 0.8612294416934871, 'hgb_weight': 0.06620368562375062, 'gb_weight': 0.08252692105218148, 'rf_weight': 0.1165646535880305}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,661] Trial 131 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.3821573411117251, 'cb_weight': 0.9430737768931767, 'lgbm_weight': 0.8265861020699502, 'hgb_weight': 7.042314636540419e-07, 'gb_weight': 0.03070998134345328, 'rf_weight': 0.029933047835762526}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,723] Trial 132 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.34918444607269294, 'cb_weight': 0.9066718865168, 'lgbm_weight': 0.8928065170613856, 'hgb_weight': 0.041875636987784105, 'gb_weight': 0.039910127428262325, 'rf_weight': 0.038752543903040754}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,785] Trial 133 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.37957820545886856, 'cb_weight': 0.96609895546043, 'lgbm_weight': 0.8170398219690709, 'hgb_weight': 0.017315700729520767, 'gb_weight': 0.054942411102090624, 'rf_weight': 0.0896584466600605}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,850] Trial 134 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.31874113116293046, 'cb_weight': 0.8724063340428552, 'lgbm_weight': 0.8391415625999974, 'hgb_weight': 0.100163579522674, 'gb_weight': 0.8292177278404996, 'rf_weight': 0.656099645891123}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,913] Trial 135 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.3965887951168245, 'cb_weight': 0.1795356663580454, 'lgbm_weight': 0.733443807573875, 'hgb_weight': 0.05039841301475555, 'gb_weight': 0.003384757996954063, 'rf_weight': 0.017577189426375685}. Best is trial 103 with value: 0.8351760370108994.
# [I 2024-06-18 08:10:25,975] Trial 136 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.4795883938978264, 'cb_weight': 0.908747563273046, 'lgbm_weight': 0.7767970339557471, 'hgb_weight': 0.0845776499640225, 'gb_weight': 0.01805079798308201, 'rf_weight': 0.06790487553573436}. Best is trial 103 with value: 0.8351760370108994.
# ...
# [I 2024-06-18 08:11:36,825] Trial 955 finished with value: 0.8351760370108994 and parameters: {'xgb_weight': 0.2703364141895601, 'cb_weight': 0.922825742383845, 'lgbm_weight': 0.7771353464846131, 'hgb_weight': 0.045321193469467044, 'gb_weight': 0.018367644636433353, 'rf_weight': 0.1446579500306482}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:36,935] Trial 956 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.21917858795243392, 'cb_weight': 0.8981355239634218, 'lgbm_weight': 0.846911643284525, 'hgb_weight': 0.07585609302820126, 'gb_weight': 0.0422379504647728, 'rf_weight': 0.17961526048611007}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,041] Trial 957 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.29541776984085466, 'cb_weight': 0.9758076198989454, 'lgbm_weight': 0.8143509557447511, 'hgb_weight': 0.11646817036510097, 'gb_weight': 0.018734656723888167, 'rf_weight': 0.2201857360153661}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,148] Trial 958 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.24207533320162172, 'cb_weight': 0.9524022590097957, 'lgbm_weight': 0.8658079887689759, 'hgb_weight': 0.09272119827667696, 'gb_weight': 0.0006689866643247392, 'rf_weight': 0.14666456529090263}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,255] Trial 959 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.317228108551215, 'cb_weight': 0.9190074991189903, 'lgbm_weight': 0.6864230812858988, 'hgb_weight': 0.11706322258723185, 'gb_weight': 0.05957416664808052, 'rf_weight': 0.19984101501788046}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,361] Trial 960 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.21440970932403872, 'cb_weight': 0.9366101624938099, 'lgbm_weight': 0.8343950310331976, 'hgb_weight': 0.05874168341506697, 'gb_weight': 0.033642769047776425, 'rf_weight': 0.17122288077784498}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,469] Trial 961 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.25384600478882624, 'cb_weight': 0.882323885447873, 'lgbm_weight': 0.7897196637742344, 'hgb_weight': 0.12852857180764282, 'gb_weight': 0.018473048671081425, 'rf_weight': 0.1338186962981002}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,580] Trial 962 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.22846695313896714, 'cb_weight': 0.974227141513069, 'lgbm_weight': 0.75249128553489, 'hgb_weight': 0.10021367352360902, 'gb_weight': 0.0895722831241261, 'rf_weight': 0.16277947317972458}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,689] Trial 963 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.27153218424319847, 'cb_weight': 0.9088982972654164, 'lgbm_weight': 0.8881366245409297, 'hgb_weight': 0.08296721560700523, 'gb_weight': 0.048374562332770585, 'rf_weight': 0.11625613875399912}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,798] Trial 964 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.2048381896212009, 'cb_weight': 0.8530438705239483, 'lgbm_weight': 0.6171703867457726, 'hgb_weight': 0.12506430478904113, 'gb_weight': 0.8574388455518461, 'rf_weight': 0.14504905206745528}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:37,907] Trial 965 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.32964564020409554, 'cb_weight': 0.955648114237421, 'lgbm_weight': 0.8470836134047662, 'hgb_weight': 0.10563473504951598, 'gb_weight': 0.07373273854557293, 'rf_weight': 0.1937814680423431}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,019] Trial 966 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.22054070161273717, 'cb_weight': 0.31733550832771895, 'lgbm_weight': 0.8065939872710969, 'hgb_weight': 0.07227437031669368, 'gb_weight': 0.017944351156109817, 'rf_weight': 0.17169972520441593}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,128] Trial 967 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.28890610393263016, 'cb_weight': 0.8033289213191617, 'lgbm_weight': 0.827858582988841, 'hgb_weight': 0.31688964434251715, 'gb_weight': 0.0009684733453398653, 'rf_weight': 0.08799789569575985}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,235] Trial 968 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.24315786881045648, 'cb_weight': 0.9354809587377027, 'lgbm_weight': 0.8643379630739697, 'hgb_weight': 0.13546634376965913, 'gb_weight': 0.03698451683530362, 'rf_weight': 0.12469301005181513}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,343] Trial 969 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.19896460384159767, 'cb_weight': 0.6728885258345367, 'lgbm_weight': 0.7284550608302294, 'hgb_weight': 0.04421166194571065, 'gb_weight': 0.0004595249754250387, 'rf_weight': 0.15080481463966355}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,454] Trial 970 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.3118731375780131, 'cb_weight': 0.9815130016478695, 'lgbm_weight': 0.7700736924572822, 'hgb_weight': 0.11129934179210652, 'gb_weight': 0.43930498426861386, 'rf_weight': 0.11201482155678397}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,563] Trial 971 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.2575484871452303, 'cb_weight': 0.8951756902604184, 'lgbm_weight': 0.7933240823937306, 'hgb_weight': 0.02003987691008781, 'gb_weight': 0.057893407058639886, 'rf_weight': 0.17940349089871266}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,671] Trial 972 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.20180525178798378, 'cb_weight': 0.9546413842945944, 'lgbm_weight': 0.9155761807567508, 'hgb_weight': 0.08884569045473001, 'gb_weight': 0.03300240344772652, 'rf_weight': 0.13571344222804843}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,779] Trial 973 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.22983087370987385, 'cb_weight': 0.9141312293611903, 'lgbm_weight': 0.8192698736066917, 'hgb_weight': 0.13602044756255038, 'gb_weight': 0.5890362133731262, 'rf_weight': 0.16148073537583285}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,886] Trial 974 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.28119999828327896, 'cb_weight': 0.9344669412037029, 'lgbm_weight': 0.8466873043709136, 'hgb_weight': 0.11662368385321015, 'gb_weight': 0.0205266033334379, 'rf_weight': 0.22940413845626706}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:38,993] Trial 975 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.18561014901971312, 'cb_weight': 0.9660487704918546, 'lgbm_weight': 0.8892584210698048, 'hgb_weight': 0.09369757583783261, 'gb_weight': 0.00035077273112974166, 'rf_weight': 0.1361296482275055}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,101] Trial 976 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.21380936581347787, 'cb_weight': 0.8676569674980312, 'lgbm_weight': 0.7592225964220781, 'hgb_weight': 0.1344343533100181, 'gb_weight': 0.046597667913612556, 'rf_weight': 0.19809221046486042}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,211] Trial 977 finished with value: 0.835058417627225 and parameters: {'xgb_weight': 0.2598795948338165, 'cb_weight': 0.9825855227701388, 'lgbm_weight': 0.8645804154138023, 'hgb_weight': 0.06523954254981341, 'gb_weight': 0.07337796880499244, 'rf_weight': 0.10824543126322085}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,319] Trial 978 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.24072845588391695, 'cb_weight': 0.9171465630084961, 'lgbm_weight': 0.8052610171302244, 'hgb_weight': 0.6734094889631008, 'gb_weight': 0.10477399369701418, 'rf_weight': 0.15512908762700425}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,427] Trial 979 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.1918381256611001, 'cb_weight': 0.9482415240922156, 'lgbm_weight': 0.8387135464287846, 'hgb_weight': 0.10540943143680513, 'gb_weight': 0.01883805776160094, 'rf_weight': 0.08609079745807367}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,536] Trial 980 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.3039895697134391, 'cb_weight': 0.8872243435526141, 'lgbm_weight': 0.782556125797042, 'hgb_weight': 0.14514592880453336, 'gb_weight': 0.03958422986781318, 'rf_weight': 0.18496125448321615}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,646] Trial 981 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.21622952650113295, 'cb_weight': 0.9978206518333773, 'lgbm_weight': 0.823849295465586, 'hgb_weight': 0.08097429733405254, 'gb_weight': 0.00023713229014577853, 'rf_weight': 0.3383174413683651}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,754] Trial 982 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.2771057692508529, 'cb_weight': 0.9324108267531525, 'lgbm_weight': 0.8708834315983209, 'hgb_weight': 0.11703012737825923, 'gb_weight': 0.02503813694271905, 'rf_weight': 0.12991121465483327}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,862] Trial 983 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.17747978331655798, 'cb_weight': 0.9654487232600976, 'lgbm_weight': 0.7421686528975036, 'hgb_weight': 0.14428342195859853, 'gb_weight': 0.060327142579448156, 'rf_weight': 0.1555511720404584}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:39,970] Trial 984 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.23541030427614817, 'cb_weight': 0.8982192570819616, 'lgbm_weight': 0.7969968850782523, 'hgb_weight': 0.12407401978356603, 'gb_weight': 0.031097423040540403, 'rf_weight': 0.11512632859603951}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,078] Trial 985 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.19635970637961214, 'cb_weight': 0.9468545243530992, 'lgbm_weight': 0.8512757677240359, 'hgb_weight': 0.096414351495009, 'gb_weight': 0.019819644979388703, 'rf_weight': 0.17376688074709853}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,187] Trial 986 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.17242873037766152, 'cb_weight': 0.9135632499817293, 'lgbm_weight': 0.8985282137831636, 'hgb_weight': 0.9428009870485086, 'gb_weight': 0.04746334725759303, 'rf_weight': 0.1443990123462924}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,294] Trial 987 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.2662358869872903, 'cb_weight': 0.8505401799817829, 'lgbm_weight': 0.8280464407219745, 'hgb_weight': 0.04151223098396192, 'gb_weight': 0.01646043111448809, 'rf_weight': 0.06503979769023974}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,404] Trial 988 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.29419068600587683, 'cb_weight': 0.9691506842407309, 'lgbm_weight': 0.7086192791608581, 'hgb_weight': 0.06713688462060644, 'gb_weight': 0.04771830823057354, 'rf_weight': 0.09727819916375012}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,512] Trial 989 finished with value: 0.8351891058313077 and parameters: {'xgb_weight': 0.3403782359827329, 'cb_weight': 0.9995663117132271, 'lgbm_weight': 0.774096095939288, 'hgb_weight': 0.10563994123641596, 'gb_weight': 0.0002099120064724437, 'rf_weight': 0.12074469210128236}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,620] Trial 990 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.3479222448726815, 'cb_weight': 0.9929747622109087, 'lgbm_weight': 0.808794152917993, 'hgb_weight': 0.146398375144848, 'gb_weight': 0.01583495659118311, 'rf_weight': 0.10320308217515323}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,729] Trial 991 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.34593443088760994, 'cb_weight': 0.9736010947080618, 'lgbm_weight': 0.783203357306913, 'hgb_weight': 0.12389266469147445, 'gb_weight': 0.015153644708422098, 'rf_weight': 0.07036391441869379}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,836] Trial 992 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.383322562350203, 'cb_weight': 0.9990283085279573, 'lgbm_weight': 0.8352236038774482, 'hgb_weight': 0.109599531115533, 'gb_weight': 0.3927437424890977, 'rf_weight': 0.08278114857582164}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:40,949] Trial 993 finished with value: 0.8351237617292663 and parameters: {'xgb_weight': 0.33106230732934844, 'cb_weight': 0.9907060686385045, 'lgbm_weight': 0.811190022450693, 'hgb_weight': 0.15436964356631339, 'gb_weight': 0.01260333378790656, 'rf_weight': 0.1175577992311713}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,057] Trial 994 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.31148556249787723, 'cb_weight': 0.9972263872480125, 'lgbm_weight': 0.877973676281424, 'hgb_weight': 0.13230390374004827, 'gb_weight': 0.0015035326488908748, 'rf_weight': 0.09383324731436671}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,186] Trial 995 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.32174544158525076, 'cb_weight': 0.9989309658532344, 'lgbm_weight': 0.8533642840149167, 'hgb_weight': 0.09008920505307963, 'gb_weight': 0.00026912855273983, 'rf_weight': 0.039226480750628706}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,294] Trial 996 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.3682311036267782, 'cb_weight': 0.9867498483410708, 'lgbm_weight': 0.790528997300924, 'hgb_weight': 0.11000307866864062, 'gb_weight': 0.028069094416485002, 'rf_weight': 0.11777385496613389}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,403] Trial 997 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.15977997359041413, 'cb_weight': 0.7203241785285923, 'lgbm_weight': 0.5249166604715492, 'hgb_weight': 0.6037071735173564, 'gb_weight': 0.017245828813176253, 'rf_weight': 0.13374353971373726}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,512] Trial 998 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.3425992073714591, 'cb_weight': 0.9778587390740436, 'lgbm_weight': 0.7717263659978738, 'hgb_weight': 0.6435203592741621, 'gb_weight': 0.027365345341175344, 'rf_weight': 0.112666504045523}. Best is trial 269 with value: 0.8352283122925325.
# [I 2024-06-18 08:11:41,620] Trial 999 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.3193648304388625, 'cb_weight': 0.9991704509785733, 'lgbm_weight': 0.8206947242205767, 'hgb_weight': 0.13343403824333927, 'gb_weight': 0.0014447467721022764, 'rf_weight': 0.08723578369753257}. Best is trial 269 with value: 0.8352283122925325.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835860, AUC: 0.930895
# --- Fold 2 - Accuracy: 0.835925, AUC: 0.932476
# --- Fold 3 - Accuracy: 0.835664, AUC: 0.930151
# --- Fold 4 - Accuracy: 0.834346, AUC: 0.930300
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.925123
#
# ------ Accuracy: 0.833751 ± 0.003443
# ------ AUC:      0.929789 ± 0.002474

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838278, AUC: 0.931279
# --- Fold 2 - Accuracy: 0.837624, AUC: 0.933070
# --- Fold 3 - Accuracy: 0.836187, AUC: 0.930611
# --- Fold 4 - Accuracy: 0.835326, AUC: 0.930479
# --- Fold 5 - Accuracy: 0.827419, AUC: 0.925408
#
# ------ Accuracy: 0.834967 ± 0.003914
# ------ AUC:      0.930169 ± 0.002553

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(20, 20))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(20, 20))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
