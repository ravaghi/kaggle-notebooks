# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'subsample': 0.9335856723937552,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.832985, AUC: 0.929269
# --- Fold 2 - Accuracy: 0.834357, AUC: 0.931514
# --- Fold 3 - Accuracy: 0.831221, AUC: 0.928572
# --- Fold 4 - Accuracy: 0.832974, AUC: 0.928795
# --- Fold 5 - Accuracy: 0.824479, AUC: 0.923588
#
# ------ Accuracy: 0.831203 ± 0.003506
# ------ AUC:      0.928348 ± 0.002599

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.833638, AUC: 0.928638
# --- Fold 2 - Accuracy: 0.835795, AUC: 0.930831
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.928433
# --- Fold 4 - Accuracy: 0.829772, AUC: 0.928001
# --- Fold 5 - Accuracy: 0.824479, AUC: 0.923409
#
# ------ Accuracy: 0.831621 ± 0.004093
# ------ AUC:      0.927862 ± 0.002433

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.835599, AUC: 0.930878
# --- Fold 2 - Accuracy: 0.837624, AUC: 0.932756
# --- Fold 3 - Accuracy: 0.836383, AUC: 0.930163
# --- Fold 4 - Accuracy: 0.835196, AUC: 0.929826
# --- Fold 5 - Accuracy: 0.826570, AUC: 0.924771
#
# ------ Accuracy: 0.834274 ± 0.003940
# ------ AUC:      0.929679 ± 0.002655

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-12 09:33:50,431] A new study created in memory with name: no-name-b6dd4cc7-52fa-4ff1-a7f5-05fdcee06be8
# [I 2024-06-12 09:33:50,450] Trial 0 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.4257214105188958, 'cb_weight': 0.8145837404945526, 'lgbm_weight': 0.7353972901996796, 'hgb_weight': 0.8680031998797357, 'gb_weight': 0.3833807728726202, 'rf_weight': 0.9794566321445206}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-12 09:33:50,468] Trial 1 finished with value: 0.833464021537416 and parameters: {'xgb_weight': 0.8931943467151353, 'cb_weight': 0.20971516975437543, 'lgbm_weight': 0.7418276474127408, 'hgb_weight': 0.6631433191297429, 'gb_weight': 0.8868014614919371, 'rf_weight': 0.8580127121355462}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-12 09:33:50,486] Trial 2 finished with value: 0.8335424344598656 and parameters: {'xgb_weight': 0.7492622137435189, 'cb_weight': 0.8701447200552547, 'lgbm_weight': 0.18675584347141305, 'hgb_weight': 0.325566716994249, 'gb_weight': 0.3729374349544643, 'rf_weight': 0.7937130250836765}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-12 09:33:50,504] Trial 3 finished with value: 0.8333594709741499 and parameters: {'xgb_weight': 0.15106026954808938, 'cb_weight': 0.16994269903780979, 'lgbm_weight': 0.08116909294984564, 'hgb_weight': 0.30517534166979365, 'gb_weight': 0.7832898018188742, 'rf_weight': 0.16290618197894668}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-12 09:33:50,522] Trial 4 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.07064129588532642, 'cb_weight': 0.701071172891538, 'lgbm_weight': 0.18097987910036895, 'hgb_weight': 0.5989172503787585, 'gb_weight': 0.41526364919539516, 'rf_weight': 0.5135722490632681}. Best is trial 0 with value: 0.8340129119945634.
# [I 2024-06-12 09:33:50,541] Trial 5 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.22065617294616224, 'cb_weight': 0.7255730076351293, 'lgbm_weight': 0.8494349483095229, 'hgb_weight': 0.9288928280136141, 'gb_weight': 0.7359400395657129, 'rf_weight': 0.4765872407403199}. Best is trial 5 with value: 0.8343004260435453.
# [I 2024-06-12 09:33:50,559] Trial 6 finished with value: 0.833555503280274 and parameters: {'xgb_weight': 0.4928929732595768, 'cb_weight': 0.5945202717681869, 'lgbm_weight': 0.07603696537169113, 'hgb_weight': 0.11747691934552718, 'gb_weight': 0.9664656660240684, 'rf_weight': 0.5833222904330377}. Best is trial 5 with value: 0.8343004260435453.
# [I 2024-06-12 09:33:50,577] Trial 7 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.0924219138777983, 'cb_weight': 0.013629501631003293, 'lgbm_weight': 0.8369301084678846, 'hgb_weight': 0.9147878993953196, 'gb_weight': 0.7045862607036278, 'rf_weight': 0.38700659769417056}. Best is trial 5 with value: 0.8343004260435453.
# [I 2024-06-12 09:33:50,595] Trial 8 finished with value: 0.833607778561907 and parameters: {'xgb_weight': 0.705693904972807, 'cb_weight': 0.9233111565425577, 'lgbm_weight': 0.28815289454812154, 'hgb_weight': 0.6840198457708746, 'gb_weight': 0.5202924997698993, 'rf_weight': 0.8773657752485579}. Best is trial 5 with value: 0.8343004260435453.
# [I 2024-06-12 09:33:50,613] Trial 9 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.9238893110931801, 'cb_weight': 0.4892301565307503, 'lgbm_weight': 0.5962139627641655, 'hgb_weight': 0.2642754157843866, 'gb_weight': 0.9917108968630512, 'rf_weight': 0.21039796338844785}. Best is trial 5 with value: 0.8343004260435453.
# [I 2024-06-12 09:33:50,673] Trial 10 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.2707756621069694, 'cb_weight': 0.41814529786990345, 'lgbm_weight': 0.9572186218304451, 'hgb_weight': 0.9401562227072523, 'gb_weight': 0.11856439846205591, 'rf_weight': 0.36522823551875394}. Best is trial 10 with value: 0.8344180454272198.
# [I 2024-06-12 09:33:50,736] Trial 11 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.3043365568430404, 'cb_weight': 0.41960342584917293, 'lgbm_weight': 0.9278352829167918, 'hgb_weight': 0.9896104680569491, 'gb_weight': 0.004276830329171033, 'rf_weight': 0.34422229723026526}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:50,797] Trial 12 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.3257492120930324, 'cb_weight': 0.39289740370246773, 'lgbm_weight': 0.9324789274355016, 'hgb_weight': 0.9807650940901366, 'gb_weight': 0.05857936458998024, 'rf_weight': 0.3062390185839179}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:50,859] Trial 13 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.30717952242679863, 'cb_weight': 0.38215845834034223, 'lgbm_weight': 0.9908080015563759, 'hgb_weight': 0.7974089360348111, 'gb_weight': 0.05373991379450331, 'rf_weight': 0.04046305539393569}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:50,924] Trial 14 finished with value: 0.8337646044068062 and parameters: {'xgb_weight': 0.6391391800691294, 'cb_weight': 0.2923354274853372, 'lgbm_weight': 0.5140015520751604, 'hgb_weight': 0.4652497054040114, 'gb_weight': 0.19071166810498613, 'rf_weight': 0.6952789535779136}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:50,986] Trial 15 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.007061197906280681, 'cb_weight': 0.5485144978409597, 'lgbm_weight': 0.6239747431570675, 'hgb_weight': 0.7848722978311345, 'gb_weight': 0.187131124525676, 'rf_weight': 0.33552795138995595}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:51,051] Trial 16 finished with value: 0.8341043937374213 and parameters: {'xgb_weight': 0.0018540538930660322, 'cb_weight': 0.5917370223622577, 'lgbm_weight': 0.3856748433472367, 'hgb_weight': 0.7584038254230397, 'gb_weight': 0.22319724296331217, 'rf_weight': 0.2290348813173924}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:51,117] Trial 17 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.43019292104601464, 'cb_weight': 0.5988090987513599, 'lgbm_weight': 0.6421424599994521, 'hgb_weight': 0.5274468107839652, 'gb_weight': 0.17478193877160547, 'rf_weight': 0.047987966394534176}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:51,178] Trial 18 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.18736485495745692, 'cb_weight': 0.9976808266486656, 'lgbm_weight': 0.43916887138259963, 'hgb_weight': 0.7578481737489023, 'gb_weight': 0.011244793472081294, 'rf_weight': 0.6206745770535387}. Best is trial 11 with value: 0.8344703207088529.
# [I 2024-06-12 09:33:51,239] Trial 19 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.015496695687709505, 'cb_weight': 0.4969458819341156, 'lgbm_weight': 0.6842679678147687, 'hgb_weight': 0.8356256108558164, 'gb_weight': 0.27840110473447655, 'rf_weight': 0.44387499192641394}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,298] Trial 20 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.3773104201679893, 'cb_weight': 0.2954233066938793, 'lgbm_weight': 0.7570018555909397, 'hgb_weight': 0.9858244278512733, 'gb_weight': 0.28992076706767544, 'rf_weight': 0.4674547626300646}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,360] Trial 21 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.011088450075901979, 'cb_weight': 0.5226563660124566, 'lgbm_weight': 0.6039160855858777, 'hgb_weight': 0.8210875351118702, 'gb_weight': 0.25605607559862564, 'rf_weight': 0.3184566040389957}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,422] Trial 22 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.1104310952330431, 'cb_weight': 0.4879737134086059, 'lgbm_weight': 0.8227263653388776, 'hgb_weight': 0.8506886023809046, 'gb_weight': 0.5546436525937707, 'rf_weight': 0.27509394293241635}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,487] Trial 23 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.5977726290960965, 'cb_weight': 0.6793188216474997, 'lgbm_weight': 0.5290728258582014, 'hgb_weight': 0.8667242129331311, 'gb_weight': 0.2886396085950013, 'rf_weight': 0.42811914786265737}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,548] Trial 24 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.20586527654936715, 'cb_weight': 0.31528855698185515, 'lgbm_weight': 0.6982362380440912, 'hgb_weight': 0.6748023219765872, 'gb_weight': 0.5940201819768571, 'rf_weight': 0.14933005050564252}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,608] Trial 25 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.04850495690366585, 'cb_weight': 0.46221181437661074, 'lgbm_weight': 0.8786099656234835, 'hgb_weight': 0.9961572696973723, 'gb_weight': 0.2900402079580193, 'rf_weight': 0.5856669027189213}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,666] Trial 26 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.12332634497065581, 'cb_weight': 0.6436702241315182, 'lgbm_weight': 0.4195158319252304, 'hgb_weight': 0.4371088671193563, 'gb_weight': 0.4433940454921151, 'rf_weight': 0.11916026647764283}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,726] Trial 27 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.2620803383172, 'cb_weight': 0.15521177937793407, 'lgbm_weight': 0.5564078630939071, 'hgb_weight': 0.5728069465562527, 'gb_weight': 0.10616429132572233, 'rf_weight': 0.5294957848782574}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,785] Trial 28 finished with value: 0.83366005384354 and parameters: {'xgb_weight': 0.5463632800109589, 'cb_weight': 0.7603607399902818, 'lgbm_weight': 0.6850003545021233, 'hgb_weight': 0.015185695957746437, 'gb_weight': 0.3218995564728054, 'rf_weight': 0.26526797963783755}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,843] Trial 29 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.40621626010820006, 'cb_weight': 0.5391383762248853, 'lgbm_weight': 0.7655575420822981, 'hgb_weight': 0.8485131298551504, 'gb_weight': 0.45247138248935903, 'rf_weight': 0.408407928994831}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,909] Trial 30 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.15154826094893642, 'cb_weight': 0.3690593110799458, 'lgbm_weight': 0.3236151279372063, 'hgb_weight': 0.7284087309725192, 'gb_weight': 0.13756388638947387, 'rf_weight': 0.34048041235188053}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:51,973] Trial 31 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.007289071541135672, 'cb_weight': 0.5496417881043365, 'lgbm_weight': 0.5917717792043694, 'hgb_weight': 0.8155006522663635, 'gb_weight': 0.20823618497585328, 'rf_weight': 0.32625817875302926}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,038] Trial 32 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.045316701950629826, 'cb_weight': 0.45729525119995507, 'lgbm_weight': 0.47545461481058465, 'hgb_weight': 0.824976851819414, 'gb_weight': 0.24128751034365278, 'rf_weight': 0.4300412650649822}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,102] Trial 33 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.00812873709318886, 'cb_weight': 0.7764617146322267, 'lgbm_weight': 0.685615313826368, 'hgb_weight': 0.6191645234046927, 'gb_weight': 0.0022919832220167913, 'rf_weight': 0.24912673441097244}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,163] Trial 34 finished with value: 0.8339344990721137 and parameters: {'xgb_weight': 0.8488817543930418, 'cb_weight': 0.551667689455094, 'lgbm_weight': 0.5695064303918076, 'hgb_weight': 0.9204511964133163, 'gb_weight': 0.3677580255123263, 'rf_weight': 0.6675001555069966}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,226] Trial 35 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.16659637682383172, 'cb_weight': 0.22769545765704402, 'lgbm_weight': 0.8990656669003062, 'hgb_weight': 0.7287105402041764, 'gb_weight': 0.343317701495186, 'rf_weight': 0.19553562830535176}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,287] Trial 36 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.08331858094648772, 'cb_weight': 0.43666092681285773, 'lgbm_weight': 0.7737994354861392, 'hgb_weight': 0.8900198948085059, 'gb_weight': 0.2344686884144693, 'rf_weight': 0.11178098892033683}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,348] Trial 37 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.23349812995931163, 'cb_weight': 0.3399064870877052, 'lgbm_weight': 0.6505738846120819, 'hgb_weight': 0.8161179830972798, 'gb_weight': 0.07791179297085908, 'rf_weight': 0.5310646871952819}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,413] Trial 38 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.057306244311000024, 'cb_weight': 0.6707296028766304, 'lgbm_weight': 0.7942911914273876, 'hgb_weight': 0.6428940404087338, 'gb_weight': 0.3939273890610231, 'rf_weight': 0.3234736374745622}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,475] Trial 39 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.47952254584789544, 'cb_weight': 0.8341175831052626, 'lgbm_weight': 0.7271514499892036, 'hgb_weight': 0.7060435646444099, 'gb_weight': 0.14627017090921685, 'rf_weight': 0.4665566714356316}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,539] Trial 40 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.12416707121622997, 'cb_weight': 0.6227878820351593, 'lgbm_weight': 0.3694369173992821, 'hgb_weight': 0.9367456922607932, 'gb_weight': 0.24309428486411316, 'rf_weight': 0.38359621858110116}. Best is trial 19 with value: 0.8344964583496693.
# [I 2024-06-12 09:33:52,602] Trial 41 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.006461606575202242, 'cb_weight': 0.5262292267763732, 'lgbm_weight': 0.6153100238854606, 'hgb_weight': 0.8056036032864912, 'gb_weight': 0.17325426269561206, 'rf_weight': 0.3132073384256466}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,664] Trial 42 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.05677692287070669, 'cb_weight': 0.5507377604022948, 'lgbm_weight': 0.580687360784754, 'hgb_weight': 0.8925343355140524, 'gb_weight': 0.09018163002414593, 'rf_weight': 0.29316733721260524}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,727] Trial 43 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.08988209723956406, 'cb_weight': 0.5104202083568151, 'lgbm_weight': 0.47764789523166495, 'hgb_weight': 0.7810373007013367, 'gb_weight': 0.16008869734235712, 'rf_weight': 0.36898569789220154}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,791] Trial 44 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.10820963552171892, 'cb_weight': 0.5378336670207888, 'lgbm_weight': 0.48215652531283115, 'hgb_weight': 0.7634494712410183, 'gb_weight': 0.18666603803323328, 'rf_weight': 0.18511296682960687}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,853] Trial 45 finished with value: 0.8337253979455814 and parameters: {'xgb_weight': 0.0005993975059062611, 'cb_weight': 0.5016425653354091, 'lgbm_weight': 0.20723423283357878, 'hgb_weight': 0.5685620817428156, 'gb_weight': 0.2818358496017577, 'rf_weight': 0.5007349187950305}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,919] Trial 46 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.05239208803141026, 'cb_weight': 0.7308780109184275, 'lgbm_weight': 0.6073000204757928, 'hgb_weight': 0.8064947023222897, 'gb_weight': 0.8737486738483178, 'rf_weight': 0.9929757339631744}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:52,984] Trial 47 finished with value: 0.8336339162027235 and parameters: {'xgb_weight': 0.16148126154303027, 'cb_weight': 0.49531383985618505, 'lgbm_weight': 0.005298893989934661, 'hgb_weight': 0.669217283710357, 'gb_weight': 0.15856712026788095, 'rf_weight': 0.3756305776215986}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:53,052] Trial 48 finished with value: 0.8340129119945634 and parameters: {'xgb_weight': 0.09405023155610417, 'cb_weight': 0.5845634764396281, 'lgbm_weight': 0.5339523905891131, 'hgb_weight': 0.3704289309401242, 'gb_weight': 0.6501254274490597, 'rf_weight': 0.4260087619882375}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:53,116] Trial 49 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.038068533154821754, 'cb_weight': 0.6395693361640973, 'lgbm_weight': 0.4592099362705473, 'hgb_weight': 0.7243960416463202, 'gb_weight': 0.21528301323300347, 'rf_weight': 0.9133689208181086}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:53,178] Trial 50 finished with value: 0.8339083614312972 and parameters: {'xgb_weight': 0.8252799852176235, 'cb_weight': 0.4259471932782884, 'lgbm_weight': 0.7189371195011873, 'hgb_weight': 0.22447319737966398, 'gb_weight': 0.33507547730520815, 'rf_weight': 0.7408471243389819}. Best is trial 41 with value: 0.8346140777333438.
# [I 2024-06-12 09:33:53,242] Trial 51 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.0004591715239400454, 'cb_weight': 0.5095875199175975, 'lgbm_weight': 0.6515150533053133, 'hgb_weight': 0.9443451310021079, 'gb_weight': 0.0012121629019696068, 'rf_weight': 0.3339301963632535}. Best is trial 51 with value: 0.834627146553752.
# [I 2024-06-12 09:33:53,306] Trial 52 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.002090998128986049, 'cb_weight': 0.4805747403312524, 'lgbm_weight': 0.6637809483621129, 'hgb_weight': 0.8898233501770002, 'gb_weight': 0.06146378834666416, 'rf_weight': 0.3051457739140283}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,370] Trial 53 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.023493613409803805, 'cb_weight': 0.389579711035914, 'lgbm_weight': 0.6620620253250592, 'hgb_weight': 0.9510808698464557, 'gb_weight': 0.062462236020800345, 'rf_weight': 0.31683277648614416}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,433] Trial 54 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.0005226773885541754, 'cb_weight': 0.46103166308619614, 'lgbm_weight': 0.6202368249860579, 'hgb_weight': 0.8892440996605545, 'gb_weight': 0.0522111785958006, 'rf_weight': 0.22445304558310145}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,497] Trial 55 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.12473917063309575, 'cb_weight': 0.5804160974763988, 'lgbm_weight': 0.6194275114790231, 'hgb_weight': 0.8450614921031078, 'gb_weight': 0.11542186076222176, 'rf_weight': 0.285951167807483}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,561] Trial 56 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.1981200648290511, 'cb_weight': 0.5096390913341643, 'lgbm_weight': 0.664275635717642, 'hgb_weight': 0.9491389706050491, 'gb_weight': 0.018057473052549004, 'rf_weight': 0.25017622937664735}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,624] Trial 57 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.08463826754582547, 'cb_weight': 0.6102103191685092, 'lgbm_weight': 0.557214726540667, 'hgb_weight': 0.8923235356808583, 'gb_weight': 0.037217411257576424, 'rf_weight': 0.4573922141575786}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,687] Trial 58 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.06540800525961085, 'cb_weight': 0.6927319936518243, 'lgbm_weight': 0.8064549323085803, 'hgb_weight': 0.906759044420845, 'gb_weight': 0.047355920407021856, 'rf_weight': 0.4546514175019067}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,752] Trial 59 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.23469052564746395, 'cb_weight': 0.6189177610208905, 'lgbm_weight': 0.5694183966573048, 'hgb_weight': 0.952150226984475, 'gb_weight': 0.11678840737495481, 'rf_weight': 0.5574413508340214}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,818] Trial 60 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.1457525182370077, 'cb_weight': 0.4638611606308346, 'lgbm_weight': 0.5383982372547227, 'hgb_weight': 0.8653071763813198, 'gb_weight': 0.038037822638266806, 'rf_weight': 0.48785070061222696}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,882] Trial 61 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.03904192136074924, 'cb_weight': 0.5748742066534506, 'lgbm_weight': 0.6075194975325963, 'hgb_weight': 0.829567000656066, 'gb_weight': 0.08971650110674197, 'rf_weight': 0.3513150942028083}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:53,949] Trial 62 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.0838172234975749, 'cb_weight': 0.6610333438723408, 'lgbm_weight': 0.7106538708713616, 'hgb_weight': 0.8733359065437746, 'gb_weight': 0.09002252347452404, 'rf_weight': 0.3980458059509905}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,020] Trial 63 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.08593308212917045, 'cb_weight': 0.674789213072329, 'lgbm_weight': 0.732966071487892, 'hgb_weight': 0.8645638515293453, 'gb_weight': 0.1283630695024733, 'rf_weight': 0.4026886702754612}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,086] Trial 64 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.06827934653306657, 'cb_weight': 0.6441704944152951, 'lgbm_weight': 0.6879100882454764, 'hgb_weight': 0.9671233176443409, 'gb_weight': 0.031007145410514227, 'rf_weight': 0.44167128482614626}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,149] Trial 65 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.34289329063879576, 'cb_weight': 0.7402816034079294, 'lgbm_weight': 0.7005980730903255, 'hgb_weight': 0.9781205673153783, 'gb_weight': 0.027455058938686716, 'rf_weight': 0.45086881803531986}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,212] Trial 66 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.1812080312051485, 'cb_weight': 0.6130278544997575, 'lgbm_weight': 0.6517070966575974, 'hgb_weight': 0.966278992643611, 'gb_weight': 0.07706949852758212, 'rf_weight': 0.6166891909852646}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,277] Trial 67 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.13069173569525228, 'cb_weight': 0.6576197382857883, 'lgbm_weight': 0.8349890765187149, 'hgb_weight': 0.9162650925154229, 'gb_weight': 0.00027141454740802623, 'rf_weight': 0.5099226303881046}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,340] Trial 68 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.12146596081485346, 'cb_weight': 0.7980007717017752, 'lgbm_weight': 0.9986818884320827, 'hgb_weight': 0.9199948925887027, 'gb_weight': 0.006202911518120843, 'rf_weight': 0.5132322717919032}. Best is trial 52 with value: 0.8346794218353851.
# [I 2024-06-12 09:33:54,404] Trial 69 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.0743570321419331, 'cb_weight': 0.6542224408560162, 'lgbm_weight': 0.8477704246926939, 'hgb_weight': 0.9954829521922688, 'gb_weight': 0.04176720049695554, 'rf_weight': 0.5824157516165694}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,467] Trial 70 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.9664781832132169, 'cb_weight': 0.704496038594377, 'lgbm_weight': 0.8389884831898028, 'hgb_weight': 0.9921975710255532, 'gb_weight': 0.03378701959398151, 'rf_weight': 0.5632836931212613}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,531] Trial 71 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.07398985871811536, 'cb_weight': 0.657870576774378, 'lgbm_weight': 0.8724987204550657, 'hgb_weight': 0.8909903573704859, 'gb_weight': 0.0011811916612838175, 'rf_weight': 0.6107623035923999}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,595] Trial 72 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.13987910218684263, 'cb_weight': 0.6355007559682482, 'lgbm_weight': 0.9457929857765377, 'hgb_weight': 0.9990966150531525, 'gb_weight': 0.09479977913967969, 'rf_weight': 0.6561461153442382}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,660] Trial 73 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.13525660269214032, 'cb_weight': 0.7109877674954853, 'lgbm_weight': 0.9558891887921199, 'hgb_weight': 0.9368408298052926, 'gb_weight': 0.06167443766247355, 'rf_weight': 0.7419243272757008}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,725] Trial 74 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.2543545942336091, 'cb_weight': 0.710491009517018, 'lgbm_weight': 0.9582477923022007, 'hgb_weight': 0.9962703733627173, 'gb_weight': 0.05965183408105587, 'rf_weight': 0.7663821227769427}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,792] Trial 75 finished with value: 0.8342742884027288 and parameters: {'xgb_weight': 0.15344413233412216, 'cb_weight': 0.8528426829254252, 'lgbm_weight': 0.9101507326049724, 'hgb_weight': 0.9242234747305428, 'gb_weight': 0.10124198449304889, 'rf_weight': 0.650778389299667}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,856] Trial 76 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.20867149174314795, 'cb_weight': 0.7629145609644202, 'lgbm_weight': 0.9448696014792884, 'hgb_weight': 0.9623949962149528, 'gb_weight': 0.13075516646455732, 'rf_weight': 0.6767239267388575}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,923] Trial 77 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.28539351218093667, 'cb_weight': 0.8088199540193838, 'lgbm_weight': 0.8575617120327179, 'hgb_weight': 0.9226728684443671, 'gb_weight': 0.05937110754249797, 'rf_weight': 0.8369666413028394}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:54,988] Trial 78 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.13939386084203043, 'cb_weight': 0.6351791799302805, 'lgbm_weight': 0.9623525602757244, 'hgb_weight': 0.9986637655353359, 'gb_weight': 0.16469184723706537, 'rf_weight': 0.754384214194459}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,061] Trial 79 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.03402420686438677, 'cb_weight': 0.5626439174221145, 'lgbm_weight': 0.9093377981225622, 'hgb_weight': 0.9586205789603766, 'gb_weight': 0.0012727350933412621, 'rf_weight': 0.6967971215776997}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,127] Trial 80 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.17207727600803233, 'cb_weight': 0.9073905428782684, 'lgbm_weight': 0.8144195692489288, 'hgb_weight': 0.9305260168659217, 'gb_weight': 0.08261000767202531, 'rf_weight': 0.7154581761228653}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,193] Trial 81 finished with value: 0.834378838965995 and parameters: {'xgb_weight': 0.10554811035405891, 'cb_weight': 0.6024139198178828, 'lgbm_weight': 0.773521933568393, 'hgb_weight': 0.9022797614174014, 'gb_weight': 0.0297508218606493, 'rf_weight': 0.8174897262072376}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,259] Trial 82 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.06844071035086977, 'cb_weight': 0.7294167602729934, 'lgbm_weight': 0.5037910256633924, 'hgb_weight': 0.9721549829481321, 'gb_weight': 0.03084248392694614, 'rf_weight': 0.6389673543278513}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,326] Trial 83 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.7273146192433106, 'cb_weight': 0.6502276406261139, 'lgbm_weight': 0.88124423619773, 'hgb_weight': 0.8744349071270282, 'gb_weight': 0.06189295877469904, 'rf_weight': 0.5723992019403357}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,393] Trial 84 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.027929197543754808, 'cb_weight': 0.5317793318221382, 'lgbm_weight': 0.9748296046036266, 'hgb_weight': 0.9087170190689354, 'gb_weight': 0.10451998829389307, 'rf_weight': 0.5379380523680892}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,458] Trial 85 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.0510677936435469, 'cb_weight': 0.6879956385065887, 'lgbm_weight': 0.8406470772728861, 'hgb_weight': 0.9713679668402536, 'gb_weight': 0.14158768086957293, 'rf_weight': 0.5953790278968618}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,525] Trial 86 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.6480253716957298, 'cb_weight': 0.6967601290245873, 'lgbm_weight': 0.7466093784394495, 'hgb_weight': 0.943138037449924, 'gb_weight': 0.19232262116064897, 'rf_weight': 0.6047379956911137}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,590] Trial 87 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.030837217886359264, 'cb_weight': 0.7835384343566876, 'lgbm_weight': 0.9217626748991045, 'hgb_weight': 0.9704958727346571, 'gb_weight': 0.1468575449931688, 'rf_weight': 0.5874571334311683}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,656] Trial 88 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.05652426965167513, 'cb_weight': 0.746519332240819, 'lgbm_weight': 0.8459001266138053, 'hgb_weight': 0.7892990108732671, 'gb_weight': 0.49085337953029357, 'rf_weight': 0.7126985962139669}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,724] Trial 89 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.10530870307315911, 'cb_weight': 0.7155591099724673, 'lgbm_weight': 0.8808066087088224, 'hgb_weight': 0.9374350072291666, 'gb_weight': 0.0719491639853799, 'rf_weight': 0.7851445896249369}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,795] Trial 90 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.14385595609856, 'cb_weight': 0.48049186154208157, 'lgbm_weight': 0.8269254907859777, 'hgb_weight': 0.851256542758156, 'gb_weight': 0.13440048134742094, 'rf_weight': 0.6365491771317637}. Best is trial 69 with value: 0.8347447659374265.
# [I 2024-06-12 09:33:55,863] Trial 91 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.020375434393047648, 'cb_weight': 0.604561976848702, 'lgbm_weight': 0.7858331357788395, 'hgb_weight': 0.9716183544870461, 'gb_weight': 0.04387625246101504, 'rf_weight': 0.4791223815317296}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:55,931] Trial 92 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.017462227517067802, 'cb_weight': 0.6369446401899103, 'lgbm_weight': 0.7976693044078257, 'hgb_weight': 0.9761412639622445, 'gb_weight': 0.7597252416984387, 'rf_weight': 0.48400527144626904}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,015] Trial 93 finished with value: 0.8339867743537468 and parameters: {'xgb_weight': 0.05706432973262292, 'cb_weight': 0.07048743982536698, 'lgbm_weight': 0.7907031728674803, 'hgb_weight': 0.9395317552234098, 'gb_weight': 0.11093374310547896, 'rf_weight': 0.536741618738267}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,091] Trial 94 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.1256737049241674, 'cb_weight': 0.6838749701172986, 'lgbm_weight': 0.9368216709232412, 'hgb_weight': 0.9959760572371009, 'gb_weight': 0.023854429318717355, 'rf_weight': 0.5017167768101882}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,158] Trial 95 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.0002965220640093911, 'cb_weight': 0.5872741942811547, 'lgbm_weight': 0.7531959027319174, 'hgb_weight': 0.9124273362477268, 'gb_weight': 0.05273050211381014, 'rf_weight': 0.3522601203146709}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,225] Trial 96 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.036805686043363095, 'cb_weight': 0.5248212171253909, 'lgbm_weight': 0.6788246675018678, 'hgb_weight': 0.9617229549065373, 'gb_weight': 0.17510506302142675, 'rf_weight': 0.41999782824716636}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,291] Trial 97 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.039083178335646576, 'cb_weight': 0.5687105511873801, 'lgbm_weight': 0.673162925676295, 'hgb_weight': 0.9541737679706974, 'gb_weight': 0.200329858318833, 'rf_weight': 0.297723576295338}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,358] Trial 98 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.07132930802993233, 'cb_weight': 0.5139640890944772, 'lgbm_weight': 0.6309777143463231, 'hgb_weight': 0.977226069489293, 'gb_weight': 0.17415035326277298, 'rf_weight': 0.423546969291708}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,425] Trial 99 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.01810486896397085, 'cb_weight': 0.44466913735978497, 'lgbm_weight': 0.6949441105832493, 'hgb_weight': 0.8790613722104168, 'gb_weight': 0.14826490278818877, 'rf_weight': 0.37050590004237727}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,491] Trial 100 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.02197601330701529, 'cb_weight': 0.41289978046009984, 'lgbm_weight': 0.6939300226128655, 'hgb_weight': 0.879796495967911, 'gb_weight': 0.25158093395076153, 'rf_weight': 0.381493238089748}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,558] Trial 101 finished with value: 0.8343265636843619 and parameters: {'xgb_weight': 0.09657556172578491, 'cb_weight': 0.47553853577590444, 'lgbm_weight': 0.6397154645282432, 'hgb_weight': 0.9396335497571909, 'gb_weight': 0.15378336438504048, 'rf_weight': 0.27124001431058603}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,628] Trial 102 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.05335058428186345, 'cb_weight': 0.5217955854892984, 'lgbm_weight': 0.7208070358888449, 'hgb_weight': 0.9982083376702892, 'gb_weight': 0.2234824129563353, 'rf_weight': 0.4147910376137186}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,695] Trial 103 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.025189291576713575, 'cb_weight': 0.4324484058554248, 'lgbm_weight': 0.6762141025641555, 'hgb_weight': 0.5079601443034503, 'gb_weight': 0.08959642830792036, 'rf_weight': 0.3376264528368459}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,761] Trial 104 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.0008129055156836928, 'cb_weight': 0.3645259497331913, 'lgbm_weight': 0.7742850450601915, 'hgb_weight': 0.1803416173642728, 'gb_weight': 0.12722421499293354, 'rf_weight': 0.3551816872685065}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,827] Trial 105 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.04127368952692518, 'cb_weight': 0.45002890468967577, 'lgbm_weight': 0.9815852672416958, 'hgb_weight': 0.8466280793168655, 'gb_weight': 0.17551760808971642, 'rf_weight': 0.30620963224825726}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,894] Trial 106 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.071166057293542, 'cb_weight': 0.5450032883205116, 'lgbm_weight': 0.699824792176207, 'hgb_weight': 0.9600763490212361, 'gb_weight': 0.10563002460293304, 'rf_weight': 0.4768166527813521}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:56,962] Trial 107 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.10842110404554994, 'cb_weight': 0.4014850475001556, 'lgbm_weight': 0.6468001803219324, 'hgb_weight': 0.8980573942539569, 'gb_weight': 0.0756951185866877, 'rf_weight': 0.4331205560333466}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,036] Trial 108 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.02192584366268191, 'cb_weight': 0.49425619255992986, 'lgbm_weight': 0.7470712221299114, 'hgb_weight': 0.3929248444057821, 'gb_weight': 0.03895047330339947, 'rf_weight': 0.24717198804532703}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,105] Trial 109 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.4645061476177518, 'cb_weight': 0.6071864221918778, 'lgbm_weight': 0.7351576467303594, 'hgb_weight': 0.9270394220985092, 'gb_weight': 0.13961755942659687, 'rf_weight': 0.8967426353932583}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,173] Trial 110 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.5384397309324472, 'cb_weight': 0.5619414626450498, 'lgbm_weight': 0.8579773531877058, 'hgb_weight': 0.8643348915884047, 'gb_weight': 0.269217545657308, 'rf_weight': 0.38966723930285885}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,240] Trial 111 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.014287233721281887, 'cb_weight': 0.40885556002240603, 'lgbm_weight': 0.6890668096529807, 'hgb_weight': 0.978585796415268, 'gb_weight': 0.09839574931273398, 'rf_weight': 0.3668395497335026}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,306] Trial 112 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.04693439289062122, 'cb_weight': 0.44253441601401766, 'lgbm_weight': 0.5859885055681334, 'hgb_weight': 0.8835855012291118, 'gb_weight': 0.25349725705371123, 'rf_weight': 0.3916001377236078}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,373] Trial 113 finished with value: 0.8343134948639536 and parameters: {'xgb_weight': 0.08960125585896131, 'cb_weight': 0.3316041917371567, 'lgbm_weight': 0.7063062935508734, 'hgb_weight': 0.9563848498262376, 'gb_weight': 0.3086662759829003, 'rf_weight': 0.3213724806241459}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,440] Trial 114 finished with value: 0.8342220131210957 and parameters: {'xgb_weight': 0.07371109491097935, 'cb_weight': 0.6228288755772363, 'lgbm_weight': 0.6703338244756931, 'hgb_weight': 0.904784172410826, 'gb_weight': 0.8243220450603447, 'rf_weight': 0.4469433843250666}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,507] Trial 115 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.021785501626001496, 'cb_weight': 0.37536204634931275, 'lgbm_weight': 0.6216715374454734, 'hgb_weight': 0.8331954213934211, 'gb_weight': 0.2186702326996287, 'rf_weight': 0.3753580354486733}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,574] Trial 116 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.044835711421892084, 'cb_weight': 0.6758873690624502, 'lgbm_weight': 0.896482682902935, 'hgb_weight': 0.8007686386898759, 'gb_weight': 0.07282525258203255, 'rf_weight': 0.6779952330666023}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,640] Trial 117 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.0655117183497346, 'cb_weight': 0.4199871691558029, 'lgbm_weight': 0.7244179034028706, 'hgb_weight': 0.9401070767569805, 'gb_weight': 0.175029529219466, 'rf_weight': 0.40265986883945126}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,708] Trial 118 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.020314037087086505, 'cb_weight': 0.47592167720283757, 'lgbm_weight': 0.6009320098706425, 'hgb_weight': 0.8819275010362396, 'gb_weight': 0.019942620845827846, 'rf_weight': 0.34053315791769456}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,775] Trial 119 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.09548264175066712, 'cb_weight': 0.4671927142469562, 'lgbm_weight': 0.6008688146801465, 'hgb_weight': 0.9762944390373126, 'gb_weight': 0.018107491085270547, 'rf_weight': 0.5487615782141113}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,842] Trial 120 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.0028085126107111496, 'cb_weight': 0.5907334662369951, 'lgbm_weight': 0.5598112502339155, 'hgb_weight': 0.011331937922525626, 'gb_weight': 0.04812041782990692, 'rf_weight': 0.28788685863670277}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,909] Trial 121 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.02906395721995709, 'cb_weight': 0.5354316268174112, 'lgbm_weight': 0.6470236473812871, 'hgb_weight': 0.8797988882039312, 'gb_weight': 0.12433866929292764, 'rf_weight': 0.34946307938195076}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:57,978] Trial 122 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.04200493541881157, 'cb_weight': 0.5155823677006208, 'lgbm_weight': 0.6364828601825485, 'hgb_weight': 0.9209810877374031, 'gb_weight': 0.12064295854695714, 'rf_weight': 0.31317090641473944}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,051] Trial 123 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.060497895181356974, 'cb_weight': 0.48812142809181297, 'lgbm_weight': 0.6608282989893779, 'hgb_weight': 0.999668523964611, 'gb_weight': 0.021516243914274424, 'rf_weight': 0.3391535960151132}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,117] Trial 124 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.06297685648261361, 'cb_weight': 0.4994113573267728, 'lgbm_weight': 0.6570958960684893, 'hgb_weight': 0.9607082999017854, 'gb_weight': 0.0159864689644212, 'rf_weight': 0.33609523862856644}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,186] Trial 125 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.08316833632027348, 'cb_weight': 0.49507253621481545, 'lgbm_weight': 0.6544484373374885, 'hgb_weight': 0.9867747995190241, 'gb_weight': 0.017409198869367794, 'rf_weight': 0.3318024820184068}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,252] Trial 126 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.05787766211848945, 'cb_weight': 0.5369117680517816, 'lgbm_weight': 0.5836342344203492, 'hgb_weight': 0.9611478907083225, 'gb_weight': 0.04611070212529117, 'rf_weight': 0.24684316766666906}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,317] Trial 127 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.10797725435261876, 'cb_weight': 0.5602307057552458, 'lgbm_weight': 0.6072246231275042, 'hgb_weight': 0.9994701013433536, 'gb_weight': 0.021588033031063634, 'rf_weight': 0.2739870600742542}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,383] Trial 128 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.038037081903093704, 'cb_weight': 0.4856541376640646, 'lgbm_weight': 0.5259966636376212, 'hgb_weight': 0.9543799575404733, 'gb_weight': 0.08357599936658441, 'rf_weight': 0.21715931022684437}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,450] Trial 129 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.0006432225782719398, 'cb_weight': 0.532376560037523, 'lgbm_weight': 0.6587921531521069, 'hgb_weight': 0.9761940649891259, 'gb_weight': 0.00023166578892902176, 'rf_weight': 0.3451490101113297}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,517] Trial 130 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.06934972452853885, 'cb_weight': 0.5819676285164674, 'lgbm_weight': 0.6220489395638549, 'hgb_weight': 0.9142354573956214, 'gb_weight': 0.040172954180145826, 'rf_weight': 0.2935225322482155}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,584] Trial 131 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.020569636276126013, 'cb_weight': 0.45622031276004804, 'lgbm_weight': 0.6599933489420461, 'hgb_weight': 0.8592246966128387, 'gb_weight': 0.0662117706771019, 'rf_weight': 0.3629303553996423}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,651] Trial 132 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.030817717220944296, 'cb_weight': 0.5019074288311418, 'lgbm_weight': 0.6751040327563803, 'hgb_weight': 0.8512654380228332, 'gb_weight': 0.05384361336532886, 'rf_weight': 0.35656300387344325}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,720] Trial 133 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.05480636009339568, 'cb_weight': 0.45913470811792967, 'lgbm_weight': 0.6347359347736162, 'hgb_weight': 0.7717780728801302, 'gb_weight': 0.06833296137252952, 'rf_weight': 0.32526829473805463}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,787] Trial 134 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.08136514153903626, 'cb_weight': 0.5240626668289217, 'lgbm_weight': 0.6021075251677872, 'hgb_weight': 0.8993393958803778, 'gb_weight': 0.9581331209706679, 'rf_weight': 0.5897424924453876}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,856] Trial 135 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.029546926749169297, 'cb_weight': 0.47657701206133, 'lgbm_weight': 0.5485971900038142, 'hgb_weight': 0.9367869465010396, 'gb_weight': 0.023690207870651667, 'rf_weight': 0.4387623052036796}. Best is trial 91 with value: 0.8347578347578347.
# [I 2024-06-12 09:33:58,926] Trial 136 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.11340524205620434, 'cb_weight': 0.6318160673273899, 'lgbm_weight': 0.6636855680335344, 'hgb_weight': 0.9996774745490353, 'gb_weight': 0.09769914361198537, 'rf_weight': 0.33830542670861397}. Best is trial 91 with value: 0.8347578347578347.
# ...
# [I 2024-06-12 09:35:19,776] Trial 955 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.05269389075517493, 'cb_weight': 0.4996885236239691, 'lgbm_weight': 0.8255698027212118, 'hgb_weight': 0.8575620107344645, 'gb_weight': 0.6296873062376716, 'rf_weight': 0.5131637317549425}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:19,900] Trial 956 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.21837191080504278, 'cb_weight': 0.6659572635727882, 'lgbm_weight': 0.8631919964590207, 'hgb_weight': 0.9223169833507715, 'gb_weight': 0.04586448813533101, 'rf_weight': 0.557213597383275}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,031] Trial 957 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.07506742411831145, 'cb_weight': 0.5952230644663261, 'lgbm_weight': 0.6853944046970877, 'hgb_weight': 0.9031109241140709, 'gb_weight': 0.07248921722425204, 'rf_weight': 0.5896998302781992}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,155] Trial 958 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.017283875012868755, 'cb_weight': 0.5645107806166018, 'lgbm_weight': 0.7075541058795635, 'hgb_weight': 0.9530801019661871, 'gb_weight': 0.018089695561348245, 'rf_weight': 0.49410173733284735}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,282] Trial 959 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.04486611876042682, 'cb_weight': 0.4344172732773295, 'lgbm_weight': 0.7856022255046425, 'hgb_weight': 0.8770850299104829, 'gb_weight': 0.032980066743166864, 'rf_weight': 0.5213636832362364}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,409] Trial 960 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.03255770640908887, 'cb_weight': 0.6273904664048665, 'lgbm_weight': 0.7562093511695663, 'hgb_weight': 0.9397887124093456, 'gb_weight': 0.059090986541812864, 'rf_weight': 0.4776227304929858}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,532] Trial 961 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.09444972712310389, 'cb_weight': 0.6126586507702768, 'lgbm_weight': 0.7500287008286548, 'hgb_weight': 0.9774948796345477, 'gb_weight': 0.04900629110290593, 'rf_weight': 0.4766620615772921}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,657] Trial 962 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.07231082560603738, 'cb_weight': 0.5819725305949865, 'lgbm_weight': 0.7597997345510944, 'hgb_weight': 0.9559119805332298, 'gb_weight': 0.023759813135497826, 'rf_weight': 0.47374071290560094}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,778] Trial 963 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.11803882668316253, 'cb_weight': 0.46785494399208705, 'lgbm_weight': 0.767005785973882, 'hgb_weight': 0.9752962116483188, 'gb_weight': 0.018620039447405482, 'rf_weight': 0.467094477792156}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:20,945] Trial 964 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.13673084591726017, 'cb_weight': 0.5365332676932546, 'lgbm_weight': 0.7626654769584367, 'hgb_weight': 0.9581741673619387, 'gb_weight': 0.013416071187927684, 'rf_weight': 0.4668517530558733}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,073] Trial 965 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.08907500015940514, 'cb_weight': 0.5520663246890793, 'lgbm_weight': 0.7359396301756634, 'hgb_weight': 0.965163064407664, 'gb_weight': 0.015143478091603844, 'rf_weight': 0.45290944878926626}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,195] Trial 966 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.42631691285557705, 'cb_weight': 0.5762586025845451, 'lgbm_weight': 0.7805458343822329, 'hgb_weight': 0.9856720666241418, 'gb_weight': 0.03163054034040498, 'rf_weight': 0.47919325605449475}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,317] Trial 967 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.07776797454197029, 'cb_weight': 0.5331756913754089, 'lgbm_weight': 0.7477062308664488, 'hgb_weight': 0.9570176138569718, 'gb_weight': 0.0014840620886901607, 'rf_weight': 0.490661742016823}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,441] Trial 968 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.10179193393549942, 'cb_weight': 0.559426960885722, 'lgbm_weight': 0.727218711043616, 'hgb_weight': 0.9443099399651755, 'gb_weight': 0.03210107351063954, 'rf_weight': 0.44139192017693313}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,563] Trial 969 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.06802903216998955, 'cb_weight': 0.5793769630581799, 'lgbm_weight': 0.7602827964566568, 'hgb_weight': 0.9821463508433556, 'gb_weight': 0.01723311604921387, 'rf_weight': 0.46549119552571383}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,685] Trial 970 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.06669751101847644, 'cb_weight': 0.5838922023485147, 'lgbm_weight': 0.7954572472291332, 'hgb_weight': 0.9657617632008887, 'gb_weight': 0.042449141877718664, 'rf_weight': 0.49702883084302635}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,810] Trial 971 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.04258535904272492, 'cb_weight': 0.5533008881414962, 'lgbm_weight': 0.7746541142476047, 'hgb_weight': 0.9433411366901824, 'gb_weight': 0.0017653325728286201, 'rf_weight': 0.4787017131061307}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:21,936] Trial 972 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.1108792097823125, 'cb_weight': 0.5100227508757091, 'lgbm_weight': 0.8012734432166244, 'hgb_weight': 0.9532886433490809, 'gb_weight': 0.0009640141197724272, 'rf_weight': 0.4471159341435773}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,066] Trial 973 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.08264916211542209, 'cb_weight': 0.555060430728157, 'lgbm_weight': 0.786171963390152, 'hgb_weight': 0.9996925897280433, 'gb_weight': 0.013067966753891595, 'rf_weight': 0.42826682892437307}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,189] Trial 974 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.06054475269654032, 'cb_weight': 0.5286378791032953, 'lgbm_weight': 0.7784134926311165, 'hgb_weight': 0.9352888564921048, 'gb_weight': 0.010907666356011644, 'rf_weight': 0.47075639227384297}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,311] Trial 975 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.04737998978904316, 'cb_weight': 0.5493417841328971, 'lgbm_weight': 0.7695432665320433, 'hgb_weight': 0.9691200548383876, 'gb_weight': 0.0011006997128507334, 'rf_weight': 0.4518342494364244}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,435] Trial 976 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.18963022719795167, 'cb_weight': 0.5953052077934404, 'lgbm_weight': 0.8068354122399402, 'hgb_weight': 0.9519756052973977, 'gb_weight': 0.026277159586254192, 'rf_weight': 0.47309393065636335}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,559] Trial 977 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.09135997452231533, 'cb_weight': 0.5713074656136342, 'lgbm_weight': 0.7839748223327282, 'hgb_weight': 0.9390962868411822, 'gb_weight': 0.027391436501197488, 'rf_weight': 0.4835698220602902}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,682] Trial 978 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.06992606193740718, 'cb_weight': 0.5995813800563855, 'lgbm_weight': 0.8077174910483818, 'hgb_weight': 0.9793236941650072, 'gb_weight': 0.014884685164370252, 'rf_weight': 0.4288388230433767}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,808] Trial 979 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.04387775991375066, 'cb_weight': 0.5166326838418703, 'lgbm_weight': 0.7572123832691702, 'hgb_weight': 0.9429721966316096, 'gb_weight': 0.0021975732946576676, 'rf_weight': 0.4524129459639994}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:22,933] Trial 980 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.06165379980649491, 'cb_weight': 0.6329603430938282, 'lgbm_weight': 0.7797549085482302, 'hgb_weight': 0.9659930536318952, 'gb_weight': 0.0017103776794389139, 'rf_weight': 0.4753296643497274}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,060] Trial 981 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.03323644994808294, 'cb_weight': 0.5436807959686892, 'lgbm_weight': 0.7352476810103772, 'hgb_weight': 0.9369571253076152, 'gb_weight': 0.03582662900584656, 'rf_weight': 0.4935199748667813}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,189] Trial 982 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.10197003697389587, 'cb_weight': 0.5701412571266258, 'lgbm_weight': 0.6577431065700017, 'hgb_weight': 0.9862546127081677, 'gb_weight': 0.029529674597335524, 'rf_weight': 0.39638306532237877}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,313] Trial 983 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 8.811518313233888e-05, 'cb_weight': 0.6083745143460527, 'lgbm_weight': 0.767658753552985, 'hgb_weight': 0.9499156204827139, 'gb_weight': 0.044474142939635544, 'rf_weight': 0.457432786141257}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,439] Trial 984 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.07863972047232458, 'cb_weight': 0.5913538111969749, 'lgbm_weight': 0.7985858055273443, 'hgb_weight': 0.9358670917184723, 'gb_weight': 0.022064535281972966, 'rf_weight': 0.47950416993962197}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,566] Trial 985 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.04654228874994249, 'cb_weight': 0.6239820863340786, 'lgbm_weight': 0.6952207865970994, 'hgb_weight': 0.9632499673305959, 'gb_weight': 0.04196160447943344, 'rf_weight': 0.5006605057975975}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,690] Trial 986 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.032285196948148694, 'cb_weight': 0.5566046659256505, 'lgbm_weight': 0.7483739514069058, 'hgb_weight': 0.9292663836063433, 'gb_weight': 0.0020952310150988834, 'rf_weight': 0.4654955004619156}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,817] Trial 987 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.027313722548735417, 'cb_weight': 0.5320896873355134, 'lgbm_weight': 0.750652522956821, 'hgb_weight': 0.9331537941140675, 'gb_weight': 0.015918246618498645, 'rf_weight': 0.4246600464092923}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:23,944] Trial 988 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.02990867693504337, 'cb_weight': 0.500078282451613, 'lgbm_weight': 0.7643481103073797, 'hgb_weight': 0.96180435715108, 'gb_weight': 0.04986275004282168, 'rf_weight': 0.453268130887917}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,078] Trial 989 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.057791313660649976, 'cb_weight': 0.5492214489522589, 'lgbm_weight': 0.7888150732159258, 'hgb_weight': 0.9450015631267793, 'gb_weight': 0.00010945147155108124, 'rf_weight': 0.42972839481078107}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,205] Trial 990 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.015906488189600897, 'cb_weight': 0.5696068239759194, 'lgbm_weight': 0.7502512770837626, 'hgb_weight': 0.9297324889247737, 'gb_weight': 0.028915665255573757, 'rf_weight': 0.4131533004050384}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,330] Trial 991 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.8587570601905299, 'cb_weight': 0.6471103441013853, 'lgbm_weight': 0.7740363638327411, 'hgb_weight': 0.9995195944215831, 'gb_weight': 0.055047401618707165, 'rf_weight': 0.44329937745288106}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,455] Trial 992 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.12607627348490108, 'cb_weight': 0.5211553982084995, 'lgbm_weight': 0.802451165131416, 'hgb_weight': 0.9706610872139564, 'gb_weight': 0.0012140862844313206, 'rf_weight': 0.46684197732472826}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,583] Trial 993 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.040942794728976765, 'cb_weight': 0.593920045147275, 'lgbm_weight': 0.7452678754180386, 'hgb_weight': 0.9288107613995268, 'gb_weight': 0.030594515017649475, 'rf_weight': 0.4877443997708254}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,709] Trial 994 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.06699138097611969, 'cb_weight': 0.5423958525851634, 'lgbm_weight': 0.7671771860706178, 'hgb_weight': 0.9522624447803405, 'gb_weight': 0.04233280474675844, 'rf_weight': 0.46481585823321914}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,835] Trial 995 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.017380034002934745, 'cb_weight': 0.6228767567729254, 'lgbm_weight': 0.8178020865480167, 'hgb_weight': 0.966382811593409, 'gb_weight': 0.05692171209141669, 'rf_weight': 0.5006654997632074}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:24,962] Trial 996 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.04176284540436099, 'cb_weight': 0.5784879236265505, 'lgbm_weight': 0.7866891104909585, 'hgb_weight': 0.9245835695278505, 'gb_weight': 0.022170698906738326, 'rf_weight': 0.4767799458124171}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:25,094] Trial 997 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.08475336347604435, 'cb_weight': 0.7203241785285923, 'lgbm_weight': 0.730559790305066, 'hgb_weight': 0.9809757790187307, 'gb_weight': 0.059966200356742085, 'rf_weight': 0.44677621054069316}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:25,220] Trial 998 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.058011013944059796, 'cb_weight': 0.4801274517134475, 'lgbm_weight': 0.7551862614743952, 'hgb_weight': 0.9478898424575273, 'gb_weight': 0.019407918106452954, 'rf_weight': 0.5065121091277044}. Best is trial 779 with value: 0.8347970412190596.
# [I 2024-06-12 09:35:25,344] Trial 999 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.03213798985683694, 'cb_weight': 0.5647209439356526, 'lgbm_weight': 0.7796228903739191, 'hgb_weight': 0.9182867823697011, 'gb_weight': 0.04134500719467103, 'rf_weight': 0.48471694636635604}. Best is trial 779 with value: 0.8347970412190596.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835337, AUC: 0.930924
# --- Fold 2 - Accuracy: 0.836971, AUC: 0.932571
# --- Fold 3 - Accuracy: 0.835141, AUC: 0.930246
# --- Fold 4 - Accuracy: 0.834869, AUC: 0.930396
# --- Fold 5 - Accuracy: 0.826766, AUC: 0.925314
#
# ------ Accuracy: 0.833817 ± 0.003601
# ------ AUC:      0.929890 ± 0.002432

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.836121, AUC: 0.930907
# --- Fold 2 - Accuracy: 0.836644, AUC: 0.932451
# --- Fold 3 - Accuracy: 0.836709, AUC: 0.930263
# --- Fold 4 - Accuracy: 0.835261, AUC: 0.930290
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.925381
#
# ------ Accuracy: 0.834274 ± 0.003854
# ------ AUC:      0.929858 ± 0.002375

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
