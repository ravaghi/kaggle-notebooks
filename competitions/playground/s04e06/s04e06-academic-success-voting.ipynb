# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

# LGBM parameters from https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
lgbm_dart_params = {
    'verbose': -1,
    'num_leaves': 11, 
    'n_estimators': 386, 
    'random_state': SEED,
    'min_child_samples': 14,
    'boosting_type': 'dart',
    'reg_lambda': 198.978101237303,
    'learning_rate': 0.4927780573536302, 
    'colsample_bytree': 0.3405129756925218, 
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
lgbm_dart_model = LGBMClassifier(**lgbm_dart_params)
lgbm_dart_model, lgbm_dart_oof_pred_probs, lgbm_dart_oof_preds, lgbm_dart_accs, lgbm_dart_aucs = Trainer(lgbm_dart_model).fit(X, y)
oof_pred_probs['LGBM_DART'] = lgbm_dart_oof_pred_probs
oof_preds['LGBM_DART'] = lgbm_dart_oof_preds
test_pred_probs['LGBM_DART'] = lgbm_dart_model.predict_proba(test)
accuracies['LGBM_DART'] = lgbm_dart_accs
aucs['LGBM_DART'] = lgbm_dart_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837167, AUC: 0.931191
# --- Fold 2 - Accuracy: 0.834749, AUC: 0.932568
# --- Fold 3 - Accuracy: 0.836775, AUC: 0.930266
# --- Fold 4 - Accuracy: 0.833627, AUC: 0.930039
# --- Fold 5 - Accuracy: 0.827812, AUC: 0.924803
#
# ------ Accuracy: 0.834026 ± 0.003368
# ------ AUC:      0.929774 ± 0.002639

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('LGBM_DART', lgbm_dart_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    lgbm_dart_weight = trial.suggest_float('lgbm_dart_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight,
        lgbm_dart_weight,
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


sampler = TPESampler(seed=SEED)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=1000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'lgbm_dart', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-15 15:05:45,193] A new study created in memory with name: no-name-23216479-3591-41ef-84d0-772c4a3cf93a
# [I 2024-06-15 15:05:45,210] Trial 0 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.4257214105188958, 'cb_weight': 0.8145837404945526, 'lgbm_weight': 0.7353972901996796, 'lgbm_dart_weight': 0.8680031998797357, 'hgb_weight': 0.3833807728726202, 'gb_weight': 0.9794566321445206, 'rf_weight': 0.8931943467151353}. Best is trial 0 with value: 0.8340521184557882.
# [I 2024-06-15 15:05:45,225] Trial 1 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.20971516975437543, 'cb_weight': 0.7418276474127408, 'lgbm_weight': 0.6631433191297429, 'lgbm_dart_weight': 0.8868014614919371, 'hgb_weight': 0.8580127121355462, 'gb_weight': 0.7492622137435189, 'rf_weight': 0.8701447200552547}. Best is trial 0 with value: 0.8340521184557882.
# [I 2024-06-15 15:05:45,240] Trial 2 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.18675584347141305, 'cb_weight': 0.325566716994249, 'lgbm_weight': 0.3729374349544643, 'lgbm_dart_weight': 0.7937130250836765, 'hgb_weight': 0.15106026954808938, 'gb_weight': 0.16994269903780979, 'rf_weight': 0.08116909294984564}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,256] Trial 3 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.30517534166979365, 'cb_weight': 0.7832898018188742, 'lgbm_weight': 0.16290618197894668, 'lgbm_dart_weight': 0.07064129588532642, 'hgb_weight': 0.701071172891538, 'gb_weight': 0.18097987910036895, 'rf_weight': 0.5989172503787585}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,271] Trial 4 finished with value: 0.8340651872761965 and parameters: {'xgb_weight': 0.41526364919539516, 'cb_weight': 0.5135722490632681, 'lgbm_weight': 0.22065617294616224, 'lgbm_dart_weight': 0.7255730076351293, 'hgb_weight': 0.8494349483095229, 'gb_weight': 0.9288928280136141, 'rf_weight': 0.7359400395657129}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,287] Trial 5 finished with value: 0.8341828066598709 and parameters: {'xgb_weight': 0.4765872407403199, 'cb_weight': 0.4928929732595768, 'lgbm_weight': 0.5945202717681869, 'lgbm_dart_weight': 0.07603696537169113, 'hgb_weight': 0.11747691934552718, 'gb_weight': 0.9664656660240684, 'rf_weight': 0.5833222904330377}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,303] Trial 6 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.0924219138777983, 'cb_weight': 0.013629501631003293, 'lgbm_weight': 0.8369301084678846, 'lgbm_dart_weight': 0.9147878993953196, 'hgb_weight': 0.7045862607036278, 'gb_weight': 0.38700659769417056, 'rf_weight': 0.705693904972807}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,319] Trial 7 finished with value: 0.8338691549700724 and parameters: {'xgb_weight': 0.9233111565425577, 'cb_weight': 0.28815289454812154, 'lgbm_weight': 0.6840198457708746, 'lgbm_dart_weight': 0.5202924997698993, 'hgb_weight': 0.8773657752485579, 'gb_weight': 0.9238893110931801, 'rf_weight': 0.4892301565307503}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,334] Trial 8 finished with value: 0.8339737055333386 and parameters: {'xgb_weight': 0.5962139627641655, 'cb_weight': 0.2642754157843866, 'lgbm_weight': 0.9917108968630512, 'lgbm_dart_weight': 0.21039796338844785, 'hgb_weight': 0.5833700814446411, 'gb_weight': 0.6488999511171065, 'rf_weight': 0.910971210191259}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,350] Trial 9 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.12165793024523441, 'cb_weight': 0.6758213297659811, 'lgbm_weight': 0.7547514055074249, 'lgbm_dart_weight': 0.9105353698560246, 'hgb_weight': 0.2416879299437812, 'gb_weight': 0.9755955327544283, 'rf_weight': 0.3037296801778313}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,410] Trial 10 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.697651620720795, 'cb_weight': 0.016344190382097223, 'lgbm_weight': 0.3381023517149757, 'lgbm_dart_weight': 0.541757479293655, 'hgb_weight': 0.014950089590623605, 'gb_weight': 0.13274273239465514, 'rf_weight': 0.006647200787701535}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,473] Trial 11 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.7137469791488825, 'cb_weight': 0.05900834106443624, 'lgbm_weight': 0.3838354882809297, 'lgbm_dart_weight': 0.5488134086670806, 'hgb_weight': 0.01254891820895565, 'gb_weight': 0.0026004996292783578, 'rf_weight': 0.003722522888559454}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,536] Trial 12 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.7921201910785496, 'cb_weight': 0.21356242802674713, 'lgbm_weight': 0.38071774078286347, 'lgbm_dart_weight': 0.675542128895207, 'hgb_weight': 0.26090320513584353, 'gb_weight': 0.2872821994074909, 'rf_weight': 0.007441620814647609}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,597] Trial 13 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.8855190710873319, 'cb_weight': 0.23623054332750332, 'lgbm_weight': 0.042194452388990555, 'lgbm_dart_weight': 0.7252200953177038, 'hgb_weight': 0.32030729919313433, 'gb_weight': 0.38323261226304717, 'rf_weight': 0.20928491175481279}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,660] Trial 14 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.7675534011696579, 'cb_weight': 0.3971847957407728, 'lgbm_weight': 0.46954916394440377, 'lgbm_dart_weight': 0.6938114961961068, 'hgb_weight': 0.20439438261312395, 'gb_weight': 0.273392885859442, 'rf_weight': 0.18844016737153396}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,723] Trial 15 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.016594206067003126, 'cb_weight': 0.43267118986746067, 'lgbm_weight': 0.5076551627070277, 'lgbm_dart_weight': 0.3374021172891254, 'hgb_weight': 0.4758832889402408, 'gb_weight': 0.5072259392293732, 'rf_weight': 0.19083350152666134}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,787] Trial 16 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.58924889846385, 'cb_weight': 0.6112802899853154, 'lgbm_weight': 0.5001825395009152, 'lgbm_dart_weight': 0.37771065192188735, 'hgb_weight': 0.16634935725591604, 'gb_weight': 0.03541661617501868, 'rf_weight': 0.38139752727246035}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,849] Trial 17 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.9976808266486656, 'cb_weight': 0.39409589886813756, 'lgbm_weight': 0.2782170980226235, 'lgbm_dart_weight': 0.6448219488337106, 'hgb_weight': 0.4168267747730878, 'gb_weight': 0.23037881083310452, 'rf_weight': 0.14622184067841518}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,912] Trial 18 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.3315519014128656, 'cb_weight': 0.36650586653610356, 'lgbm_weight': 0.08986618864163087, 'lgbm_dart_weight': 0.7926333266760854, 'hgb_weight': 0.15884836884207587, 'gb_weight': 0.3447447885746169, 'rf_weight': 0.33589556289950373}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:45,978] Trial 19 finished with value: 0.834091324917013 and parameters: {'xgb_weight': 0.5757930205820538, 'cb_weight': 0.9574493392527821, 'lgbm_weight': 0.42249140321852374, 'lgbm_dart_weight': 0.982402872210558, 'hgb_weight': 0.5670454675035568, 'gb_weight': 0.49980211678642567, 'rf_weight': 0.12782643252842565}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,041] Trial 20 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.29446186499027727, 'cb_weight': 0.10597826662944143, 'lgbm_weight': 0.5707706571616917, 'lgbm_dart_weight': 0.4214884289353704, 'hgb_weight': 0.09868606531845849, 'gb_weight': 0.0784660632970221, 'rf_weight': 0.4374924753527845}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,105] Trial 21 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.6035380237425723, 'cb_weight': 0.605099007873885, 'lgbm_weight': 0.4878349311481274, 'lgbm_dart_weight': 0.33217196085865786, 'hgb_weight': 0.21535063301955742, 'gb_weight': 0.0007397129210550135, 'rf_weight': 0.3137130574411029}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,170] Trial 22 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.7693856603707223, 'cb_weight': 0.567685590628439, 'lgbm_weight': 0.47335727241848186, 'lgbm_dart_weight': 0.4092505417455733, 'hgb_weight': 0.15065825470290678, 'gb_weight': 0.1114547329323225, 'rf_weight': 0.1030042577618554}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,236] Trial 23 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.7907451526565253, 'cb_weight': 0.5390731049815972, 'lgbm_weight': 0.2868270497489592, 'lgbm_dart_weight': 0.6076715122556512, 'hgb_weight': 0.30933056973610745, 'gb_weight': 0.13741935403005634, 'rf_weight': 0.09478998979433173}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,299] Trial 24 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.719629829593518, 'cb_weight': 0.35741363941291904, 'lgbm_weight': 0.5791785736141488, 'lgbm_dart_weight': 0.22558235742249338, 'hgb_weight': 0.07829729008704162, 'gb_weight': 0.245367972325, 'rf_weight': 0.19625300266855206}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,365] Trial 25 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.8180202373450167, 'cb_weight': 0.13596941334477775, 'lgbm_weight': 0.44488411065574107, 'lgbm_dart_weight': 0.794270126105317, 'hgb_weight': 0.33877825627059804, 'gb_weight': 0.1218993197868854, 'rf_weight': 0.0700037076961878}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,430] Trial 26 finished with value: 0.833947567892522 and parameters: {'xgb_weight': 0.6688369741963411, 'cb_weight': 0.4394284060596118, 'lgbm_weight': 0.19792648310109795, 'lgbm_dart_weight': 0.4528769453625393, 'hgb_weight': 0.9816808093462899, 'gb_weight': 0.4455713541975022, 'rf_weight': 0.25375139473471986}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,497] Trial 27 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.9978273241980554, 'cb_weight': 0.32249247242663337, 'lgbm_weight': 0.32673790328940255, 'lgbm_dart_weight': 0.8087932242528522, 'hgb_weight': 0.2020246435241682, 'gb_weight': 0.30042562275702256, 'rf_weight': 0.0970002595629708}. Best is trial 2 with value: 0.8348101100394678.
# [I 2024-06-15 15:05:46,565] Trial 28 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.8770977987459164, 'cb_weight': 0.1658204141521582, 'lgbm_weight': 0.5507841595165782, 'lgbm_dart_weight': 0.5946423383619798, 'hgb_weight': 0.06474561239106441, 'gb_weight': 0.20242394626133595, 'rf_weight': 0.24405637960507692}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,631] Trial 29 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.888212359736383, 'cb_weight': 0.15773329775493278, 'lgbm_weight': 0.8624823332398801, 'lgbm_dart_weight': 0.588341990924706, 'hgb_weight': 0.032428748629334425, 'gb_weight': 0.18346273885370434, 'rf_weight': 0.23008511357030892}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,697] Trial 30 finished with value: 0.8338952926108889 and parameters: {'xgb_weight': 0.38521727815812323, 'cb_weight': 0.17787148645526937, 'lgbm_weight': 0.5490553326864673, 'lgbm_dart_weight': 0.7332545288788764, 'hgb_weight': 0.42561757156785124, 'gb_weight': 0.6541736518998695, 'rf_weight': 0.4177641267989072}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,768] Trial 31 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.8754224280553501, 'cb_weight': 0.1399663201311666, 'lgbm_weight': 0.8979441371504557, 'lgbm_dart_weight': 0.5970602677427119, 'hgb_weight': 0.06550971402620516, 'gb_weight': 0.21251392264284324, 'rf_weight': 0.24891319823567135}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,832] Trial 32 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.8907583956483867, 'cb_weight': 0.20096923021045204, 'lgbm_weight': 0.7577039496640077, 'lgbm_dart_weight': 0.6627797127443346, 'hgb_weight': 0.039069612861379215, 'gb_weight': 0.1891671994558879, 'rf_weight': 0.2725488671001577}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,898] Trial 33 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.9492855093426631, 'cb_weight': 0.11230885047130731, 'lgbm_weight': 0.6412281667566059, 'lgbm_dart_weight': 0.4741208677662657, 'hgb_weight': 0.10273914769051078, 'gb_weight': 0.2750512896464752, 'rf_weight': 0.18622511416083973}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:46,963] Trial 34 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.8383730634927951, 'cb_weight': 0.334373490908509, 'lgbm_weight': 0.8539236977707154, 'lgbm_dart_weight': 0.6047714806064456, 'hgb_weight': 0.2429571321250581, 'gb_weight': 0.17188967799065383, 'rf_weight': 0.3662759182161916}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,033] Trial 35 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.5057631807533219, 'cb_weight': 0.2807664470811144, 'lgbm_weight': 0.9656632989124587, 'lgbm_dart_weight': 0.8487363064484323, 'hgb_weight': 0.009875197841422101, 'gb_weight': 0.34344020776766393, 'rf_weight': 0.15995317350433857}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,099] Trial 36 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.21267968277909022, 'cb_weight': 0.4570054614181547, 'lgbm_weight': 0.9441817599977239, 'lgbm_dart_weight': 0.8417423409739966, 'hgb_weight': 0.13207811501430516, 'gb_weight': 0.332769029753897, 'rf_weight': 0.8105489082038322}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,165] Trial 37 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.45910297131711525, 'cb_weight': 0.26243360459631493, 'lgbm_weight': 0.6991247215944475, 'lgbm_dart_weight': 0.9885530880020543, 'hgb_weight': 0.005985737182944559, 'gb_weight': 0.4203875065345368, 'rf_weight': 0.5796389964431516}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,232] Trial 38 finished with value: 0.8335162968190492 and parameters: {'xgb_weight': 0.5122965185253923, 'cb_weight': 0.32122138186347526, 'lgbm_weight': 0.11940721073881422, 'lgbm_dart_weight': 0.7115075853458372, 'hgb_weight': 0.19562051145556542, 'gb_weight': 0.3534909803004066, 'rf_weight': 0.9846199330306256}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,299] Trial 39 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.18287916137118376, 'cb_weight': 0.4894286943592204, 'lgbm_weight': 0.24779518205111728, 'lgbm_dart_weight': 0.8627663058373811, 'hgb_weight': 0.28604834396531487, 'gb_weight': 0.0631320573088692, 'rf_weight': 0.0661747041586381}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,366] Trial 40 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.5265420079808009, 'cb_weight': 0.41089647692181214, 'lgbm_weight': 0.7977153950983149, 'lgbm_dart_weight': 0.7613692106140438, 'hgb_weight': 0.7001845557317312, 'gb_weight': 0.5311067317309537, 'rf_weight': 0.1584943597301931}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,432] Trial 41 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.6510880253462827, 'cb_weight': 0.2835930009531315, 'lgbm_weight': 0.9816356348411504, 'lgbm_dart_weight': 0.9297931348584668, 'hgb_weight': 0.07813465662093666, 'gb_weight': 0.252757998665619, 'rf_weight': 0.23010059654249979}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,502] Trial 42 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.6505939045007606, 'cb_weight': 0.28970834616291796, 'lgbm_weight': 0.9084380498735024, 'lgbm_dart_weight': 0.9203288156113965, 'hgb_weight': 0.06794266595618659, 'gb_weight': 0.26628498347664065, 'rf_weight': 0.28979918892114553}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,568] Trial 43 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.6470173948197498, 'cb_weight': 0.23594627696272075, 'lgbm_weight': 0.9354638112321291, 'lgbm_dart_weight': 0.9169407021463141, 'hgb_weight': 0.07609298454157974, 'gb_weight': 0.25132243980816793, 'rf_weight': 0.2862732692709497}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,636] Trial 44 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.6595075151120806, 'cb_weight': 0.06053695320929636, 'lgbm_weight': 0.9181482647792989, 'lgbm_dart_weight': 0.9288147992773906, 'hgb_weight': 0.07059405644545184, 'gb_weight': 0.8200060337029303, 'rf_weight': 0.5139979720711044}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,704] Trial 45 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.6277939407780107, 'cb_weight': 0.26703828841668314, 'lgbm_weight': 0.8047774964525756, 'lgbm_dart_weight': 0.9310823936266504, 'hgb_weight': 0.13092126883135397, 'gb_weight': 0.23533968605999397, 'rf_weight': 0.28943010254594964}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,772] Trial 46 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.38697409287317586, 'cb_weight': 0.21494189443451867, 'lgbm_weight': 0.9850068495746851, 'lgbm_dart_weight': 0.8839449309880586, 'hgb_weight': 0.05849404759722811, 'gb_weight': 0.14887812920222265, 'rf_weight': 0.3505497810013357}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,840] Trial 47 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.7022630202360893, 'cb_weight': 0.08487751672587324, 'lgbm_weight': 0.923150667724292, 'lgbm_dart_weight': 0.9573299289370557, 'hgb_weight': 0.12294966107532943, 'gb_weight': 0.08725697879874718, 'rf_weight': 0.5015177064585205}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,908] Trial 48 finished with value: 0.8341958754802792 and parameters: {'xgb_weight': 0.5501609765138582, 'cb_weight': 0.23770746033543727, 'lgbm_weight': 0.6342172469710793, 'lgbm_dart_weight': 0.0021444576594700226, 'hgb_weight': 0.17017946401298434, 'gb_weight': 0.2986812899576542, 'rf_weight': 0.4361814946768079}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:47,975] Trial 49 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.7425568214849029, 'cb_weight': 0.1690855336563581, 'lgbm_weight': 0.9955169645188738, 'lgbm_dart_weight': 0.9057248023443968, 'hgb_weight': 0.09283179237683946, 'gb_weight': 0.40900045506756433, 'rf_weight': 0.04151837807598158}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:48,042] Trial 50 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.6375424008568253, 'cb_weight': 0.30751139293272756, 'lgbm_weight': 0.8932544622052463, 'lgbm_dart_weight': 0.9987269299375173, 'hgb_weight': 0.371576327187532, 'gb_weight': 0.4680367750199801, 'rf_weight': 0.40031299558575806}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:48,110] Trial 51 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.7436219913781745, 'cb_weight': 0.3746740317263861, 'lgbm_weight': 0.3706016545563242, 'lgbm_dart_weight': 0.8259804421299876, 'hgb_weight': 0.20198110807376207, 'gb_weight': 0.26061400426549874, 'rf_weight': 0.3004701201066746}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:48,177] Trial 52 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.8382685268990924, 'cb_weight': 0.2303400995545223, 'lgbm_weight': 0.5359095806261036, 'lgbm_dart_weight': 0.7719435913667785, 'hgb_weight': 0.26901807336393346, 'gb_weight': 0.20966762870033057, 'rf_weight': 0.23134037453758524}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:48,246] Trial 53 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.6761199919249247, 'cb_weight': 0.39543586538161885, 'lgbm_weight': 0.8749118540333105, 'lgbm_dart_weight': 0.7064494855056563, 'hgb_weight': 0.16896481345916223, 'gb_weight': 0.5733084032399328, 'rf_weight': 0.13561628576806292}. Best is trial 28 with value: 0.8348885229619175.
# [I 2024-06-15 15:05:48,312] Trial 54 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.9427776180333955, 'cb_weight': 0.3452377927239152, 'lgbm_weight': 0.41383518471434516, 'lgbm_dart_weight': 0.8869334465918026, 'hgb_weight': 0.04424505269525009, 'gb_weight': 0.30446162793150944, 'rf_weight': 0.3290794494490596}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,378] Trial 55 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.46053310166545014, 'cb_weight': 0.34668399827642626, 'lgbm_weight': 0.41784094186400184, 'lgbm_dart_weight': 0.892882460381216, 'hgb_weight': 0.04483644638065972, 'gb_weight': 0.31265292925930954, 'rf_weight': 0.3305413307436257}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,447] Trial 56 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.01515974770743922, 'cb_weight': 0.289613568265887, 'lgbm_weight': 0.8181042017120226, 'lgbm_dart_weight': 0.9408568954385331, 'hgb_weight': 0.10868023062439316, 'gb_weight': 0.3702651078025446, 'rf_weight': 0.4724033875748396}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,516] Trial 57 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.9442567268723496, 'cb_weight': 0.8589339415888523, 'lgbm_weight': 0.9476047833992477, 'lgbm_dart_weight': 0.8661960846506213, 'hgb_weight': 0.04543729092095973, 'gb_weight': 0.2591842138775397, 'rf_weight': 0.291891428347137}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,585] Trial 58 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.9594230289543375, 'cb_weight': 0.19068703733399367, 'lgbm_weight': 0.7314541632938804, 'lgbm_dart_weight': 0.9647836102327507, 'hgb_weight': 0.08324752826398721, 'gb_weight': 0.15824241897541236, 'rf_weight': 0.6868873872551562}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,652] Trial 59 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.27714438593923274, 'cb_weight': 0.4781443829517607, 'lgbm_weight': 0.3479041657657904, 'lgbm_dart_weight': 0.9052287859829855, 'hgb_weight': 0.7826880340536089, 'gb_weight': 0.21003285596116517, 'rf_weight': 0.21382774131361093}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,722] Trial 60 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.5578916925451831, 'cb_weight': 0.24856718624162738, 'lgbm_weight': 0.31828979671896407, 'lgbm_dart_weight': 0.7668680885703913, 'hgb_weight': 0.5284747091218609, 'gb_weight': 0.04327123277693018, 'rf_weight': 0.046984177980350816}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,789] Trial 61 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.7911004735985679, 'cb_weight': 0.37362813198464195, 'lgbm_weight': 0.46129984177762157, 'lgbm_dart_weight': 0.8298944001768511, 'hgb_weight': 0.23038862045758612, 'gb_weight': 0.10289509680890285, 'rf_weight': 0.2630305055447473}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,859] Trial 62 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.754830638991032, 'cb_weight': 0.4248504030352713, 'lgbm_weight': 0.5189818102255818, 'lgbm_dart_weight': 0.6769491819981954, 'hgb_weight': 0.15092098144934685, 'gb_weight': 0.28999361562471504, 'rf_weight': 0.1622466676008838}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,927] Trial 63 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.07666965333155021, 'cb_weight': 0.30593884524295634, 'lgbm_weight': 0.29670639113599273, 'lgbm_dart_weight': 0.5360079531609078, 'hgb_weight': 0.0037810750506582363, 'gb_weight': 0.24477463627332366, 'rf_weight': 0.18498973681684477}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:48,994] Trial 64 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.6138877804154006, 'cb_weight': 0.3450161523457084, 'lgbm_weight': 0.4176943108312345, 'lgbm_dart_weight': 0.6365748677753092, 'hgb_weight': 0.12006132180205749, 'gb_weight': 0.1903954499036685, 'rf_weight': 0.32299266775509794}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:49,066] Trial 65 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.5833775125274364, 'cb_weight': 0.021258756784051536, 'lgbm_weight': 0.3887662984907882, 'lgbm_dart_weight': 0.6389657472067963, 'hgb_weight': 0.124037689751343, 'gb_weight': 0.1324943838062198, 'rf_weight': 0.3667958592791478}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:49,135] Trial 66 finished with value: 0.8346140777333438 and parameters: {'xgb_weight': 0.6089332505691369, 'cb_weight': 0.21053996739962152, 'lgbm_weight': 0.4214801119058174, 'lgbm_dart_weight': 0.5711863256630973, 'hgb_weight': 0.07546480600578656, 'gb_weight': 0.18891596373554254, 'rf_weight': 0.39682885262945}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:49,203] Trial 67 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.9157009533245074, 'cb_weight': 0.3446125924373004, 'lgbm_weight': 0.6021870151117119, 'lgbm_dart_weight': 0.747644918842021, 'hgb_weight': 0.0347776307669641, 'gb_weight': 0.21206792890751966, 'rf_weight': 0.3191482253026046}. Best is trial 54 with value: 0.8349407982435505.
# [I 2024-06-15 15:05:49,273] Trial 68 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.850757843724355, 'cb_weight': 0.28571758956378696, 'lgbm_weight': 0.6043527519769345, 'lgbm_dart_weight': 0.7412063110657143, 'hgb_weight': 0.0358590639491153, 'gb_weight': 0.32698713139943525, 'rf_weight': 0.31953046533407214}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,342] Trial 69 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.9151169654310077, 'cb_weight': 0.14355366149343968, 'lgbm_weight': 0.5842776058032022, 'lgbm_dart_weight': 0.7431159727642309, 'hgb_weight': 0.03546280637967831, 'gb_weight': 0.3214837237725882, 'rf_weight': 0.45896303540336025}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,411] Trial 70 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.8598015979883373, 'cb_weight': 0.5298424435019209, 'lgbm_weight': 0.6156563302056582, 'lgbm_dart_weight': 0.9542226218689439, 'hgb_weight': 0.022462151070573158, 'gb_weight': 0.38944280108989376, 'rf_weight': 0.27391504773066244}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,481] Trial 71 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.8410318666029994, 'cb_weight': 0.6953399850741526, 'lgbm_weight': 0.6069351882287055, 'lgbm_dart_weight': 0.9569133051453218, 'hgb_weight': 0.020711144245949095, 'gb_weight': 0.36291219305733663, 'rf_weight': 0.24280732494289126}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,550] Trial 72 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.9694077703720521, 'cb_weight': 0.5419895291848538, 'lgbm_weight': 0.6923923169090295, 'lgbm_dart_weight': 0.8807303248983868, 'hgb_weight': 0.0602706800006263, 'gb_weight': 0.4180584923546876, 'rf_weight': 0.33628743440690223}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,617] Trial 73 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.9166421288423214, 'cb_weight': 0.5299137621142291, 'lgbm_weight': 0.6658308441295588, 'lgbm_dart_weight': 0.7983532918457347, 'hgb_weight': 0.04764482222114685, 'gb_weight': 0.4308998165924845, 'rf_weight': 0.3302219310883196}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,688] Trial 74 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.9711072826196893, 'cb_weight': 0.6005124829901523, 'lgbm_weight': 0.6850137673409737, 'lgbm_dart_weight': 0.780702984771817, 'hgb_weight': 0.0021934178159010304, 'gb_weight': 0.46472344039996594, 'rf_weight': 0.3407194503377446}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,759] Trial 75 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.9855007688869145, 'cb_weight': 0.6044952274557804, 'lgbm_weight': 0.6665891030187345, 'lgbm_dart_weight': 0.804308064994669, 'hgb_weight': 0.044768178259586976, 'gb_weight': 0.46684090853874977, 'rf_weight': 0.37960983688822764}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,832] Trial 76 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.9132705206191691, 'cb_weight': 0.5673302259700684, 'lgbm_weight': 0.7066614920315651, 'lgbm_dart_weight': 0.7816570848368959, 'hgb_weight': 0.004473113089699762, 'gb_weight': 0.44532937948132306, 'rf_weight': 0.3419900436084309}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:49,914] Trial 77 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.9753347292261098, 'cb_weight': 0.6563886615220187, 'lgbm_weight': 0.7605839386198632, 'lgbm_dart_weight': 0.7492237675194068, 'hgb_weight': 0.09853026421168833, 'gb_weight': 0.5644997750602206, 'rf_weight': 0.5337115720624778}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,004] Trial 78 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.9248522163136834, 'cb_weight': 0.6475838586922995, 'lgbm_weight': 0.5568799642463474, 'lgbm_dart_weight': 0.8196313248012044, 'hgb_weight': 0.6277831278242594, 'gb_weight': 0.40760895615336606, 'rf_weight': 0.42154957919909536}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,083] Trial 79 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.8973262356629363, 'cb_weight': 0.5519109676557321, 'lgbm_weight': 0.6455931180269211, 'lgbm_dart_weight': 0.8737124095258012, 'hgb_weight': 0.054964861189552724, 'gb_weight': 0.43542793000441193, 'rf_weight': 0.35973631052497324}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,159] Trial 80 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.8147531753608829, 'cb_weight': 0.4523363912494204, 'lgbm_weight': 0.6797073007727611, 'lgbm_dart_weight': 0.8492489635821363, 'hgb_weight': 0.18244169697554835, 'gb_weight': 0.5001774726207634, 'rf_weight': 0.3122821781140022}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,231] Trial 81 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.950730241803274, 'cb_weight': 0.507641657771527, 'lgbm_weight': 0.7124375734852517, 'lgbm_dart_weight': 0.7965938323646377, 'hgb_weight': 0.1474246955659319, 'gb_weight': 0.3900059397566522, 'rf_weight': 0.21474569918610587}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,309] Trial 82 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.8654859252446714, 'cb_weight': 0.5867142573711929, 'lgbm_weight': 0.6132233138918891, 'lgbm_dart_weight': 0.7264988787823893, 'hgb_weight': 0.06736831079222823, 'gb_weight': 0.3279254411075381, 'rf_weight': 0.2599648192065309}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,390] Trial 83 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.9349966975156674, 'cb_weight': 0.622735743269312, 'lgbm_weight': 0.780294291602667, 'lgbm_dart_weight': 0.6836519035221357, 'hgb_weight': 8.935117941376303e-05, 'gb_weight': 0.28091021203891736, 'rf_weight': 0.32640365470386684}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,464] Trial 84 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.9823278990043062, 'cb_weight': 0.5231223610920127, 'lgbm_weight': 0.5273121048167699, 'lgbm_dart_weight': 0.8820423569081693, 'hgb_weight': 0.09438295157778687, 'gb_weight': 0.4823825187528459, 'rf_weight': 0.3000739742848426}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,536] Trial 85 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.9075161857600192, 'cb_weight': 0.7691635604439943, 'lgbm_weight': 0.5731105322815327, 'lgbm_dart_weight': 0.8450616124291809, 'hgb_weight': 0.030109716937376668, 'gb_weight': 0.5414164151608336, 'rf_weight': 0.40102193385354495}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,610] Trial 86 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.8133028001575908, 'cb_weight': 0.4857906489973982, 'lgbm_weight': 0.7317330548867079, 'lgbm_dart_weight': 0.4886575197720995, 'hgb_weight': 0.06266705227971976, 'gb_weight': 0.2234702379670898, 'rf_weight': 0.3496505077469382}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,681] Trial 87 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.9695385811220395, 'cb_weight': 0.28827567465736276, 'lgbm_weight': 0.48477068851887284, 'lgbm_dart_weight': 0.9248103743259225, 'hgb_weight': 0.10784733216346835, 'gb_weight': 0.6158714167324629, 'rf_weight': 0.2425991961752692}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,753] Trial 88 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.876596320960353, 'cb_weight': 0.6949413113208835, 'lgbm_weight': 0.6490944021312567, 'lgbm_dart_weight': 0.8195984123981814, 'hgb_weight': 0.13876678649260638, 'gb_weight': 0.34740894207080153, 'rf_weight': 0.38708475894701716}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,827] Trial 89 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.8535354691072302, 'cb_weight': 0.4111727289546192, 'lgbm_weight': 0.6756470495040799, 'lgbm_dart_weight': 0.23431787328938503, 'hgb_weight': 0.035025056755560786, 'gb_weight': 0.30346806650313607, 'rf_weight': 0.27994254460839607}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,901] Trial 90 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.942807094884448, 'cb_weight': 0.32307105741589015, 'lgbm_weight': 0.5085967154413318, 'lgbm_dart_weight': 0.7063764560800303, 'hgb_weight': 0.08406608118809336, 'gb_weight': 0.4198699832858445, 'rf_weight': 0.2121388534927633}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:50,973] Trial 91 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.9994497469953015, 'cb_weight': 0.32400552690005013, 'lgbm_weight': 0.5564960436538617, 'lgbm_dart_weight': 0.6579659157380859, 'hgb_weight': 0.07104375230111747, 'gb_weight': 0.4144064073176997, 'rf_weight': 0.11981163314236098}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,052] Trial 92 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.9373023123868706, 'cb_weight': 0.26241719651289874, 'lgbm_weight': 0.49811742091560035, 'lgbm_dart_weight': 0.6986731959742913, 'hgb_weight': 0.0879562922956295, 'gb_weight': 0.3712787723235712, 'rf_weight': 0.22089315871330079}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,130] Trial 93 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.8962293611480222, 'cb_weight': 0.3778034537432915, 'lgbm_weight': 0.6291418106956138, 'lgbm_dart_weight': 0.7836339996237001, 'hgb_weight': 0.05399399767500856, 'gb_weight': 0.43625262389765196, 'rf_weight': 0.19212382851810147}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,205] Trial 94 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.9576780249748805, 'cb_weight': 0.35617158534215426, 'lgbm_weight': 0.5890160064975513, 'lgbm_dart_weight': 0.7501342112432822, 'hgb_weight': 0.02424737490320151, 'gb_weight': 0.5232310402953432, 'rf_weight': 0.31587377563496327}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,278] Trial 95 finished with value: 0.8337907420476228 and parameters: {'xgb_weight': 0.9619046008925779, 'cb_weight': 0.3130998880945623, 'lgbm_weight': 0.5909804631184392, 'lgbm_dart_weight': 0.722173775592603, 'hgb_weight': 0.9857317063083328, 'gb_weight': 0.520531119711887, 'rf_weight': 0.30895801133273465}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,351] Trial 96 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.9339172083378692, 'cb_weight': 0.44675902786644145, 'lgbm_weight': 0.5406252876859883, 'lgbm_dart_weight': 0.7526599306312939, 'hgb_weight': 0.021171089451762402, 'gb_weight': 0.5558676278566633, 'rf_weight': 0.3505753489291764}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,423] Trial 97 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.8796069807751771, 'cb_weight': 0.46505316934045, 'lgbm_weight': 0.4510740057230648, 'lgbm_dart_weight': 0.6227981417659454, 'hgb_weight': 0.10559752130332362, 'gb_weight': 0.6199093581958366, 'rf_weight': 0.4390311280928031}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,497] Trial 98 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.966317903823545, 'cb_weight': 0.5771665780464135, 'lgbm_weight': 0.00317799300608268, 'lgbm_dart_weight': 0.5771789008973002, 'hgb_weight': 0.0003164042940880449, 'gb_weight': 0.4664305445037309, 'rf_weight': 0.33081889550700805}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,569] Trial 99 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.9181986064977844, 'cb_weight': 0.4251063204296498, 'lgbm_weight': 0.5104483561376851, 'lgbm_dart_weight': 0.7716575953976041, 'hgb_weight': 0.049383852121063276, 'gb_weight': 0.5834466328026308, 'rf_weight': 0.2610160148196509}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,640] Trial 100 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.9510479901756488, 'cb_weight': 0.36278670704986077, 'lgbm_weight': 0.5982148541357991, 'lgbm_dart_weight': 0.7085876791071419, 'hgb_weight': 0.024372074220472, 'gb_weight': 0.4944486253106115, 'rf_weight': 0.29505379390162983}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,710] Trial 101 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.9432823207629855, 'cb_weight': 0.35644457007238267, 'lgbm_weight': 0.5610154705908162, 'lgbm_dart_weight': 0.6935475757938594, 'hgb_weight': 0.02895622701040287, 'gb_weight': 0.49003678970008924, 'rf_weight': 0.3735621150002682}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,781] Trial 102 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.8972906144831085, 'cb_weight': 0.38902182814069525, 'lgbm_weight': 0.5913232340416269, 'lgbm_dart_weight': 0.7319511149012227, 'hgb_weight': 0.02326235550853711, 'gb_weight': 0.5269725293491548, 'rf_weight': 0.2788933065658572}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,853] Trial 103 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.8329609119425057, 'cb_weight': 0.39339019163317374, 'lgbm_weight': 0.5992983343561179, 'lgbm_dart_weight': 0.7276481228973075, 'hgb_weight': 0.025637320820161874, 'gb_weight': 0.5204521392681077, 'rf_weight': 0.28958747676995394}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,924] Trial 104 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.8928491518916135, 'cb_weight': 0.5061308007793925, 'lgbm_weight': 0.6521495448074226, 'lgbm_dart_weight': 0.6625706683886827, 'hgb_weight': 0.05291982502644853, 'gb_weight': 0.6976795795949697, 'rf_weight': 0.313418267056577}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:51,995] Trial 105 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.9942506894332122, 'cb_weight': 0.5460129544796142, 'lgbm_weight': 0.6181252887147077, 'lgbm_dart_weight': 0.8054601535326522, 'hgb_weight': 0.11980565009603647, 'gb_weight': 0.4540231493569672, 'rf_weight': 0.4105335703713662}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,066] Trial 106 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.8662431418964399, 'cb_weight': 0.3563471166310925, 'lgbm_weight': 0.6982196636604769, 'lgbm_dart_weight': 0.8596011438576455, 'hgb_weight': 0.019570277618879126, 'gb_weight': 0.5399821125807422, 'rf_weight': 0.33943491100640694}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,137] Trial 107 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.9223694258421451, 'cb_weight': 0.33951677598142666, 'lgbm_weight': 0.5895780297935743, 'lgbm_dart_weight': 0.7453686220273605, 'hgb_weight': 0.06587223557050113, 'gb_weight': 0.4826118781132534, 'rf_weight': 0.271463794156065}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,206] Trial 108 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.9622949074067053, 'cb_weight': 0.2920230863867954, 'lgbm_weight': 0.6317347019843949, 'lgbm_dart_weight': 0.9034020133866095, 'hgb_weight': 0.04334872376630668, 'gb_weight': 0.5905177467456135, 'rf_weight': 0.24727103819676632}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,277] Trial 109 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.7874477616364396, 'cb_weight': 0.40342738175609333, 'lgbm_weight': 0.6899299628985883, 'lgbm_dart_weight': 0.8307630015940464, 'hgb_weight': 0.09440123760374962, 'gb_weight': 0.510051177342931, 'rf_weight': 0.3040381408883102}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,349] Trial 110 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.9001558618816428, 'cb_weight': 0.2641846338165345, 'lgbm_weight': 0.6654662384256602, 'lgbm_dart_weight': 0.7629709620256909, 'hgb_weight': 0.9497625754877428, 'gb_weight': 0.39826849942953746, 'rf_weight': 0.3725282741199407}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,421] Trial 111 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.9783341625070632, 'cb_weight': 0.3312173221992293, 'lgbm_weight': 0.5301666576003351, 'lgbm_dart_weight': 0.7170372918403227, 'hgb_weight': 0.08508338055028075, 'gb_weight': 0.4172513612466856, 'rf_weight': 0.17279797875220426}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,495] Trial 112 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.9332127437312829, 'cb_weight': 0.37917799987072676, 'lgbm_weight': 0.5457872575535977, 'lgbm_dart_weight': 0.7930288178100943, 'hgb_weight': 0.00025250772106231653, 'gb_weight': 0.27161428316941666, 'rf_weight': 0.21031526847357512}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,567] Trial 113 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.9484900787250232, 'cb_weight': 0.307701812039378, 'lgbm_weight': 0.48135206650731044, 'lgbm_dart_weight': 0.7420715070154122, 'hgb_weight': 0.038705378991710775, 'gb_weight': 0.45811530176613535, 'rf_weight': 0.324596309036947}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,639] Trial 114 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.9104031457295113, 'cb_weight': 0.4694569574059442, 'lgbm_weight': 0.5755276814312167, 'lgbm_dart_weight': 0.7059640189179054, 'hgb_weight': 0.0829075383189191, 'gb_weight': 0.42535970555108066, 'rf_weight': 0.27961949439542877}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,711] Trial 115 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.8469713996500157, 'cb_weight': 0.42663875280193975, 'lgbm_weight': 0.5971302045647449, 'lgbm_dart_weight': 0.6194707092297832, 'hgb_weight': 0.016456716630478402, 'gb_weight': 0.3720415172578534, 'rf_weight': 0.24100663793408633}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,783] Trial 116 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.8440641071872856, 'cb_weight': 0.4311687191385445, 'lgbm_weight': 0.6014375374298214, 'lgbm_dart_weight': 0.6736750791370241, 'hgb_weight': 0.023611340813621016, 'gb_weight': 0.3356073386383202, 'rf_weight': 0.23903703394707962}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,857] Trial 117 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.8846264941936877, 'cb_weight': 0.3861477056772966, 'lgbm_weight': 0.627549723477238, 'lgbm_dart_weight': 0.5245306530700891, 'hgb_weight': 0.05934160405920601, 'gb_weight': 0.3799626192640342, 'rf_weight': 0.29098636787163323}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:52,930] Trial 118 finished with value: 0.8346663530149768 and parameters: {'xgb_weight': 0.818315875537665, 'cb_weight': 0.41521291333408084, 'lgbm_weight': 0.7472959380121994, 'lgbm_dart_weight': 0.9790232827866381, 'hgb_weight': 0.4262843170758077, 'gb_weight': 0.2325099427134483, 'rf_weight': 0.3578337655462303}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:53,007] Trial 119 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.8746536195895479, 'cb_weight': 0.3657426359738111, 'lgbm_weight': 0.6523793767896329, 'lgbm_dart_weight': 0.616993835459565, 'hgb_weight': 0.12955444052539244, 'gb_weight': 0.3129940281260578, 'rf_weight': 0.26889893792070946}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:53,081] Trial 120 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.7808101603936737, 'cb_weight': 0.11614353707679645, 'lgbm_weight': 0.7262344529544681, 'lgbm_dart_weight': 0.5594135723954058, 'hgb_weight': 0.013861675241546176, 'gb_weight': 0.35543354944425704, 'rf_weight': 0.3223877314443691}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:53,154] Trial 121 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.8532521352113102, 'cb_weight': 0.4468655307432695, 'lgbm_weight': 0.6054131923283841, 'lgbm_dart_weight': 0.6716417231432465, 'hgb_weight': 0.02051780026736178, 'gb_weight': 0.33773933262519645, 'rf_weight': 0.2396769216763285}. Best is trial 68 with value: 0.8350192111660002.
# [I 2024-06-15 15:05:53,249] Trial 122 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.8324738685972702, 'cb_weight': 0.4323435745336707, 'lgbm_weight': 0.5677964497142006, 'lgbm_dart_weight': 0.6410174093203191, 'hgb_weight': 0.040833883996541816, 'gb_weight': 0.2904429308790298, 'rf_weight': 0.2517620393174352}. Best is trial 68 with value: 0.8350192111660002.
# ...
# [I 2024-06-15 15:07:17,485] Trial 960 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.8924035176114439, 'cb_weight': 0.3697435986384145, 'lgbm_weight': 0.09879820233647851, 'lgbm_dart_weight': 0.7502697666249123, 'hgb_weight': 0.09994391405482395, 'gb_weight': 0.37148216286359576, 'rf_weight': 0.35496280466067914}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:17,613] Trial 961 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.9301867927423583, 'cb_weight': 0.4193980291328392, 'lgbm_weight': 0.5780358511408473, 'lgbm_dart_weight': 0.6814844908562242, 'hgb_weight': 0.017831913211937014, 'gb_weight': 0.33137812147062495, 'rf_weight': 0.37799265586695785}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:17,741] Trial 962 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.8742593044553899, 'cb_weight': 0.3514355982898079, 'lgbm_weight': 0.5494370506562549, 'lgbm_dart_weight': 0.7718327333533357, 'hgb_weight': 0.7510412219216916, 'gb_weight': 0.2675469281761993, 'rf_weight': 0.3315029839990813}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:17,873] Trial 963 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.8153242701034351, 'cb_weight': 0.2895654848136842, 'lgbm_weight': 0.6106057589410782, 'lgbm_dart_weight': 0.7145214015971173, 'hgb_weight': 0.06488910101296937, 'gb_weight': 0.3022461364324648, 'rf_weight': 0.45500347056092383}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,002] Trial 964 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.9113422355989504, 'cb_weight': 0.38910753947635746, 'lgbm_weight': 0.5654851350042537, 'lgbm_dart_weight': 0.8574322194380688, 'hgb_weight': 0.03650225526168013, 'gb_weight': 0.35198623904853055, 'rf_weight': 0.3923956913557319}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,129] Trial 965 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.7978073410891081, 'cb_weight': 0.3171549384883434, 'lgbm_weight': 0.4727650542182412, 'lgbm_dart_weight': 0.7985070128713003, 'hgb_weight': 0.0008691114432721444, 'gb_weight': 0.316433865985613, 'rf_weight': 0.3698775970289433}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,258] Trial 966 finished with value: 0.8346794218353851 and parameters: {'xgb_weight': 0.1358742123939286, 'cb_weight': 0.4325312529316563, 'lgbm_weight': 0.526340878140807, 'lgbm_dart_weight': 0.7440326150838962, 'hgb_weight': 0.018280941577464717, 'gb_weight': 0.38228050091874566, 'rf_weight': 0.35050186635382613}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,386] Trial 967 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.894894062517315, 'cb_weight': 0.40577549666715057, 'lgbm_weight': 0.5991754428809262, 'lgbm_dart_weight': 0.8273054479612617, 'hgb_weight': 5.14033608691373e-05, 'gb_weight': 0.3394671742889339, 'rf_weight': 0.4083198376930632}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,515] Trial 968 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.8464104478528798, 'cb_weight': 0.36667605423844984, 'lgbm_weight': 0.6232009532071859, 'lgbm_dart_weight': 0.7772216436988283, 'hgb_weight': 0.04091775603611124, 'gb_weight': 0.3595617810319906, 'rf_weight': 0.32893270428283067}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,642] Trial 969 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.9328415143779408, 'cb_weight': 0.3297550759365044, 'lgbm_weight': 0.5046906783008527, 'lgbm_dart_weight': 0.8101107442259512, 'hgb_weight': 0.01816896818679509, 'gb_weight': 0.3889778863653183, 'rf_weight': 0.3896290572636224}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,772] Trial 970 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.8659382445311524, 'cb_weight': 0.464590199022954, 'lgbm_weight': 0.5839090772252777, 'lgbm_dart_weight': 0.8729686353635017, 'hgb_weight': 0.05588923955479002, 'gb_weight': 0.3215562815082271, 'rf_weight': 0.3612734373097945}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:18,903] Trial 971 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.9114592746775342, 'cb_weight': 0.8411350260725992, 'lgbm_weight': 0.5551372145624908, 'lgbm_dart_weight': 0.6068930930531702, 'hgb_weight': 0.03609393178147443, 'gb_weight': 0.2879453664475571, 'rf_weight': 0.4210791096291526}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,033] Trial 972 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.8430986224765574, 'cb_weight': 0.3510566630995308, 'lgbm_weight': 0.539168987693092, 'lgbm_dart_weight': 0.7335412765153361, 'hgb_weight': 0.019120413596380722, 'gb_weight': 0.3640968929613712, 'rf_weight': 0.3457905864597285}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,162] Trial 973 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.8872943144231384, 'cb_weight': 0.380874819550387, 'lgbm_weight': 0.5935029078417581, 'lgbm_dart_weight': 0.7907803761197119, 'hgb_weight': 0.06823299975449142, 'gb_weight': 0.3403839459152762, 'rf_weight': 0.38038866558209794}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,292] Trial 974 finished with value: 0.8347970412190596 and parameters: {'xgb_weight': 0.93260689718856, 'cb_weight': 0.40046952866053004, 'lgbm_weight': 0.403421663807089, 'lgbm_dart_weight': 0.7596367870708486, 'hgb_weight': 0.019224282241732577, 'gb_weight': 0.3152361339917264, 'rf_weight': 0.43969754934936545}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,420] Trial 975 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.8725087585467756, 'cb_weight': 0.3027443983167103, 'lgbm_weight': 0.5607346427410771, 'lgbm_dart_weight': 0.701005481044501, 'hgb_weight': 0.04721083444852578, 'gb_weight': 0.39555308122780725, 'rf_weight': 0.4039486942329278}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,549] Trial 976 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.8989840910714003, 'cb_weight': 0.6776953189527222, 'lgbm_weight': 0.6274508193759291, 'lgbm_dart_weight': 0.8370384466645647, 'hgb_weight': 0.000309186362749485, 'gb_weight': 0.9218118987022571, 'rf_weight': 0.3726210568515103}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,677] Trial 977 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.8294561852578859, 'cb_weight': 0.34320318279171214, 'lgbm_weight': 0.5770397738161827, 'lgbm_dart_weight': 0.8151983304827318, 'hgb_weight': 0.22047298289823955, 'gb_weight': 0.3523088283573374, 'rf_weight': 0.520073789298352}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,806] Trial 978 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.9199362523044532, 'cb_weight': 0.44195610333341234, 'lgbm_weight': 0.37638759125708615, 'lgbm_dart_weight': 0.9142073054245863, 'hgb_weight': 0.08308426702584346, 'gb_weight': 0.37366562215330096, 'rf_weight': 0.32240174491035856}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:19,938] Trial 979 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.9420308127626402, 'cb_weight': 0.3694510647661737, 'lgbm_weight': 0.5202769440906458, 'lgbm_dart_weight': 0.7829093944190132, 'hgb_weight': 0.00011355994453865546, 'gb_weight': 0.3338171779933668, 'rf_weight': 0.3517100356095922}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,071] Trial 980 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.8648631158884995, 'cb_weight': 0.5043148214579799, 'lgbm_weight': 0.6014599506382011, 'lgbm_dart_weight': 0.7617692890216805, 'hgb_weight': 0.03420209461790726, 'gb_weight': 0.3076033615407009, 'rf_weight': 0.3927044338858806}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,200] Trial 981 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.9074391780496402, 'cb_weight': 0.4146553015232552, 'lgbm_weight': 0.5632033640415882, 'lgbm_dart_weight': 0.6480231472636724, 'hgb_weight': 0.01770455599121706, 'gb_weight': 0.37248364685480717, 'rf_weight': 0.3687215209460697}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,331] Trial 982 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.8873721320363449, 'cb_weight': 0.39232188890045994, 'lgbm_weight': 0.5381413630273538, 'lgbm_dart_weight': 0.8504895189465941, 'hgb_weight': 0.050814256770141154, 'gb_weight': 0.261953969711789, 'rf_weight': 0.4136775664517568}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,462] Trial 983 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.9426183457976562, 'cb_weight': 0.3583497459989227, 'lgbm_weight': 0.5811739357435164, 'lgbm_dart_weight': 0.4876233986568447, 'hgb_weight': 0.03111333787823679, 'gb_weight': 0.3496543772044588, 'rf_weight': 0.3387820342187347}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,590] Trial 984 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.8478803563031057, 'cb_weight': 0.3324190520233005, 'lgbm_weight': 0.613775970746425, 'lgbm_dart_weight': 0.8919361446318983, 'hgb_weight': 0.01780086869633851, 'gb_weight': 0.39652040882793116, 'rf_weight': 0.3925730248348124}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,720] Trial 985 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.9108515076516308, 'cb_weight': 0.37309993030442856, 'lgbm_weight': 0.5058772441789848, 'lgbm_dart_weight': 0.7400411059624752, 'hgb_weight': 0.0507450692255532, 'gb_weight': 0.2928322199337545, 'rf_weight': 0.4288107695509281}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,852] Trial 986 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.9274180306485256, 'cb_weight': 0.3109960534995403, 'lgbm_weight': 0.5533410078022888, 'lgbm_dart_weight': 0.8044612694051023, 'hgb_weight': 0.029958816622989163, 'gb_weight': 0.32620503002679974, 'rf_weight': 0.46200122040503244}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:20,986] Trial 987 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.8789845962703571, 'cb_weight': 0.42225386549055544, 'lgbm_weight': 0.5355713209185234, 'lgbm_dart_weight': 0.777510509977526, 'hgb_weight': 0.017497049447476536, 'gb_weight': 0.36138371671438857, 'rf_weight': 0.22398598896877395}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,122] Trial 988 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.9519547775665518, 'cb_weight': 0.3947766166954332, 'lgbm_weight': 0.5951533562918468, 'lgbm_dart_weight': 0.7261381903283535, 'hgb_weight': 0.06761053201183523, 'gb_weight': 0.3880981816991543, 'rf_weight': 0.36315531442560695}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,256] Trial 989 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.8582260441417757, 'cb_weight': 0.34021017810790805, 'lgbm_weight': 0.6416079911616313, 'lgbm_dart_weight': 0.8269198439296777, 'hgb_weight': 0.035027534795240345, 'gb_weight': 0.3442428811991186, 'rf_weight': 0.3810587658264562}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,386] Trial 990 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.8967365116470725, 'cb_weight': 0.37745111398947834, 'lgbm_weight': 0.5707237652943155, 'lgbm_dart_weight': 0.7545880405515194, 'hgb_weight': 0.018123651183458902, 'gb_weight': 0.3045342483952737, 'rf_weight': 0.32175582345417936}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,514] Trial 991 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.9293483720794811, 'cb_weight': 0.3590689218878782, 'lgbm_weight': 0.6199487023551109, 'lgbm_dart_weight': 0.7949907370233321, 'hgb_weight': 0.0500689909898059, 'gb_weight': 0.32819821991551223, 'rf_weight': 0.3545285022674548}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,642] Trial 992 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.8793544131587457, 'cb_weight': 0.40873608594620064, 'lgbm_weight': 0.584650208530955, 'lgbm_dart_weight': 0.8603637889216039, 'hgb_weight': 0.0007641917213755999, 'gb_weight': 0.37446745181951024, 'rf_weight': 0.39902052836523483}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,773] Trial 993 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.8274583529526148, 'cb_weight': 0.44996227377870723, 'lgbm_weight': 0.5465628581633465, 'lgbm_dart_weight': 0.7679043154238989, 'hgb_weight': 0.03406640708691933, 'gb_weight': 0.35547705801558827, 'rf_weight': 0.3741128409254471}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:21,905] Trial 994 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.9436695799417376, 'cb_weight': 0.27999860807593063, 'lgbm_weight': 0.519792653854407, 'lgbm_dart_weight': 0.6716622812992058, 'hgb_weight': 0.0005507021751869343, 'gb_weight': 0.7966733843326453, 'rf_weight': 0.34231465522427884}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:22,036] Trial 995 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.7077167515699371, 'cb_weight': 0.31942136363440815, 'lgbm_weight': 0.4886085956738568, 'lgbm_dart_weight': 0.7074094790499248, 'hgb_weight': 0.00017902445258567365, 'gb_weight': 0.4019822762426993, 'rf_weight': 0.43604939492301825}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:22,167] Trial 996 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.9028752892831118, 'cb_weight': 0.388676413840881, 'lgbm_weight': 0.6066475295851645, 'lgbm_dart_weight': 0.7948244506424941, 'hgb_weight': 0.0672505730534389, 'gb_weight': 0.014476089488815957, 'rf_weight': 0.41034795204624575}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:22,299] Trial 997 finished with value: 0.8340259808149716 and parameters: {'xgb_weight': 0.18369561695578163, 'cb_weight': 0.3518056709509707, 'lgbm_weight': 0.5635924260139636, 'lgbm_dart_weight': 0.8217355615046824, 'hgb_weight': 0.021297975540440668, 'gb_weight': 0.33099988470927877, 'rf_weight': 0.9954830077490737}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:22,429] Trial 998 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.7839616348601798, 'cb_weight': 0.4240625760330978, 'lgbm_weight': 0.8252978395640672, 'lgbm_dart_weight': 0.8384845026757898, 'hgb_weight': 0.04634179903569885, 'gb_weight': 0.28572633884005166, 'rf_weight': 0.30510810756332546}. Best is trial 858 with value: 0.8351368305496746.
# [I 2024-06-15 15:07:22,560] Trial 999 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.7589805270867704, 'cb_weight': 0.3753846185004446, 'lgbm_weight': 0.5829395022611423, 'lgbm_dart_weight': 0.7397197379438658, 'hgb_weight': 0.0974916529790893, 'gb_weight': 0.306732951302369, 'rf_weight': 0.3633195709470733}. Best is trial 858 with value: 0.8351368305496746.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.931140
# --- Fold 2 - Accuracy: 0.835664, AUC: 0.932689
# --- Fold 3 - Accuracy: 0.835795, AUC: 0.930383
# --- Fold 4 - Accuracy: 0.835000, AUC: 0.930459
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.925267
#
# ------ Accuracy: 0.834000 ± 0.003590
# ------ AUC:      0.929988 ± 0.002502

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838604, AUC: 0.931374
# --- Fold 2 - Accuracy: 0.836905, AUC: 0.933009
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930535
# --- Fold 4 - Accuracy: 0.835392, AUC: 0.930531
# --- Fold 5 - Accuracy: 0.827681, AUC: 0.925258
#
# ------ Accuracy: 0.835032 ± 0.003817
# ------ AUC:      0.930141 ± 0.002604

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(20, 20))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(20, 20))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
