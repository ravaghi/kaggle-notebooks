# %% [markdown]
# # Imports and Configs

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (
    VotingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import os

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %%
SEED = 27
N_FOLDS = 5
TARGET = 'Target'

# %% [markdown]
# # Loading and Processing the Datasets

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv', index_col='id')
test = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv', index_col='id')

train.shape, test.shape
# Out:
# ((76518, 37), (51012, 36))

# %%
# Reference: https://www.kaggle.com/code/ambrosm/pss4e6-eda-which-makes-sense
cat_features = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]


for col in cat_features:
    train[col] = train[col].astype('category')
    test[col] = test[col].astype('category')

# %%
X = train.drop(TARGET, axis=1)
y = train[TARGET]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # Defining Training and Cross Validation Functions

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit(self, X, y):
        print(f'Training {self.model.__class__.__name__}')

        rskf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)

        accs = []
        aucs = []
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        oof_preds = np.zeros(X.shape[0])
        for fold_idx, (train_idx, val_idx) in enumerate(rskf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            self.model.fit(X_train, y_train)

            y_pred_probs = self.model.predict_proba(X_val)
            y_pred = np.argmax(y_pred_probs, axis=1)

            oof_pred_probs[val_idx] = y_pred_probs
            oof_preds[val_idx] = y_pred

            acc = accuracy_score(y_val, y_pred)
            auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovo')
            accs.append(acc)
            aucs.append(auc)

            print(f'--- Fold {fold_idx + 1} - Accuracy: {acc:.6f}, AUC: {auc:.6f}')

        print(f'\n------ Accuracy: {np.mean(accs):.6f} ± {np.std(accs):.6f}')
        print(f'------ AUC:      {np.mean(aucs):.6f} ± {np.std(aucs):.6f}\n\n')

        return self.model, oof_pred_probs, oof_preds, accs, aucs

# %%
xgb_params = {
    'n_jobs': -1,
    'max_bin': 86,
    'verbosity': 0,
    'max_depth': 5,
    'max_leaves': 64,
    'booster': 'gbtree',
    'n_estimators': 1539,
    'random_state': SEED,
    'enable_categorical': True,
    'gamma': 0.9069384135972282,
    'reg_alpha': 9.076826031603096,
    'subsample': 0.9335856723937552,
    'reg_lambda': 3.7191495119106976,
    'max_delta_step': 1.1802158903460869,
    'min_child_weight': 8.745168792677534,
    'colsample_bynode': 0.8390631221126779,
    'colsample_bytree': 0.5534666374509267,
    'colsample_bylevel': 0.5695267422612745,
}

cb_params = {
    'depth': 9,
    'verbose': False,
    'thread_count': -1,
    'iterations': 1830,
    'border_count': 200,
    'random_state': SEED,
    'min_child_samples': 4,
    'bootstrap_type': 'MVS',
    'grow_policy': 'Depthwise',
    'l2_leaf_reg': 4.349614487163372,
    'random_strength': 0.16489500172653238,
    'colsample_bylevel': 0.45740812601887504,
}

lgbm_params = {
    'n_jobs': -1,
    'verbose': -1,
    'max_depth': 77,
    'num_leaves': 42,
    'subsample_freq': 8,
    'n_estimators': 169,
    'random_state': SEED,
    'min_child_samples': 199,
    'subsample': 0.9178993412905838,
    'reg_alpha': 0.9200214666236493,
    'reg_lambda': 0.2652568189927319,
    'min_child_weight': 0.4410010971781976,
    'colsample_bytree': 0.35379935570036725,
}

hgb_params = {
    'verbose': 0,
    'max_depth': 4,
    'max_bins': 250,
    'max_iter': 1522,
    'max_leaf_nodes': 92,
    'random_state': SEED,
    'min_samples_leaf': 44,
    'l2_regularization': 0.4495943539321024,
}

gb_params = {
    'verbose': 0,
    'max_depth': 4,
    'subsample': 0.9,
    'n_estimators': 600,
    'random_state': SEED,
    'learning_rate': 0.05,
}

rf_params = {
    'verbose': 0,
    'max_depth': None,
    'n_estimators': 1200,
    'random_state': SEED,
}

# %%
accuracies = {}
aucs = {}

test_pred_probs = {}
oof_pred_probs = {}
oof_preds = {}

# %% [markdown]
# # Training Base Models

# %%
xgb_model = XGBClassifier(**xgb_params)
xgb_model, xgb_oof_pred_probs, xgb_oof_preds, xgb_accs, xgb_aucs = Trainer(xgb_model).fit(X, y)
oof_pred_probs['XGB'] = xgb_oof_pred_probs
oof_preds['XGB'] = xgb_oof_preds
test_pred_probs['XGB'] = xgb_model.predict_proba(test)
accuracies['XGB'] = xgb_accs
aucs['XGB'] = xgb_aucs
# Out:
# Training XGBClassifier
# --- Fold 1 - Accuracy: 0.836644, AUC: 0.930521
# --- Fold 2 - Accuracy: 0.837101, AUC: 0.932307
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.929514
# --- Fold 4 - Accuracy: 0.833235, AUC: 0.929363
# --- Fold 5 - Accuracy: 0.825590, AUC: 0.924143
#
# ------ Accuracy: 0.833595 ± 0.004221
# ------ AUC:      0.929170 ± 0.002724

# %%
cb_model = CatBoostClassifier(**cb_params, cat_features=cat_features)
cb_model, cb_oof_pred_probs, cb_oof_preds, cb_accs, cb_aucs = Trainer(cb_model).fit(X, y)
oof_pred_probs['CB'] = cb_oof_pred_probs
oof_preds['CB'] = cb_oof_preds
test_pred_probs['CB'] = cb_model.predict_proba(test)
accuracies['CB'] = cb_accs
aucs['CB'] = cb_aucs
# Out:
# Training CatBoostClassifier
# --- Fold 1 - Accuracy: 0.836448, AUC: 0.930153
# --- Fold 2 - Accuracy: 0.837493, AUC: 0.932018
# --- Fold 3 - Accuracy: 0.834422, AUC: 0.929325
# --- Fold 4 - Accuracy: 0.832843, AUC: 0.929248
# --- Fold 5 - Accuracy: 0.826897, AUC: 0.924452
#
# ------ Accuracy: 0.833621 ± 0.003727
# ------ AUC:      0.929039 ± 0.002501

# %%
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_model, lgbm_oof_pred_probs, lgbm_oof_preds, lgbm_accs, lgbm_aucs = Trainer(lgbm_model).fit(X, y)
oof_pred_probs['LGBM'] = lgbm_oof_pred_probs
oof_preds['LGBM'] = lgbm_oof_preds
test_pred_probs['LGBM'] = lgbm_model.predict_proba(test)
accuracies['LGBM'] = lgbm_accs
aucs['LGBM'] = lgbm_aucs
# Out:
# Training LGBMClassifier
# --- Fold 1 - Accuracy: 0.837036, AUC: 0.930935
# --- Fold 2 - Accuracy: 0.836317, AUC: 0.932722
# --- Fold 3 - Accuracy: 0.836579, AUC: 0.930180
# --- Fold 4 - Accuracy: 0.834804, AUC: 0.930146
# --- Fold 5 - Accuracy: 0.826635, AUC: 0.924594
#
# ------ Accuracy: 0.834274 ± 0.003892
# ------ AUC:      0.929715 ± 0.002726

# %%
hgb_model = HistGradientBoostingClassifier(**hgb_params)
hgb_model, hgb_oof_pred_probs, hgb_oof_preds, hgb_accs, hgb_aucs = Trainer(hgb_model).fit(X, y)
oof_pred_probs['HGB'] = hgb_oof_pred_probs
oof_preds['HGB'] = hgb_oof_preds
test_pred_probs['HGB'] = hgb_model.predict_proba(test)
accuracies['HGB'] = hgb_accs
aucs['HGB'] = hgb_aucs
# Out:
# Training HistGradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929074
# --- Fold 2 - Accuracy: 0.835010, AUC: 0.930172
# --- Fold 3 - Accuracy: 0.835403, AUC: 0.928571
# --- Fold 4 - Accuracy: 0.832517, AUC: 0.928758
# --- Fold 5 - Accuracy: 0.825132, AUC: 0.924181
#
# ------ Accuracy: 0.832575 ± 0.003856
# ------ AUC:      0.928151 ± 0.002061

# %%
gb_model = GradientBoostingClassifier(**gb_params)
gb_model, gb_oof_pred_probs, gb_oof_preds, gb_accs, gb_aucs = Trainer(gb_model).fit(X, y)
oof_pred_probs['GB'] = gb_oof_pred_probs
oof_preds['GB'] = gb_oof_preds
test_pred_probs['GB'] = gb_model.predict_proba(test)
accuracies['GB'] = gb_accs
aucs['GB'] = gb_aucs
# Out:
# Training GradientBoostingClassifier
# --- Fold 1 - Accuracy: 0.834814, AUC: 0.929448
# --- Fold 2 - Accuracy: 0.833965, AUC: 0.930748
# --- Fold 3 - Accuracy: 0.833638, AUC: 0.928923
# --- Fold 4 - Accuracy: 0.832124, AUC: 0.929367
# --- Fold 5 - Accuracy: 0.826113, AUC: 0.923983
#
# ------ Accuracy: 0.832131 ± 0.003132
# ------ AUC:      0.928494 ± 0.002336

# %%
rf_model = RandomForestClassifier(**rf_params)
rf_model, rf_oof_pred_probs, rf_oof_preds, rf_accs, rf_aucs = Trainer(rf_model).fit(X, y)
oof_pred_probs['RF'] = rf_oof_pred_probs
oof_preds['RF'] = rf_oof_preds
test_pred_probs['RF'] = rf_model.predict_proba(test)
accuracies['RF'] = rf_accs
aucs['RF'] = rf_aucs
# Out:
# Training RandomForestClassifier
# --- Fold 1 - Accuracy: 0.828738, AUC: 0.923348
# --- Fold 2 - Accuracy: 0.831939, AUC: 0.925072
# --- Fold 3 - Accuracy: 0.830306, AUC: 0.921366
# --- Fold 4 - Accuracy: 0.826766, AUC: 0.923187
# --- Fold 5 - Accuracy: 0.821865, AUC: 0.917795
#
# ------ Accuracy: 0.827923 ± 0.003479
# ------ AUC:      0.922154 ± 0.002475

# %% [markdown]
# # Training Voting Models

# %%
estimators = [
    ('XGB', xgb_model),
    ('CB', cb_model),
    ('LGBM', lgbm_model),
    ('HGB', hgb_model),
    ('GB', gb_model),
    ('RF', rf_model)
]

# %%
def objective(trial):
    xgb_weight = trial.suggest_float('xgb_weight', 0.0, 1.0)
    cb_weight = trial.suggest_float('cb_weight', 0.0, 1.0)
    lgbm_weight = trial.suggest_float('lgbm_weight', 0.0, 1.0)
    hgb_weight = trial.suggest_float('hgb_weight', 0.0, 1.0)
    gb_weight = trial.suggest_float('gb_weight', 0.0, 1.0)
    rf_weight = trial.suggest_float('rf_weight', 0.0, 1.0)

    weights = [
        xgb_weight, 
        cb_weight, 
        lgbm_weight, 
        hgb_weight, 
        gb_weight, 
        rf_weight
    ]
    weights /= np.sum(weights)

    pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
    for model, weight in zip(oof_pred_probs.keys(), weights):
        pred_probs += oof_pred_probs[model] * weight

    preds = np.argmax(pred_probs, axis=1)

    return accuracy_score(y, preds)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=5000)

best_weights = study.best_params
best_weights = [best_weights[f'{model}_weight'] for model in ['xgb', 'cb', 'lgbm', 'hgb', 'gb', 'rf']]
best_weights /= np.sum(best_weights)
# Out:
# [I 2024-06-10 11:58:46,091] A new study created in memory with name: no-name-eeef861f-dc41-4ee6-a63d-4e24a1021589
# [I 2024-06-10 11:58:46,107] Trial 0 finished with value: 0.8335816409210904 and parameters: {'xgb_weight': 0.776574587077941, 'cb_weight': 0.6057068640455455, 'lgbm_weight': 0.11183126817860978, 'hgb_weight': 0.6685928282795227, 'gb_weight': 0.7978825817216698, 'rf_weight': 0.8616105426760106}. Best is trial 0 with value: 0.8335816409210904.
# [I 2024-06-10 11:58:46,121] Trial 1 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.7667737794767533, 'cb_weight': 0.10550854633154894, 'lgbm_weight': 0.8825191062122992, 'hgb_weight': 0.4982919587581671, 'gb_weight': 0.3789960099403157, 'rf_weight': 0.981434766107775}. Best is trial 1 with value: 0.8340521184557882.
# [I 2024-06-10 11:58:46,135] Trial 2 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.5080973242186845, 'cb_weight': 0.8473662653067573, 'lgbm_weight': 0.8265456091556473, 'hgb_weight': 0.8668652176320439, 'gb_weight': 0.9621233065951462, 'rf_weight': 0.36786543412963435}. Best is trial 2 with value: 0.8340782560966047.
# [I 2024-06-10 11:58:46,148] Trial 3 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.42894293132632644, 'cb_weight': 0.47084885290652034, 'lgbm_weight': 0.7082494750339863, 'hgb_weight': 0.2565618241539167, 'gb_weight': 0.739049667156803, 'rf_weight': 0.8124124787918903}. Best is trial 2 with value: 0.8340782560966047.
# [I 2024-06-10 11:58:46,162] Trial 4 finished with value: 0.8341436001986461 and parameters: {'xgb_weight': 0.6298227109895477, 'cb_weight': 0.5777402378961425, 'lgbm_weight': 0.4376633356808134, 'hgb_weight': 0.45224063016226124, 'gb_weight': 0.1585712493663881, 'rf_weight': 0.4624851098833096}. Best is trial 4 with value: 0.8341436001986461.
# [I 2024-06-10 11:58:46,175] Trial 5 finished with value: 0.8338822237904807 and parameters: {'xgb_weight': 0.6112635068167974, 'cb_weight': 0.5052401322917724, 'lgbm_weight': 0.3838219751903664, 'hgb_weight': 0.5554593842954106, 'gb_weight': 0.6902004523085615, 'rf_weight': 0.6259351015831733}. Best is trial 4 with value: 0.8341436001986461.
# [I 2024-06-10 11:58:46,190] Trial 6 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.17848233702542393, 'cb_weight': 0.18778477476743205, 'lgbm_weight': 0.9844173229217966, 'hgb_weight': 0.20190111051860693, 'gb_weight': 0.8160489619701343, 'rf_weight': 0.8126320959741135}. Best is trial 6 with value: 0.8341697378394626.
# [I 2024-06-10 11:58:46,205] Trial 7 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.8172620341166944, 'cb_weight': 0.04177471814993661, 'lgbm_weight': 0.467955773187291, 'hgb_weight': 0.8352559315017161, 'gb_weight': 0.32063245539041796, 'rf_weight': 0.5148569716793414}. Best is trial 6 with value: 0.8341697378394626.
# [I 2024-06-10 11:58:46,218] Trial 8 finished with value: 0.8338299485088476 and parameters: {'xgb_weight': 0.569511543381022, 'cb_weight': 0.87978638959201, 'lgbm_weight': 0.14935309855345968, 'hgb_weight': 0.6923453147111359, 'gb_weight': 0.015791026767412286, 'rf_weight': 0.19042955443654785}. Best is trial 6 with value: 0.8341697378394626.
# [I 2024-06-10 11:58:46,232] Trial 9 finished with value: 0.8337776732272145 and parameters: {'xgb_weight': 0.13499982209912642, 'cb_weight': 0.04610347358659039, 'lgbm_weight': 0.6608343081122742, 'hgb_weight': 0.8953326980991699, 'gb_weight': 0.8024929702659424, 'rf_weight': 0.9948263899326338}. Best is trial 6 with value: 0.8341697378394626.
# [I 2024-06-10 11:58:46,272] Trial 10 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.036917097947727295, 'cb_weight': 0.275649049056058, 'lgbm_weight': 0.9981049047645633, 'hgb_weight': 0.027960317871031704, 'gb_weight': 0.5612288282108586, 'rf_weight': 0.021707410744407296}. Best is trial 10 with value: 0.8344703207088529.
# [I 2024-06-10 11:58:46,312] Trial 11 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.016329559107418, 'cb_weight': 0.252154101528531, 'lgbm_weight': 0.985072043768367, 'hgb_weight': 0.041667450722963434, 'gb_weight': 0.5688194492226374, 'rf_weight': 0.03935128564232066}. Best is trial 10 with value: 0.8344703207088529.
# [I 2024-06-10 11:58:46,354] Trial 12 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.020517805775239567, 'cb_weight': 0.3153692958680344, 'lgbm_weight': 0.9806885016682318, 'hgb_weight': 0.05572737839482632, 'gb_weight': 0.5270116810130866, 'rf_weight': 0.028590143133604307}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,396] Trial 13 finished with value: 0.8343919077864032 and parameters: {'xgb_weight': 0.3005502186079006, 'cb_weight': 0.33507175293575897, 'lgbm_weight': 0.6746235582893172, 'hgb_weight': 0.002352644639917023, 'gb_weight': 0.49546494465066004, 'rf_weight': 0.01759424447118059}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,437] Trial 14 finished with value: 0.8344441830680362 and parameters: {'xgb_weight': 0.010651696115902203, 'cb_weight': 0.3695372824084415, 'lgbm_weight': 0.818571351126544, 'hgb_weight': 0.19187301791161265, 'gb_weight': 0.545837565927356, 'rf_weight': 0.2170347851713592}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,479] Trial 15 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.9976589739746003, 'cb_weight': 0.7119437374232278, 'lgbm_weight': 0.996940117474865, 'hgb_weight': 0.33975901035803935, 'gb_weight': 0.37094378318492016, 'rf_weight': 0.1772480045813924}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,521] Trial 16 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.26369722200218315, 'cb_weight': 0.34967340905723704, 'lgbm_weight': 0.2562809717425357, 'hgb_weight': 0.10198988554206942, 'gb_weight': 0.5843893545263235, 'rf_weight': 0.31119849022976687}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,562] Trial 17 finished with value: 0.8341697378394626 and parameters: {'xgb_weight': 0.3645952601568526, 'cb_weight': 0.19260443472985933, 'lgbm_weight': 0.5954043725551477, 'hgb_weight': 0.3434112238826281, 'gb_weight': 0.44793337920392, 'rf_weight': 0.08956859284205437}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,604] Trial 18 finished with value: 0.8345356648108941 and parameters: {'xgb_weight': 0.12848135413432532, 'cb_weight': 0.42740298985836656, 'lgbm_weight': 0.8711551933639399, 'hgb_weight': 0.11594646752652832, 'gb_weight': 0.25188600001621014, 'rf_weight': 0.11504324614041012}. Best is trial 12 with value: 0.8345879400925272.
# [I 2024-06-10 11:58:46,646] Trial 19 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.1504024674013097, 'cb_weight': 0.736934294544795, 'lgbm_weight': 0.7579585292333877, 'hgb_weight': 0.13785672298117846, 'gb_weight': 0.02180150324003005, 'rf_weight': 0.3052701428870848}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,689] Trial 20 finished with value: 0.8346402153741603 and parameters: {'xgb_weight': 0.2194167174429578, 'cb_weight': 0.7758316825290085, 'lgbm_weight': 0.7538354155359197, 'hgb_weight': 0.3362444549020882, 'gb_weight': 0.04577783438270833, 'rf_weight': 0.3089777702568391}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,733] Trial 21 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.22786807634616826, 'cb_weight': 0.7447679880462281, 'lgbm_weight': 0.7549729380019087, 'hgb_weight': 0.317253955757227, 'gb_weight': 0.002777524005084169, 'rf_weight': 0.3092925157974086}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,776] Trial 22 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.23987619989163794, 'cb_weight': 0.7537556357557885, 'lgbm_weight': 0.5947033001438973, 'hgb_weight': 0.3712180295018921, 'gb_weight': 0.007843241492586556, 'rf_weight': 0.3305919025587331}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,819] Trial 23 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.37315625757029486, 'cb_weight': 0.7568374697129681, 'lgbm_weight': 0.7493986695650308, 'hgb_weight': 0.27933277440010273, 'gb_weight': 0.11947628374864204, 'rf_weight': 0.4714869234747796}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,863] Trial 24 finished with value: 0.834627146553752 and parameters: {'xgb_weight': 0.17494005011351765, 'cb_weight': 0.9992122699634417, 'lgbm_weight': 0.5645475924459383, 'hgb_weight': 0.40877127393623386, 'gb_weight': 0.13385789930906322, 'rf_weight': 0.2694612735727638}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,906] Trial 25 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.3263352619531747, 'cb_weight': 0.6509190916165789, 'lgbm_weight': 0.7656248524042188, 'hgb_weight': 0.22184231593338033, 'gb_weight': 0.07797532189553431, 'rf_weight': 0.3846159189698806}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,949] Trial 26 finished with value: 0.8334770903578244 and parameters: {'xgb_weight': 0.20912814310929914, 'cb_weight': 0.8676205736035765, 'lgbm_weight': 0.0065587383262233345, 'hgb_weight': 0.1286967006151987, 'gb_weight': 0.1936265928793505, 'rf_weight': 0.6424499852802856}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:46,993] Trial 27 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.45413170687174054, 'cb_weight': 0.9558475335602616, 'lgbm_weight': 0.8821719290075293, 'hgb_weight': 0.28814381242604636, 'gb_weight': 0.24334023345334865, 'rf_weight': 0.5747221022911444}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,038] Trial 28 finished with value: 0.8343527013251784 and parameters: {'xgb_weight': 0.09288466637025142, 'cb_weight': 0.6884366209904984, 'lgbm_weight': 0.5153247527721427, 'hgb_weight': 0.5062647374032597, 'gb_weight': 0.08179011951080464, 'rf_weight': 0.391326553993798}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,083] Trial 29 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.08456588282878938, 'cb_weight': 0.5929476257321699, 'lgbm_weight': 0.6394022048230781, 'hgb_weight': 0.613187930760018, 'gb_weight': 0.013654471809447446, 'rf_weight': 0.2620328783485533}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,127] Trial 30 finished with value: 0.8341174625578295 and parameters: {'xgb_weight': 0.28082423780342325, 'cb_weight': 0.7897836932601514, 'lgbm_weight': 0.3449131808590023, 'hgb_weight': 0.7536955855633459, 'gb_weight': 0.23181493980626622, 'rf_weight': 0.4171792743723651}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,173] Trial 31 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.1734588013621996, 'cb_weight': 0.9928689972612771, 'lgbm_weight': 0.5370718328748677, 'hgb_weight': 0.4153113651876838, 'gb_weight': 0.08375082375822183, 'rf_weight': 0.273814189550941}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,217] Trial 32 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.20747985270747182, 'cb_weight': 0.9380618225132205, 'lgbm_weight': 0.7437260124339489, 'hgb_weight': 0.4372409591952889, 'gb_weight': 0.08012278531096995, 'rf_weight': 0.2660955232846969}. Best is trial 19 with value: 0.8348362476802844.
# [I 2024-06-10 11:58:47,262] Trial 33 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.14596029281046358, 'cb_weight': 0.9337481188444106, 'lgbm_weight': 0.8230361802917379, 'hgb_weight': 0.46399611286223363, 'gb_weight': 0.11476989972207763, 'rf_weight': 0.15280136981881787}. Best is trial 33 with value: 0.8348623853211009.
# [I 2024-06-10 11:58:47,308] Trial 34 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.08886140291787722, 'cb_weight': 0.9376776575129055, 'lgbm_weight': 0.8771490744824469, 'hgb_weight': 0.5570727427991623, 'gb_weight': 0.3082367128116844, 'rf_weight': 0.13714261789525622}. Best is trial 33 with value: 0.8348623853211009.
# [I 2024-06-10 11:58:47,353] Trial 35 finished with value: 0.8345618024517107 and parameters: {'xgb_weight': 0.15104884464693594, 'cb_weight': 0.9381345419855619, 'lgbm_weight': 0.5435807393807817, 'hgb_weight': 0.4627484348331329, 'gb_weight': 0.17786484767581162, 'rf_weight': 0.2136063505409527}. Best is trial 33 with value: 0.8348623853211009.
# [I 2024-06-10 11:58:47,398] Trial 36 finished with value: 0.8342873572231371 and parameters: {'xgb_weight': 0.4571668073755976, 'cb_weight': 0.8220900384385857, 'lgbm_weight': 0.8128064489093482, 'hgb_weight': 0.9675443764866214, 'gb_weight': 0.09951167618596596, 'rf_weight': 0.2548597672871376}. Best is trial 33 with value: 0.8348623853211009.
# [I 2024-06-10 11:58:47,441] Trial 37 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.3701189531078743, 'cb_weight': 0.8964411642012379, 'lgbm_weight': 0.682239890293614, 'hgb_weight': 0.42895732139360876, 'gb_weight': 0.16395776220157401, 'rf_weight': 0.13235999163272677}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,485] Trial 38 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.3328750636548249, 'cb_weight': 0.9974586131193147, 'lgbm_weight': 0.3968693344104278, 'hgb_weight': 0.5084479630994627, 'gb_weight': 0.9972740903974933, 'rf_weight': 0.14978364770212768}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,529] Trial 39 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.3926073311631252, 'cb_weight': 0.9021031370596342, 'lgbm_weight': 0.9220593362205021, 'hgb_weight': 0.6259126353078286, 'gb_weight': 0.17548774571644188, 'rf_weight': 0.08275557048220115}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,574] Trial 40 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.5451106199612106, 'cb_weight': 0.8856182022613471, 'lgbm_weight': 0.9266982143952908, 'hgb_weight': 0.6678975781587285, 'gb_weight': 0.17938492731946298, 'rf_weight': 0.08374475655062172}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,619] Trial 41 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.5840074623582414, 'cb_weight': 0.8884324425768167, 'lgbm_weight': 0.9132215439817113, 'hgb_weight': 0.6860695768678856, 'gb_weight': 0.3036102656999094, 'rf_weight': 0.08952614848068755}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,664] Trial 42 finished with value: 0.8346924906557934 and parameters: {'xgb_weight': 0.6762566927415993, 'cb_weight': 0.8269950927350882, 'lgbm_weight': 0.9234270916697005, 'hgb_weight': 0.623091252642228, 'gb_weight': 0.18917186117467236, 'rf_weight': 0.06797199567843142}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,709] Trial 43 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.40179487110910395, 'cb_weight': 0.8969613890296202, 'lgbm_weight': 0.8294630206516681, 'hgb_weight': 0.5934087363044205, 'gb_weight': 0.14312801684778975, 'rf_weight': 0.1573111266497233}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,755] Trial 44 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.41532437139990913, 'cb_weight': 0.8324568489573605, 'lgbm_weight': 0.8188229598785011, 'hgb_weight': 0.5709709748465119, 'gb_weight': 0.13633723939398013, 'rf_weight': 0.16361529791530638}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,800] Trial 45 finished with value: 0.8340782560966047 and parameters: {'xgb_weight': 0.5042078544358092, 'cb_weight': 0.5280712845292233, 'lgbm_weight': 0.7123053015967273, 'hgb_weight': 0.7639010682394873, 'gb_weight': 0.26666484175590144, 'rf_weight': 0.8999043774115894}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,846] Trial 46 finished with value: 0.8343396325047702 and parameters: {'xgb_weight': 0.39021478252634384, 'cb_weight': 0.8963506738656322, 'lgbm_weight': 0.8413784193556788, 'hgb_weight': 0.7427827269851673, 'gb_weight': 0.41568542873427594, 'rf_weight': 0.20825538935703752}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,890] Trial 47 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.3151075254305029, 'cb_weight': 0.6309441184961468, 'lgbm_weight': 0.6804516232253628, 'hgb_weight': 0.6106159235050456, 'gb_weight': 0.04654104785436629, 'rf_weight': 0.13027902066784622}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,936] Trial 48 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.6430961903698214, 'cb_weight': 0.9135671825345406, 'lgbm_weight': 0.938856372698234, 'hgb_weight': 0.47437495672085783, 'gb_weight': 0.36016966946413687, 'rf_weight': 0.04267232017667029}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:47,981] Trial 49 finished with value: 0.8342612195823205 and parameters: {'xgb_weight': 0.44320044931963853, 'cb_weight': 0.8399116218611921, 'lgbm_weight': 0.7937988845749566, 'hgb_weight': 0.5191759410476335, 'gb_weight': 0.8950115543688877, 'rf_weight': 0.18462643780167956}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,025] Trial 50 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.7168023048586581, 'cb_weight': 0.7021292065464394, 'lgbm_weight': 0.6367286379036552, 'hgb_weight': 0.580836579925677, 'gb_weight': 0.6680611192885708, 'rf_weight': 0.10251372865362779}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,071] Trial 51 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.4817085577725595, 'cb_weight': 0.8219910367330208, 'lgbm_weight': 0.8431110862113635, 'hgb_weight': 0.5480805809643401, 'gb_weight': 0.14910850834036415, 'rf_weight': 0.16503735042101336}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,115] Trial 52 finished with value: 0.8344572518884446 and parameters: {'xgb_weight': 0.40531829871541575, 'cb_weight': 0.7952981691040127, 'lgbm_weight': 0.79200299246485, 'hgb_weight': 0.8170651043750854, 'gb_weight': 0.13407880484069426, 'rf_weight': 0.009331785573012008}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,160] Trial 53 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.35249069929315646, 'cb_weight': 0.8562880443326086, 'lgbm_weight': 0.7188490829091481, 'hgb_weight': 0.6441561920884548, 'gb_weight': 0.21253064357215243, 'rf_weight': 0.22924004991068392}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,206] Trial 54 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.5503224371627287, 'cb_weight': 0.9488842046635975, 'lgbm_weight': 0.9602413272815925, 'hgb_weight': 0.7099746900258983, 'gb_weight': 0.05537978005462946, 'rf_weight': 0.059440570025104805}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,251] Trial 55 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.406743844648683, 'cb_weight': 0.9170330376368344, 'lgbm_weight': 0.8582332148387584, 'hgb_weight': 0.5881313461856958, 'gb_weight': 0.14982184126322398, 'rf_weight': 0.17375413730783196}. Best is trial 37 with value: 0.8349277294231423.
# [I 2024-06-10 11:58:48,298] Trial 56 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.2731058027790909, 'cb_weight': 0.967110452875964, 'lgbm_weight': 0.8547885980168306, 'hgb_weight': 0.388917965256796, 'gb_weight': 0.2800703757873358, 'rf_weight': 0.12359808627996774}. Best is trial 56 with value: 0.8349407982435505.
# [I 2024-06-10 11:58:48,344] Trial 57 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.26307401219300375, 'cb_weight': 0.9697484472469257, 'lgbm_weight': 0.8557876927797848, 'hgb_weight': 0.380982531809972, 'gb_weight': 0.2745981551430807, 'rf_weight': 0.11646182261542623}. Best is trial 57 with value: 0.8349669358843671.
# [I 2024-06-10 11:58:48,390] Trial 58 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.2681416887784255, 'cb_weight': 0.9643273599393403, 'lgbm_weight': 0.852149566245, 'hgb_weight': 0.4202590726469632, 'gb_weight': 0.2789632430513993, 'rf_weight': 0.12414911898563043}. Best is trial 57 with value: 0.8349669358843671.
# [I 2024-06-10 11:58:48,435] Trial 59 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.29197179231954096, 'cb_weight': 0.9689871115366456, 'lgbm_weight': 0.8946925452101739, 'hgb_weight': 0.37376480032570597, 'gb_weight': 0.3318210977971778, 'rf_weight': 0.18007591831878655}. Best is trial 57 with value: 0.8349669358843671.
# [I 2024-06-10 11:58:48,480] Trial 60 finished with value: 0.8339606367129303 and parameters: {'xgb_weight': 0.9264128599526241, 'cb_weight': 0.924246494194565, 'lgbm_weight': 0.7914636679619858, 'hgb_weight': 0.39623564038526343, 'gb_weight': 0.43086698318327665, 'rf_weight': 0.6905675429155517}. Best is trial 57 with value: 0.8349669358843671.
# [I 2024-06-10 11:58:48,526] Trial 61 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.2714506297889659, 'cb_weight': 0.9605219013182026, 'lgbm_weight': 0.8528466642353655, 'hgb_weight': 0.4639961768865301, 'gb_weight': 0.22471456751319047, 'rf_weight': 0.12091923660736725}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,572] Trial 62 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.2453344749016272, 'cb_weight': 0.8653870002404785, 'lgbm_weight': 0.9606667562411066, 'hgb_weight': 0.48220019300388317, 'gb_weight': 0.22113735430838372, 'rf_weight': 0.11993017924362213}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,618] Trial 63 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.3392829568698831, 'cb_weight': 0.9745928201651421, 'lgbm_weight': 0.8623478969283759, 'hgb_weight': 0.4536722020623077, 'gb_weight': 0.2919670035175535, 'rf_weight': 0.22829336774247702}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,663] Trial 64 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.2907404359487928, 'cb_weight': 0.9210473811409995, 'lgbm_weight': 0.6858258746295391, 'hgb_weight': 0.36571295725785447, 'gb_weight': 0.25198686013036437, 'rf_weight': 0.012837945797241929}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,709] Trial 65 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.3620872950386778, 'cb_weight': 0.0015342294880783536, 'lgbm_weight': 0.8916148666072191, 'hgb_weight': 0.5321860561607047, 'gb_weight': 0.11295496785394875, 'rf_weight': 0.3512305592686814}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,756] Trial 66 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.24849735922775001, 'cb_weight': 0.9727084193409349, 'lgbm_weight': 0.7802268432756228, 'hgb_weight': 0.4940310387492628, 'gb_weight': 0.3408250346450337, 'rf_weight': 0.04967921489191751}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,802] Trial 67 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.19917126022678305, 'cb_weight': 0.8791196739903709, 'lgbm_weight': 0.7280271149658386, 'hgb_weight': 0.32389202268504125, 'gb_weight': 0.3969195051770264, 'rf_weight': 0.14949766085887367}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,849] Trial 68 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.11077042995155084, 'cb_weight': 0.7993390001513265, 'lgbm_weight': 0.8241369299285428, 'hgb_weight': 0.2294846542238571, 'gb_weight': 0.22058631845672003, 'rf_weight': 0.2013810545932584}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,895] Trial 69 finished with value: 0.8346010089129355 and parameters: {'xgb_weight': 0.4764540972977573, 'cb_weight': 0.9126788910472833, 'lgbm_weight': 0.9604788453196185, 'hgb_weight': 0.43728994119053455, 'gb_weight': 0.4862344605680367, 'rf_weight': 0.10581576530407236}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,941] Trial 70 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.43261548523939697, 'cb_weight': 0.9968707199789105, 'lgbm_weight': 0.8582036329298948, 'hgb_weight': 0.2940696730886904, 'gb_weight': 0.2016113344531702, 'rf_weight': 0.058051979173094514}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:48,986] Trial 71 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.43114671932030024, 'cb_weight': 0.999581084160818, 'lgbm_weight': 0.8686367288342938, 'hgb_weight': 0.29333957880144623, 'gb_weight': 0.16897846172319467, 'rf_weight': 0.049432753379835256}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,033] Trial 72 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.43218462458001017, 'cb_weight': 0.9965750008805355, 'lgbm_weight': 0.8627076225529425, 'hgb_weight': 0.29655447134259455, 'gb_weight': 0.2004841111367449, 'rf_weight': 0.04235347902309669}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,079] Trial 73 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.4176271471296806, 'cb_weight': 0.9558810011294333, 'lgbm_weight': 0.8988647951092871, 'hgb_weight': 0.23362795039525186, 'gb_weight': 0.14588329118788618, 'rf_weight': 0.00557766769030596}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,125] Trial 74 finished with value: 0.8344703207088529 and parameters: {'xgb_weight': 0.5273424058178264, 'cb_weight': 0.9763200616805671, 'lgbm_weight': 0.4610378615261712, 'hgb_weight': 0.1654081980345804, 'gb_weight': 0.2513096918047209, 'rf_weight': 0.10877060858816655}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,172] Trial 75 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.3141492789860947, 'cb_weight': 0.12202799301814382, 'lgbm_weight': 0.8665477077695432, 'hgb_weight': 0.2548584285412417, 'gb_weight': 0.1662914058377142, 'rf_weight': 0.06912593457542401}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,218] Trial 76 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.37641972650788696, 'cb_weight': 0.9988580873103005, 'lgbm_weight': 0.7700966935790459, 'hgb_weight': 0.38473553038013875, 'gb_weight': 0.2342503935436519, 'rf_weight': 0.06870645481673963}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,265] Trial 77 finished with value: 0.8347186282966099 and parameters: {'xgb_weight': 0.37771811666183, 'cb_weight': 0.8616276471878254, 'lgbm_weight': 0.7673173137512251, 'hgb_weight': 0.38555757315690314, 'gb_weight': 0.279043328516132, 'rf_weight': 0.23488035669766472}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,310] Trial 78 finished with value: 0.8344311142476281 and parameters: {'xgb_weight': 0.3569804836685261, 'cb_weight': 0.9423426276538833, 'lgbm_weight': 0.8041051649004471, 'hgb_weight': 0.35871577058650655, 'gb_weight': 0.6158411036491744, 'rf_weight': 0.13583805522499104}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,357] Trial 79 finished with value: 0.8345095271700776 and parameters: {'xgb_weight': 0.4696090739821595, 'cb_weight': 0.4442857145491068, 'lgbm_weight': 0.6393005620629341, 'hgb_weight': 0.5844797435164932, 'gb_weight': 0.15778629121373486, 'rf_weight': 0.18097828436148758}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,405] Trial 80 finished with value: 0.8344964583496693 and parameters: {'xgb_weight': 0.2704772638615005, 'cb_weight': 0.9240584251837272, 'lgbm_weight': 0.9992317529790425, 'hgb_weight': 0.41234993504413125, 'gb_weight': 0.2381055267085345, 'rf_weight': 0.5250138277468834}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,453] Trial 81 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.38183281861225643, 'cb_weight': 0.992658973055287, 'lgbm_weight': 0.8344107264466908, 'hgb_weight': 0.29869888512115883, 'gb_weight': 0.19835919459022616, 'rf_weight': 0.037561752864900516}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,500] Trial 82 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.4276938242322169, 'cb_weight': 0.89728058361809, 'lgbm_weight': 0.9009874859122271, 'hgb_weight': 0.33023148936109914, 'gb_weight': 0.09302912190612272, 'rf_weight': 0.08545470818152118}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,548] Trial 83 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.4965169711280598, 'cb_weight': 0.9094312855106287, 'lgbm_weight': 0.9434530144458323, 'hgb_weight': 0.3437261551955765, 'gb_weight': 0.06941635805069697, 'rf_weight': 0.07645810857846987}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,595] Trial 84 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.509980097696499, 'cb_weight': 0.8914339411051859, 'lgbm_weight': 0.9471759691926884, 'hgb_weight': 0.33888404650865084, 'gb_weight': 0.03218592771622292, 'rf_weight': 0.0965098286780061}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,645] Trial 85 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.5119628712982277, 'cb_weight': 0.8879297556356414, 'lgbm_weight': 0.9433131981059495, 'hgb_weight': 0.34217550956297504, 'gb_weight': 0.05991940785220767, 'rf_weight': 0.07673573768964084}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,693] Trial 86 finished with value: 0.8347578347578347 and parameters: {'xgb_weight': 0.6046331676014312, 'cb_weight': 0.9536363394949622, 'lgbm_weight': 0.9103191639972884, 'hgb_weight': 0.26608256318918144, 'gb_weight': 0.031690646038085885, 'rf_weight': 0.10711800492609728}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,741] Trial 87 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.49461395042972667, 'cb_weight': 0.5500964988663012, 'lgbm_weight': 0.9634227602108448, 'hgb_weight': 0.32879825042370203, 'gb_weight': 0.09493805655746848, 'rf_weight': 0.09137748647620009}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,788] Trial 88 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.538040583292704, 'cb_weight': 0.7678748241350304, 'lgbm_weight': 0.98096666550924, 'hgb_weight': 0.39169100312081717, 'gb_weight': 0.06542357712664004, 'rf_weight': 0.031676377231070994}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,836] Trial 89 finished with value: 0.8343004260435453 and parameters: {'xgb_weight': 0.31123575459098546, 'cb_weight': 0.8478555075667735, 'lgbm_weight': 0.19020251411682654, 'hgb_weight': 0.19345860520293479, 'gb_weight': 0.11154825734755146, 'rf_weight': 0.13056270920903607}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,882] Trial 90 finished with value: 0.8348754541415092 and parameters: {'xgb_weight': 0.5842661388995757, 'cb_weight': 0.8115690077835657, 'lgbm_weight': 0.8854558308713566, 'hgb_weight': 0.3147295824720988, 'gb_weight': 0.027025075461943486, 'rf_weight': 0.0013812762373218157}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,929] Trial 91 finished with value: 0.8349015917823257 and parameters: {'xgb_weight': 0.5201764909051115, 'cb_weight': 0.8867656741346391, 'lgbm_weight': 0.9420153336299617, 'hgb_weight': 0.3570922780001352, 'gb_weight': 0.000510571290981976, 'rf_weight': 0.07647934008557507}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:49,976] Trial 92 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.5005964962607975, 'cb_weight': 0.8994592509790049, 'lgbm_weight': 0.9365314016660111, 'hgb_weight': 0.4374808587514186, 'gb_weight': 0.06611723508069811, 'rf_weight': 0.0713088371152975}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,023] Trial 93 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.567096003131371, 'cb_weight': 0.9428413831920245, 'lgbm_weight': 0.9072530816526746, 'hgb_weight': 0.3449497909066391, 'gb_weight': 0.04131573580558085, 'rf_weight': 0.02943075490860768}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,070] Trial 94 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.6310563952108897, 'cb_weight': 0.9409752389131057, 'lgbm_weight': 0.9092090058757825, 'hgb_weight': 0.2753557191700527, 'gb_weight': 0.09737881177725567, 'rf_weight': 0.02520812089100463}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,117] Trial 95 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.5713045465136449, 'cb_weight': 0.9752832522320862, 'lgbm_weight': 0.8734866810480773, 'hgb_weight': 0.3441980502642079, 'gb_weight': 0.03945135868555827, 'rf_weight': 0.051458157718150536}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,164] Trial 96 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.44096454995740547, 'cb_weight': 0.9612218345133137, 'lgbm_weight': 0.9088335427059288, 'hgb_weight': 0.4264265513819838, 'gb_weight': 0.12636703281521994, 'rf_weight': 0.09443386771385749}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,211] Trial 97 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.3402160879707048, 'cb_weight': 0.8684646842915036, 'lgbm_weight': 0.9757818390925652, 'hgb_weight': 0.3782160189627452, 'gb_weight': 0.17025516349449082, 'rf_weight': 0.13996223849743522}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,259] Trial 98 finished with value: 0.834770903578243 and parameters: {'xgb_weight': 0.4708560202604168, 'cb_weight': 0.9294439866524126, 'lgbm_weight': 0.8031746014831316, 'hgb_weight': 0.39815168763277325, 'gb_weight': 0.31938089490209287, 'rf_weight': 0.1194748804355968}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,306] Trial 99 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.5520631804414973, 'cb_weight': 0.9078437792687953, 'lgbm_weight': 0.7700766925668899, 'hgb_weight': 0.25621706014752244, 'gb_weight': 0.08050724562497244, 'rf_weight': 0.09654211100396826}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,354] Trial 100 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.1916879951325886, 'cb_weight': 0.9795483624058854, 'lgbm_weight': 0.7364013361490278, 'hgb_weight': 0.3121004024357943, 'gb_weight': 0.26994283569584576, 'rf_weight': 0.02771260043156404}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,401] Trial 101 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.5161125317638305, 'cb_weight': 0.8494104950143049, 'lgbm_weight': 0.9412301889766304, 'hgb_weight': 0.3509213459093533, 'gb_weight': 0.06708658512678345, 'rf_weight': 0.07415936690046658}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,449] Trial 102 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.4627854515280869, 'cb_weight': 0.8843170819792738, 'lgbm_weight': 0.8848070816548131, 'hgb_weight': 0.33483196669830323, 'gb_weight': 0.10243626423084957, 'rf_weight': 0.060171559713617505}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,496] Trial 103 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.22581450926880603, 'cb_weight': 0.9540951521971164, 'lgbm_weight': 0.9305700885011089, 'hgb_weight': 0.44793567977248255, 'gb_weight': 0.04823065419985484, 'rf_weight': 0.155273449277187}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,544] Trial 104 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.2299245517921678, 'cb_weight': 0.9497674363451074, 'lgbm_weight': 0.8446281782889302, 'hgb_weight': 0.45994198226298866, 'gb_weight': 0.02638719067218631, 'rf_weight': 0.19513693036817853}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,592] Trial 105 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.2230495603121031, 'cb_weight': 0.9448441367371763, 'lgbm_weight': 0.8393189262986018, 'hgb_weight': 0.45394794485448775, 'gb_weight': 0.02092212231576778, 'rf_weight': 0.19677842118866823}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,641] Trial 106 finished with value: 0.8345748712721189 and parameters: {'xgb_weight': 0.21806997965123298, 'cb_weight': 0.38315119118365787, 'lgbm_weight': 0.8355362506623628, 'hgb_weight': 0.46322883749955446, 'gb_weight': 0.021879266005968876, 'rf_weight': 0.19804586348811692}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,688] Trial 107 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.23957789622270245, 'cb_weight': 0.9484813672510296, 'lgbm_weight': 0.92441819074309, 'hgb_weight': 0.49012081591632206, 'gb_weight': 0.04269210351986198, 'rf_weight': 0.1626447798040207}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,737] Trial 108 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.1741829519978332, 'cb_weight': 0.9462999419438269, 'lgbm_weight': 0.9218535029542411, 'hgb_weight': 0.4955408284623453, 'gb_weight': 0.0002576235756628978, 'rf_weight': 0.2470041868691589}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,785] Trial 109 finished with value: 0.8337123291251731 and parameters: {'xgb_weight': 0.2369417941661081, 'cb_weight': 0.9253019194558426, 'lgbm_weight': 0.008802709525793873, 'hgb_weight': 0.5280896646159793, 'gb_weight': 0.044589587292128856, 'rf_weight': 0.2918729038332355}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,835] Trial 110 finished with value: 0.8347055594762017 and parameters: {'xgb_weight': 0.2550058140430154, 'cb_weight': 0.26022984238005364, 'lgbm_weight': 0.9700230566632629, 'hgb_weight': 0.4472294325798584, 'gb_weight': 0.019221921391605584, 'rf_weight': 0.15642477318409198}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,883] Trial 111 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.2218210791517072, 'cb_weight': 0.9580943523003155, 'lgbm_weight': 0.898957755482679, 'hgb_weight': 0.47713552121784364, 'gb_weight': 0.05282564570094819, 'rf_weight': 0.21571473041355999}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,931] Trial 112 finished with value: 0.8348493165006926 and parameters: {'xgb_weight': 0.1512456798941206, 'cb_weight': 0.9078279025168763, 'lgbm_weight': 0.9220328011077842, 'hgb_weight': 0.4121260827433035, 'gb_weight': 0.0846390195618282, 'rf_weight': 0.16753001597015402}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:50,979] Trial 113 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.2923843579693598, 'cb_weight': 0.9386440170232405, 'lgbm_weight': 0.8445896331238875, 'hgb_weight': 0.4291255956962905, 'gb_weight': 0.03967531050549071, 'rf_weight': 0.7545841097323789}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,030] Trial 114 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.2728420447186215, 'cb_weight': 0.8731165118096063, 'lgbm_weight': 0.9517775509808433, 'hgb_weight': 0.45602550308066103, 'gb_weight': 0.019135379730530314, 'rf_weight': 0.1412858673828966}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,078] Trial 115 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.23483017133398323, 'cb_weight': 0.9087617675795168, 'lgbm_weight': 0.9855243943283988, 'hgb_weight': 0.5098491302228765, 'gb_weight': 0.08384549067667565, 'rf_weight': 0.11824648702139047}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,127] Trial 116 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.193846767709012, 'cb_weight': 0.9688908173626606, 'lgbm_weight': 0.8853502091014205, 'hgb_weight': 0.4913551689570893, 'gb_weight': 0.049342292839015436, 'rf_weight': 0.18658165748406869}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,176] Trial 117 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.1841666771226131, 'cb_weight': 0.9772065594687351, 'lgbm_weight': 0.8846177138958794, 'hgb_weight': 0.48600197879366946, 'gb_weight': 0.11944671597574474, 'rf_weight': 0.17725827036409603}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,224] Trial 118 finished with value: 0.834235081941504 and parameters: {'xgb_weight': 0.21881029244055075, 'cb_weight': 0.9526652970435147, 'lgbm_weight': 0.3039954368508373, 'hgb_weight': 0.5457745290290019, 'gb_weight': 0.02952239658972968, 'rf_weight': 0.24741807758755144}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,273] Trial 119 finished with value: 0.8343657701455867 and parameters: {'xgb_weight': 0.05474391391829084, 'cb_weight': 0.9798465895394316, 'lgbm_weight': 0.8121538073136466, 'hgb_weight': 0.40976425216130685, 'gb_weight': 0.7729943026188458, 'rf_weight': 0.1957346386908022}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,321] Trial 120 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.12357985630042899, 'cb_weight': 0.9288964467168209, 'lgbm_weight': 0.9289181847134844, 'hgb_weight': 0.3736313738744618, 'gb_weight': 0.00010842517769360516, 'rf_weight': 0.1548333063376155}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,371] Trial 121 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.14739610578360257, 'cb_weight': 0.9251811307615947, 'lgbm_weight': 0.9269559823819626, 'hgb_weight': 0.37120771927831847, 'gb_weight': 0.0034266722900116314, 'rf_weight': 0.15666851894933653}. Best is trial 61 with value: 0.8349800047047753.
# [I 2024-06-10 11:58:51,419] Trial 122 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.11592416848835979, 'cb_weight': 0.9219864450020158, 'lgbm_weight': 0.9006409194183014, 'hgb_weight': 0.3665912450573344, 'gb_weight': 0.0007074035253162025, 'rf_weight': 0.18930824113703237}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,468] Trial 123 finished with value: 0.8345879400925272 and parameters: {'xgb_weight': 0.12218538662323597, 'cb_weight': 0.9225263294615305, 'lgbm_weight': 0.8908711026810514, 'hgb_weight': 0.3645699694461427, 'gb_weight': 0.010785718079953412, 'rf_weight': 0.425254601140318}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,517] Trial 124 finished with value: 0.8347839723986513 and parameters: {'xgb_weight': 0.0626930404696992, 'cb_weight': 0.8478734685596134, 'lgbm_weight': 0.9528182574577341, 'hgb_weight': 0.3784531381190465, 'gb_weight': 0.061320477823420254, 'rf_weight': 0.1188291576266051}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,565] Trial 125 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.1615992867316687, 'cb_weight': 0.9635384260974814, 'lgbm_weight': 0.9981459539479779, 'hgb_weight': 0.33147078996513524, 'gb_weight': 0.0494383458570744, 'rf_weight': 0.27994506445716766}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,614] Trial 126 finished with value: 0.8340521184557882 and parameters: {'xgb_weight': 0.10043957831304608, 'cb_weight': 0.9006508884232614, 'lgbm_weight': 0.9143610563768594, 'hgb_weight': 0.3989129464936817, 'gb_weight': 0.0011984087032098692, 'rf_weight': 0.9308337017408526}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,663] Trial 127 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.13508870076313167, 'cb_weight': 0.9228487444794495, 'lgbm_weight': 0.9362975842813659, 'hgb_weight': 0.31503734998712196, 'gb_weight': 0.0645788841727268, 'rf_weight': 0.15184944745494589}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,711] Trial 128 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.06857126818641572, 'cb_weight': 0.8331199756868806, 'lgbm_weight': 0.9041998617432272, 'hgb_weight': 0.39607363410722907, 'gb_weight': 0.09376289417659231, 'rf_weight': 0.22409013392622984}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,759] Trial 129 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.017918957971802, 'cb_weight': 0.8701094490327498, 'lgbm_weight': 0.8727461649982561, 'hgb_weight': 0.363934836094989, 'gb_weight': 0.09388618792134579, 'rf_weight': 0.21860906963314258}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,808] Trial 130 finished with value: 0.8346532841945686 and parameters: {'xgb_weight': 0.07568701744722267, 'cb_weight': 0.8335655191709257, 'lgbm_weight': 0.8481395772492347, 'hgb_weight': 0.3799315849763727, 'gb_weight': 0.3516768841277377, 'rf_weight': 0.2126432997314221}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,857] Trial 131 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.11545277008541856, 'cb_weight': 0.9311135829893573, 'lgbm_weight': 0.8755082259796493, 'hgb_weight': 0.3605715213972483, 'gb_weight': 0.10632256259251546, 'rf_weight': 0.23495992446705702}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,906] Trial 132 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.05111474563716224, 'cb_weight': 0.8682002159815116, 'lgbm_weight': 0.9021350128595275, 'hgb_weight': 0.4201866496131258, 'gb_weight': 0.08004636140520884, 'rf_weight': 0.17342915217418625}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:51,954] Trial 133 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.030495791787091386, 'cb_weight': 0.8714546459961755, 'lgbm_weight': 0.8606861274522903, 'hgb_weight': 0.41912867886473415, 'gb_weight': 0.13143865031186946, 'rf_weight': 0.17852435222253493}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:52,003] Trial 134 finished with value: 0.8349407982435505 and parameters: {'xgb_weight': 0.004357572629126283, 'cb_weight': 0.8591276532700002, 'lgbm_weight': 0.8570237682875932, 'hgb_weight': 0.42277110687441116, 'gb_weight': 0.12440919911953197, 'rf_weight': 0.18669187139905527}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:52,052] Trial 135 finished with value: 0.8347447659374265 and parameters: {'xgb_weight': 0.03227877107255898, 'cb_weight': 0.6617595362096865, 'lgbm_weight': 0.8738342055507029, 'hgb_weight': 0.44209768458312293, 'gb_weight': 0.04665624550912905, 'rf_weight': 0.21645335151171768}. Best is trial 122 with value: 0.8350845552680415.
# [I 2024-06-10 11:58:52,101] Trial 136 finished with value: 0.8348231788598761 and parameters: {'xgb_weight': 0.0419036518207848, 'cb_weight': 0.7225413664971707, 'lgbm_weight': 0.8292176375871114, 'hgb_weight': 0.39958442988230586, 'gb_weight': 0.08059661189574609, 'rf_weight': 0.17392008010982393}. Best is trial 122 with value: 0.8350845552680415.
# ...
# [I 2024-06-10 12:12:06,884] Trial 4955 finished with value: 0.8345487336313024 and parameters: {'xgb_weight': 0.09287433969552109, 'cb_weight': 0.8592870131819077, 'lgbm_weight': 0.8644548909927674, 'hgb_weight': 0.08125230455944592, 'gb_weight': 0.04456641308710011, 'rf_weight': 0.4850747143650197}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:07,146] Trial 4956 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.055816985550088676, 'cb_weight': 0.9252509039419261, 'lgbm_weight': 0.9163836036567844, 'hgb_weight': 0.1913714192063297, 'gb_weight': 0.08187561174875123, 'rf_weight': 0.17435944090812014}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:07,412] Trial 4957 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.0771613426419125, 'cb_weight': 0.8232139449833655, 'lgbm_weight': 0.7817604425236842, 'hgb_weight': 0.16407261350423974, 'gb_weight': 0.014241178891252482, 'rf_weight': 0.10023709314285281}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:07,680] Trial 4958 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.11121573450047578, 'cb_weight': 0.7854184576787095, 'lgbm_weight': 0.8855167370543944, 'hgb_weight': 0.14165111049198847, 'gb_weight': 0.21027619261576141, 'rf_weight': 0.20287028556231596}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:07,943] Trial 4959 finished with value: 0.8342481507619123 and parameters: {'xgb_weight': 0.02998052429029139, 'cb_weight': 0.8841150923178547, 'lgbm_weight': 0.3189378319252375, 'hgb_weight': 0.11104335873546214, 'gb_weight': 0.0002343101717777532, 'rf_weight': 0.2232896741847159}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:08,207] Trial 4960 finished with value: 0.8348623853211009 and parameters: {'xgb_weight': 0.06388101750530951, 'cb_weight': 0.9434023849818889, 'lgbm_weight': 0.8510313397388938, 'hgb_weight': 0.5490688972894445, 'gb_weight': 0.056895708177631434, 'rf_weight': 0.19194884465674306}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:08,473] Trial 4961 finished with value: 0.8350976240884498 and parameters: {'xgb_weight': 0.09420423205543661, 'cb_weight': 0.9083417961411335, 'lgbm_weight': 0.827190816462754, 'hgb_weight': 0.13153019064325921, 'gb_weight': 0.03949248134922237, 'rf_weight': 0.2615086503925434}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:08,734] Trial 4962 finished with value: 0.8351106929088581 and parameters: {'xgb_weight': 0.12319290742459911, 'cb_weight': 0.8464701550671285, 'lgbm_weight': 0.9018186033677511, 'hgb_weight': 0.16781645377111762, 'gb_weight': 0.08417864200783735, 'rf_weight': 0.2104834754497808}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:08,994] Trial 4963 finished with value: 0.8344180454272198 and parameters: {'xgb_weight': 0.04511375530538383, 'cb_weight': 0.8702146827690779, 'lgbm_weight': 0.8724773978751041, 'hgb_weight': 0.14809424272837063, 'gb_weight': 0.6542295047356437, 'rf_weight': 0.1608382390219532}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:09,253] Trial 4964 finished with value: 0.8338560861496641 and parameters: {'xgb_weight': 0.0010419043055995836, 'cb_weight': 0.8933984009625217, 'lgbm_weight': 0.24469908251660244, 'hgb_weight': 0.20051593950123545, 'gb_weight': 0.0317172424925917, 'rf_weight': 0.2435649308758537}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:09,512] Trial 4965 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.07692941327371722, 'cb_weight': 0.8343019689488637, 'lgbm_weight': 0.9171788962501187, 'hgb_weight': 0.09788922955859834, 'gb_weight': 0.062361128565364694, 'rf_weight': 0.18065122284954815}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:09,770] Trial 4966 finished with value: 0.8351368305496746 and parameters: {'xgb_weight': 0.1027358849330144, 'cb_weight': 0.8602552659591696, 'lgbm_weight': 0.9367472154221355, 'hgb_weight': 0.12896104574905323, 'gb_weight': 0.10696253492287941, 'rf_weight': 0.22698089902849775}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:10,027] Trial 4967 finished with value: 0.834483389529261 and parameters: {'xgb_weight': 0.8082476952535584, 'cb_weight': 0.9098385159966953, 'lgbm_weight': 0.8842346455521385, 'hgb_weight': 0.9267331221204067, 'gb_weight': 0.02990624077056475, 'rf_weight': 0.20023807412707495}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:10,283] Trial 4968 finished with value: 0.8350714864476332 and parameters: {'xgb_weight': 0.07743013545463406, 'cb_weight': 0.8833346339955405, 'lgbm_weight': 0.8511277728391761, 'hgb_weight': 0.17117714674676582, 'gb_weight': 0.07004178773317792, 'rf_weight': 0.12366755018829748}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:10,542] Trial 4969 finished with value: 0.8347316971170182 and parameters: {'xgb_weight': 0.05326358861219305, 'cb_weight': 0.499477743251364, 'lgbm_weight': 0.8987094438053329, 'hgb_weight': 0.15199114792331336, 'gb_weight': 0.05017402181364958, 'rf_weight': 0.21777684642564007}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:10,801] Trial 4970 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.02040584714456889, 'cb_weight': 0.8072441338833609, 'lgbm_weight': 0.8692425441991811, 'hgb_weight': 0.11696293947432106, 'gb_weight': 0.3642182884122055, 'rf_weight': 0.17670589461212438}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:11,059] Trial 4971 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.13020756462641792, 'cb_weight': 0.9346443388553477, 'lgbm_weight': 0.924751388675392, 'hgb_weight': 0.17925213001122095, 'gb_weight': 0.09185705735211716, 'rf_weight': 0.24927986395379675}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:11,324] Trial 4972 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.09573313010700682, 'cb_weight': 0.8742148271402478, 'lgbm_weight': 0.9568103226416627, 'hgb_weight': 0.14210253586130042, 'gb_weight': 0.019648737065666645, 'rf_weight': 0.3002855046105789}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:11,591] Trial 4973 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.06596700008121574, 'cb_weight': 0.8489140613814401, 'lgbm_weight': 0.8337431697101908, 'hgb_weight': 0.22012995441701572, 'gb_weight': 0.05293341362701577, 'rf_weight': 0.14936141862259344}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:11,852] Trial 4974 finished with value: 0.8351629681904911 and parameters: {'xgb_weight': 0.03852896065122544, 'cb_weight': 0.8988691756383138, 'lgbm_weight': 0.8863960971747806, 'hgb_weight': 0.15981342569311738, 'gb_weight': 0.07366681977605954, 'rf_weight': 0.19476486382564057}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:12,114] Trial 4975 finished with value: 0.834914660602734 and parameters: {'xgb_weight': 0.08422816431192973, 'cb_weight': 0.7271739680237661, 'lgbm_weight': 0.8113624817625852, 'hgb_weight': 0.19349052716042564, 'gb_weight': 0.11896824065768308, 'rf_weight': 0.23261906437665875}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:12,375] Trial 4976 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.10351681016754245, 'cb_weight': 0.9192262003752543, 'lgbm_weight': 0.905993344162046, 'hgb_weight': 0.1187635431371206, 'gb_weight': 0.0347113566058097, 'rf_weight': 0.21056010415547}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:12,640] Trial 4977 finished with value: 0.8348362476802844 and parameters: {'xgb_weight': 0.06141404070941261, 'cb_weight': 0.8239550675888985, 'lgbm_weight': 0.8631653603687328, 'hgb_weight': 0.09051802019774964, 'gb_weight': 5.9955518399629204e-05, 'rf_weight': 0.17295034812645535}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:12,916] Trial 4978 finished with value: 0.8351368305496746 and parameters: {'xgb_weight': 0.11502325463564822, 'cb_weight': 0.8609310958546454, 'lgbm_weight': 0.930586006891993, 'hgb_weight': 0.1433304177703057, 'gb_weight': 0.09043114980001778, 'rf_weight': 0.19632877862323475}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:13,247] Trial 4979 finished with value: 0.8348101100394678 and parameters: {'xgb_weight': 0.05049735200466039, 'cb_weight': 0.2341665116357886, 'lgbm_weight': 0.879864981544623, 'hgb_weight': 0.1631541043650908, 'gb_weight': 0.05661241203426525, 'rf_weight': 0.22806995845254727}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:13,550] Trial 4980 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.08017711659423402, 'cb_weight': 0.9507976323728802, 'lgbm_weight': 0.8471771908203218, 'hgb_weight': 0.12401874620809492, 'gb_weight': 0.030651166305626924, 'rf_weight': 0.2772965317319076}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:13,815] Trial 4981 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.02298904342583504, 'cb_weight': 0.8849057583923794, 'lgbm_weight': 0.8995377489833775, 'hgb_weight': 0.18305216410302322, 'gb_weight': 0.07095823809378342, 'rf_weight': 0.2073459285006402}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:14,082] Trial 4982 finished with value: 0.834522595990486 and parameters: {'xgb_weight': 0.09388751342723499, 'cb_weight': 0.16701045084758104, 'lgbm_weight': 0.8693354299998478, 'hgb_weight': 0.06223515925508537, 'gb_weight': 0.04675233546144337, 'rf_weight': 0.25346444553046754}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:14,349] Trial 4983 finished with value: 0.8350192111660002 and parameters: {'xgb_weight': 0.06790433741112425, 'cb_weight': 0.8410785923752343, 'lgbm_weight': 0.7029624407602284, 'hgb_weight': 0.10517966056838264, 'gb_weight': 0.015375397612341218, 'rf_weight': 0.18369096839196977}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:14,613] Trial 4984 finished with value: 0.8349930735251836 and parameters: {'xgb_weight': 0.047309583056387675, 'cb_weight': 0.8968511033219997, 'lgbm_weight': 0.9426095283824335, 'hgb_weight': 0.13606728455411518, 'gb_weight': 0.0979918017923325, 'rf_weight': 0.15640046930355414}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:14,880] Trial 4985 finished with value: 0.8351891058313077 and parameters: {'xgb_weight': 0.12758249347552075, 'cb_weight': 0.9273421800222246, 'lgbm_weight': 0.9178804855519785, 'hgb_weight': 0.15900763322939118, 'gb_weight': 0.07609183692841896, 'rf_weight': 0.22658662621856634}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:15,162] Trial 4986 finished with value: 0.8350061423455919 and parameters: {'xgb_weight': 0.07657458161210731, 'cb_weight': 0.8696367287231034, 'lgbm_weight': 0.9718632530092881, 'hgb_weight': 0.19610875353743565, 'gb_weight': 0.048704972905887316, 'rf_weight': 0.19323528025974857}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:15,431] Trial 4987 finished with value: 0.8350845552680415 and parameters: {'xgb_weight': 0.10534421910213224, 'cb_weight': 0.9078880379814124, 'lgbm_weight': 0.8917816653564966, 'hgb_weight': 0.1503179482795738, 'gb_weight': 0.13431799629915636, 'rf_weight': 0.21443018535295222}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:15,699] Trial 4988 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.037187363700627675, 'cb_weight': 0.8516725448315857, 'lgbm_weight': 0.832048900289371, 'hgb_weight': 0.12853191968195637, 'gb_weight': 0.06450108654351745, 'rf_weight': 0.24495242113887095}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:15,964] Trial 4989 finished with value: 0.8348885229619175 and parameters: {'xgb_weight': 0.06038249244089851, 'cb_weight': 0.8822258901706028, 'lgbm_weight': 0.6789739018489466, 'hgb_weight': 0.17142649444582228, 'gb_weight': 0.033706072388605145, 'rf_weight': 0.16936503312873932}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:16,235] Trial 4990 finished with value: 0.8351498993700829 and parameters: {'xgb_weight': 0.08714958452422729, 'cb_weight': 0.8362034161900369, 'lgbm_weight': 0.8530290611901723, 'hgb_weight': 0.10646139806399701, 'gb_weight': 0.08281290302431364, 'rf_weight': 0.21293747052972203}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:16,508] Trial 4991 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.10776189143565286, 'cb_weight': 0.8070869491572409, 'lgbm_weight': 0.9026024759318342, 'hgb_weight': 0.1458038246315023, 'gb_weight': 0.01626259142995189, 'rf_weight': 0.18280522375187538}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:16,776] Trial 4992 finished with value: 0.8349800047047753 and parameters: {'xgb_weight': 0.07674873472156149, 'cb_weight': 0.8660418116675517, 'lgbm_weight': 0.8658629058713687, 'hgb_weight': 0.17577592916524262, 'gb_weight': 0.057331572331651044, 'rf_weight': 0.13859279096865218}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:17,042] Trial 4993 finished with value: 0.8349669358843671 and parameters: {'xgb_weight': 0.05377240985456817, 'cb_weight': 0.9038742217142874, 'lgbm_weight': 0.8820830136679748, 'hgb_weight': 0.209696405441245, 'gb_weight': 0.11002778973807095, 'rf_weight': 0.23278062233664346}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:17,309] Trial 4994 finished with value: 0.8350322799864084 and parameters: {'xgb_weight': 0.13584543700608476, 'cb_weight': 0.9261787136332165, 'lgbm_weight': 0.9228069430443937, 'hgb_weight': 0.08541193710749667, 'gb_weight': 0.04182799944441164, 'rf_weight': 0.2050068098975515}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:17,579] Trial 4995 finished with value: 0.8349538670639588 and parameters: {'xgb_weight': 0.018906486685581272, 'cb_weight': 0.8886765361449647, 'lgbm_weight': 0.9472960092081976, 'hgb_weight': 0.1254466474142503, 'gb_weight': 0.08586327960462097, 'rf_weight': 0.2719827059753087}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:17,847] Trial 4996 finished with value: 0.8352283122925325 and parameters: {'xgb_weight': 0.09373760779918267, 'cb_weight': 0.8240476090383653, 'lgbm_weight': 0.8432641335635825, 'hgb_weight': 0.15946221887597758, 'gb_weight': 0.06441447794211999, 'rf_weight': 0.1870160874752182}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:18,116] Trial 4997 finished with value: 0.8349277294231423 and parameters: {'xgb_weight': 0.06496658039965941, 'cb_weight': 0.8605260292439042, 'lgbm_weight': 0.8059103867831695, 'hgb_weight': 0.13958915818176762, 'gb_weight': 0.17379012649032755, 'rf_weight': 0.22919385830681793}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:18,384] Trial 4998 finished with value: 0.8350453488068167 and parameters: {'xgb_weight': 0.1096380501607139, 'cb_weight': 0.8792919339731426, 'lgbm_weight': 0.9023191496352689, 'hgb_weight': 0.19013747670439804, 'gb_weight': 0.019721022645064812, 'rf_weight': 0.1641294915575119}. Best is trial 1153 with value: 0.8352936563945739.
# [I 2024-06-10 12:12:18,656] Trial 4999 finished with value: 0.8344049766068115 and parameters: {'xgb_weight': 0.03542960371287749, 'cb_weight': 0.7904548463932657, 'lgbm_weight': 0.49517571436669416, 'hgb_weight': 0.1673248748137407, 'gb_weight': 0.047437873041891905, 'rf_weight': 0.2600622711445234}. Best is trial 1153 with value: 0.8352936563945739.

# %%
voting_model = VotingClassifier(estimators=estimators, voting='soft')
voting_model, voting_oof_pred_probs, voting_oof_preds, voting_accs, voting_aucs = Trainer(voting_model).fit(X, y)
oof_pred_probs['Voting'] = voting_oof_pred_probs
oof_preds['Voting'] = voting_oof_preds
test_pred_probs['Voting'] = voting_model.predict_proba(test)
accuracies['Voting'] = voting_accs
aucs['Voting'] = voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.835860, AUC: 0.930895
# --- Fold 2 - Accuracy: 0.835925, AUC: 0.932476
# --- Fold 3 - Accuracy: 0.835664, AUC: 0.930151
# --- Fold 4 - Accuracy: 0.834346, AUC: 0.930300
# --- Fold 5 - Accuracy: 0.826962, AUC: 0.925123
#
# ------ Accuracy: 0.833751 ± 0.003443
# ------ AUC:      0.929789 ± 0.002474

# %%
weighted_voting_model = VotingClassifier(estimators=estimators, voting='soft', weights=best_weights)
weighted_voting_model, weighted_voting_oof_pred_probs, weighted_voting_oof_preds, weighted_voting_accs, weighted_voting_aucs = Trainer(weighted_voting_model).fit(X, y)
oof_pred_probs['Weighted Voting'] = weighted_voting_oof_pred_probs
oof_preds['Weighted Voting'] = weighted_voting_oof_preds
test_pred_probs['Weighted Voting'] = weighted_voting_model.predict_proba(test)
accuracies['Weighted Voting'] = weighted_voting_accs
aucs['Weighted Voting'] = weighted_voting_aucs
# Out:
# Training VotingClassifier
# --- Fold 1 - Accuracy: 0.838408, AUC: 0.931190
# --- Fold 2 - Accuracy: 0.837559, AUC: 0.932935
# --- Fold 3 - Accuracy: 0.836775, AUC: 0.930522
# --- Fold 4 - Accuracy: 0.835326, AUC: 0.930475
# --- Fold 5 - Accuracy: 0.827289, AUC: 0.925355
#
# ------ Accuracy: 0.835071 ± 0.004021
# ------ AUC:      0.930095 ± 0.002532

# %% [markdown]
# # Visualizing The Results

# %%
accuracies = pd.DataFrame(accuracies)
aucs = pd.DataFrame(aucs)

# %%
mean_accs = accuracies.mean().sort_values(ascending=False)
order = accuracies.mean().sort_values(ascending=False).index.tolist()

min_acc = mean_accs.min()
max_acc = mean_accs.max()
padding = (max_acc - min_acc) * 0.1
lower_limit = min_acc - padding
upper_limit = max_acc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_accs.values, y=mean_accs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_accs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
mean_aucs = aucs.mean().sort_values(ascending=False)
order = aucs.mean().sort_values(ascending=False).index.tolist()

min_auc = mean_aucs.min()
max_auc = mean_aucs.max()
padding = (max_auc - min_auc) * 0.1
lower_limit = min_auc - padding
upper_limit = max_auc + padding

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=accuracies, order=order, ax=axs[0], palette='husl', orient='h')
axs[0].set_title('Fold AUC')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_aucs.values, y=mean_aucs.index, ax=axs[1], palette='husl')
axs[1].set_title('Average AUC')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, score in enumerate(mean_aucs.values):
    barplot.text(score, i, round(score, 4), va='center')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    for i in range(pred_probs.shape[1]):
        fpr, tpr, _ = roc_curve(y, pred_probs[:, i], pos_label=i)
        ax.plot(fpr, tpr, label=f'{label_encoder.inverse_transform([i])[0]}')

    ax.plot([0, 1], [0, 1], color='black', linestyle='--')
    ax.set_title(model)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for ax, (model, pred_probs) in zip(axs.flatten(), oof_pred_probs.items()):
    y_pred = np.argmax(pred_probs, axis=1)
    cm = confusion_matrix(y, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        cmap='Blues',
        ax=ax,
        xticklabels=label_encoder.classes_,
        yticklabels=label_encoder.classes_,
        cbar=False,
        fmt='d'
    )
    ax.set_title(model)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Post-Processing and Creating a Submission File

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'voting_acc-{mean_accs["Voting"]:.6f}_auc-{mean_aucs["Voting"]:.6f}.csv', index=False)

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')
submission['Target'] = np.argmax(test_pred_probs['Weighted Voting'], axis=1)
submission['Target'] = label_encoder.inverse_transform(submission['Target'])
submission.to_csv(f'weighted_voting_acc-{mean_accs["Weighted Voting"]:.6f}_auc-{mean_aucs["Weighted Voting"]:.6f}.csv', index=False)

# %%
os.mkdir('oof_pred_probs')
os.mkdir('test_pred_probs')

for model, pred_probs in oof_pred_probs.items():
    with open(f'oof_pred_probs/{model.lower().replace(" ", "")}_oof_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)
        
for model, pred_probs in test_pred_probs.items():
    with open(f'test_pred_probs/{model.lower().replace(" ", "")}_test_pred_probs.pkl', 'wb') as f:
        pickle.dump(pred_probs, f)

# %%
shutil.rmtree('catboost_info')
