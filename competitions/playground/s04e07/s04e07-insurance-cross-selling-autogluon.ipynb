# %%
# !pip install -q -U autogluon
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.13.0 requires aiohttp<4.0.0,>=3.9.2, but you have aiohttp 3.9.1 which is incompatible.
# aiobotocore 2.13.0 requires botocore<1.34.107,>=1.34.70, but you have botocore 1.29.165 which is incompatible.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.20.0 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# torchaudio 2.1.2+cpu requires torch==2.1.2, but you have torch 2.3.1 which is incompatible.
# torchtext 0.16.2+cpu requires torch==2.1.2, but you have torch 2.3.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
from autogluon.tabular import TabularPredictor, TabularDataset
import pandas as pd
import numpy as np
import pickle
import shutil

# %% [markdown]
# # Configs

# %%
TARGET = 'Response'
TIME_LIMIT = 3600 * 10

TRAIN_PATH = '/kaggle/input/playground-series-s4e7/train.csv'
TEST_PATH = '/kaggle/input/playground-series-s4e7/test.csv'

# %% [markdown]
# # Loading and Processing Data

# %%
class DataLoader:
    def __init__(self, path):
        self.path = path

    @staticmethod
    def encode_categorical_features(dataframe):  
        print("--- Encoding categorical features")
        dataframe = dataframe.copy()
        
        gender_mapping = {"Male": 0, "Female": 1}
        vehicle_age_mapping = {"< 1 Year": 0, "1-2 Year": 1, "> 2 Years": 2}
        vehicle_damage_mapping = {'No': 0, 'Yes': 1}
        
        dataframe["Gender"] = dataframe["Gender"].map(gender_mapping)
        dataframe["Vehicle_Age"] = dataframe["Vehicle_Age"].map(vehicle_age_mapping)
        dataframe['Vehicle_Damage'] = dataframe['Vehicle_Damage'].map(vehicle_damage_mapping)
        
        return dataframe
    
    @staticmethod
    def convert_data_types(dataframe):  
        print("--- Converting data types")
        dataframe = dataframe.copy()
        
        dataframe["Region_Code"] = dataframe["Region_Code"].astype(int) 
        dataframe["Annual_Premium"] = dataframe["Annual_Premium"].astype(int) 
        dataframe["Policy_Sales_Channel"] = dataframe["Policy_Sales_Channel"].astype(int) 
        
        return dataframe
    
    @staticmethod
    def add_features(dataframe):  
        print("--- Adding new features")
        dataframe = dataframe.copy()
        
        # Reference: https://www.kaggle.com/code/rohanrao/automl-grand-prix-1st-place-solution
        dataframe['Previously_Insured_Annual_Premium'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Annual_Premium'].astype(str))[0]
        dataframe['Previously_Insured_Vehicle_Age'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vehicle_Age'].astype(str))[0]
        dataframe['Previously_Insured_Vehicle_Damage'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vehicle_Damage'].astype(str))[0]
        dataframe['Previously_Insured_Vintage'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vintage'].astype(str))[0]
        
        return dataframe
    
    @staticmethod
    def reduce_mem_usage(dataframe):
        # Reference: https://www.kaggle.com/competitions/playground-series-s4e7/discussion/516103#2899151
        
        print("--- Reducing memory usage")
        dataframe = dataframe.copy()
        initial_mem_usage = dataframe.memory_usage().sum() / 1024**2
        
        for col in dataframe.columns:
            col_type = dataframe[col].dtype

            if col_type.name in ['category', 'object']:
                raise ValueError(f"Column '{col}' is of type '{col_type.name}'")

            c_min = dataframe[col].min()
            c_max = dataframe[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    dataframe[col] = dataframe[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    dataframe[col] = dataframe[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    dataframe[col] = dataframe[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    dataframe[col] = dataframe[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    dataframe[col] = dataframe[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    dataframe[col] = dataframe[col].astype(np.float32)
                else:
                    dataframe[col] = dataframe[col].astype(np.float64)

        final_mem_usage = dataframe.memory_usage().sum() / 1024**2
        print('------ Memory usage before: {:.2f} MB'.format(initial_mem_usage))
        print('------ Memory usage after: {:.2f} MB'.format(final_mem_usage))
        print('------ Decreased memory usage by {:.1f}%'.format(100 * (initial_mem_usage - final_mem_usage) / initial_mem_usage))
        print(f"\nDataset size: {dataframe.shape}\n\n")

        return dataframe


    def load(self):
        print(f"Loading data from {self.path}")
        dataframe = pd.read_csv(self.path, index_col="id")
        
        dataframe = self.encode_categorical_features(dataframe)
        dataframe = self.convert_data_types(dataframe)
        dataframe = self.add_features(dataframe)
        dataframe = self.reduce_mem_usage(dataframe)
        
        return TabularDataset(dataframe)

# %%
train = DataLoader(TRAIN_PATH).load()
test = DataLoader(TEST_PATH).load()
# Out:
# Loading data from /kaggle/input/playground-series-s4e7/train.csv
# --- Encoding categorical features
# --- Converting data types
# --- Adding new features
# --- Reducing memory usage
# ------ Memory usage before: 1404.39 MB
# ------ Memory usage after: 351.10 MB
# ------ Decreased memory usage by 75.0%
#
# Dataset size: (11504798, 15)
#
#
# Loading data from /kaggle/input/playground-series-s4e7/test.csv
# --- Encoding categorical features
# --- Converting data types
# --- Adding new features
# --- Reducing memory usage
# ------ Memory usage before: 877.75 MB
# ------ Memory usage after: 226.75 MB
# ------ Decreased memory usage by 74.2%
#
# Dataset size: (7669866, 14)

# %% [markdown]
# # Training

# %%
predictor = TabularPredictor(
    label=TARGET,
    eval_metric='roc_auc',
    verbosity=2
).fit(
    train_data=train,
    time_limit=TIME_LIMIT, 
    presets='best_quality'
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240703_184453"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Jun 27 20:43:36 UTC 2024
# CPU Count:          4
# Memory Avail:       29.61 GB / 31.36 GB (94.4%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9000s of the 36000s of remaining time (25%).
# 2024-07-03 18:44:54,222	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-07-03 18:44:57,588	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/ag-20240703_184453/ds_sub_fit/sub_fit_ho"
# (_dystack pid=207) Running DyStack sub-fit ...
# (_dystack pid=207) Beginning AutoGluon training ... Time limit = 8994s
# (_dystack pid=207) AutoGluon will save models to "AutogluonModels/ag-20240703_184453/ds_sub_fit/sub_fit_ho"
# (_dystack pid=207) Train Data Rows:    10226487
# (_dystack pid=207) Train Data Columns: 14
# (_dystack pid=207) Label Column:       Response
# (_dystack pid=207) Problem Type:       binary
# (_dystack pid=207) Preprocessing data ...
# (_dystack pid=207) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=207) Using Feature Generators to preprocess the data ...
# (_dystack pid=207) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=207) 	Available Memory:                    29119.44 MB
# (_dystack pid=207) 	Train Data (Original)  Memory Usage: 224.31 MB (0.8% of available memory)
# (_dystack pid=207) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=207) 	Stage 1 Generators:
# (_dystack pid=207) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=207) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=207) 	Stage 2 Generators:
# (_dystack pid=207) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=207) 	Stage 3 Generators:
# (_dystack pid=207) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=207) 	Stage 4 Generators:
# (_dystack pid=207) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=207) 	Stage 5 Generators:
# (_dystack pid=207) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=207) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=207) 		('int', []) : 14 | ['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured', ...]
# (_dystack pid=207) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=207) 		('int', [])       : 10 | ['Age', 'Region_Code', 'Vehicle_Age', 'Annual_Premium', 'Policy_Sales_Channel', ...]
# (_dystack pid=207) 		('int', ['bool']) :  4 | ['Gender', 'Driving_License', 'Previously_Insured', 'Vehicle_Damage']
# (_dystack pid=207) 	17.6s = Fit runtime
# (_dystack pid=207) 	14 features in original data used to generate 14 features in processed data.
# (_dystack pid=207) 	Train Data (Processed) Memory Usage: 224.31 MB (0.8% of available memory)
# (_dystack pid=207) Data preprocessing and feature engineering runtime = 18.46s ...
# (_dystack pid=207) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=207) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=207) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=207) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=207) User-specified model hyperparameters to be fit:
# (_dystack pid=207) {
# (_dystack pid=207) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=207) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=207) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=207) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=207) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=207) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=207) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=207) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=207) }
# (_dystack pid=207) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=207) Fitting 110 L1 models ...
# (_dystack pid=207) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 5982.23s of the 8975.56s of remaining time.
# (_dystack pid=207) 	0.7562	 = Validation score   (roc_auc)
# (_dystack pid=207) 	34.06s	 = Training   runtime
# (_dystack pid=207) 	173.7s	 = Validation runtime
# (_dystack pid=207) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 5763.14s of the 8756.48s of remaining time.
# (_dystack pid=207) 	0.7502	 = Validation score   (roc_auc)
# (_dystack pid=207) 	35.35s	 = Training   runtime
# (_dystack pid=207) 	169.49s	 = Validation runtime
# (_dystack pid=207) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 5548.84s of the 8542.18s of remaining time.
# (_dystack pid=207) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.31%)
# (_ray_fit pid=628) 	Ran out of time, early stopping on iteration 256. Best iteration is:
# (_ray_fit pid=628) 	[256]	valid_set's binary_logloss: 0.259868
# (_ray_fit pid=629) 	Ran out of time, early stopping on iteration 253. Best iteration is: [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=629) 	[253]	valid_set's binary_logloss: 0.259922 [repeated 3x across cluster]
# (_ray_fit pid=753) 	Ran out of time, early stopping on iteration 257. Best iteration is:
# (_ray_fit pid=753) 	[257]	valid_set's binary_logloss: 0.260217
# (_ray_fit pid=793) 	Ran out of time, early stopping on iteration 256. Best iteration is:
# (_ray_fit pid=793) 	[256]	valid_set's binary_logloss: 0.260108
# (_dystack pid=207) 	0.8666	 = Validation score   (roc_auc)
# (_dystack pid=207) 	4576.41s	 = Training   runtime
# (_dystack pid=207) 	882.34s	 = Validation runtime
# (_dystack pid=207) Fitting model: LightGBM_BAG_L1 ... Training model for up to 849.27s of the 3842.6s of remaining time.
# (_ray_fit pid=786) 	Ran out of time, early stopping on iteration 258. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=786) 	[258]	valid_set's binary_logloss: 0.260033 [repeated 2x across cluster]
# (_dystack pid=207) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.61%)
# (_ray_fit pid=1052) 	Ran out of time, early stopping on iteration 35. Best iteration is:
# (_ray_fit pid=1052) 	[35]	valid_set's binary_logloss: 0.271895
# (_ray_fit pid=1054) 	Ran out of time, early stopping on iteration 35. Best iteration is:
# (_ray_fit pid=1054) 	[35]	valid_set's binary_logloss: 0.27189
# (_ray_fit pid=1176) 	Ran out of time, early stopping on iteration 36. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=1176) 	[36]	valid_set's binary_logloss: 0.271673 [repeated 3x across cluster]
# (_ray_fit pid=1210) 	Ran out of time, early stopping on iteration 35. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=1210) 	[35]	valid_set's binary_logloss: 0.272044 [repeated 2x across cluster]
# (_dystack pid=207) 	0.8662	 = Validation score   (roc_auc)
# (_dystack pid=207) 	715.64s	 = Training   runtime
# (_dystack pid=207) 	82.37s	 = Validation runtime
# (_dystack pid=207) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 113.76s of the 3107.1s of remaining time.
# (_ray_fit pid=1223) 	Ran out of time, early stopping on iteration 36. Best iteration is:
# (_ray_fit pid=1223) 	[36]	valid_set's binary_logloss: 0.271493
# (_dystack pid=207) 	Warning: Model is expected to require 3312.5s to train, which exceeds the maximum time limit of 113.8s, skipping model...
# (_dystack pid=207) 	Time limit exceeded... Skipping RandomForestGini_BAG_L1.
# (_dystack pid=207) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 67.36s of the 3060.7s of remaining time.
# (_dystack pid=207) 	Warning: Model is expected to require 4370.7s to train, which exceeds the maximum time limit of 67.4s, skipping model...
# (_dystack pid=207) 	Time limit exceeded... Skipping RandomForestEntr_BAG_L1.
# (_dystack pid=207) Fitting model: CatBoost_BAG_L1 ... Training model for up to 6.83s of the 3000.17s of remaining time.
# (_dystack pid=207) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.66%)
# (_dystack pid=207) 	Time limit exceeded... Skipping CatBoost_BAG_L1.
# (_dystack pid=207) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=1490, ip=172.19.2.2)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=207)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=207)     out = self._fit(**kwargs)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 197, in _fit
# (_dystack pid=207)     raise TimeLimitExceeded
# (_dystack pid=207) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=207) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=1489, ip=172.19.2.2)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=207)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=207)     out = self._fit(**kwargs)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 197, in _fit
# (_dystack pid=207)     raise TimeLimitExceeded
# (_dystack pid=207) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=207) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=1488, ip=172.19.2.2)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=207)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=207)     out = self._fit(**kwargs)
# (_dystack pid=207)   File "/opt/conda/lib/python3.10/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 197, in _fit
# (_dystack pid=207)     raise TimeLimitExceeded
# (_dystack pid=207) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=207) Fitting model: WeightedEnsemble_L2 ... Training model for up to 598.22s of the 2985.69s of remaining time.
# (_dystack pid=207) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.524, 'LightGBMXT_BAG_L1': 0.333, 'KNeighborsUnif_BAG_L1': 0.095, 'KNeighborsDist_BAG_L1': 0.048}
# (_dystack pid=207) 	0.8729	 = Validation score   (roc_auc)
# (_dystack pid=207) 	28.01s	 = Training   runtime
# (_dystack pid=207) 	3.49s	 = Validation runtime
# (_dystack pid=207) Fitting 108 L2 models ...
# (_dystack pid=207) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2953.14s of the 2952.28s of remaining time.
# (_dystack pid=207) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.58% memory usage per fold, 46.31%/80.00% total).
# (_dystack pid=207) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=11.58%)
# (_ray_fit pid=1792) 	Ran out of time, early stopping on iteration 115. Best iteration is:
# (_ray_fit pid=1792) 	[115]	valid_set's binary_logloss: 0.255256
# (_ray_fit pid=1793) 	Ran out of time, early stopping on iteration 116. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=1793) 	[116]	valid_set's binary_logloss: 0.255354 [repeated 3x across cluster]
# (_ray_fit pid=1948) 	Ran out of time, early stopping on iteration 115. Best iteration is:
# (_ray_fit pid=1948) 	[115]	valid_set's binary_logloss: 0.25516
# (_ray_fit pid=1915) 	Ran out of time, early stopping on iteration 117. Best iteration is:
# (_ray_fit pid=1915) 	[117]	valid_set's binary_logloss: 0.25547
# (_dystack pid=207) 	0.8748	 = Validation score   (roc_auc)
# (_dystack pid=207) 	2433.52s	 = Training   runtime
# (_dystack pid=207) 	310.18s	 = Validation runtime
# (_ray_fit pid=2020) 	Ran out of time, early stopping on iteration 116. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=2020) 	[116]	valid_set's binary_logloss: 0.255544 [repeated 2x across cluster]
# (_dystack pid=207) Fitting model: LightGBM_BAG_L2 ... Training model for up to 460.76s of the 459.89s of remaining time.
# (_dystack pid=207) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.64% memory usage per fold, 46.56%/80.00% total).
# (_dystack pid=207) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=11.64%)
# (_ray_fit pid=2221) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=2221) 	[10]	valid_set's binary_logloss: 0.307541
# (_ray_fit pid=2220) 	Ran out of time, early stopping on iteration 11. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=2220) 	[11]	valid_set's binary_logloss: 0.304047 [repeated 3x across cluster]
# (_ray_fit pid=2345) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=2345) 	[10]	valid_set's binary_logloss: 0.307662
# (_ray_fit pid=2352) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=2352) 	[10]	valid_set's binary_logloss: 0.307596
# (_ray_fit pid=2450) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=2450) 	[10]	valid_set's binary_logloss: 0.307768
# (_ray_fit pid=2413) 	Ran out of time, early stopping on iteration 11. Best iteration is:
# (_ray_fit pid=2413) 	[11]	valid_set's binary_logloss: 0.30404
# (_dystack pid=207) 	0.8731	 = Validation score   (roc_auc)
# (_dystack pid=207) 	411.52s	 = Training   runtime
# (_dystack pid=207) 	26.21s	 = Validation runtime
# (_dystack pid=207) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 29.56s of the 28.69s of remaining time.
# (_dystack pid=207) 	Warning: Model is expected to require 4392.9s to train, which exceeds the maximum time limit of 29.6s, skipping model...
# (_dystack pid=207) 	Time limit exceeded... Skipping RandomForestGini_BAG_L2.
# (_dystack pid=207) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -49.45s of remaining time.
# (_dystack pid=207) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# (_dystack pid=207) 	0.8748	 = Validation score   (roc_auc)
# (_dystack pid=207) 	35.68s	 = Training   runtime
# (_dystack pid=207) 	3.02s	 = Validation runtime
# (_dystack pid=207) AutoGluon training complete, total runtime = 9083.95s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 969.8 rows/s (1278311 batch size)
# (_dystack pid=207) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240703_184453/ds_sub_fit/sub_fit_ho")
# (_dystack pid=207) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                    model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBMXT_BAG_L2       0.875268   0.874847     roc_auc      226.021279    1618.073700  7794.989244                39.971684              310.183892        2433.517265            2       True          6
# 1    WeightedEnsemble_L3       0.875268   0.874847     roc_auc      226.034672    1621.091500  7830.670851                 0.013393                3.017799          35.681606            3       True          8
# 2        LightGBM_BAG_L2       0.873760   0.873085     roc_auc      190.257070    1334.099551  5772.994451                 4.207475               26.209743         411.522472            2       True          7
# 3    WeightedEnsemble_L2       0.873190   0.872861     roc_auc      186.084888    1311.383937  5389.481492                 0.035294                3.494129          28.009512            2       True          5
# 4      LightGBMXT_BAG_L1       0.866813   0.866643     roc_auc      107.488729     882.338499  4576.413062               107.488729              882.338499        4576.413062            1       True          3
# 5        LightGBM_BAG_L1       0.866431   0.866182     roc_auc       11.255727      82.365113   715.640298                11.255727               82.365113         715.640298            1       True          4
# 6  KNeighborsUnif_BAG_L1       0.757440   0.756153     roc_auc       29.690413     173.697978    34.063658                29.690413              173.697978          34.063658            1       True          1
# 7  KNeighborsDist_BAG_L1       0.751185   0.750181     roc_auc       37.614726     169.488219    35.354960                37.614726              169.488219          35.354960            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	9336s	 = DyStack   runtime |	26664s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 26664s
# AutoGluon will save models to "AutogluonModels/ag-20240703_184453"
# Train Data Rows:    11504798
# Train Data Columns: 14
# Label Column:       Response
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    28388.32 MB
# 	Train Data (Original)  Memory Usage: 252.35 MB (0.9% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', []) : 14 | ['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('int', [])       : 10 | ['Age', 'Region_Code', 'Vehicle_Age', 'Annual_Premium', 'Policy_Sales_Channel', ...]
# 		('int', ['bool']) :  4 | ['Gender', 'Driving_License', 'Previously_Insured', 'Vehicle_Damage']
# 	20.8s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 252.35 MB (0.9% of available memory)
# Data preprocessing and feature engineering runtime = 22.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 17756.54s of the 26641.45s of remaining time.
# 	0.7583	 = Validation score   (roc_auc)
# 	53.09s	 = Training   runtime
# 	193.43s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 17496.02s of the 26380.93s of remaining time.
# 	0.7513	 = Validation score   (roc_auc)
# 	39.17s	 = Training   runtime
# 	192.59s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 17253.83s of the 26138.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=8.48%)
# 	0.872	 = Validation score   (roc_auc)
# 	14332.78s	 = Training   runtime
# 	3977.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2412.21s of the 11297.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=8.49%)
# 	0.8732	 = Validation score   (roc_auc)
# 	2000.11s	 = Training   runtime
# 	271.99s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 367.56s of the 9252.46s of remaining time.
# 	Warning: Model is expected to require 4041.0s to train, which exceeds the maximum time limit of 367.6s, skipping model...
# 	Time limit exceeded... Skipping RandomForestGini_BAG_L1.
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 310.65s of the 9195.56s of remaining time.
# 	Warning: Model is expected to require 4918.5s to train, which exceeds the maximum time limit of 310.6s, skipping model...
# 	Time limit exceeded... Skipping RandomForestEntr_BAG_L1.
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 242.4s of the 9127.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=8.56%)
# 	0.7263	 = Validation score   (roc_auc)
# 	139.41s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 90.01s of the 8974.92s of remaining time.
# 	Warning: Model is expected to require 2173.3s to train, which exceeds the maximum time limit of 90.0s, skipping model...
# 	Time limit exceeded... Skipping ExtraTreesGini_BAG_L1.
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 58.22s of the 8943.13s of remaining time.
# 	Warning: Model is expected to require 2691.3s to train, which exceeds the maximum time limit of 58.2s, skipping model...
# 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 19.74s of the 8904.65s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.27% memory usage per fold, 57.10%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=14.27%)
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L1.
# 2024-07-04 02:17:47,550	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-07-04 02:17:47,560	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-07-04 02:17:47,562	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1775.65s of the 8824.58s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.6, 'LightGBMXT_BAG_L1': 0.24, 'KNeighborsUnif_BAG_L1': 0.12, 'KNeighborsDist_BAG_L1': 0.04}
# 	0.8778	 = Validation score   (roc_auc)
# 	34.54s	 = Training   runtime
# 	4.25s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 8784.53s of the 8783.29s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.17% memory usage per fold, 56.69%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=14.17%)
# 	0.8808	 = Validation score   (roc_auc)
# 	7214.8s	 = Training   runtime
# 	1158.44s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1399.65s of the 1398.13s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.16% memory usage per fold, 56.65%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=14.16%)
# 	0.8791	 = Validation score   (roc_auc)
# 	1173.98s	 = Training   runtime
# 	93.9s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 192.36s of the 191.08s of remaining time.
# 	Warning: Model is expected to require 7287.4s to train, which exceeds the maximum time limit of 192.4s, skipping model...
# 	Time limit exceeded... Skipping RandomForestGini_BAG_L2.
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 81.28s of the 79.99s of remaining time.
# 	Warning: Model is expected to require 8039.3s to train, which exceeds the maximum time limit of 81.3s, skipping model...
# 	Time limit exceeded... Skipping RandomForestEntr_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 878.45s of the -60.73s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# 	0.8808	 = Validation score   (roc_auc)
# 	48.8s	 = Training   runtime
# 	4.43s	 = Validation runtime
# AutoGluon training complete, total runtime = 26779.71s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 263.4 rows/s (1438100 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240703_184453")

# %%
predictor.leaderboard().style.background_gradient('RdYlGn', subset=['score_val'])
# Out:
# <style type="text/css">
# #T_bc9c6_row0_col1, #T_bc9c6_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bc9c6_row2_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_bc9c6_row3_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_bc9c6_row4_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_bc9c6_row5_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_bc9c6_row6_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_bc9c6_row7_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_bc9c6_row8_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc9c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc9c6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_bc9c6_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_bc9c6_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_bc9c6_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_bc9c6_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_bc9c6_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_bc9c6_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_bc9c6_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_bc9c6_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_bc9c6_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc9c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc9c6_row0_col0" class="data row0 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_bc9c6_row0_col1" class="data row0 col1" >0.880765</td>
#       <td id="T_bc9c6_row0_col2" class="data row0 col2" >roc_auc</td>
#       <td id="T_bc9c6_row0_col3" class="data row0 col3" >5795.993498</td>
#       <td id="T_bc9c6_row0_col4" class="data row0 col4" >23779.364881</td>
#       <td id="T_bc9c6_row0_col5" class="data row0 col5" >1158.438339</td>
#       <td id="T_bc9c6_row0_col6" class="data row0 col6" >7214.802805</td>
#       <td id="T_bc9c6_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_bc9c6_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_bc9c6_row0_col9" class="data row0 col9" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc9c6_row1_col0" class="data row1 col0" >WeightedEnsemble_L3</td>
#       <td id="T_bc9c6_row1_col1" class="data row1 col1" >0.880765</td>
#       <td id="T_bc9c6_row1_col2" class="data row1 col2" >roc_auc</td>
#       <td id="T_bc9c6_row1_col3" class="data row1 col3" >5800.419006</td>
#       <td id="T_bc9c6_row1_col4" class="data row1 col4" >23828.161579</td>
#       <td id="T_bc9c6_row1_col5" class="data row1 col5" >4.425508</td>
#       <td id="T_bc9c6_row1_col6" class="data row1 col6" >48.796698</td>
#       <td id="T_bc9c6_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_bc9c6_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_bc9c6_row1_col9" class="data row1 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc9c6_row2_col0" class="data row2 col0" >LightGBM_BAG_L2</td>
#       <td id="T_bc9c6_row2_col1" class="data row2 col1" >0.879145</td>
#       <td id="T_bc9c6_row2_col2" class="data row2 col2" >roc_auc</td>
#       <td id="T_bc9c6_row2_col3" class="data row2 col3" >4731.452361</td>
#       <td id="T_bc9c6_row2_col4" class="data row2 col4" >17738.542772</td>
#       <td id="T_bc9c6_row2_col5" class="data row2 col5" >93.897202</td>
#       <td id="T_bc9c6_row2_col6" class="data row2 col6" >1173.980696</td>
#       <td id="T_bc9c6_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_bc9c6_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_bc9c6_row2_col9" class="data row2 col9" >8</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc9c6_row3_col0" class="data row3 col0" >WeightedEnsemble_L2</td>
#       <td id="T_bc9c6_row3_col1" class="data row3 col1" >0.877849</td>
#       <td id="T_bc9c6_row3_col2" class="data row3 col2" >roc_auc</td>
#       <td id="T_bc9c6_row3_col3" class="data row3 col3" >4639.394775</td>
#       <td id="T_bc9c6_row3_col4" class="data row3 col4" >16459.692617</td>
#       <td id="T_bc9c6_row3_col5" class="data row3 col5" >4.248143</td>
#       <td id="T_bc9c6_row3_col6" class="data row3 col6" >34.541680</td>
#       <td id="T_bc9c6_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_bc9c6_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_bc9c6_row3_col9" class="data row3 col9" >6</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc9c6_row4_col0" class="data row4 col0" >LightGBM_BAG_L1</td>
#       <td id="T_bc9c6_row4_col1" class="data row4 col1" >0.873157</td>
#       <td id="T_bc9c6_row4_col2" class="data row4 col2" >roc_auc</td>
#       <td id="T_bc9c6_row4_col3" class="data row4 col3" >271.986627</td>
#       <td id="T_bc9c6_row4_col4" class="data row4 col4" >2000.109174</td>
#       <td id="T_bc9c6_row4_col5" class="data row4 col5" >271.986627</td>
#       <td id="T_bc9c6_row4_col6" class="data row4 col6" >2000.109174</td>
#       <td id="T_bc9c6_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_bc9c6_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_bc9c6_row4_col9" class="data row4 col9" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc9c6_row5_col0" class="data row5 col0" >LightGBMXT_BAG_L1</td>
#       <td id="T_bc9c6_row5_col1" class="data row5 col1" >0.871993</td>
#       <td id="T_bc9c6_row5_col2" class="data row5 col2" >roc_auc</td>
#       <td id="T_bc9c6_row5_col3" class="data row5 col3" >3977.139974</td>
#       <td id="T_bc9c6_row5_col4" class="data row5 col4" >14332.783266</td>
#       <td id="T_bc9c6_row5_col5" class="data row5 col5" >3977.139974</td>
#       <td id="T_bc9c6_row5_col6" class="data row5 col6" >14332.783266</td>
#       <td id="T_bc9c6_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_bc9c6_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_bc9c6_row5_col9" class="data row5 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bc9c6_row6_col0" class="data row6 col0" >KNeighborsUnif_BAG_L1</td>
#       <td id="T_bc9c6_row6_col1" class="data row6 col1" >0.758307</td>
#       <td id="T_bc9c6_row6_col2" class="data row6 col2" >roc_auc</td>
#       <td id="T_bc9c6_row6_col3" class="data row6 col3" >193.432872</td>
#       <td id="T_bc9c6_row6_col4" class="data row6 col4" >53.089103</td>
#       <td id="T_bc9c6_row6_col5" class="data row6 col5" >193.432872</td>
#       <td id="T_bc9c6_row6_col6" class="data row6 col6" >53.089103</td>
#       <td id="T_bc9c6_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_bc9c6_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_bc9c6_row6_col9" class="data row6 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bc9c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bc9c6_row7_col0" class="data row7 col0" >KNeighborsDist_BAG_L1</td>
#       <td id="T_bc9c6_row7_col1" class="data row7 col1" >0.751273</td>
#       <td id="T_bc9c6_row7_col2" class="data row7 col2" >roc_auc</td>
#       <td id="T_bc9c6_row7_col3" class="data row7 col3" >192.587159</td>
#       <td id="T_bc9c6_row7_col4" class="data row7 col4" >39.169394</td>
#       <td id="T_bc9c6_row7_col5" class="data row7 col5" >192.587159</td>
#       <td id="T_bc9c6_row7_col6" class="data row7 col6" >39.169394</td>
#       <td id="T_bc9c6_row7_col7" class="data row7 col7" >1</td>
#       <td id="T_bc9c6_row7_col8" class="data row7 col8" >True</td>
#       <td id="T_bc9c6_row7_col9" class="data row7 col9"

# %%
oof_predictions = predictor.predict_proba_oof()
with open('autogluon_oof_pred_probs.pkl', 'wb') as f:
    pickle.dump(oof_predictions.values, f)

# %% [markdown]
# # Inference

# %%
test_pred_probs = predictor.predict_proba(test, as_multiclass=True)

# %%
with open('autogluon_test_pred_probs.pkl', 'wb') as f:
    pickle.dump(test_pred_probs.values, f)

# %%
sub = pd.read_csv('/kaggle/input/playground-series-s4e7/sample_submission.csv')
sub['id'] = sub['id'].astype(np.int32)
sub[TARGET] = test_pred_probs.values[:, 1].astype(np.float16)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#          id  Response
# 0  11504798  0.037720
# 1  11504799  0.048462
# 2  11504800  0.056580
# 3  11504801  0.000111
# 4  11504802  0.109314

# %%
shutil.rmtree('AutogluonModels')
