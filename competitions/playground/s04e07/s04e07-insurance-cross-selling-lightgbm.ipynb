# %% [markdown]
# # Configs and Imports

# %%
from lightgbm import LGBMClassifier, log_evaluation, early_stopping
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import mutual_info_classif
from sklearn.base import clone
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle

warnings.filterwarnings('ignore')

# %%
TARGET = 'Response'
N_FOLDS = 5
SEED = 90
ES_ROUNDS = 150
ES_LOG_STEPS = 50

TRAIN_PATH = '/kaggle/input/playground-series-s4e7/train.csv'
TEST_PATH = '/kaggle/input/playground-series-s4e7/test.csv'

# %% [markdown]
# # Loading and Processing The Datasets

# %%
class DataLoader:
    def __init__(self, path):
        self.path = path

    @staticmethod
    def encode_categorical_features(dataframe):  
        print('--- Encoding categorical features')
        dataframe = dataframe.copy()
        
        gender_mapping = {'Male': 0, 'Female': 1}
        vehicle_age_mapping = {'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2}
        vehicle_damage_mapping = {'No': 0, 'Yes': 1}
        
        dataframe['Gender'] = dataframe['Gender'].map(gender_mapping)
        dataframe['Vehicle_Age'] = dataframe['Vehicle_Age'].map(vehicle_age_mapping)
        dataframe['Vehicle_Damage'] = dataframe['Vehicle_Damage'].map(vehicle_damage_mapping)
        
        return dataframe
    
    @staticmethod
    def convert_data_types(dataframe):  
        print('--- Converting data types')
        dataframe = dataframe.copy()
        
        dataframe['Region_Code'] = dataframe['Region_Code'].astype(int) 
        dataframe['Annual_Premium'] = dataframe['Annual_Premium'].astype(int) 
        dataframe['Policy_Sales_Channel'] = dataframe['Policy_Sales_Channel'].astype(int) 
        
        return dataframe
    
    @staticmethod
    def add_features(dataframe):  
        print('--- Adding new features')
        dataframe = dataframe.copy()
        
        # Reference: https://www.kaggle.com/code/rohanrao/automl-grand-prix-1st-place-solution
        dataframe['Previously_Insured_Annual_Premium'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Annual_Premium'].astype(str))[0]
        dataframe['Previously_Insured_Vehicle_Age'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vehicle_Age'].astype(str))[0]
        dataframe['Previously_Insured_Vehicle_Damage'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vehicle_Damage'].astype(str))[0]
        dataframe['Previously_Insured_Vintage'] = pd.factorize(dataframe['Previously_Insured'].astype(str) + dataframe['Vintage'].astype(str))[0]
        
        return dataframe
    
    @staticmethod
    def reduce_mem_usage(dataframe):
        # Reference: https://www.kaggle.com/competitions/playground-series-s4e7/discussion/516103#2899151
        
        print('--- Reducing memory usage')
        dataframe = dataframe.copy()
        initial_mem_usage = dataframe.memory_usage().sum() / 1024**2
        
        for col in dataframe.columns:
            col_type = dataframe[col].dtype

            if col_type.name in ['category', 'object']:
                raise ValueError(f"Column '{col}' is of type '{col_type.name}'")

            c_min = dataframe[col].min()
            c_max = dataframe[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    dataframe[col] = dataframe[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    dataframe[col] = dataframe[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    dataframe[col] = dataframe[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    dataframe[col] = dataframe[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    dataframe[col] = dataframe[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    dataframe[col] = dataframe[col].astype(np.float32)
                else:
                    dataframe[col] = dataframe[col].astype(np.float64)

        final_mem_usage = dataframe.memory_usage().sum() / 1024**2
        print('------ Memory usage before: {:.2f} MB'.format(initial_mem_usage))
        print('------ Memory usage after: {:.2f} MB'.format(final_mem_usage))
        print('------ Decreased memory usage by {:.1f}%'.format(100 * (initial_mem_usage - final_mem_usage) / initial_mem_usage))
        print(f'\nDataset size: {dataframe.shape}\n\n')

        return dataframe


    def load(self):
        print(f'Loading data from {self.path}')
        dataframe = pd.read_csv(self.path, index_col='id')
        
        dataframe = self.encode_categorical_features(dataframe)
        dataframe = self.convert_data_types(dataframe)
        dataframe = self.add_features(dataframe)
        dataframe = self.reduce_mem_usage(dataframe)
        
        return dataframe

# %%
train = DataLoader(TRAIN_PATH).load()
test = DataLoader(TEST_PATH).load()

X = train.drop(columns=TARGET)
y = train[TARGET]
# Out:
# Loading data from /kaggle/input/playground-series-s4e7/train.csv
# --- Encoding categorical features
# --- Converting data types
# --- Adding new features
# --- Reducing memory usage
# ------ Memory usage before: 1404.39 MB
# ------ Memory usage after: 351.10 MB
# ------ Decreased memory usage by 75.0%
#
# Dataset size: (11504798, 15)
#
#
# Loading data from /kaggle/input/playground-series-s4e7/test.csv
# --- Encoding categorical features
# --- Converting data types
# --- Adding new features
# --- Reducing memory usage
# ------ Memory usage before: 877.75 MB
# ------ Memory usage after: 226.75 MB
# ------ Decreased memory usage by 74.2%
#
# Dataset size: (7669866, 14)

# %%
sns.set_style('white')
fig, ax = plt.subplots(figsize=(10, 10))

cols = list(X.columns) + [TARGET]
temp_train = train[cols]

corr_train = temp_train.corr()
mask_train = np.triu(np.ones_like(corr_train, dtype=bool), k=1)
sns.heatmap(
    data=corr_train,
    annot=True,
    fmt='.2f',
    mask=mask_train,
    square=True,
    cmap='RdYlGn',
    cbar_kws={'shrink': .7, 'format': '%.2f'},   
    annot_kws={'size': 8},
    center=0,
    ax=ax 
)

ax.set_title('Pearson Correlation Matrix', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()

# %%
train_mi = train.copy()
train_mi = train.sample(1000_000)
X_mi = train_mi.drop(columns=TARGET)
y_mi = train_mi[TARGET]

mutual_info = mutual_info_classif(X_mi, y_mi, random_state=SEED)
mutual_info = pd.Series(mutual_info)
mutual_info.index = X.columns
mutual_info = pd.DataFrame(mutual_info.sort_values(ascending=False), columns=['Mutual Information'])
mutual_info.style.background_gradient('RdYlGn')

plt.figure(figsize=(10, 8))
sns.barplot(x=mutual_info['Mutual Information'], y=mutual_info.index, palette='RdYlGn_r')
plt.title('Feature Importance based on Mutual Information')
plt.xlabel('Mutual Information Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Training

# %%
class Trainer:
    def __init__(self, model, n_folds=N_FOLDS):
        self.model = model
        self.n_folds = n_folds

    def fit_predict(self, X, y, X_test):
        print(f'Training {self.model.__class__.__name__}\n')
        
        scores = []
        feature_importances = np.zeros(X.shape[1])
        eval_history = []
        
        oof_pred_probs = np.zeros((X.shape[0], len(np.unique(y))))
        test_pred_probs = np.zeros((X_test.shape[0], len(np.unique(y))))
        test_preds = []
        
        skf = StratifiedKFold(n_splits=self.n_folds, random_state=SEED, shuffle=True)
        for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]
            
            callbacks = [log_evaluation(period=ES_LOG_STEPS), early_stopping(stopping_rounds=ES_ROUNDS)]
            model = clone(self.model)
            model.fit(
                X_train, 
                y_train, 
                eval_set=[(X_val, y_val)], 
                eval_metric='auc',
                callbacks=callbacks
            )
            
            feature_importances += model.feature_importances_ / self.n_folds
            eval_history.append(model.evals_result_)
            
            y_pred_probs = model.predict_proba(X_val)
            oof_pred_probs[val_idx] = y_pred_probs            
            
            temp_test_pred_probs = model.predict_proba(X_test)
            test_pred_probs += temp_test_pred_probs / self.n_folds
            test_preds.append(temp_test_pred_probs[:, 1])
            
            score = roc_auc_score(y_val, y_pred_probs[:, 1])
            scores.append(score)
            
            print(f'\n--- Fold {fold_idx + 1} - AUC: {score:.5f}\n\n')
            
        self._save_pred_probs(oof_pred_probs, np.mean(scores), 'oof')
        self._save_pred_probs(test_pred_probs, np.mean(scores), 'test')
        self._save_submission(test_preds, np.mean(scores))
        
        print(f'------ Average AUC:      {np.mean(scores):.5f} ± {np.std(scores):.5f}\n\n')

        return oof_pred_probs, scores, feature_importances, eval_history
        
    def _save_pred_probs(self, pred_probs, cv_score, name):
        model_name = self.model.__class__.__name__.lower().replace('classifier', '')
        with open(f'{model_name}_{name}_pred_probs_{cv_score:.5f}.pkl', 'wb') as f:
            pickle.dump(pred_probs, f)
    
    def _save_submission(self, test_preds, score):
        sub = pd.read_csv('/kaggle/input/playground-series-s4e7/sample_submission.csv')
        
        # Reference: https://www.kaggle.com/competitions/playground-series-s4e7/discussion/516269
        sub['id'] = sub['id'].astype(np.int32)
        sub[TARGET] = np.mean(test_preds, axis=0).astype(np.float16)
        
        name = self.model.__class__.__name__.lower().replace('classifier', '')
        sub.to_csv(f'sub_{name}_{score:.5f}.csv', index=False)

# %%
params = {
    "colsample_bytree": 0.562059978947087,
    "learning_rate": 0.07100599377123995,
    "min_child_samples": 115,
    "min_child_weight": 0.6587928032850406,
    "n_estimators": 10000,
    "n_jobs": -1,
    "num_leaves": 308,
    "random_state": SEED,
    "reg_alpha": 0.5867589814051922,
    "reg_lambda": 0.9203465727217996,
    "subsample": 0.9921820088092972,
    "subsample_freq": 96,
    "verbose": -1
}

model = LGBMClassifier(**params)
trainer = Trainer(model)
oof_pred_probs, scores, feature_importances, eval_history = trainer.fit_predict(X, y, test)
# Out:
# Training LGBMClassifier
#
# Training until validation scores don't improve for 150 rounds
# [50]	valid_0's auc: 0.878683	valid_0's binary_logloss: 0.254615
# [100]	valid_0's auc: 0.881443	valid_0's binary_logloss: 0.250751
# [150]	valid_0's auc: 0.882689	valid_0's binary_logloss: 0.249767
# [200]	valid_0's auc: 0.883686	valid_0's binary_logloss: 0.249051
# [250]	valid_0's auc: 0.884326	valid_0's binary_logloss: 0.24859
# [300]	valid_0's auc: 0.884866	valid_0's binary_logloss: 0.248201
# [350]	valid_0's auc: 0.885049	valid_0's binary_logloss: 0.248058
# [400]	valid_0's auc: 0.885332	valid_0's binary_logloss: 0.247852
# [450]	valid_0's auc: 0.885704	valid_0's binary_logloss: 0.247577
# [500]	valid_0's auc: 0.886	valid_0's binary_logloss: 0.247362
# [550]	valid_0's auc: 0.886297	valid_0's binary_logloss: 0.247141
# [600]	valid_0's auc: 0.886494	valid_0's binary_logloss: 0.24699
# [650]	valid_0's auc: 0.886578	valid_0's binary_logloss: 0.246928
# [700]	valid_0's auc: 0.886772	valid_0's binary_logloss: 0.246787
# [750]	valid_0's auc: 0.886906	valid_0's binary_logloss: 0.246686
# [800]	valid_0's auc: 0.887033	valid_0's binary_logloss: 0.246589
# [850]	valid_0's auc: 0.887115	valid_0's binary_logloss: 0.246525
# [900]	valid_0's auc: 0.887234	valid_0's binary_logloss: 0.246436
# [950]	valid_0's auc: 0.887394	valid_0's binary_logloss: 0.246317
# [1000]	valid_0's auc: 0.887446	valid_0's binary_logloss: 0.246277
# [1050]	valid_0's auc: 0.887619	valid_0's binary_logloss: 0.24615
# [1100]	valid_0's auc: 0.887715	valid_0's binary_logloss: 0.246075
# [1150]	valid_0's auc: 0.88775	valid_0's binary_logloss: 0.246046
# [1200]	valid_0's auc: 0.887795	valid_0's binary_logloss: 0.246008
# [1250]	valid_0's auc: 0.887885	valid_0's binary_logloss: 0.24594
# [1300]	valid_0's auc: 0.887918	valid_0's binary_logloss: 0.245917
# [1350]	valid_0's auc: 0.887958	valid_0's binary_logloss: 0.245886
# [1400]	valid_0's auc: 0.888038	valid_0's binary_logloss: 0.245825
# [1450]	valid_0's auc: 0.888087	valid_0's binary_logloss: 0.245785
# [1500]	valid_0's auc: 0.888155	valid_0's binary_logloss: 0.245731
# [1550]	valid_0's auc: 0.888217	valid_0's binary_logloss: 0.24568
# [1600]	valid_0's auc: 0.888273	valid_0's binary_logloss: 0.245636
# [1650]	valid_0's auc: 0.888321	valid_0's binary_logloss: 0.245596
# [1700]	valid_0's auc: 0.88835	valid_0's binary_logloss: 0.245576
# [1750]	valid_0's auc: 0.888418	valid_0's binary_logloss: 0.245525
# [1800]	valid_0's auc: 0.888475	valid_0's binary_logloss: 0.245481
# [1850]	valid_0's auc: 0.888486	valid_0's binary_logloss: 0.245472
# [1900]	valid_0's auc: 0.88849	valid_0's binary_logloss: 0.24547
# [1950]	valid_0's auc: 0.8885	valid_0's binary_logloss: 0.245463
# [2000]	valid_0's auc: 0.888523	valid_0's binary_logloss: 0.245445
# [2050]	valid_0's auc: 0.888536	valid_0's binary_logloss: 0.245435
# [2100]	valid_0's auc: 0.888555	valid_0's binary_logloss: 0.245421
# [2150]	valid_0's auc: 0.888564	valid_0's binary_logloss: 0.245414
# [2200]	valid_0's auc: 0.888576	valid_0's binary_logloss: 0.245408
# [2250]	valid_0's auc: 0.888577	valid_0's binary_logloss: 0.245407
# [2300]	valid_0's auc: 0.888595	valid_0's binary_logloss: 0.245394
# [2350]	valid_0's auc: 0.888598	valid_0's binary_logloss: 0.245394
# [2400]	valid_0's auc: 0.888603	valid_0's binary_logloss: 0.24539
# [2450]	valid_0's auc: 0.888619	valid_0's binary_logloss: 0.245381
# [2500]	valid_0's auc: 0.888627	valid_0's binary_logloss: 0.245377
# [2550]	valid_0's auc: 0.888625	valid_0's binary_logloss: 0.245376
# [2600]	valid_0's auc: 0.888646	valid_0's binary_logloss: 0.245359
# [2650]	valid_0's auc: 0.888693	valid_0's binary_logloss: 0.245326
# [2700]	valid_0's auc: 0.888702	valid_0's binary_logloss: 0.245319
# [2750]	valid_0's auc: 0.888695	valid_0's binary_logloss: 0.245326
# [2800]	valid_0's auc: 0.888684	valid_0's binary_logloss: 0.245336
# Early stopping, best iteration is:
# [2672]	valid_0's auc: 0.88871	valid_0's binary_logloss: 0.245311
#
# --- Fold 1 - AUC: 0.88871
#
#
# Training until validation scores don't improve for 150 rounds
# [50]	valid_0's auc: 0.878967	valid_0's binary_logloss: 0.254563
# [100]	valid_0's auc: 0.881651	valid_0's binary_logloss: 0.250725
# [150]	valid_0's auc: 0.882877	valid_0's binary_logloss: 0.249746
# [200]	valid_0's auc: 0.883388	valid_0's binary_logloss: 0.249353
# [250]	valid_0's auc: 0.884194	valid_0's binary_logloss: 0.248779
# [300]	valid_0's auc: 0.884641	valid_0's binary_logloss: 0.248451
# [350]	valid_0's auc: 0.885051	valid_0's binary_logloss: 0.248148
# [400]	valid_0's auc: 0.885385	valid_0's binary_logloss: 0.247898
# [450]	valid_0's auc: 0.885817	valid_0's binary_logloss: 0.24758
# [500]	valid_0's auc: 0.886029	valid_0's binary_logloss: 0.247426
# [550]	valid_0's auc: 0.886297	valid_0's binary_logloss: 0.247224
# [600]	valid_0's auc: 0.886522	valid_0's binary_logloss: 0.247061
# [650]	valid_0's auc: 0.886589	valid_0's binary_logloss: 0.247007
# [700]	valid_0's auc: 0.886713	valid_0's binary_logloss: 0.246917
# [750]	valid_0's auc: 0.886858	valid_0's binary_logloss: 0.246805
# [800]	valid_0's auc: 0.88704	valid_0's binary_logloss: 0.246664
# [850]	valid_0's auc: 0.887131	valid_0's binary_logloss: 0.246595
# [900]	valid_0's auc: 0.88727	valid_0's binary_logloss: 0.246488
# [950]	valid_0's auc: 0.88735	valid_0's binary_logloss: 0.24642
# [1000]	valid_0's auc: 0.887415	valid_0's binary_logloss: 0.246371
# [1050]	valid_0's auc: 0.887481	valid_0's binary_logloss: 0.246321
# [1100]	valid_0's auc: 0.887519	valid_0's binary_logloss: 0.246292
# [1150]	valid_0's auc: 0.887576	valid_0's binary_logloss: 0.246251
# [1200]	valid_0's auc: 0.887634	valid_0's binary_logloss: 0.246207
# [1250]	valid_0's auc: 0.887723	valid_0's binary_logloss: 0.246137
# [1300]	valid_0's auc: 0.887819	valid_0's binary_logloss: 0.246064
# [1350]	valid_0's auc: 0.887866	valid_0's binary_logloss: 0.246027
# [1400]	valid_0's auc: 0.887944	valid_0's binary_logloss: 0.245967
# [1450]	valid_0's auc: 0.887973	valid_0's binary_logloss: 0.245942
# [1500]	valid_0's auc: 0.888031	valid_0's binary_logloss: 0.245898
# [1550]	valid_0's auc: 0.888118	valid_0's binary_logloss: 0.245829
# [1600]	valid_0's auc: 0.888156	valid_0's binary_logloss: 0.245802
# [1650]	valid_0's auc: 0.888193	valid_0's binary_logloss: 0.245775
# [1700]	valid_0's auc: 0.888258	valid_0's binary_logloss: 0.245726
# [1750]	valid_0's auc: 0.888281	valid_0's binary_logloss: 0.245709
# [1800]	valid_0's auc: 0.888287	valid_0's binary_logloss: 0.245705
# [1850]	valid_0's auc: 0.88836	valid_0's binary_logloss: 0.24565
# [1900]	valid_0's auc: 0.888378	valid_0's binary_logloss: 0.245637
# [1950]	valid_0's auc: 0.888384	valid_0's binary_logloss: 0.245634
# [2000]	valid_0's auc: 0.88841	valid_0's binary_logloss: 0.245614
# [2050]	valid_0's auc: 0.888458	valid_0's binary_logloss: 0.24558
# [2100]	valid_0's auc: 0.888476	valid_0's binary_logloss: 0.245568
# [2150]	valid_0's auc: 0.888512	valid_0's binary_logloss: 0.24554
# [2200]	valid_0's auc: 0.888551	valid_0's binary_logloss: 0.245511
# [2250]	valid_0's auc: 0.88854	valid_0's binary_logloss: 0.245521
# [2300]	valid_0's auc: 0.888544	valid_0's binary_logloss: 0.245519
# Early stopping, best iteration is:
# [2198]	valid_0's auc: 0.888552	valid_0's binary_logloss: 0.24551
#
# --- Fold 2 - AUC: 0.88855
#
#
# Training until validation scores don't improve for 150 rounds
# [50]	valid_0's auc: 0.878864	valid_0's binary_logloss: 0.254566
# [100]	valid_0's auc: 0.881411	valid_0's binary_logloss: 0.250827
# [150]	valid_0's auc: 0.88272	valid_0's binary_logloss: 0.249785
# [200]	valid_0's auc: 0.883388	valid_0's binary_logloss: 0.249298
# [250]	valid_0's auc: 0.884297	valid_0's binary_logloss: 0.248647
# [300]	valid_0's auc: 0.884686	valid_0's binary_logloss: 0.248366
# [350]	valid_0's auc: 0.885091	valid_0's binary_logloss: 0.24807
# [400]	valid_0's auc: 0.885419	valid_0's binary_logloss: 0.247836
# [450]	valid_0's auc: 0.885663	valid_0's binary_logloss: 0.247658
# [500]	valid_0's auc: 0.885879	valid_0's binary_logloss: 0.247495
# [550]	valid_0's auc: 0.886058	valid_0's binary_logloss: 0.247362
# [600]	valid_0's auc: 0.886204	valid_0's binary_logloss: 0.247256
# [650]	valid_0's auc: 0.886345	valid_0's binary_logloss: 0.247149
# [700]	valid_0's auc: 0.886545	valid_0's binary_logloss: 0.247005
# [750]	valid_0's auc: 0.886728	valid_0's binary_logloss: 0.24687
# [800]	valid_0's auc: 0.886837	valid_0's binary_logloss: 0.246788
# [850]	valid_0's auc: 0.886931	valid_0's binary_logloss: 0.246711
# [900]	valid_0's auc: 0.887022	valid_0's binary_logloss: 0.246644
# [950]	valid_0's auc: 0.887128	valid_0's binary_logloss: 0.246564
# [1000]	valid_0's auc: 0.887198	valid_0's binary_logloss: 0.246511
# [1050]	valid_0's auc: 0.887325	valid_0's binary_logloss: 0.246412
# [1100]	valid_0's auc: 0.887367	valid_0's binary_logloss: 0.246376
# [1150]	valid_0's auc: 0.887426	valid_0's binary_logloss: 0.246331
# [1200]	valid_0's auc: 0.887499	valid_0's binary_logloss: 0.246274
# [1250]	valid_0's auc: 0.88757	valid_0's binary_logloss: 0.246222
# [1300]	valid_0's auc: 0.887631	valid_0's binary_logloss: 0.246175
# [1350]	valid_0's auc: 0.887677	valid_0's binary_logloss: 0.24614
# [1400]	valid_0's auc: 0.887757	valid_0's binary_logloss: 0.246081
# [1450]	valid_0's auc: 0.887809	valid_0's binary_logloss: 0.246041
# [1500]	valid_0's auc: 0.887838	valid_0's binary_logloss: 0.246019
# [1550]	valid_0's auc: 0.887911	valid_0's binary_logloss: 0.245964
# [1600]	valid_0's auc: 0.887969	valid_0's binary_logloss: 0.245917
# [1650]	valid_0's auc: 0.887997	valid_0's binary_logloss: 0.245894
# [1700]	valid_0's auc: 0.888028	valid_0's binary_logloss: 0.245872
# [1750]	valid_0's auc: 0.888104	valid_0's binary_logloss: 0.245811
# [1800]	valid_0's auc: 0.888122	valid_0's binary_logloss: 0.245796
# [1850]	valid_0's auc: 0.88817	valid_0's binary_logloss: 0.245761
# [1900]	valid_0's auc: 0.888229	valid_0's binary_logloss: 0.245718
# [1950]	valid_0's auc: 0.888252	valid_0's binary_logloss: 0.245698
# [2000]	valid_0's auc: 0.888269	valid_0's binary_logloss: 0.245686
# [2050]	valid_0's auc: 0.888285	valid_0's binary_logloss: 0.245676
# [2100]	valid_0's auc: 0.888312	valid_0's binary_logloss: 0.245657
# [2150]	valid_0's auc: 0.888293	valid_0's binary_logloss: 0.245668
# [2200]	valid_0's auc: 0.888309	valid_0's binary_logloss: 0.245658
# Early stopping, best iteration is:
# [2093]	valid_0's auc: 0.888315	valid_0's binary_logloss: 0.245654
#
# --- Fold 3 - AUC: 0.88831
#
#
# Training until validation scores don't improve for 150 rounds
# [50]	valid_0's auc: 0.878981	valid_0's binary_logloss: 0.254557
# [100]	valid_0's auc: 0.881599	valid_0's binary_logloss: 0.250719
# [150]	valid_0's auc: 0.882766	valid_0's binary_logloss: 0.249766
# [200]	valid_0's auc: 0.8835	valid_0's binary_logloss: 0.249236
# [250]	valid_0's auc: 0.884323	valid_0's binary_logloss: 0.248646
# [300]	valid_0's auc: 0.884699	valid_0's binary_logloss: 0.248364
# [350]	valid_0's auc: 0.885048	valid_0's binary_logloss: 0.248106
# [400]	valid_0's auc: 0.88539	valid_0's binary_logloss: 0.247855
# [450]	valid_0's auc: 0.88583	valid_0's binary_logloss: 0.247532
# [500]	valid_0's auc: 0.886031	valid_0's binary_logloss: 0.24738
# [550]	valid_0's auc: 0.886407	valid_0's binary_logloss: 0.247101
# [600]	valid_0's auc: 0.886632	valid_0's binary_logloss: 0.246939
# [650]	valid_0's auc: 0.886731	valid_0's binary_logloss: 0.246862
# [700]	valid_0's auc: 0.886887	valid_0's binary_logloss: 0.246747
# [750]	valid_0's auc: 0.887018	valid_0's binary_logloss: 0.246646
# [800]	valid_0's auc: 0.887112	valid_0's binary_logloss: 0.246575
# [850]	valid_0's auc: 0.887213	valid_0's binary_logloss: 0.246498
# [900]	valid_0's auc: 0.887309	valid_0's binary_logloss: 0.246424
# [950]	valid_0's auc: 0.88749	valid_0's binary_logloss: 0.24629
# [1000]	valid_0's auc: 0.887612	valid_0's binary_logloss: 0.246197
# [1050]	valid_0's auc: 0.887759	valid_0's binary_logloss: 0.246083
# [1100]	valid_0's auc: 0.88778	valid_0's binary_logloss: 0.246069
# [1150]	valid_0's auc: 0.887811	valid_0's binary_logloss: 0.246042
# [1200]	valid_0's auc: 0.887844	valid_0's binary_logloss: 0.246011
# [1250]	valid_0's auc: 0.887886	valid_0's binary_logloss: 0.245978
# [1300]	valid_0's auc: 0.887987	valid_0's binary_logloss: 0.2459
# [1350]	valid_0's auc: 0.888057	valid_0's binary_logloss: 0.245846
# [1400]	valid_0's auc: 0.888117	valid_0's binary_logloss: 0.245798
# [1450]	valid_0's auc: 0.888165	valid_0's binary_logloss: 0.245761
# [1500]	valid_0's auc: 0.888202	valid_0's binary_logloss: 0.245734
# [1550]	valid_0's auc: 0.888235	valid_0's binary_logloss: 0.245707
# [1600]	valid_0's auc: 0.888286	valid_0's binary_logloss: 0.245669
# [1650]	valid_0's auc: 0.888354	valid_0's binary_logloss: 0.245616
# [1700]	valid_0's auc: 0.888367	valid_0's binary_logloss: 0.245605
# [1750]	valid_0's auc: 0.888395	valid_0's binary_logloss: 0.245585
# [1800]	valid_0's auc: 0.888413	valid_0's binary_logloss: 0.245571
# [1850]	valid_0's auc: 0.888433	valid_0's binary_logloss: 0.245557
# [1900]	valid_0's auc: 0.888445	valid_0's binary_logloss: 0.245546
# [1950]	valid_0's auc: 0.888448	valid_0's binary_logloss: 0.245545
# [2000]	valid_0's auc: 0.888471	valid_0's binary_logloss: 0.245527
# [2050]	valid_0's auc: 0.888495	valid_0's binary_logloss: 0.245509
# [2100]	valid_0's auc: 0.888494	valid_0's binary_logloss: 0.24551
# [2150]	valid_0's auc: 0.888529	valid_0's binary_logloss: 0.245485
# [2200]	valid_0's auc: 0.888544	valid_0's binary_logloss: 0.245473
# [2250]	valid_0's auc: 0.888524	valid_0's binary_logloss: 0.245489
# [2300]	valid_0's auc: 0.888545	valid_0's binary_logloss: 0.245473
# [2350]	valid_0's auc: 0.888536	valid_0's binary_logloss: 0.245477
# [2400]	valid_0's auc: 0.888553	valid_0's binary_logloss: 0.245463
# [2450]	valid_0's auc: 0.888594	valid_0's binary_logloss: 0.245431
# [2500]	valid_0's auc: 0.888609	valid_0's binary_logloss: 0.245419
# [2550]	valid_0's auc: 0.888618	valid_0's binary_logloss: 0.245418
# [2600]	valid_0's auc: 0.88862	valid_0's binary_logloss: 0.245424
# [2650]	valid_0's auc: 0.88862	valid_0's binary_logloss: 0.245429
# Early stopping, best iteration is:
# [2512]	valid_0's auc: 0.888621	valid_0's binary_logloss: 0.24541
#
# --- Fold 4 - AUC: 0.88862
#
#
# Training until validation scores don't improve for 150 rounds
# [50]	valid_0's auc: 0.878618	valid_0's binary_logloss: 0.254735
# [100]	valid_0's auc: 0.881207	valid_0's binary_logloss: 0.250949
# [150]	valid_0's auc: 0.8825	valid_0's binary_logloss: 0.249924
# [200]	valid_0's auc: 0.883369	valid_0's binary_logloss: 0.249296
# [250]	valid_0's auc: 0.884262	valid_0's binary_logloss: 0.248658
# [300]	valid_0's auc: 0.884617	valid_0's binary_logloss: 0.248392
# [350]	valid_0's auc: 0.885049	valid_0's binary_logloss: 0.248077
# [400]	valid_0's auc: 0.885301	valid_0's binary_logloss: 0.247889
# [450]	valid_0's auc: 0.88561	valid_0's binary_logloss: 0.24766
# [500]	valid_0's auc: 0.885844	valid_0's binary_logloss: 0.247484
# [550]	valid_0's auc: 0.886263	valid_0's binary_logloss: 0.247175
# [600]	valid_0's auc: 0.886445	valid_0's binary_logloss: 0.247032
# [650]	valid_0's auc: 0.88653	valid_0's binary_logloss: 0.246965
# [700]	valid_0's auc: 0.886721	valid_0's binary_logloss: 0.246824
# [750]	valid_0's auc: 0.886961	valid_0's binary_logloss: 0.246645
# [800]	valid_0's auc: 0.887053	valid_0's binary_logloss: 0.246576
# [850]	valid_0's auc: 0.887134	valid_0's binary_logloss: 0.246512
# [900]	valid_0's auc: 0.887223	valid_0's binary_logloss: 0.246443
# [950]	valid_0's auc: 0.88737	valid_0's binary_logloss: 0.246326
# [1000]	valid_0's auc: 0.887489	valid_0's binary_logloss: 0.246239
# [1050]	valid_0's auc: 0.887602	valid_0's binary_logloss: 0.246153
# [1100]	valid_0's auc: 0.887693	valid_0's binary_logloss: 0.246084
# [1150]	valid_0's auc: 0.887733	valid_0's binary_logloss: 0.246052
# [1200]	valid_0's auc: 0.88781	valid_0's binary_logloss: 0.24599
# [1250]	valid_0's auc: 0.887888	valid_0's binary_logloss: 0.245928
# [1300]	valid_0's auc: 0.887948	valid_0's binary_logloss: 0.245882
# [1350]	valid_0's auc: 0.888	valid_0's binary_logloss: 0.245838
# [1400]	valid_0's auc: 0.88806	valid_0's binary_logloss: 0.245791
# [1450]	valid_0's auc: 0.888105	valid_0's binary_logloss: 0.245755
# [1500]	valid_0's auc: 0.888112	valid_0's binary_logloss: 0.245747
# [1550]	valid_0's auc: 0.888145	valid_0's binary_logloss: 0.245721
# [1600]	valid_0's auc: 0.888186	valid_0's binary_logloss: 0.245688
# [1650]	valid_0's auc: 0.888218	valid_0's binary_logloss: 0.245662
# [1700]	valid_0's auc: 0.888255	valid_0's binary_logloss: 0.245631
# [1750]	valid_0's auc: 0.888305	valid_0's binary_logloss: 0.245593
# [1800]	valid_0's auc: 0.888309	valid_0's binary_logloss: 0.24559
# [1850]	valid_0's auc: 0.88834	valid_0's binary_logloss: 0.245566
# [1900]	valid_0's auc: 0.888355	valid_0's binary_logloss: 0.245554
# [1950]	valid_0's auc: 0.888385	valid_0's binary_logloss: 0.245534
# [2000]	valid_0's auc: 0.888397	valid_0's binary_logloss: 0.245524
# [2050]	valid_0's auc: 0.888449	valid_0's binary_logloss: 0.245486
# [2100]	valid_0's auc: 0.888436	valid_0's binary_logloss: 0.245495
# [2150]	valid_0's auc: 0.888456	valid_0's binary_logloss: 0.245481
# [2200]	valid_0's auc: 0.888448	valid_0's binary_logloss: 0.245488
# [2250]	valid_0's auc: 0.88845	valid_0's binary_logloss: 0.245485
# [2300]	valid_0's auc: 0.888468	valid_0's binary_logloss: 0.245471
# [2350]	valid_0's auc: 0.888469	valid_0's binary_logloss: 0.24547
# [2400]	valid_0's auc: 0.888458	valid_0's binary_logloss: 0.24548
# [2450]	valid_0's auc: 0.888466	valid_0's binary_logloss: 0.245475
# [2500]	valid_0's auc: 0.888492	valid_0's binary_logloss: 0.245456
# [2550]	valid_0's auc: 0.888484	valid_0's binary_logloss: 0.245474
# [2600]	valid_0's auc: 0.888465	valid_0's binary_logloss: 0.245502
# Early stopping, best iteration is:
# [2471]	valid_0's auc: 0.888495	valid_0's binary_logloss: 0.245453
#
# --- Fold 5 - AUC: 0.88849
#
#
# ------ Average AUC:      0.88854 ± 0.00013

# %% [markdown]
# # Visualizing The Results

# %%
data = []
for fold_idx, fold_eval_history in enumerate(eval_history):
    for metric, values in fold_eval_history.items():
        for iteration, auc_value in enumerate(values['auc']):
            data.append({'Fold': f'Fold {fold_idx + 1}', 'Metric': metric, 'Iteration': iteration, 'AUC': auc_value})
df = pd.DataFrame(data)

plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='Iteration', y='AUC', hue='Fold', palette='hls')
plt.title('Evaluation History Across Folds')
plt.xlabel('Iterations')
plt.ylabel('AUC')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 7))

fi = pd.Series(feature_importances, index=X.columns).sort_values(ascending=False)
sns.barplot(
    y=fi.index, 
    x=fi.values, 
    orient='h', 
    palette=sns.color_palette('RdYlGn_r', len(X.columns))
)
plt.title('Feature Importance')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))

fpr, tpr, _ = roc_curve(y, oof_pred_probs[:, 1])
axes[0].plot(fpr, tpr, label=f'AUC: {np.mean(scores):.5f}', color='#651FFF')
axes[0].plot([0, 1], [0, 1], color='black', linestyle='--')
axes[0].set_xlabel('False Positive Rate')
axes[0].set_ylabel('True Positive Rate')
axes[0].legend()
axes[0].grid(True)
axes[0].set_aspect('equal', adjustable='box')

y_pred = oof_pred_probs.argmax(axis=1)
cm = confusion_matrix(y, y_pred)
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    ax=axes[1], 
    cbar=False,
    cmap=sns.light_palette('#651FFF', reverse=False, as_cmap=True), 
)
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')
axes[1].set_aspect('equal', adjustable='box')

plt.tight_layout()
plt.show()
